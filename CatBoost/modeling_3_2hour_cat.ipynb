# %% [markdown]
# ### 파일 불러오기, 모듈 설치

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
# %config InlineBackend.figure_format='retina'
pd.set_option('display.max_columns', None)

from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder

# %%
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting koreanize-matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 58.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from koreanize-matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.22.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (4.39.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (8.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)
# Installing collected packages: koreanize-matplotlib
# Successfully installed koreanize-matplotlib-0.1.1

# %%
train_pm_공주 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/공주.csv')
train_pm_노은동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/노은동.csv')
train_pm_논산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/논산.csv')
train_pm_대천2동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/대천2동.csv')
train_pm_독곶리 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/독곶리.csv')
train_pm_동문동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/동문동.csv')
train_pm_모종동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/모종동.csv')
train_pm_문창동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/문창동.csv')
train_pm_성성동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/성성동.csv')
train_pm_신방동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/신방동.csv')
train_pm_신흥동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/신흥동.csv')
train_pm_아름동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/아름동.csv')
train_pm_예산군 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/예산군.csv')
train_pm_읍내동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/읍내동.csv')
train_pm_이원면 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/이원면.csv')
train_pm_정림동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/정림동.csv')
train_pm_홍성읍 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/홍성읍.csv')

# %%
train_aws_계룡 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/계룡.csv')
train_aws_공주 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/공주.csv')
train_aws_논산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/논산.csv')
train_aws_당진 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/당진.csv')
train_aws_대산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/대산.csv')
train_aws_대천항 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/대천항.csv')
train_aws_북격렬비도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/북격렬비도.csv')
train_aws_서천 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/서천.csv')
train_aws_성거 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/성거.csv')
train_aws_세종고운 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/세종고운.csv')
train_aws_세종금남 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/세종금남.csv')
train_aws_세종연서 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/세종연서.csv')
train_aws_세종전의 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/세종전의.csv')
train_aws_세천 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/세천.csv')
train_aws_아산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/아산.csv')
train_aws_안도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/안도.csv')
train_aws_양화 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/양화.csv')
train_aws_예산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/예산.csv')
train_aws_오월드 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/오월드.csv')
train_aws_옹도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/옹도.csv')
train_aws_유구 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/유구.csv')
train_aws_장동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/장동.csv')
train_aws_정산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/정산.csv')
train_aws_정안 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/정안.csv')
train_aws_청양 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/청양.csv')
train_aws_춘장대 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/춘장대.csv')
train_aws_태안 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/태안.csv')
train_aws_호도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/호도.csv')
train_aws_홍북 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/홍북.csv')
train_aws_홍성죽도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/홍성죽도.csv')

# %%
test_pm_공주 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/공주.csv')
test_pm_노은동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/노은동.csv')
test_pm_논산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/논산.csv')
test_pm_대천2동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/대천2동.csv')
test_pm_독곶리 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/독곶리.csv')
test_pm_동문동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/동문동.csv')
test_pm_모종동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/모종동.csv')
test_pm_문창동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/문창동.csv')
test_pm_성성동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/성성동.csv')
test_pm_신방동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/신방동.csv')
test_pm_신흥동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/신흥동.csv')
test_pm_아름동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/아름동.csv')
test_pm_예산군 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/예산군.csv')
test_pm_읍내동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/읍내동.csv')
test_pm_이원면 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/이원면.csv')
test_pm_정림동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/정림동.csv')
test_pm_홍성읍 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/홍성읍.csv')

# %%
test_aws_계룡 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/계룡.csv')
test_aws_공주 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/공주.csv')
test_aws_논산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/논산.csv')
test_aws_당진 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/당진.csv')
test_aws_대산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/대산.csv')
test_aws_대천항 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/대천항.csv')
test_aws_북격렬비도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/북격렬비도.csv')
test_aws_서천 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/서천.csv')
test_aws_성거 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/성거.csv')
test_aws_세종고운 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/세종고운.csv')
test_aws_세종금남 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/세종금남.csv')
test_aws_세종연서 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/세종연서.csv')
test_aws_세종전의 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/세종전의.csv')
test_aws_세천 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/세천.csv')
test_aws_아산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/아산.csv')
test_aws_안도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/안도.csv')
test_aws_양화 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/양화.csv')
test_aws_예산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/예산.csv')
test_aws_오월드 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/오월드.csv')
test_aws_옹도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/옹도.csv')
test_aws_유구 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/유구.csv')
test_aws_장동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/장동.csv')
test_aws_정산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/정산.csv')
test_aws_정안 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/정안.csv')
test_aws_청양 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/청양.csv')
test_aws_춘장대 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/춘장대.csv')
test_aws_태안 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/태안.csv')
test_aws_호도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/호도.csv')
test_aws_홍북 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/홍북.csv')
test_aws_홍성죽도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/홍성죽도.csv')

# %%
awsmap = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/META/awsmap.csv')
pmmap = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/META/pmmap.csv')

# %%
answer = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/answer_sample.csv')

# %%
pm_aws = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling1/pm_aws.csv', index_col='Location')
test_aws = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling1/test_aws.csv', index_col='Unnamed: 0')
train_aws = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling1/train_aws.csv', index_col='Unnamed: 0')
train_pm = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling1/train_pm.csv')

# %%
aws_loc = awsmap['Location'].unique()
pm_loc = pmmap['Location'].unique()

# %% [markdown]
# ### 데이터 생성

# %% [markdown]
# ##### PM위치 - AWS위치 거리 데이터

# %%
print('AWS 측정 위치 : ', awsmap['Location'].unique())
print('PM 측정 위치 : ', pmmap['Location'].unique())
# Out:
# AWS 측정 위치 :  ['오월드' '세천' '장동' '세종고운' '세종금남' '세종연서' '세종전의' '북격렬비도' '호도' '대산' '홍북' '홍성죽도'
#  '공주' '서천' '논산' '당진' '성거' '청양' '태안' '예산' '유구' '정안' '아산' '양화' '계룡' '춘장대'
#  '대천항' '안도' '옹도' '정산']
# PM 측정 위치 :  ['아름동' '신흥동' '노은동' '문창동' '읍내동' '정림동' '공주' '논산' '대천2동' '독곶리' '동문동' '모종동'
#  '신방동' '예산군' '이원면' '홍성읍' '성성동']

# %%
# PM 측정 위치별 PM-AWS 거리 변수 생성
aws_loc = awsmap['Location'].unique()
pm_loc = pmmap['Location'].unique()

pm_aws = {}

for idx_aws, aws in enumerate(aws_loc):
    pm_aws[aws] = []
    for idx_pm, pm in enumerate(pm_loc):
        pm_aws[aws].append(((pmmap.loc[idx_pm, 'Latitude'] - awsmap.loc[idx_aws, 'Latitude'])**2 + (pmmap.loc[idx_pm, 'Longitude'] - awsmap.loc[idx_aws, 'Longitude'])**2)**0.5)

# %%
pm_aws = pd.DataFrame(pm_aws)
pm_aws.index = pmmap['Location']

# %%
pm_aws
# Out:
#                오월드        세천        장동      세종고운      세종금남      세종연서  \
# Location
# 아름동       0.266559  0.301025  0.215384  0.020219  0.058084  0.064092
# 신흥동       0.318804  0.323037  0.231071  0.080419  0.136470  0.028785
# 노은동       0.109138  0.177531  0.127973  0.180890  0.103036  0.202044
# 문창동       0.049288  0.060511  0.096286  0.291232  0.220297  0.294894
# 읍내동       0.083970  0.082615  0.045934  0.238088  0.172019  0.237818
# 정림동       0.031983  0.131993  0.130383  0.259744  0.182555  0.276043
# 공주        0.317467  0.389505  0.320740  0.147933  0.150036  0.200965
# 논산        0.322313  0.430518  0.411393  0.366058  0.316657  0.415351
# 대천2동      0.808534  0.904158  0.850609  0.674859  0.687189  0.723118
# 독곶리       1.221998  1.278197  1.193645  0.963684  1.024343  0.983531
# 동문동       1.060143  1.127944  1.049158  0.823825  0.874879  0.852557
# 모종동       0.621977  0.652249  0.561905  0.337895  0.411968  0.342646
# 신방동       0.563007  0.578662  0.486809  0.278120  0.356192  0.268584
# 예산군       0.669523  0.727719  0.645674  0.417972  0.473516  0.445649
# 이원면       1.256457  1.323814  1.244348  1.017930  1.070437  1.044997
# 홍성읍       0.801666  0.877343  0.804478  0.589240  0.629295  0.626279
# 성성동       0.604974  0.611583  0.519650  0.324240  0.402388  0.306816
#
#               세종전의     북격렬비도        호도        대산        홍북      홍성죽도  \
# Location
# 아름동       0.184451  1.691079  1.002947  0.992823  0.612665  0.804426
# 신흥동       0.134388  1.733355  1.066897  0.996250  0.648385  0.853268
# 노은동       0.343463  1.777696  1.054331  1.130603  0.721653  0.889144
# 문창동       0.442594  1.903440  1.171634  1.258056  0.851360  1.015870
# 읍내동       0.385446  1.875359  1.153612  1.211371  0.813705  0.986421
# 정림동       0.420605  1.835521  1.100447  1.206814  0.790736  0.949144
# 공주        0.257042  1.569884  0.865273  0.923158  0.507395  0.680740
# 논산        0.504511  1.585860  0.827033  1.070903  0.615542  0.720026
# 대천2동      0.697885  1.065601  0.327580  0.687677  0.280079  0.222592
# 독곶리       0.861557  0.907570  0.697735  0.023296  0.440158  0.470323
# 동문동       0.750640  0.908968  0.514862  0.240012  0.243529  0.260472
# 모종동       0.207366  1.463588  0.889837  0.666673  0.400703  0.629631
# 신방동       0.121579  1.568876  0.980396  0.767147  0.499929  0.727088
# 예산군       0.351837  1.290466  0.693519  0.568662  0.209789  0.435925
# 이원면       0.937235  0.761271  0.568696  0.177271  0.437613  0.385376
# 홍성읍       0.553306  1.095938  0.488929  0.491723  0.031645  0.226426
# 성성동       0.160632  1.596806  1.028155  0.772675  0.540271  0.769239
#
#                 공주        서천        논산        당진        성거        청양  \
# Location
# 아름동       0.114154  0.704832  0.331057  0.733738  0.377018  0.475998
# 신흥동       0.190973  0.792202  0.423515  0.737392  0.316262  0.540606
# 노은동       0.215050  0.686267  0.262225  0.873581  0.535192  0.542241
# 문창동       0.343824  0.776680  0.346132  1.000246  0.627753  0.667276
# 읍내동       0.302113  0.777994  0.348785  0.952787  0.569463  0.640672
# 정림동       0.291244  0.705430  0.274707  0.950626  0.611202  0.599621
# 공주        0.039801  0.565790  0.235609  0.669009  0.432824  0.340903
# 논산        0.287867  0.406595  0.024534  0.834803  0.682488  0.381061
# 대천2동      0.561927  0.312339  0.537440  0.536965  0.772302  0.202081
# 독곶리       0.899762  0.976413  1.056199  0.246155  0.772214  0.684149
# 동문동       0.743367  0.759595  0.865835  0.195560  0.707727  0.481638
# 모종동       0.323724  0.784286  0.578718  0.411292  0.170703  0.429355
# 신방동       0.299981  0.831615  0.570887  0.514368  0.102241  0.495168
# 예산군       0.347234  0.631721  0.533099  0.313920  0.366991  0.263129
# 이원면       0.939383  0.911613  1.057453  0.337473  0.875640  0.668980
# 홍성읍       0.494928  0.537412  0.595284  0.294152  0.574204  0.213648
# 성성동       0.357552  0.892499  0.629609  0.526669  0.040504  0.552360
#
#                 태안        예산        유구        정안        아산        양화  \
# Location
# 아름동       0.981773  0.489684  0.314478  0.157844  0.506668  0.542327
# 신흥동       1.009823  0.500891  0.362724  0.203095  0.496409  0.632009
# 노은동       1.094068  0.627602  0.421768  0.289700  0.658300  0.515649
# 문창동       1.223758  0.754444  0.551533  0.415999  0.779149  0.606623
# 읍내동       1.185929  0.707584  0.512538  0.369943  0.727441  0.607170
# 정림동       1.162670  0.704717  0.493386  0.367882  0.737843  0.535122
# 공주        0.879817  0.424289  0.207941  0.107203  0.472757  0.407852
# 논산        0.968441  0.607490  0.374364  0.351948  0.683510  0.236599
# 대천2동      0.500356  0.449175  0.391688  0.541541  0.564533  0.349431
# 독곶리       0.248101  0.488834  0.702415  0.826739  0.494489  0.975554
# 동문동       0.160267  0.361213  0.534985  0.678440  0.415422  0.764372
# 모종동       0.718618  0.204285  0.255199  0.244764  0.162004  0.668867
# 신방동       0.824451  0.308741  0.305501  0.232791  0.262877  0.700607
# 예산군       0.558439  0.073334  0.160802  0.275533  0.169207  0.545614
# 이원면       0.112349  0.548940  0.731295  0.873483  0.585388  0.938311
# 홍성읍       0.393093  0.215035  0.284280  0.441178  0.325267  0.508936
# 성성동       0.849326  0.341792  0.364837  0.293166  0.276431  0.762322
#
#                 계룡       춘장대       대천항        안도        옹도        정산
# Location
# 아름동       0.199145  0.793905  0.768017  1.167242  1.244869  0.316476
# 신흥동       0.284453  0.871295  0.834803  1.182267  1.284416  0.394524
# 노은동       0.095300  0.813503  0.817574  1.292902  1.338671  0.362443
# 문창동       0.197166  0.920518  0.935752  1.422391  1.466233  0.486243
# 읍내동       0.186647  0.911054  0.916870  1.380144  1.435051  0.461420
# 정림동       0.126346  0.848316  0.864873  1.365400  1.400145  0.418310
# 공주        0.180692  0.650680  0.629160  1.079868  1.127900  0.173681
# 논산        0.191336  0.559085  0.598166  1.191999  1.167274  0.228031
# 대천2동      0.652190  0.189229  0.092229  0.737767  0.650851  0.368252
# 독곶리       1.084268  0.824906  0.672310  0.225231  0.511658  0.825038
# 동문동       0.913818  0.610475  0.458165  0.337916  0.465184  0.637579
# 모종동       0.521101  0.778907  0.687536  0.864417  1.014347  0.400735
# 신방동       0.484306  0.848790  0.769511  0.968397  1.119347  0.428761
# 예산군       0.534914  0.596637  0.494864  0.736459  0.840146  0.310435
# 이원면       1.109818  0.738505  0.588624  0.143202  0.350552  0.831123
# 홍성읍       0.651051  0.442084  0.313182  0.606055  0.647714  0.368199
# 성성동       0.536315  0.905510  0.821799  0.980649  1.148757  0.490455

# %%
pm_aws.to_csv('pm_aws.csv')

# %% [markdown]
# ##### train AWS 전처리 및 병합

# %%
pm_loc, aws_loc
# Out:
# (array(['아름동', '신흥동', '노은동', '문창동', '읍내동', '정림동', '공주', '논산', '대천2동',
#         '독곶리', '동문동', '모종동', '신방동', '예산군', '이원면', '홍성읍', '성성동'],
#        dtype=object),
#  array(['오월드', '세천', '장동', '세종고운', '세종금남', '세종연서', '세종전의', '북격렬비도', '호도',
#         '대산', '홍북', '홍성죽도', '공주', '서천', '논산', '당진', '성거', '청양', '태안', '예산',
#         '유구', '정안', '아산', '양화', '계룡', '춘장대', '대천항', '안도', '옹도', '정산'],
#        dtype=object))

# %%
# 년, 월, 일, 시 컬럼 생성 / 연도, 일시 컬럼 삭제
def datetime(data):
    for i in range(len(data)):
        if data.loc[i, '연도'] == 0:
            data.loc[i, '년'] = 2017
        elif data.loc[i, '연도'] == 1:
            data.loc[i, '년'] = 2018
        elif data.loc[i, '연도'] == 2:
            data.loc[i, '년'] = 2019
        else:
            data.loc[i, '년'] = 2020

    for i in range(len(data)):
        data.loc[i, '월'] = int(str(data.loc[i, '일시'])[:2])
    for i in range(len(data)):
        data.loc[i, '일'] = int(str(data.loc[i, '일시'])[3:5])
    for i in range(len(data)):
        data.loc[i, '시'] = int(str(data.loc[i, '일시'])[6:8])

    data.drop(['지점', '연도', '일시'], axis=1, inplace=True)
    return data

# 결측치 처리 : KNNimputer
def imputation(data):
    imputer = KNNImputer(n_neighbors=5)
    return pd.DataFrame(imputer.fit_transform(data))

# %%
# train_aws 날짜 칼럼 생성, 결측치 처리
datetime(train_aws_오월드)
train_aws_오월드 = imputation(train_aws_오월드)
train_aws_오월드['지점'] = '오월드'

datetime(train_aws_세천)
train_aws_세천 = imputation(train_aws_세천)
train_aws_세천['지점'] = '세천'

datetime(train_aws_장동)
train_aws_장동 = imputation(train_aws_장동)
train_aws_장동['지점'] = '장동'

datetime(train_aws_세종고운)
train_aws_세종고운 = imputation(train_aws_세종고운)
train_aws_세종고운['지점'] = '세종고운'

datetime(train_aws_세종금남)
train_aws_세종금남 = imputation(train_aws_세종금남)
train_aws_세종금남['지점'] = '세종금남'

datetime(train_aws_세종연서)
train_aws_세종연서 = imputation(train_aws_세종연서)
train_aws_세종연서['지점'] = '세종연서'

datetime(train_aws_세종전의)
train_aws_세종전의 = imputation(train_aws_세종전의)
train_aws_세종전의['지점'] = '세종전의'

datetime(train_aws_북격렬비도)
train_aws_북격렬비도 = imputation(train_aws_북격렬비도)
train_aws_북격렬비도['지점'] = '북격렬비도'

datetime(train_aws_호도)
train_aws_호도 = imputation(train_aws_호도)
train_aws_호도['지점'] = '호도'

datetime(train_aws_대산)
train_aws_대산 = imputation(train_aws_대산)
train_aws_대산['지점'] = '대산'

datetime(train_aws_홍북)
train_aws_홍북 = imputation(train_aws_홍북)
train_aws_홍북['지점'] = '홍북'

datetime(train_aws_홍성죽도)
train_aws_홍성죽도 = imputation(train_aws_홍성죽도)
train_aws_홍성죽도['지점'] = '홍성죽도'

datetime(train_aws_공주)
train_aws_공주 = imputation(train_aws_공주)
train_aws_공주['지점'] = '공주'

datetime(train_aws_서천)
train_aws_서천 = imputation(train_aws_서천)
train_aws_서천['지점'] = '서천'

datetime(train_aws_논산)
train_aws_논산 = imputation(train_aws_논산)
train_aws_논산['지점'] = '논산'

datetime(train_aws_당진)
train_aws_당진 = imputation(train_aws_당진)
train_aws_당진['지점'] = '당진'

datetime(train_aws_성거)
train_aws_성거 = imputation(train_aws_성거)
train_aws_성거['지점'] = '성거'

datetime(train_aws_청양)
train_aws_청양 = imputation(train_aws_청양)
train_aws_청양['지점'] = '청양'

datetime(train_aws_태안)
train_aws_태안 = imputation(train_aws_태안)
train_aws_태안['지점'] = '태안'

datetime(train_aws_예산)
train_aws_예산 = imputation(train_aws_예산)
train_aws_예산['지점'] = '예산'

datetime(train_aws_유구)
train_aws_유구 = imputation(train_aws_유구)
train_aws_유구['지점'] = '유구'

datetime(train_aws_정안)
train_aws_정안 = imputation(train_aws_정안)
train_aws_정안['지점'] = '정안'

datetime(train_aws_아산)
train_aws_아산 = imputation(train_aws_아산)
train_aws_아산['지점'] = '아산'

datetime(train_aws_양화)
train_aws_양화 = imputation(train_aws_양화)
train_aws_양화['지점'] = '양화'

datetime(train_aws_계룡)
train_aws_계룡 = imputation(train_aws_계룡)
train_aws_계룡['지점'] = '계룡'

datetime(train_aws_춘장대)
train_aws_춘장대 = imputation(train_aws_춘장대)
train_aws_춘장대['지점'] = '춘장대'

datetime(train_aws_대천항)
train_aws_대천항 = imputation(train_aws_대천항)
train_aws_대천항['지점'] = '대천항'

datetime(train_aws_안도)
train_aws_안도 = imputation(train_aws_안도)
train_aws_안도['지점'] = '안도'

datetime(train_aws_옹도)
train_aws_옹도 = imputation(train_aws_옹도)
train_aws_옹도['지점'] = '옹도'

datetime(train_aws_정산)
train_aws_정산 = imputation(train_aws_정산)
train_aws_정산['지점'] = '정산'
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-ea41f2b8a64d> in <cell line: 18>()
#      16 train_aws_세종고운['지점'] = '세종고운'
#      17
# ---> 18 datetime(train_aws_세종금남)
#      19 train_aws_세종금남 = imputation(train_aws_세종금남)
#      20 train_aws_세종금남['지점'] = '세종금남'
#
# <ipython-input-14-0abeb448ba52> in datetime(data)
#      14         data.loc[i, '월'] = int(str(data.loc[i, '일시'])[:2])
#      15     for i in range(len(data)):
# ---> 16         data.loc[i, '일'] = int(str(data.loc[i, '일시'])[3:5])
#      17     for i in range(len(data)):
#      18         data.loc[i, '시'] = int(str(data.loc[i, '일시'])[6:8])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1064             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1065             if self._is_scalar_access(key):
# -> 1066                 return self.obj._get_value(*key, takeable=self._takeable)
#    1067             return self._getitem_tuple(key)
#    1068         else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    3915             return series._values[index]
#    3916
# -> 3917         series = self._get_item_cache(col)
#    3918         engine = self.index._engine
#    3919
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _get_item_cache(self, item)
#    4286
#    4287             # for a chain
# -> 4288             res._is_copy = self._is_copy
#    4289         return res
#    4290
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5913         try:
#    5914             object.__getattribute__(self, name)
# -> 5915             return object.__setattr__(self, name, value)
#    5916         except AttributeError:
#    5917             pass
#
# KeyboardInterrupt:

# %%
# trian aws 합치기
train_aws = pd.concat([train_aws_오월드, train_aws_세천, train_aws_장동, train_aws_세종고운, train_aws_세종금남, train_aws_세종연서, train_aws_세종전의, train_aws_북격렬비도, train_aws_호도, 
                       train_aws_대산, train_aws_홍북, train_aws_홍성죽도, train_aws_공주, train_aws_서천, train_aws_논산, train_aws_당진, train_aws_성거, train_aws_청양, train_aws_태안,
                       train_aws_예산, train_aws_유구, train_aws_정안, train_aws_아산, train_aws_양화, train_aws_계룡, train_aws_춘장대, train_aws_대천항, train_aws_안도, train_aws_옹도,
                       train_aws_정산])

# %%
train_aws.columns = ['기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '지점']

# %%
train_aws.head()
# Out:
#          기온        풍향        풍속  강수량     습도       년    월    일    시   지점
# 0  0.211690  0.953056  0.033248  0.0  0.791  2017.0  1.0  1.0  0.0  오월드
# 1  0.205371  0.045556  0.028133  0.0  0.771  2017.0  1.0  1.0  1.0  오월드
# 2  0.199052  0.890833  0.028133  0.0  0.733  2017.0  1.0  1.0  2.0  오월드
# 3  0.194313  0.114167  0.043478  0.0  0.774  2017.0  1.0  1.0  3.0  오월드
# 4  0.194313  0.130833  0.025575  0.0  0.700  2017.0  1.0  1.0  4.0  오월드

# %% [markdown]
# #### train PM 전처리 및 데이터 생성
# - PM 측정 위치별로 전처리 및 데이터 생성
# - PM 위치별 데이터 모두 병합
# - 병합한 데이터로 모델 학습

# %%
pm_loc
# Out:
# array(['아름동', '신흥동', '노은동', '문창동', '읍내동', '정림동', '공주', '논산', '대천2동',
#        '독곶리', '동문동', '모종동', '신방동', '예산군', '이원면', '홍성읍', '성성동'],
#       dtype=object)

# %%
# PM : 년, 월, 일, 시 컬럼 생성 / 연도, 일시 컬럼 삭제
def datetime_pm(data):
    for i in range(len(data)):
        if data.loc[i, '연도'] == 0:
            data.loc[i, '년'] = 2017
        elif data.loc[i, '연도'] == 1:
            data.loc[i, '년'] = 2018
        elif data.loc[i, '연도'] == 2:
            data.loc[i, '년'] = 2019
        else:
            data.loc[i, '년'] = 2020

    for i in range(len(data)):
        data.loc[i, '월'] = int(str(data.loc[i, '일시'])[:2])
    for i in range(len(data)):
        data.loc[i, '일'] = int(str(data.loc[i, '일시'])[3:5])
    for i in range(len(data)):
        data.loc[i, '시'] = int(str(data.loc[i, '일시'])[6:8])

    data.drop(['측정소', '연도', '일시'], axis=1, inplace=True)
    return data

# %% [markdown]
# ##### 1. 아름동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_아름동 = (1 / pm_aws.loc['아름동']) / (1 / pm_aws.loc['아름동']).sum()
# 2. 가중치 * aws
train_아름동 = train_pm_아름동.copy()

for i in range(len(train_pm_공주)):
    train_아름동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_아름동.values).sum()
    train_아름동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_아름동.values).sum()
    train_아름동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_아름동.values).sum()
    train_아름동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_아름동.values).sum()
    train_아름동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_아름동.values).sum()

# %%
datetime_pm(train_아름동)
train_아름동 = imputation(train_아름동)
train_아름동['측정소'] = '아름동'
train_아름동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_아름동[train_아름동['PM2.5'].isna()]), len(train_아름동[train_아름동['기온'].isna()]))
# Out:
# 0 0

# %%
train_아름동.to_csv('train_아름동.csv', index=False)

# %% [markdown]
# ##### 2. 신흥동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_신흥동 = (1 / pm_aws.loc['신흥동']) / (1 / pm_aws.loc['신흥동']).sum()
# 2. 가중치 * aws
train_신흥동 = train_pm_신흥동.copy()

for i in range(len(train_pm_신흥동)):
    train_신흥동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_신흥동.values).sum()
    train_신흥동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_신흥동.values).sum()
    train_신흥동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_신흥동.values).sum()
    train_신흥동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_신흥동.values).sum()
    train_신흥동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_신흥동.values).sum()

# %%
datetime_pm(train_신흥동)
train_신흥동 = imputation(train_신흥동)
train_신흥동['측정소'] = '신흥동'
train_신흥동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_신흥동[train_신흥동['PM2.5'].isna()]), len(train_신흥동[train_신흥동['기온'].isna()]))
# Out:
# 0 0

# %%
train_신흥동.to_csv('train_신흥동.csv', index=False)

# %% [markdown]
# ##### 3. 노은동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_노은동 = (1 / pm_aws.loc['노은동']) / (1 / pm_aws.loc['노은동']).sum()
# 2. 가중치 * aws
train_노은동 = train_pm_노은동.copy()

for i in range(len(train_pm_노은동)):
    train_노은동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_노은동.values).sum()
    train_노은동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_노은동.values).sum()
    train_노은동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_노은동.values).sum()
    train_노은동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_노은동.values).sum()
    train_노은동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_노은동.values).sum()

# %%
datetime_pm(train_노은동)
train_노은동 = imputation(train_노은동)
train_노은동['측정소'] = '노은동'
train_노은동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_노은동[train_노은동['PM2.5'].isna()]), len(train_노은동[train_노은동['기온'].isna()]))
# Out:
# 0 0

# %%
train_노은동.to_csv('train_노은동.csv', index=False)

# %% [markdown]
# ##### 4. 문창동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_문창동 = (1 / pm_aws.loc['문창동']) / (1 / pm_aws.loc['문창동']).sum()
# 2. 가중치 * aws
train_문창동 = train_pm_문창동.copy()

for i in range(len(train_pm_문창동)):
    train_문창동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_문창동.values).sum()
    train_문창동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_문창동.values).sum()
    train_문창동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_문창동.values).sum()
    train_문창동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_문창동.values).sum()
    train_문창동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_문창동.values).sum()

# %%
datetime_pm(train_문창동)
train_문창동 = imputation(train_문창동)
train_문창동['측정소'] = '문창동'
train_문창동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_문창동[train_문창동['PM2.5'].isna()]), len(train_문창동[train_문창동['기온'].isna()]))
# Out:
# 0 0

# %%
train_문창동.to_csv('train_문창동.csv', index=False)

# %% [markdown]
# ##### 5. 읍내동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_읍내동 = (1 / pm_aws.loc['읍내동']) / (1 / pm_aws.loc['읍내동']).sum()
# 2. 가중치 * aws
train_읍내동 = train_pm_읍내동.copy()

for i in range(len(train_pm_읍내동)):
    train_읍내동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_읍내동.values).sum()
    train_읍내동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_읍내동.values).sum()
    train_읍내동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_읍내동.values).sum()
    train_읍내동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_읍내동.values).sum()
    train_읍내동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_읍내동.values).sum()

# %%
datetime_pm(train_읍내동)
train_읍내동 = imputation(train_읍내동)
train_읍내동['측정소'] = '읍내동'
train_읍내동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_읍내동[train_읍내동['PM2.5'].isna()]), len(train_읍내동[train_읍내동['기온'].isna()]))
# Out:
# 0 0

# %%
train_읍내동.to_csv('train_읍내동.csv', index=False)

# %% [markdown]
# ##### 6. 정림동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_정림동 = (1 / pm_aws.loc['정림동']) / (1 / pm_aws.loc['정림동']).sum()
# 2. 가중치 * aws
train_정림동 = train_pm_정림동.copy()

for i in range(len(train_pm_정림동)):
    train_정림동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_정림동.values).sum()
    train_정림동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_정림동.values).sum()
    train_정림동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_정림동.values).sum()
    train_정림동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_정림동.values).sum()
    train_정림동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_정림동.values).sum()

# %%
datetime_pm(train_정림동)
train_정림동 = imputation(train_정림동)
train_정림동['측정소'] = '정림동'
train_정림동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_정림동[train_정림동['PM2.5'].isna()]), len(train_정림동[train_정림동['기온'].isna()]))
# Out:
# 0 0

# %%
train_정림동.to_csv('train_정림동.csv', index=False)

# %% [markdown]
# ##### 7. 공주

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_공주 = (1 / pm_aws.loc['공주']) / (1 / pm_aws.loc['공주']).sum()
# 2. 가중치 * aws
train_공주 = train_pm_공주.copy()

for i in range(len(train_pm_공주)):
    train_공주.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_공주.values).sum()
    train_공주.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_공주.values).sum()
    train_공주.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_공주.values).sum()
    train_공주.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_공주.values).sum()
    train_공주.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_공주.values).sum()

# %%
datetime_pm(train_공주)
train_공주 = imputation(train_공주)
train_공주['측정소'] = '공주'

# %%
train_공주.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']

# %%
len(train_공주[train_공주['PM2.5'].isna()]), len(train_공주[train_공주['기온'].isna()])
# Out:
# (0, 0)

# %%
#train_공주.to_csv('train_공주.csv', index=False)

# %% [markdown]
# ##### 8. 논산

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_논산 = (1 / pm_aws.loc['논산']) / (1 / pm_aws.loc['논산']).sum()
# 2. 가중치 * aws
train_논산 = train_pm_논산.copy()

for i in range(len(train_pm_논산)):
    train_논산.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_논산.values).sum()
    train_논산.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_논산.values).sum()
    train_논산.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_논산.values).sum()
    train_논산.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_논산.values).sum()
    train_논산.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_논산.values).sum()

# %%
datetime_pm(train_논산)
train_논산 = imputation(train_논산)
train_논산['측정소'] = '논산'
train_논산.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_논산[train_논산['PM2.5'].isna()]), len(train_논산[train_논산['기온'].isna()]))
# Out:
# 0 0

# %%
train_논산.to_csv('train_논산.csv', index=False)

# %% [markdown]
# ##### 9. 대천2동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_대천2동 = (1 / pm_aws.loc['대천2동']) / (1 / pm_aws.loc['대천2동']).sum()
# 2. 가중치 * aws
train_대천2동 = train_pm_대천2동.copy()

for i in range(len(train_pm_대천2동)):
    train_대천2동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_대천2동.values).sum()
    train_대천2동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_대천2동.values).sum()
    train_대천2동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_대천2동.values).sum()
    train_대천2동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_대천2동.values).sum()
    train_대천2동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_대천2동.values).sum()

# %%
datetime_pm(train_대천2동)
train_대천2동 = imputation(train_대천2동)
train_대천2동['측정소'] = '대천2동'
train_대천2동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_대천2동[train_대천2동['PM2.5'].isna()]), len(train_대천2동[train_대천2동['기온'].isna()]))
# Out:
# 0 0

# %%
train_대천2동.to_csv('train_대천2동.csv', index=False)

# %% [markdown]
# ##### 10. 독곶리

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_독곶리 = (1 / pm_aws.loc['독곶리']) / (1 / pm_aws.loc['독곶리']).sum()
# 2. 가중치 * aws
train_독곶리 = train_pm_독곶리.copy()

for i in range(len(train_pm_독곶리)):
    train_독곶리.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_독곶리.values).sum()
    train_독곶리.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_독곶리.values).sum()
    train_독곶리.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_독곶리.values).sum()
    train_독곶리.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_독곶리.values).sum()
    train_독곶리.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_독곶리.values).sum()

# %%
datetime_pm(train_독곶리)
train_독곶리 = imputation(train_독곶리)
train_독곶리['측정소'] = '독곶리'
train_독곶리.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_독곶리[train_독곶리['PM2.5'].isna()]), len(train_독곶리[train_독곶리['기온'].isna()]))
# Out:
# 0 0

# %%
train_독곶리.to_csv('train_독곶리.csv', index=False)

# %% [markdown]
# ##### 11. 동문동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_동문동 = (1 / pm_aws.loc['동문동']) / (1 / pm_aws.loc['동문동']).sum()
# 2. 가중치 * aws
train_동문동 = train_pm_동문동.copy()

for i in range(len(train_pm_동문동)):
    train_동문동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_동문동.values).sum()
    train_동문동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_동문동.values).sum()
    train_동문동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_동문동.values).sum()
    train_동문동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_동문동.values).sum()
    train_동문동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_동문동.values).sum()

# %%
datetime_pm(train_동문동)
train_동문동 = imputation(train_동문동)
train_동문동['측정소'] = '동문동'
train_동문동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_동문동[train_동문동['PM2.5'].isna()]), len(train_동문동[train_동문동['기온'].isna()]))
# Out:
# 0 0

# %%
train_동문동.to_csv('train_동문동.csv', index=False)

# %% [markdown]
# ##### 12. 모종동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_모종동 = (1 / pm_aws.loc['모종동']) / (1 / pm_aws.loc['모종동']).sum()
# 2. 가중치 * aws
train_모종동 = train_pm_모종동.copy()

for i in range(len(train_pm_모종동)):
    train_모종동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_모종동.values).sum()
    train_모종동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_모종동.values).sum()
    train_모종동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_모종동.values).sum()
    train_모종동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_모종동.values).sum()
    train_모종동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_모종동.values).sum()

# %%
datetime_pm(train_모종동)
train_모종동 = imputation(train_모종동)
train_모종동['측정소'] = '모종동'
train_모종동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_모종동[train_모종동['PM2.5'].isna()]), len(train_모종동[train_모종동['기온'].isna()]))
# Out:
# 0 0

# %%
train_모종동.to_csv('train_모종동.csv', index=False)

# %% [markdown]
# ##### 13. 신방동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_신방동 = (1 / pm_aws.loc['신방동']) / (1 / pm_aws.loc['신방동']).sum()
# 2. 가중치 * aws
train_신방동 = train_pm_신방동.copy()

for i in range(len(train_pm_신방동)):
    train_신방동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_신방동.values).sum()
    train_신방동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_신방동.values).sum()
    train_신방동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_신방동.values).sum()
    train_신방동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_신방동.values).sum()
    train_신방동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_신방동.values).sum()

# %%
datetime_pm(train_신방동)
train_신방동 = imputation(train_신방동)
train_신방동['측정소'] = '신방동'
train_신방동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_신방동[train_신방동['PM2.5'].isna()]), len(train_신방동[train_신방동['기온'].isna()]))
# Out:
# 0 0

# %%
train_신방동.to_csv('train_신방동.csv', index=False)

# %% [markdown]
# ##### 14. 예산군

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_예산군 = (1 / pm_aws.loc['예산군']) / (1 / pm_aws.loc['예산군']).sum()
# 2. 가중치 * aws
train_예산군 = train_pm_예산군.copy()

for i in range(len(train_pm_예산군)):
    train_예산군.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_예산군.values).sum()
    train_예산군.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_예산군.values).sum()
    train_예산군.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_예산군.values).sum()
    train_예산군.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_예산군.values).sum()
    train_예산군.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_예산군.values).sum()

# %%
datetime_pm(train_예산군)
train_예산군 = imputation(train_예산군)
train_예산군['측정소'] = '예산군'
train_예산군.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_예산군[train_예산군['PM2.5'].isna()]), len(train_예산군[train_예산군['기온'].isna()]))
# Out:
# 0 0

# %%
train_예산군.to_csv('train_예산군.csv', index=False)

# %% [markdown]
# ##### 15. 이원면

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_이원면 = (1 / pm_aws.loc['이원면']) / (1 / pm_aws.loc['이원면']).sum()
# 2. 가중치 * aws
train_이원면 = train_pm_이원면.copy()

for i in range(len(train_pm_이원면)):
    train_이원면.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_이원면.values).sum()
    train_이원면.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_이원면.values).sum()
    train_이원면.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_이원면.values).sum()
    train_이원면.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_이원면.values).sum()
    train_이원면.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_이원면.values).sum()

# %%
datetime_pm(train_이원면)
train_이원면 = imputation(train_이원면)
train_이원면['측정소'] = '이원면'
train_이원면.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_이원면[train_이원면['PM2.5'].isna()]), len(train_이원면[train_이원면['기온'].isna()]))
# Out:
# 0 0

# %%
train_이원면.to_csv('train_이원면.csv', index=False)

# %% [markdown]
# ##### 16. 홍성읍

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_홍성읍 = (1 / pm_aws.loc['홍성읍']) / (1 / pm_aws.loc['홍성읍']).sum()
# 2. 가중치 * aws
train_홍성읍 = train_pm_홍성읍.copy()

for i in range(len(train_pm_홍성읍)):
    train_홍성읍.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_홍성읍.values).sum()
    train_홍성읍.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_홍성읍.values).sum()
    train_홍성읍.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_홍성읍.values).sum()
    train_홍성읍.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_홍성읍.values).sum()
    train_홍성읍.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_홍성읍.values).sum()

# %%
datetime_pm(train_홍성읍)
train_홍성읍 = imputation(train_홍성읍)
train_홍성읍['측정소'] = '홍성읍'
train_홍성읍.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_홍성읍[train_홍성읍['PM2.5'].isna()]), len(train_홍성읍[train_홍성읍['기온'].isna()]))
# Out:
# 0 0

# %%
train_홍성읍.to_csv('train_홍성읍.csv', index=False)

# %% [markdown]
# ##### 17. 성성동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_성성동 = (1 / pm_aws.loc['성성동']) / (1 / pm_aws.loc['성성동']).sum()
# 2. 가중치 * aws
train_성성동 = train_pm_성성동.copy()

for i in range(len(train_pm_성성동)):
    train_성성동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_성성동.values).sum()
    train_성성동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_성성동.values).sum()
    train_성성동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_성성동.values).sum()
    train_성성동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_성성동.values).sum()
    train_성성동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_성성동.values).sum()

# %%
datetime_pm(train_성성동)
train_성성동 = imputation(train_성성동)
train_성성동['측정소'] = '성성동'
train_성성동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_성성동[train_성성동['PM2.5'].isna()]), len(train_성성동[train_성성동['기온'].isna()]))
# Out:
# 0 0

# %%
train_성성동.to_csv('train_성성동.csv', index=False)

# %% [markdown]
# ##### train PM 병합

# %%
# trian pm 합치기
train_pm = pd.concat([train_아름동, train_신흥동, train_노은동, train_문창동, train_읍내동, train_정림동, train_공주, train_논산, train_대천2동,
                      train_독곶리, train_동문동, train_모종동, train_신방동, train_예산군, train_이원면, train_홍성읍, train_성성동])

# %%
# 측정소 라벨링
le = LabelEncoder()
train_pm['측정소'] = le.fit_transform(train_pm['측정소'])

# %%
train_pm['측정소'].unique()
# Out:
# array([11, 10,  1,  7, 13, 15,  0,  2,  3,  4,  5,  6,  9, 12, 14, 16,  8])

# %%
train_pm.tail()
# Out:
#         PM2.5        기온        풍향        풍속  강수량        습도       년     월  \
# 596083  0.052  0.284019  0.783190  0.075672  0.0  0.592138  2020.0  12.0
# 596084  0.064  0.275426  0.802148  0.070671  0.0  0.614577  2020.0  12.0
# 596085  0.064  0.265070  0.441289  0.063398  0.0  0.618624  2020.0  12.0
# 596086  0.068  0.257490  0.337988  0.056784  0.0  0.618259  2020.0  12.0
# 596087  0.068  0.250238  0.393590  0.051147  0.0  0.614556  2020.0  12.0
#
#            일     시  측정소
# 596083  31.0  19.0    8
# 596084  31.0  20.0    8
# 596085  31.0  21.0    8
# 596086  31.0  22.0    8
# 596087  31.0  23.0    8

# %%
train_pm.to_csv('train_pm.csv', index=False)

# %% [markdown]
# ### 모델링 2 : lgbm

# %%
# !pip install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting catboost
#   Downloading catboost-1.2-cp310-cp310-manylinux2014_x86_64.whl (98.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.39.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.2)
# Installing collected packages: catboost
# Successfully installed catboost-1.2

# %%
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.1.1-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.10.4-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 21.0 MB/s eta 0:00:00
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.10.4 cmaes-0.9.1 colorlog-6.7.0 optuna-3.1.1

# %%
train_pm_shift = train_pm.copy()

# 1시간 전 PM2.5 칼럼 추가
train_pm_shift['PM2.5_1'] = train_pm_shift['PM2.5'].shift(periods=1, fill_value=0)

# 2시간 전 PM2.5 칼럼 추가
train_pm_shift['PM2.5_2'] = train_pm_shift['PM2.5'].shift(periods=2, fill_value=0)

# 24시간 전 PM2.5 칼럼 추가
train_pm_shift['PM2.5_24'] = train_pm_shift['PM2.5'].shift(periods=24, fill_value=0)

# '년' 범주화
for i in range(2017, 2022):
    train_pm_shift[f'{i}'] = np.where(train_pm_shift['년']==i, 1, 0)
train_pm_shift.drop('년', axis=1, inplace=True)

# object 타입으로 변경
train_pm_shift['월'] = train_pm_shift['월'].astype('str')
train_pm_shift['일'] = train_pm_shift['일'].astype('str')
train_pm_shift['시'] = train_pm_shift['시'].astype('str')
train_pm_shift['측정소'] = train_pm_shift['측정소'].astype('str')

# object 변수 cat features 이용
cat_features = ['월', '일', '시', '측정소']

# %%
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import optuna 
from optuna import Trial, visualization
from optuna.samplers import TPESampler


x = train_pm_shift.drop('PM2.5', axis=1)
y = train_pm_shift.loc[:, 'PM2.5']

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=2023, stratify=train_pm_shift['측정소'])

# %%
# random sampler
sampler = TPESampler(seed=10)

def objectiveCat(trial: Trial):
    params = {
        'learning_rate' : trial.suggest_loguniform('learning_rate', 0.001, 0.1),
        "depth": trial.suggest_int("depth", 1, 15),
        "iterations": trial.suggest_int("iteration", 1000, 10000),
        "l2_leaf_reg" : trial.suggest_int("l2_leaf_reg", 2, 30),
    }

    model = CatBoostRegressor(**params)
    model.fit(x_train, y_train, eval_set=[(x_val, y_val)], early_stopping_rounds=25, cat_features=cat_features, verbose=1)

    y_pred = model.predict(x_val)
    mse = mean_squared_error(y_val, y_pred)
    return mse

# MSE가 최소가 되는 방향으로 학습을 진행
studyCat = optuna.create_study(direction='minimize', sampler=sampler)

# n_trials 지정
studyCat.optimize(objectiveCat, n_trials=1)
# Out:
# [I 2023-05-07 08:44:36,721] A new study created in memory with name: no-name-b6c9d686-72a4-4515-b690-a215b329c243
# <ipython-input-16-4ea365da6825>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate' : trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 1707:	learn: 0.0209231	test: 0.0208565	best: 0.0208565 (1707)	total: 1m 40s	remaining: 4m 53s
# 1708:	learn: 0.0209230	test: 0.0208565	best: 0.0208565 (1708)	total: 1m 40s	remaining: 4m 53s
# 1709:	learn: 0.0209230	test: 0.0208564	best: 0.0208564 (1709)	total: 1m 40s	remaining: 4m 53s
# 1710:	learn: 0.0209229	test: 0.0208564	best: 0.0208564 (1710)	total: 1m 40s	remaining: 4m 53s
# 1711:	learn: 0.0209229	test: 0.0208563	best: 0.0208563 (1711)	total: 1m 40s	remaining: 4m 53s
# 1712:	learn: 0.0209228	test: 0.0208562	best: 0.0208562 (1712)	total: 1m 40s	remaining: 4m 53s
# 1713:	learn: 0.0209228	test: 0.0208562	best: 0.0208562 (1713)	total: 1m 40s	remaining: 4m 53s
# 1714:	learn: 0.0209227	test: 0.0208562	best: 0.0208562 (1714)	total: 1m 40s	remaining: 4m 53s
# 1715:	learn: 0.0209227	test: 0.0208562	best: 0.0208562 (1715)	total: 1m 40s	remaining: 4m 53s
# 1716:	learn: 0.0209226	test: 0.0208561	best: 0.0208561 (1716)	total: 1m 40s	remaining: 4m 53s
# 1717:	learn: 0.0209226	test: 0.0208561	best: 0.0208561 (1717)	total: 1m 40s	remaining: 4m 53s
# 1718:	learn: 0.0209225	test: 0.0208560	best: 0.0208560 (1718)	total: 1m 41s	remaining: 4m 52s
# 1719:	learn: 0.0209224	test: 0.0208560	best: 0.0208560 (1719)	total: 1m 41s	remaining: 4m 52s
# 1720:	learn: 0.0209224	test: 0.0208559	best: 0.0208559 (1720)	total: 1m 41s	remaining: 4m 52s
# 1721:	learn: 0.0209223	test: 0.0208558	best: 0.0208558 (1721)	total: 1m 41s	remaining: 4m 52s
# 1722:	learn: 0.0209223	test: 0.0208557	best: 0.0208557 (1722)	total: 1m 41s	remaining: 4m 52s
# 1723:	learn: 0.0209222	test: 0.0208557	best: 0.0208557 (1723)	total: 1m 41s	remaining: 4m 52s
# 1724:	learn: 0.0209221	test: 0.0208556	best: 0.0208556 (1724)	total: 1m 41s	remaining: 4m 52s
# 1725:	learn: 0.0209221	test: 0.0208555	best: 0.0208555 (1725)	total: 1m 41s	remaining: 4m 52s
# 1726:	learn: 0.0209220	test: 0.0208555	best: 0.0208555 (1725)	total: 1m 41s	remaining: 4m 52s
# 1727:	learn: 0.0209220	test: 0.0208555	best: 0.0208555 (1727)	total: 1m 41s	remaining: 4m 52s
# 1728:	learn: 0.0209219	test: 0.0208555	best: 0.0208555 (1727)	total: 1m 41s	remaining: 4m 52s
# 1729:	learn: 0.0209218	test: 0.0208554	best: 0.0208554 (1729)	total: 1m 41s	remaining: 4m 52s
# 1730:	learn: 0.0209218	test: 0.0208553	best: 0.0208553 (1730)	total: 1m 41s	remaining: 4m 52s
# 1731:	learn: 0.0209217	test: 0.0208551	best: 0.0208551 (1731)	total: 1m 41s	remaining: 4m 51s
# 1732:	learn: 0.0209217	test: 0.0208551	best: 0.0208551 (1732)	total: 1m 41s	remaining: 4m 51s
# 1733:	learn: 0.0209216	test: 0.0208550	best: 0.0208550 (1733)	total: 1m 41s	remaining: 4m 51s
# 1734:	learn: 0.0209215	test: 0.0208550	best: 0.0208550 (1734)	total: 1m 41s	remaining: 4m 51s
# 1735:	learn: 0.0209215	test: 0.0208548	best: 0.0208548 (1735)	total: 1m 41s	remaining: 4m 51s
# 1736:	learn: 0.0209214	test: 0.0208548	best: 0.0208548 (1736)	total: 1m 41s	remaining: 4m 51s
# 1737:	learn: 0.0209214	test: 0.0208547	best: 0.0208547 (1737)	total: 1m 42s	remaining: 4m 51s
# 1738:	learn: 0.0209213	test: 0.0208547	best: 0.0208547 (1738)	total: 1m 42s	remaining: 4m 51s
# 1739:	learn: 0.0209212	test: 0.0208546	best: 0.0208546 (1739)	total: 1m 42s	remaining: 4m 51s
# 1740:	learn: 0.0209212	test: 0.0208546	best: 0.0208546 (1740)	total: 1m 42s	remaining: 4m 51s
# 1741:	learn: 0.0209211	test: 0.0208546	best: 0.0208546 (1741)	total: 1m 42s	remaining: 4m 51s
# 1742:	learn: 0.0209211	test: 0.0208546	best: 0.0208546 (1742)	total: 1m 42s	remaining: 4m 51s
# 1743:	learn: 0.0209210	test: 0.0208545	best: 0.0208545 (1743)	total: 1m 42s	remaining: 4m 50s
# 1744:	learn: 0.0209209	test: 0.0208545	best: 0.0208545 (1744)	total: 1m 42s	remaining: 4m 50s
# 1745:	learn: 0.0209209	test: 0.0208544	best: 0.0208544 (1745)	total: 1m 42s	remaining: 4m 50s
# 1746:	learn: 0.0209208	test: 0.0208543	best: 0.0208543 (1746)	total: 1m 42s	remaining: 4m 50s
# 1747:	learn: 0.0209208	test: 0.0208544	best: 0.0208543 (1746)	total: 1m 42s	remaining: 4m 50s
# 1748:	learn: 0.0209207	test: 0.0208542	best: 0.0208542 (1748)	total: 1m 42s	remaining: 4m 50s
# 1749:	learn: 0.0209207	test: 0.0208541	best: 0.0208541 (1749)	total: 1m 42s	remaining: 4m 50s
# 1750:	learn: 0.0209206	test: 0.0208541	best: 0.0208541 (1750)	total: 1m 42s	remaining: 4m 50s
# 1751:	learn: 0.0209205	test: 0.0208541	best: 0.0208541 (1751)	total: 1m 42s	remaining: 4m 50s
# 1752:	learn: 0.0209205	test: 0.0208541	best: 0.0208541 (1751)	total: 1m 42s	remaining: 4m 50s
# 1753:	learn: 0.0209204	test: 0.0208540	best: 0.0208540 (1753)	total: 1m 42s	remaining: 4m 50s
# 1754:	learn: 0.0209204	test: 0.0208539	best: 0.0208539 (1754)	total: 1m 42s	remaining: 4m 50s
# 1755:	learn: 0.0209203	test: 0.0208539	best: 0.0208539 (1754)	total: 1m 42s	remaining: 4m 50s
# 1756:	learn: 0.0209203	test: 0.0208538	best: 0.0208538 (1756)	total: 1m 43s	remaining: 4m 50s
# 1757:	learn: 0.0209202	test: 0.0208538	best: 0.0208538 (1757)	total: 1m 43s	remaining: 4m 50s
# 1758:	learn: 0.0209201	test: 0.0208536	best: 0.0208536 (1758)	total: 1m 43s	remaining: 4m 49s
# 1759:	learn: 0.0209201	test: 0.0208536	best: 0.0208536 (1759)	total: 1m 43s	remaining: 4m 49s
# 1760:	learn: 0.0209200	test: 0.0208535	best: 0.0208535 (1760)	total: 1m 43s	remaining: 4m 49s
# 1761:	learn: 0.0209200	test: 0.0208535	best: 0.0208535 (1761)	total: 1m 43s	remaining: 4m 49s
# 1762:	learn: 0.0209199	test: 0.0208534	best: 0.0208534 (1762)	total: 1m 43s	remaining: 4m 49s
# 1763:	learn: 0.0209199	test: 0.0208533	best: 0.0208533 (1763)	total: 1m 43s	remaining: 4m 49s
# 1764:	learn: 0.0209198	test: 0.0208533	best: 0.0208533 (1764)	total: 1m 43s	remaining: 4m 49s
# 1765:	learn: 0.0209197	test: 0.0208532	best: 0.0208532 (1765)	total: 1m 43s	remaining: 4m 49s
# 1766:	learn: 0.0209197	test: 0.0208532	best: 0.0208532 (1766)	total: 1m 43s	remaining: 4m 49s
# 1767:	learn: 0.0209196	test: 0.0208531	best: 0.0208531 (1767)	total: 1m 43s	remaining: 4m 49s
# 1768:	learn: 0.0209196	test: 0.0208530	best: 0.0208530 (1768)	total: 1m 43s	remaining: 4m 49s
# 1769:	learn: 0.0209195	test: 0.0208529	best: 0.0208529 (1769)	total: 1m 43s	remaining: 4m 49s
# 1770:	learn: 0.0209194	test: 0.0208529	best: 0.0208529 (1770)	total: 1m 43s	remaining: 4m 49s
# 1771:	learn: 0.0209194	test: 0.0208529	best: 0.0208529 (1770)	total: 1m 43s	remaining: 4m 48s
# 1772:	learn: 0.0209193	test: 0.0208528	best: 0.0208528 (1772)	total: 1m 43s	remaining: 4m 48s
# 1773:	learn: 0.0209193	test: 0.0208528	best: 0.0208528 (1773)	total: 1m 43s	remaining: 4m 48s
# 1774:	learn: 0.0209192	test: 0.0208526	best: 0.0208526 (1774)	total: 1m 43s	remaining: 4m 48s
# 1775:	learn: 0.0209192	test: 0.0208526	best: 0.0208526 (1774)	total: 1m 44s	remaining: 4m 48s
# 1776:	learn: 0.0209191	test: 0.0208526	best: 0.0208526 (1776)	total: 1m 44s	remaining: 4m 48s
# 1777:	learn: 0.0209191	test: 0.0208526	best: 0.0208526 (1777)	total: 1m 44s	remaining: 4m 48s
# 1778:	learn: 0.0209190	test: 0.0208525	best: 0.0208525 (1778)	total: 1m 44s	remaining: 4m 48s
# 1779:	learn: 0.0209190	test: 0.0208525	best: 0.0208525 (1779)	total: 1m 44s	remaining: 4m 48s
# 1780:	learn: 0.0209189	test: 0.0208525	best: 0.0208525 (1779)	total: 1m 44s	remaining: 4m 48s
# 1781:	learn: 0.0209189	test: 0.0208524	best: 0.0208524 (1781)	total: 1m 44s	remaining: 4m 48s
# 1782:	learn: 0.0209188	test: 0.0208523	best: 0.0208523 (1782)	total: 1m 44s	remaining: 4m 48s
# 1783:	learn: 0.0209188	test: 0.0208523	best: 0.0208523 (1783)	total: 1m 44s	remaining: 4m 48s
# 1784:	learn: 0.0209187	test: 0.0208522	best: 0.0208522 (1784)	total: 1m 44s	remaining: 4m 47s
# 1785:	learn: 0.0209186	test: 0.0208521	best: 0.0208521 (1785)	total: 1m 44s	remaining: 4m 47s
# 1786:	learn: 0.0209186	test: 0.0208521	best: 0.0208521 (1785)	total: 1m 44s	remaining: 4m 47s
# 1787:	learn: 0.0209185	test: 0.0208520	best: 0.0208520 (1787)	total: 1m 44s	remaining: 4m 47s
# 1788:	learn: 0.0209184	test: 0.0208520	best: 0.0208520 (1788)	total: 1m 44s	remaining: 4m 47s
# 1789:	learn: 0.0209183	test: 0.0208519	best: 0.0208519 (1789)	total: 1m 44s	remaining: 4m 47s
# 1790:	learn: 0.0209183	test: 0.0208519	best: 0.0208519 (1790)	total: 1m 44s	remaining: 4m 47s
# 1791:	learn: 0.0209182	test: 0.0208518	best: 0.0208518 (1791)	total: 1m 44s	remaining: 4m 47s
# 1792:	learn: 0.0209182	test: 0.0208517	best: 0.0208517 (1792)	total: 1m 44s	remaining: 4m 47s
# 1793:	learn: 0.0209181	test: 0.0208517	best: 0.0208517 (1793)	total: 1m 44s	remaining: 4m 47s
# 1794:	learn: 0.0209181	test: 0.0208515	best: 0.0208515 (1794)	total: 1m 45s	remaining: 4m 47s
# 1795:	learn: 0.0209180	test: 0.0208514	best: 0.0208514 (1795)	total: 1m 45s	remaining: 4m 47s
# 1796:	learn: 0.0209180	test: 0.0208514	best: 0.0208514 (1796)	total: 1m 45s	remaining: 4m 47s
# 1797:	learn: 0.0209179	test: 0.0208513	best: 0.0208513 (1797)	total: 1m 45s	remaining: 4m 47s
# 1798:	learn: 0.0209178	test: 0.0208513	best: 0.0208513 (1798)	total: 1m 45s	remaining: 4m 46s
# 1799:	learn: 0.0209178	test: 0.0208513	best: 0.0208513 (1799)	total: 1m 45s	remaining: 4m 46s
# 1800:	learn: 0.0209177	test: 0.0208512	best: 0.0208512 (1800)	total: 1m 45s	remaining: 4m 46s
# 1801:	learn: 0.0209177	test: 0.0208512	best: 0.0208512 (1801)	total: 1m 45s	remaining: 4m 46s
# 1802:	learn: 0.0209176	test: 0.0208511	best: 0.0208511 (1802)	total: 1m 45s	remaining: 4m 46s
# 1803:	learn: 0.0209176	test: 0.0208510	best: 0.0208510 (1803)	total: 1m 45s	remaining: 4m 46s
# 1804:	learn: 0.0209175	test: 0.0208510	best: 0.0208510 (1803)	total: 1m 45s	remaining: 4m 46s
# 1805:	learn: 0.0209175	test: 0.0208509	best: 0.0208509 (1805)	total: 1m 45s	remaining: 4m 46s
# 1806:	learn: 0.0209174	test: 0.0208509	best: 0.0208509 (1806)	total: 1m 45s	remaining: 4m 46s
# 1807:	learn: 0.0209174	test: 0.0208508	best: 0.0208508 (1807)	total: 1m 45s	remaining: 4m 46s
# 1808:	learn: 0.0209173	test: 0.0208507	best: 0.0208507 (1808)	total: 1m 45s	remaining: 4m 46s
# 1809:	learn: 0.0209172	test: 0.0208507	best: 0.0208507 (1809)	total: 1m 45s	remaining: 4m 46s
# 1810:	learn: 0.0209172	test: 0.0208507	best: 0.0208507 (1809)	total: 1m 45s	remaining: 4m 46s
# 1811:	learn: 0.0209171	test: 0.0208507	best: 0.0208507 (1811)	total: 1m 45s	remaining: 4m 45s
# 1812:	learn: 0.0209171	test: 0.0208506	best: 0.0208506 (1812)	total: 1m 45s	remaining: 4m 45s
# 1813:	learn: 0.0209170	test: 0.0208506	best: 0.0208506 (1813)	total: 1m 46s	remaining: 4m 45s
# 1814:	learn: 0.0209170	test: 0.0208506	best: 0.0208506 (1814)	total: 1m 46s	remaining: 4m 45s
# 1815:	learn: 0.0209169	test: 0.0208505	best: 0.0208505 (1815)	total: 1m 46s	remaining: 4m 45s
# 1816:	learn: 0.0209169	test: 0.0208504	best: 0.0208504 (1816)	total: 1m 46s	remaining: 4m 45s
# 1817:	learn: 0.0209168	test: 0.0208504	best: 0.0208504 (1817)	total: 1m 46s	remaining: 4m 45s
# 1818:	learn: 0.0209168	test: 0.0208503	best: 0.0208503 (1818)	total: 1m 46s	remaining: 4m 45s
# 1819:	learn: 0.0209167	test: 0.0208503	best: 0.0208503 (1819)	total: 1m 46s	remaining: 4m 45s
# 1820:	learn: 0.0209166	test: 0.0208502	best: 0.0208502 (1820)	total: 1m 46s	remaining: 4m 45s
# 1821:	learn: 0.0209166	test: 0.0208501	best: 0.0208501 (1821)	total: 1m 46s	remaining: 4m 45s
# 1822:	learn: 0.0209165	test: 0.0208500	best: 0.0208500 (1822)	total: 1m 46s	remaining: 4m 45s
# 1823:	learn: 0.0209165	test: 0.0208500	best: 0.0208500 (1823)	total: 1m 46s	remaining: 4m 45s
# 1824:	learn: 0.0209164	test: 0.0208499	best: 0.0208499 (1824)	total: 1m 46s	remaining: 4m 44s
# 1825:	learn: 0.0209164	test: 0.0208499	best: 0.0208499 (1825)	total: 1m 46s	remaining: 4m 44s
# 1826:	learn: 0.0209163	test: 0.0208498	best: 0.0208498 (1826)	total: 1m 46s	remaining: 4m 44s
# 1827:	learn: 0.0209162	test: 0.0208498	best: 0.0208498 (1827)	total: 1m 46s	remaining: 4m 44s
# 1828:	learn: 0.0209161	test: 0.0208497	best: 0.0208497 (1828)	total: 1m 46s	remaining: 4m 44s
# 1829:	learn: 0.0209161	test: 0.0208497	best: 0.0208497 (1829)	total: 1m 46s	remaining: 4m 44s
# 1830:	learn: 0.0209160	test: 0.0208497	best: 0.0208497 (1829)	total: 1m 46s	remaining: 4m 44s
# 1831:	learn: 0.0209160	test: 0.0208497	best: 0.0208497 (1829)	total: 1m 46s	remaining: 4m 44s
# 1832:	learn: 0.0209159	test: 0.0208495	best: 0.0208495 (1832)	total: 1m 47s	remaining: 4m 44s
# 1833:	learn: 0.0209159	test: 0.0208494	best: 0.0208494 (1833)	total: 1m 47s	remaining: 4m 44s
# 1834:	learn: 0.0209158	test: 0.0208493	best: 0.0208493 (1834)	total: 1m 47s	remaining: 4m 44s
# 1835:	learn: 0.0209158	test: 0.0208493	best: 0.0208493 (1835)	total: 1m 47s	remaining: 4m 44s
# 1836:	learn: 0.0209157	test: 0.0208493	best: 0.0208493 (1835)	total: 1m 47s	remaining: 4m 44s
# 1837:	learn: 0.0209157	test: 0.0208492	best: 0.0208492 (1837)	total: 1m 47s	remaining: 4m 43s
# 1838:	learn: 0.0209156	test: 0.0208492	best: 0.0208492 (1838)	total: 1m 47s	remaining: 4m 43s
# 1839:	learn: 0.0209155	test: 0.0208491	best: 0.0208491 (1839)	total: 1m 47s	remaining: 4m 43s
# 1840:	learn: 0.0209155	test: 0.0208490	best: 0.0208490 (1840)	total: 1m 47s	remaining: 4m 43s
# 1841:	learn: 0.0209155	test: 0.0208489	best: 0.0208489 (1841)	total: 1m 47s	remaining: 4m 43s
# 1842:	learn: 0.0209154	test: 0.0208489	best: 0.0208489 (1842)	total: 1m 47s	remaining: 4m 43s
# 1843:	learn: 0.0209153	test: 0.0208488	best: 0.0208488 (1843)	total: 1m 47s	remaining: 4m 43s
# 1844:	learn: 0.0209153	test: 0.0208488	best: 0.0208488 (1844)	total: 1m 47s	remaining: 4m 43s
# 1845:	learn: 0.0209152	test: 0.0208487	best: 0.0208487 (1845)	total: 1m 47s	remaining: 4m 43s
# 1846:	learn: 0.0209152	test: 0.0208487	best: 0.0208487 (1845)	total: 1m 47s	remaining: 4m 43s
# 1847:	learn: 0.0209152	test: 0.0208487	best: 0.0208487 (1845)	total: 1m 47s	remaining: 4m 43s
# 1848:	learn: 0.0209151	test: 0.0208486	best: 0.0208486 (1848)	total: 1m 47s	remaining: 4m 43s
# 1849:	learn: 0.0209150	test: 0.0208486	best: 0.0208486 (1849)	total: 1m 47s	remaining: 4m 43s
# 1850:	learn: 0.0209150	test: 0.0208485	best: 0.0208485 (1850)	total: 1m 47s	remaining: 4m 42s
# 1851:	learn: 0.0209149	test: 0.0208485	best: 0.0208485 (1851)	total: 1m 48s	remaining: 4m 42s
# 1852:	learn: 0.0209149	test: 0.0208485	best: 0.0208485 (1852)	total: 1m 48s	remaining: 4m 42s
# 1853:	learn: 0.0209149	test: 0.0208484	best: 0.0208484 (1853)	total: 1m 48s	remaining: 4m 42s
# 1854:	learn: 0.0209148	test: 0.0208483	best: 0.0208483 (1854)	total: 1m 48s	remaining: 4m 42s
# 1855:	learn: 0.0209147	test: 0.0208483	best: 0.0208483 (1855)	total: 1m 48s	remaining: 4m 42s
# 1856:	learn: 0.0209147	test: 0.0208483	best: 0.0208483 (1856)	total: 1m 48s	remaining: 4m 42s
# 1857:	learn: 0.0209146	test: 0.0208482	best: 0.0208482 (1857)	total: 1m 48s	remaining: 4m 42s
# 1858:	learn: 0.0209146	test: 0.0208482	best: 0.0208482 (1857)	total: 1m 48s	remaining: 4m 42s
# 1859:	learn: 0.0209145	test: 0.0208481	best: 0.0208481 (1859)	total: 1m 48s	remaining: 4m 42s
# 1860:	learn: 0.0209145	test: 0.0208480	best: 0.0208480 (1860)	total: 1m 48s	remaining: 4m 42s
# 1861:	learn: 0.0209144	test: 0.0208480	best: 0.0208480 (1861)	total: 1m 48s	remaining: 4m 42s
# 1862:	learn: 0.0209144	test: 0.0208480	best: 0.0208480 (1862)	total: 1m 48s	remaining: 4m 42s
# 1863:	learn: 0.0209143	test: 0.0208479	best: 0.0208479 (1863)	total: 1m 48s	remaining: 4m 42s
# 1864:	learn: 0.0209143	test: 0.0208478	best: 0.0208478 (1864)	total: 1m 48s	remaining: 4m 41s
# 1865:	learn: 0.0209142	test: 0.0208478	best: 0.0208478 (1864)	total: 1m 48s	remaining: 4m 41s
# 1866:	learn: 0.0209141	test: 0.0208477	best: 0.0208477 (1866)	total: 1m 48s	remaining: 4m 41s
# 1867:	learn: 0.0209141	test: 0.0208477	best: 0.0208477 (1867)	total: 1m 48s	remaining: 4m 41s
# 1868:	learn: 0.0209140	test: 0.0208477	best: 0.0208477 (1867)	total: 1m 48s	remaining: 4m 41s
# 1869:	learn: 0.0209140	test: 0.0208476	best: 0.0208476 (1869)	total: 1m 48s	remaining: 4m 41s
# 1870:	learn: 0.0209139	test: 0.0208474	best: 0.0208474 (1870)	total: 1m 49s	remaining: 4m 41s
# 1871:	learn: 0.0209139	test: 0.0208474	best: 0.0208474 (1870)	total: 1m 49s	remaining: 4m 41s
# 1872:	learn: 0.0209138	test: 0.0208474	best: 0.0208474 (1872)	total: 1m 49s	remaining: 4m 41s
# 1873:	learn: 0.0209138	test: 0.0208473	best: 0.0208473 (1873)	total: 1m 49s	remaining: 4m 41s
# 1874:	learn: 0.0209137	test: 0.0208473	best: 0.0208473 (1874)	total: 1m 49s	remaining: 4m 41s
# 1875:	learn: 0.0209137	test: 0.0208472	best: 0.0208472 (1875)	total: 1m 49s	remaining: 4m 41s
# 1876:	learn: 0.0209136	test: 0.0208471	best: 0.0208471 (1876)	total: 1m 49s	remaining: 4m 41s
# 1877:	learn: 0.0209136	test: 0.0208471	best: 0.0208471 (1877)	total: 1m 49s	remaining: 4m 40s
# 1878:	learn: 0.0209135	test: 0.0208471	best: 0.0208471 (1878)	total: 1m 49s	remaining: 4m 40s
# 1879:	learn: 0.0209134	test: 0.0208470	best: 0.0208470 (1879)	total: 1m 49s	remaining: 4m 40s
# 1880:	learn: 0.0209134	test: 0.0208469	best: 0.0208469 (1880)	total: 1m 49s	remaining: 4m 40s
# 1881:	learn: 0.0209133	test: 0.0208468	best: 0.0208468 (1881)	total: 1m 49s	remaining: 4m 40s
# 1882:	learn: 0.0209133	test: 0.0208468	best: 0.0208468 (1882)	total: 1m 49s	remaining: 4m 40s
# 1883:	learn: 0.0209132	test: 0.0208468	best: 0.0208468 (1883)	total: 1m 49s	remaining: 4m 40s
# 1884:	learn: 0.0209132	test: 0.0208467	best: 0.0208467 (1884)	total: 1m 49s	remaining: 4m 40s
# 1885:	learn: 0.0209131	test: 0.0208466	best: 0.0208466 (1885)	total: 1m 49s	remaining: 4m 40s
# 1886:	learn: 0.0209131	test: 0.0208466	best: 0.0208466 (1885)	total: 1m 49s	remaining: 4m 40s
# 1887:	learn: 0.0209130	test: 0.0208466	best: 0.0208466 (1885)	total: 1m 49s	remaining: 4m 40s
# 1888:	learn: 0.0209130	test: 0.0208465	best: 0.0208465 (1888)	total: 1m 49s	remaining: 4m 40s
# 1889:	learn: 0.0209129	test: 0.0208465	best: 0.0208465 (1888)	total: 1m 49s	remaining: 4m 40s
# 1890:	learn: 0.0209129	test: 0.0208464	best: 0.0208464 (1890)	total: 1m 50s	remaining: 4m 40s
# 1891:	learn: 0.0209128	test: 0.0208464	best: 0.0208464 (1891)	total: 1m 50s	remaining: 4m 39s
# 1892:	learn: 0.0209128	test: 0.0208464	best: 0.0208464 (1891)	total: 1m 50s	remaining: 4m 39s
# 1893:	learn: 0.0209127	test: 0.0208463	best: 0.0208463 (1893)	total: 1m 50s	remaining: 4m 39s
# 1894:	learn: 0.0209127	test: 0.0208463	best: 0.0208463 (1894)	total: 1m 50s	remaining: 4m 39s
# 1895:	learn: 0.0209126	test: 0.0208462	best: 0.0208462 (1895)	total: 1m 50s	remaining: 4m 39s
# 1896:	learn: 0.0209126	test: 0.0208462	best: 0.0208462 (1896)	total: 1m 50s	remaining: 4m 39s
# 1897:	learn: 0.0209125	test: 0.0208461	best: 0.0208461 (1897)	total: 1m 50s	remaining: 4m 39s
# 1898:	learn: 0.0209125	test: 0.0208460	best: 0.0208460 (1898)	total: 1m 50s	remaining: 4m 39s
# 1899:	learn: 0.0209124	test: 0.0208460	best: 0.0208460 (1899)	total: 1m 50s	remaining: 4m 39s
# 1900:	learn: 0.0209124	test: 0.0208460	best: 0.0208460 (1900)	total: 1m 50s	remaining: 4m 39s
# 1901:	learn: 0.0209123	test: 0.0208460	best: 0.0208460 (1900)	total: 1m 50s	remaining: 4m 39s
# 1902:	learn: 0.0209123	test: 0.0208459	best: 0.0208459 (1902)	total: 1m 50s	remaining: 4m 39s
# 1903:	learn: 0.0209122	test: 0.0208458	best: 0.0208458 (1903)	total: 1m 50s	remaining: 4m 39s
# 1904:	learn: 0.0209122	test: 0.0208458	best: 0.0208458 (1904)	total: 1m 50s	remaining: 4m 39s
# 1905:	learn: 0.0209121	test: 0.0208458	best: 0.0208458 (1905)	total: 1m 50s	remaining: 4m 39s
# 1906:	learn: 0.0209120	test: 0.0208456	best: 0.0208456 (1906)	total: 1m 51s	remaining: 4m 39s
# 1907:	learn: 0.0209119	test: 0.0208455	best: 0.0208455 (1907)	total: 1m 51s	remaining: 4m 39s
# 1908:	learn: 0.0209118	test: 0.0208454	best: 0.0208454 (1908)	total: 1m 51s	remaining: 4m 39s
# 1909:	learn: 0.0209117	test: 0.0208453	best: 0.0208453 (1909)	total: 1m 51s	remaining: 4m 39s
# 1910:	learn: 0.0209116	test: 0.0208452	best: 0.0208452 (1910)	total: 1m 51s	remaining: 4m 39s
# 1911:	learn: 0.0209115	test: 0.0208451	best: 0.0208451 (1911)	total: 1m 51s	remaining: 4m 39s
# 1912:	learn: 0.0209114	test: 0.0208450	best: 0.0208450 (1912)	total: 1m 51s	remaining: 4m 39s
# 1913:	learn: 0.0209114	test: 0.0208449	best: 0.0208449 (1913)	total: 1m 51s	remaining: 4m 39s
# 1914:	learn: 0.0209113	test: 0.0208448	best: 0.0208448 (1914)	total: 1m 51s	remaining: 4m 39s
# 1915:	learn: 0.0209112	test: 0.0208448	best: 0.0208448 (1915)	total: 1m 51s	remaining: 4m 39s
# 1916:	learn: 0.0209112	test: 0.0208448	best: 0.0208448 (1915)	total: 1m 51s	remaining: 4m 39s
# 1917:	learn: 0.0209112	test: 0.0208447	best: 0.0208447 (1917)	total: 1m 52s	remaining: 4m 39s
# 1918:	learn: 0.0209111	test: 0.0208447	best: 0.0208447 (1917)	total: 1m 52s	remaining: 4m 39s
# 1919:	learn: 0.0209111	test: 0.0208446	best: 0.0208446 (1919)	total: 1m 52s	remaining: 4m 39s
# 1920:	learn: 0.0209110	test: 0.0208445	best: 0.0208445 (1920)	total: 1m 52s	remaining: 4m 39s
# 1921:	learn: 0.0209110	test: 0.0208445	best: 0.0208445 (1920)	total: 1m 52s	remaining: 4m 39s
# 1922:	learn: 0.0209109	test: 0.0208445	best: 0.0208445 (1920)	total: 1m 52s	remaining: 4m 39s
# 1923:	learn: 0.0209109	test: 0.0208444	best: 0.0208444 (1923)	total: 1m 52s	remaining: 4m 39s
# 1924:	learn: 0.0209108	test: 0.0208444	best: 0.0208444 (1924)	total: 1m 52s	remaining: 4m 39s
# 1925:	learn: 0.0209108	test: 0.0208443	best: 0.0208443 (1925)	total: 1m 52s	remaining: 4m 39s
# 1926:	learn: 0.0209107	test: 0.0208443	best: 0.0208443 (1926)	total: 1m 52s	remaining: 4m 39s
# 1927:	learn: 0.0209107	test: 0.0208442	best: 0.0208442 (1927)	total: 1m 52s	remaining: 4m 39s
# 1928:	learn: 0.0209106	test: 0.0208442	best: 0.0208442 (1928)	total: 1m 53s	remaining: 4m 39s
# 1929:	learn: 0.0209106	test: 0.0208441	best: 0.0208441 (1929)	total: 1m 53s	remaining: 4m 39s
# 1930:	learn: 0.0209105	test: 0.0208441	best: 0.0208441 (1929)	total: 1m 53s	remaining: 4m 39s
# 1931:	learn: 0.0209105	test: 0.0208440	best: 0.0208440 (1931)	total: 1m 53s	remaining: 4m 39s
# 1932:	learn: 0.0209104	test: 0.0208440	best: 0.0208440 (1932)	total: 1m 53s	remaining: 4m 39s
# 1933:	learn: 0.0209104	test: 0.0208439	best: 0.0208439 (1933)	total: 1m 53s	remaining: 4m 39s
# 1934:	learn: 0.0209103	test: 0.0208439	best: 0.0208439 (1933)	total: 1m 53s	remaining: 4m 40s
# 1935:	learn: 0.0209103	test: 0.0208439	best: 0.0208439 (1935)	total: 1m 53s	remaining: 4m 40s
# 1936:	learn: 0.0209102	test: 0.0208438	best: 0.0208438 (1936)	total: 1m 53s	remaining: 4m 40s
# 1937:	learn: 0.0209102	test: 0.0208438	best: 0.0208438 (1936)	total: 1m 53s	remaining: 4m 40s
# 1938:	learn: 0.0209101	test: 0.0208437	best: 0.0208437 (1938)	total: 1m 54s	remaining: 4m 40s
# 1939:	learn: 0.0209100	test: 0.0208437	best: 0.0208437 (1939)	total: 1m 54s	remaining: 4m 40s
# 1940:	learn: 0.0209100	test: 0.0208436	best: 0.0208436 (1940)	total: 1m 54s	remaining: 4m 39s
# 1941:	learn: 0.0209099	test: 0.0208436	best: 0.0208436 (1941)	total: 1m 54s	remaining: 4m 39s
# 1942:	learn: 0.0209099	test: 0.0208435	best: 0.0208435 (1942)	total: 1m 54s	remaining: 4m 39s
# 1943:	learn: 0.0209099	test: 0.0208435	best: 0.0208435 (1943)	total: 1m 54s	remaining: 4m 39s
# 1944:	learn: 0.0209098	test: 0.0208434	best: 0.0208434 (1944)	total: 1m 54s	remaining: 4m 39s
# 1945:	learn: 0.0209097	test: 0.0208433	best: 0.0208433 (1945)	total: 1m 54s	remaining: 4m 39s
# 1946:	learn: 0.0209097	test: 0.0208433	best: 0.0208433 (1946)	total: 1m 54s	remaining: 4m 39s
# 1947:	learn: 0.0209096	test: 0.0208433	best: 0.0208433 (1947)	total: 1m 54s	remaining: 4m 39s
# 1948:	learn: 0.0209096	test: 0.0208432	best: 0.0208432 (1948)	total: 1m 54s	remaining: 4m 39s
# 1949:	learn: 0.0209095	test: 0.0208432	best: 0.0208432 (1948)	total: 1m 54s	remaining: 4m 39s
# 1950:	learn: 0.0209095	test: 0.0208431	best: 0.0208431 (1950)	total: 1m 54s	remaining: 4m 39s
# 1951:	learn: 0.0209094	test: 0.0208431	best: 0.0208431 (1951)	total: 1m 54s	remaining: 4m 39s
# 1952:	learn: 0.0209094	test: 0.0208430	best: 0.0208430 (1952)	total: 1m 54s	remaining: 4m 39s
# 1953:	learn: 0.0209093	test: 0.0208430	best: 0.0208430 (1952)	total: 1m 54s	remaining: 4m 39s
# 1954:	learn: 0.0209093	test: 0.0208430	best: 0.0208430 (1952)	total: 1m 54s	remaining: 4m 38s
# 1955:	learn: 0.0209093	test: 0.0208429	best: 0.0208429 (1955)	total: 1m 54s	remaining: 4m 38s
# 1956:	learn: 0.0209092	test: 0.0208429	best: 0.0208429 (1955)	total: 1m 54s	remaining: 4m 38s
# 1957:	learn: 0.0209092	test: 0.0208429	best: 0.0208429 (1957)	total: 1m 55s	remaining: 4m 38s
# 1958:	learn: 0.0209091	test: 0.0208428	best: 0.0208428 (1958)	total: 1m 55s	remaining: 4m 38s
# 1959:	learn: 0.0209090	test: 0.0208427	best: 0.0208427 (1959)	total: 1m 55s	remaining: 4m 38s
# 1960:	learn: 0.0209090	test: 0.0208427	best: 0.0208427 (1959)	total: 1m 55s	remaining: 4m 38s
# 1961:	learn: 0.0209090	test: 0.0208427	best: 0.0208427 (1961)	total: 1m 55s	remaining: 4m 38s
# 1962:	learn: 0.0209089	test: 0.0208426	best: 0.0208426 (1962)	total: 1m 55s	remaining: 4m 38s
# 1963:	learn: 0.0209089	test: 0.0208426	best: 0.0208426 (1962)	total: 1m 55s	remaining: 4m 38s
# 1964:	learn: 0.0209088	test: 0.0208426	best: 0.0208426 (1964)	total: 1m 55s	remaining: 4m 38s
# 1965:	learn: 0.0209088	test: 0.0208425	best: 0.0208425 (1965)	total: 1m 55s	remaining: 4m 38s
# 1966:	learn: 0.0209087	test: 0.0208425	best: 0.0208425 (1966)	total: 1m 55s	remaining: 4m 38s
# 1967:	learn: 0.0209087	test: 0.0208424	best: 0.0208424 (1967)	total: 1m 55s	remaining: 4m 37s
# 1968:	learn: 0.0209086	test: 0.0208424	best: 0.0208424 (1967)	total: 1m 55s	remaining: 4m 37s
# 1969:	learn: 0.0209086	test: 0.0208423	best: 0.0208423 (1969)	total: 1m 55s	remaining: 4m 37s
# 1970:	learn: 0.0209085	test: 0.0208422	best: 0.0208422 (1970)	total: 1m 55s	remaining: 4m 37s
# 1971:	learn: 0.0209085	test: 0.0208421	best: 0.0208421 (1971)	total: 1m 55s	remaining: 4m 37s
# 1972:	learn: 0.0209084	test: 0.0208421	best: 0.0208421 (1972)	total: 1m 55s	remaining: 4m 37s
# 1973:	learn: 0.0209084	test: 0.0208420	best: 0.0208420 (1973)	total: 1m 55s	remaining: 4m 37s
# 1974:	learn: 0.0209083	test: 0.0208420	best: 0.0208420 (1973)	total: 1m 55s	remaining: 4m 37s
# 1975:	learn: 0.0209083	test: 0.0208419	best: 0.0208419 (1975)	total: 1m 55s	remaining: 4m 37s
# 1976:	learn: 0.0209082	test: 0.0208419	best: 0.0208419 (1976)	total: 1m 56s	remaining: 4m 37s
# 1977:	learn: 0.0209081	test: 0.0208418	best: 0.0208418 (1977)	total: 1m 56s	remaining: 4m 37s
# 1978:	learn: 0.0209080	test: 0.0208418	best: 0.0208418 (1977)	total: 1m 56s	remaining: 4m 37s
# 1979:	learn: 0.0209080	test: 0.0208418	best: 0.0208418 (1977)	total: 1m 56s	remaining: 4m 37s
# 1980:	learn: 0.0209080	test: 0.0208417	best: 0.0208417 (1980)	total: 1m 56s	remaining: 4m 37s
# 1981:	learn: 0.0209079	test: 0.0208416	best: 0.0208416 (1981)	total: 1m 56s	remaining: 4m 36s
# 1982:	learn: 0.0209079	test: 0.0208416	best: 0.0208416 (1981)	total: 1m 56s	remaining: 4m 36s
# 1983:	learn: 0.0209078	test: 0.0208416	best: 0.0208416 (1981)	total: 1m 56s	remaining: 4m 36s
# 1984:	learn: 0.0209078	test: 0.0208415	best: 0.0208415 (1984)	total: 1m 56s	remaining: 4m 36s
# 1985:	learn: 0.0209077	test: 0.0208415	best: 0.0208415 (1985)	total: 1m 56s	remaining: 4m 36s
# 1986:	learn: 0.0209077	test: 0.0208415	best: 0.0208415 (1986)	total: 1m 56s	remaining: 4m 36s
# 1987:	learn: 0.0209076	test: 0.0208414	best: 0.0208414 (1987)	total: 1m 56s	remaining: 4m 36s
# 1988:	learn: 0.0209076	test: 0.0208415	best: 0.0208414 (1987)	total: 1m 56s	remaining: 4m 36s
# 1989:	learn: 0.0209075	test: 0.0208414	best: 0.0208414 (1989)	total: 1m 56s	remaining: 4m 36s
# 1990:	learn: 0.0209075	test: 0.0208414	best: 0.0208414 (1990)	total: 1m 56s	remaining: 4m 36s
# 1991:	learn: 0.0209074	test: 0.0208413	best: 0.0208413 (1991)	total: 1m 56s	remaining: 4m 36s
# 1992:	learn: 0.0209074	test: 0.0208412	best: 0.0208412 (1992)	total: 1m 56s	remaining: 4m 36s
# 1993:	learn: 0.0209073	test: 0.0208412	best: 0.0208412 (1993)	total: 1m 56s	remaining: 4m 36s
# 1994:	learn: 0.0209073	test: 0.0208411	best: 0.0208411 (1994)	total: 1m 56s	remaining: 4m 35s
# 1995:	learn: 0.0209073	test: 0.0208411	best: 0.0208411 (1995)	total: 1m 57s	remaining: 4m 35s
# 1996:	learn: 0.0209072	test: 0.0208410	best: 0.0208410 (1996)	total: 1m 57s	remaining: 4m 35s
# 1997:	learn: 0.0209072	test: 0.0208410	best: 0.0208410 (1997)	total: 1m 57s	remaining: 4m 35s
# 1998:	learn: 0.0209071	test: 0.0208408	best: 0.0208408 (1998)	total: 1m 57s	remaining: 4m 35s
# 1999:	learn: 0.0209071	test: 0.0208408	best: 0.0208408 (1998)	total: 1m 57s	remaining: 4m 35s
# 2000:	learn: 0.0209070	test: 0.0208407	best: 0.0208407 (2000)	total: 1m 57s	remaining: 4m 35s
# 2001:	learn: 0.0209069	test: 0.0208407	best: 0.0208407 (2000)	total: 1m 57s	remaining: 4m 35s
# 2002:	learn: 0.0209069	test: 0.0208406	best: 0.0208406 (2002)	total: 1m 57s	remaining: 4m 35s
# 2003:	learn: 0.0209068	test: 0.0208406	best: 0.0208406 (2002)	total: 1m 57s	remaining: 4m 35s
# 2004:	learn: 0.0209068	test: 0.0208405	best: 0.0208405 (2004)	total: 1m 57s	remaining: 4m 35s
# 2005:	learn: 0.0209068	test: 0.0208405	best: 0.0208405 (2005)	total: 1m 57s	remaining: 4m 35s
# 2006:	learn: 0.0209067	test: 0.0208404	best: 0.0208404 (2006)	total: 1m 57s	remaining: 4m 35s
# 2007:	learn: 0.0209067	test: 0.0208404	best: 0.0208404 (2007)	total: 1m 57s	remaining: 4m 35s
# 2008:	learn: 0.0209066	test: 0.0208404	best: 0.0208404 (2007)	total: 1m 57s	remaining: 4m 34s
# 2009:	learn: 0.0209066	test: 0.0208403	best: 0.0208403 (2009)	total: 1m 57s	remaining: 4m 34s
# 2010:	learn: 0.0209065	test: 0.0208402	best: 0.0208402 (2010)	total: 1m 57s	remaining: 4m 34s
# 2011:	learn: 0.0209065	test: 0.0208402	best: 0.0208402 (2011)	total: 1m 57s	remaining: 4m 34s
# 2012:	learn: 0.0209064	test: 0.0208401	best: 0.0208401 (2012)	total: 1m 57s	remaining: 4m 34s
# 2013:	learn: 0.0209064	test: 0.0208401	best: 0.0208401 (2012)	total: 1m 57s	remaining: 4m 34s
# 2014:	learn: 0.0209063	test: 0.0208400	best: 0.0208400 (2014)	total: 1m 57s	remaining: 4m 34s
# 2015:	learn: 0.0209063	test: 0.0208400	best: 0.0208400 (2015)	total: 1m 58s	remaining: 4m 34s
# 2016:	learn: 0.0209062	test: 0.0208400	best: 0.0208400 (2015)	total: 1m 58s	remaining: 4m 34s
# 2017:	learn: 0.0209062	test: 0.0208399	best: 0.0208399 (2017)	total: 1m 58s	remaining: 4m 34s
# 2018:	learn: 0.0209061	test: 0.0208398	best: 0.0208398 (2018)	total: 1m 58s	remaining: 4m 34s
# 2019:	learn: 0.0209061	test: 0.0208398	best: 0.0208398 (2019)	total: 1m 58s	remaining: 4m 34s
# 2020:	learn: 0.0209060	test: 0.0208398	best: 0.0208398 (2020)	total: 1m 58s	remaining: 4m 34s
# 2021:	learn: 0.0209060	test: 0.0208397	best: 0.0208397 (2021)	total: 1m 58s	remaining: 4m 33s
# 2022:	learn: 0.0209059	test: 0.0208397	best: 0.0208397 (2022)	total: 1m 58s	remaining: 4m 33s
# 2023:	learn: 0.0209059	test: 0.0208396	best: 0.0208396 (2023)	total: 1m 58s	remaining: 4m 33s
# 2024:	learn: 0.0209058	test: 0.0208395	best: 0.0208395 (2024)	total: 1m 58s	remaining: 4m 33s
# 2025:	learn: 0.0209058	test: 0.0208394	best: 0.0208394 (2025)	total: 1m 58s	remaining: 4m 33s
# 2026:	learn: 0.0209057	test: 0.0208394	best: 0.0208394 (2026)	total: 1m 58s	remaining: 4m 33s
# 2027:	learn: 0.0209057	test: 0.0208394	best: 0.0208394 (2027)	total: 1m 58s	remaining: 4m 33s
# 2028:	learn: 0.0209056	test: 0.0208394	best: 0.0208394 (2028)	total: 1m 58s	remaining: 4m 33s
# 2029:	learn: 0.0209056	test: 0.0208393	best: 0.0208393 (2029)	total: 1m 58s	remaining: 4m 33s
# 2030:	learn: 0.0209055	test: 0.0208393	best: 0.0208393 (2029)	total: 1m 58s	remaining: 4m 33s
# 2031:	learn: 0.0209055	test: 0.0208392	best: 0.0208392 (2031)	total: 1m 58s	remaining: 4m 33s
# 2032:	learn: 0.0209054	test: 0.0208392	best: 0.0208392 (2031)	total: 1m 58s	remaining: 4m 33s
# 2033:	learn: 0.0209054	test: 0.0208392	best: 0.0208392 (2033)	total: 1m 58s	remaining: 4m 33s
# 2034:	learn: 0.0209054	test: 0.0208392	best: 0.0208392 (2034)	total: 1m 59s	remaining: 4m 33s
# 2035:	learn: 0.0209053	test: 0.0208391	best: 0.0208391 (2035)	total: 1m 59s	remaining: 4m 32s
# 2036:	learn: 0.0209053	test: 0.0208390	best: 0.0208390 (2036)	total: 1m 59s	remaining: 4m 32s
# 2037:	learn: 0.0209052	test: 0.0208389	best: 0.0208389 (2037)	total: 1m 59s	remaining: 4m 32s
# 2038:	learn: 0.0209052	test: 0.0208389	best: 0.0208389 (2038)	total: 1m 59s	remaining: 4m 32s
# 2039:	learn: 0.0209052	test: 0.0208389	best: 0.0208389 (2038)	total: 1m 59s	remaining: 4m 32s
# 2040:	learn: 0.0209051	test: 0.0208389	best: 0.0208389 (2040)	total: 1m 59s	remaining: 4m 32s
# 2041:	learn: 0.0209051	test: 0.0208388	best: 0.0208388 (2041)	total: 1m 59s	remaining: 4m 32s
# 2042:	learn: 0.0209050	test: 0.0208388	best: 0.0208388 (2042)	total: 1m 59s	remaining: 4m 32s
# 2043:	learn: 0.0209050	test: 0.0208388	best: 0.0208388 (2042)	total: 1m 59s	remaining: 4m 32s
# 2044:	learn: 0.0209049	test: 0.0208388	best: 0.0208388 (2042)	total: 1m 59s	remaining: 4m 32s
# 2045:	learn: 0.0209049	test: 0.0208387	best: 0.0208387 (2045)	total: 1m 59s	remaining: 4m 32s
# 2046:	learn: 0.0209048	test: 0.0208387	best: 0.0208387 (2046)	total: 1m 59s	remaining: 4m 32s
# 2047:	learn: 0.0209048	test: 0.0208387	best: 0.0208387 (2047)	total: 1m 59s	remaining: 4m 32s
# 2048:	learn: 0.0209047	test: 0.0208386	best: 0.0208386 (2048)	total: 1m 59s	remaining: 4m 31s
# 2049:	learn: 0.0209047	test: 0.0208386	best: 0.0208386 (2049)	total: 1m 59s	remaining: 4m 31s
# 2050:	learn: 0.0209047	test: 0.0208386	best: 0.0208386 (2049)	total: 1m 59s	remaining: 4m 31s
# 2051:	learn: 0.0209046	test: 0.0208385	best: 0.0208385 (2051)	total: 1m 59s	remaining: 4m 31s
# 2052:	learn: 0.0209046	test: 0.0208384	best: 0.0208384 (2052)	total: 1m 59s	remaining: 4m 31s
# 2053:	learn: 0.0209045	test: 0.0208384	best: 0.0208384 (2053)	total: 2m	remaining: 4m 31s
# 2054:	learn: 0.0209045	test: 0.0208384	best: 0.0208384 (2053)	total: 2m	remaining: 4m 31s
# 2055:	learn: 0.0209044	test: 0.0208383	best: 0.0208383 (2055)	total: 2m	remaining: 4m 31s
# 2056:	learn: 0.0209044	test: 0.0208383	best: 0.0208383 (2055)	total: 2m	remaining: 4m 31s
# 2057:	learn: 0.0209043	test: 0.0208382	best: 0.0208382 (2057)	total: 2m	remaining: 4m 31s
# 2058:	learn: 0.0209043	test: 0.0208381	best: 0.0208381 (2058)	total: 2m	remaining: 4m 31s
# 2059:	learn: 0.0209042	test: 0.0208380	best: 0.0208380 (2059)	total: 2m	remaining: 4m 31s
# 2060:	learn: 0.0209042	test: 0.0208380	best: 0.0208380 (2060)	total: 2m	remaining: 4m 31s
# 2061:	learn: 0.0209041	test: 0.0208379	best: 0.0208379 (2061)	total: 2m	remaining: 4m 31s
# 2062:	learn: 0.0209041	test: 0.0208379	best: 0.0208379 (2062)	total: 2m	remaining: 4m 30s
# 2063:	learn: 0.0209040	test: 0.0208378	best: 0.0208378 (2063)	total: 2m	remaining: 4m 30s
# 2064:	learn: 0.0209040	test: 0.0208378	best: 0.0208378 (2063)	total: 2m	remaining: 4m 30s
# 2065:	learn: 0.0209039	test: 0.0208378	best: 0.0208378 (2063)	total: 2m	remaining: 4m 30s
# 2066:	learn: 0.0209039	test: 0.0208378	best: 0.0208378 (2066)	total: 2m	remaining: 4m 30s
# 2067:	learn: 0.0209038	test: 0.0208377	best: 0.0208377 (2067)	total: 2m	remaining: 4m 30s
# 2068:	learn: 0.0209038	test: 0.0208377	best: 0.0208377 (2068)	total: 2m	remaining: 4m 30s
# 2069:	learn: 0.0209037	test: 0.0208376	best: 0.0208376 (2069)	total: 2m	remaining: 4m 30s
# 2070:	learn: 0.0209037	test: 0.0208376	best: 0.0208376 (2070)	total: 2m	remaining: 4m 30s
# 2071:	learn: 0.0209037	test: 0.0208375	best: 0.0208375 (2071)	total: 2m	remaining: 4m 30s
# 2072:	learn: 0.0209036	test: 0.0208375	best: 0.0208375 (2071)	total: 2m 1s	remaining: 4m 30s
# 2073:	learn: 0.0209036	test: 0.0208374	best: 0.0208374 (2073)	total: 2m 1s	remaining: 4m 30s
# 2074:	learn: 0.0209036	test: 0.0208373	best: 0.0208373 (2074)	total: 2m 1s	remaining: 4m 30s
# 2075:	learn: 0.0209035	test: 0.0208373	best: 0.0208373 (2075)	total: 2m 1s	remaining: 4m 30s
# 2076:	learn: 0.0209035	test: 0.0208373	best: 0.0208373 (2076)	total: 2m 1s	remaining: 4m 29s
# 2077:	learn: 0.0209034	test: 0.0208373	best: 0.0208373 (2077)	total: 2m 1s	remaining: 4m 29s
# 2078:	learn: 0.0209034	test: 0.0208372	best: 0.0208372 (2078)	total: 2m 1s	remaining: 4m 29s
# 2079:	learn: 0.0209033	test: 0.0208372	best: 0.0208372 (2079)	total: 2m 1s	remaining: 4m 29s
# 2080:	learn: 0.0209033	test: 0.0208372	best: 0.0208372 (2080)	total: 2m 1s	remaining: 4m 29s
# 2081:	learn: 0.0209033	test: 0.0208371	best: 0.0208371 (2081)	total: 2m 1s	remaining: 4m 29s
# 2082:	learn: 0.0209032	test: 0.0208371	best: 0.0208371 (2082)	total: 2m 1s	remaining: 4m 29s
# 2083:	learn: 0.0209032	test: 0.0208370	best: 0.0208370 (2083)	total: 2m 1s	remaining: 4m 29s
# 2084:	learn: 0.0209031	test: 0.0208370	best: 0.0208370 (2084)	total: 2m 1s	remaining: 4m 29s
# 2085:	learn: 0.0209031	test: 0.0208370	best: 0.0208370 (2084)	total: 2m 1s	remaining: 4m 29s
# 2086:	learn: 0.0209030	test: 0.0208369	best: 0.0208369 (2086)	total: 2m 1s	remaining: 4m 29s
# 2087:	learn: 0.0209030	test: 0.0208369	best: 0.0208369 (2087)	total: 2m 1s	remaining: 4m 29s
# 2088:	learn: 0.0209029	test: 0.0208368	best: 0.0208368 (2088)	total: 2m 1s	remaining: 4m 29s
# 2089:	learn: 0.0209029	test: 0.0208368	best: 0.0208368 (2088)	total: 2m 1s	remaining: 4m 29s
# 2090:	learn: 0.0209029	test: 0.0208368	best: 0.0208368 (2090)	total: 2m 1s	remaining: 4m 29s
# 2091:	learn: 0.0209028	test: 0.0208367	best: 0.0208367 (2091)	total: 2m 2s	remaining: 4m 28s
# 2092:	learn: 0.0209028	test: 0.0208367	best: 0.0208367 (2091)	total: 2m 2s	remaining: 4m 28s
# 2093:	learn: 0.0209027	test: 0.0208366	best: 0.0208366 (2093)	total: 2m 2s	remaining: 4m 28s
# 2094:	learn: 0.0209027	test: 0.0208366	best: 0.0208366 (2094)	total: 2m 2s	remaining: 4m 28s
# 2095:	learn: 0.0209026	test: 0.0208366	best: 0.0208366 (2095)	total: 2m 2s	remaining: 4m 28s
# 2096:	learn: 0.0209026	test: 0.0208365	best: 0.0208365 (2096)	total: 2m 2s	remaining: 4m 28s
# 2097:	learn: 0.0209025	test: 0.0208366	best: 0.0208365 (2096)	total: 2m 2s	remaining: 4m 28s
# 2098:	learn: 0.0209025	test: 0.0208365	best: 0.0208365 (2098)	total: 2m 2s	remaining: 4m 28s
# 2099:	learn: 0.0209024	test: 0.0208363	best: 0.0208363 (2099)	total: 2m 2s	remaining: 4m 28s
# 2100:	learn: 0.0209024	test: 0.0208363	best: 0.0208363 (2099)	total: 2m 2s	remaining: 4m 28s
# 2101:	learn: 0.0209024	test: 0.0208363	best: 0.0208363 (2101)	total: 2m 2s	remaining: 4m 28s
# 2102:	learn: 0.0209023	test: 0.0208363	best: 0.0208363 (2101)	total: 2m 2s	remaining: 4m 28s
# 2103:	learn: 0.0209023	test: 0.0208362	best: 0.0208362 (2103)	total: 2m 2s	remaining: 4m 28s
# 2104:	learn: 0.0209022	test: 0.0208361	best: 0.0208361 (2104)	total: 2m 2s	remaining: 4m 27s
# 2105:	learn: 0.0209022	test: 0.0208361	best: 0.0208361 (2104)	total: 2m 2s	remaining: 4m 27s
# 2106:	learn: 0.0209021	test: 0.0208360	best: 0.0208360 (2106)	total: 2m 2s	remaining: 4m 27s
# 2107:	learn: 0.0209021	test: 0.0208360	best: 0.0208360 (2106)	total: 2m 2s	remaining: 4m 27s
# 2108:	learn: 0.0209020	test: 0.0208360	best: 0.0208360 (2108)	total: 2m 2s	remaining: 4m 27s
# 2109:	learn: 0.0209020	test: 0.0208359	best: 0.0208359 (2109)	total: 2m 2s	remaining: 4m 27s
# 2110:	learn: 0.0209019	test: 0.0208358	best: 0.0208358 (2110)	total: 2m 3s	remaining: 4m 27s
# 2111:	learn: 0.0209019	test: 0.0208358	best: 0.0208358 (2110)	total: 2m 3s	remaining: 4m 27s
# 2112:	learn: 0.0209018	test: 0.0208358	best: 0.0208358 (2112)	total: 2m 3s	remaining: 4m 27s
# 2113:	learn: 0.0209018	test: 0.0208357	best: 0.0208357 (2113)	total: 2m 3s	remaining: 4m 27s
# 2114:	learn: 0.0209018	test: 0.0208357	best: 0.0208357 (2114)	total: 2m 3s	remaining: 4m 27s
# 2115:	learn: 0.0209017	test: 0.0208356	best: 0.0208356 (2115)	total: 2m 3s	remaining: 4m 27s
# 2116:	learn: 0.0209017	test: 0.0208355	best: 0.0208355 (2116)	total: 2m 3s	remaining: 4m 27s
# 2117:	learn: 0.0209016	test: 0.0208355	best: 0.0208355 (2117)	total: 2m 3s	remaining: 4m 27s
# 2118:	learn: 0.0209016	test: 0.0208356	best: 0.0208355 (2117)	total: 2m 3s	remaining: 4m 27s
# 2119:	learn: 0.0209015	test: 0.0208355	best: 0.0208355 (2119)	total: 2m 3s	remaining: 4m 26s
# 2120:	learn: 0.0209015	test: 0.0208354	best: 0.0208354 (2120)	total: 2m 3s	remaining: 4m 26s
# 2121:	learn: 0.0209014	test: 0.0208354	best: 0.0208354 (2121)	total: 2m 3s	remaining: 4m 26s
# 2122:	learn: 0.0209014	test: 0.0208354	best: 0.0208354 (2121)	total: 2m 3s	remaining: 4m 26s
# 2123:	learn: 0.0209013	test: 0.0208354	best: 0.0208354 (2123)	total: 2m 3s	remaining: 4m 26s
# 2124:	learn: 0.0209013	test: 0.0208353	best: 0.0208353 (2124)	total: 2m 3s	remaining: 4m 26s
# 2125:	learn: 0.0209013	test: 0.0208353	best: 0.0208353 (2124)	total: 2m 3s	remaining: 4m 26s
# 2126:	learn: 0.0209013	test: 0.0208352	best: 0.0208352 (2126)	total: 2m 3s	remaining: 4m 26s
# 2127:	learn: 0.0209012	test: 0.0208352	best: 0.0208352 (2127)	total: 2m 3s	remaining: 4m 26s
# 2128:	learn: 0.0209012	test: 0.0208352	best: 0.0208352 (2128)	total: 2m 3s	remaining: 4m 26s
# 2129:	learn: 0.0209011	test: 0.0208351	best: 0.0208351 (2129)	total: 2m 4s	remaining: 4m 26s
# 2130:	learn: 0.0209011	test: 0.0208351	best: 0.0208351 (2130)	total: 2m 4s	remaining: 4m 26s
# 2131:	learn: 0.0209010	test: 0.0208351	best: 0.0208351 (2130)	total: 2m 4s	remaining: 4m 26s
# 2132:	learn: 0.0209009	test: 0.0208350	best: 0.0208350 (2132)	total: 2m 4s	remaining: 4m 26s
# 2133:	learn: 0.0209009	test: 0.0208349	best: 0.0208349 (2133)	total: 2m 4s	remaining: 4m 26s
# 2134:	learn: 0.0209008	test: 0.0208349	best: 0.0208349 (2134)	total: 2m 4s	remaining: 4m 26s
# 2135:	learn: 0.0209008	test: 0.0208348	best: 0.0208348 (2135)	total: 2m 4s	remaining: 4m 26s
# 2136:	learn: 0.0209008	test: 0.0208347	best: 0.0208347 (2136)	total: 2m 4s	remaining: 4m 26s
# 2137:	learn: 0.0209007	test: 0.0208347	best: 0.0208347 (2136)	total: 2m 4s	remaining: 4m 26s
# 2138:	learn: 0.0209007	test: 0.0208347	best: 0.0208347 (2138)	total: 2m 4s	remaining: 4m 26s
# 2139:	learn: 0.0209006	test: 0.0208346	best: 0.0208346 (2139)	total: 2m 4s	remaining: 4m 26s
# 2140:	learn: 0.0209006	test: 0.0208346	best: 0.0208346 (2140)	total: 2m 5s	remaining: 4m 26s
# 2141:	learn: 0.0209005	test: 0.0208345	best: 0.0208345 (2141)	total: 2m 5s	remaining: 4m 26s
# 2142:	learn: 0.0209005	test: 0.0208345	best: 0.0208345 (2142)	total: 2m 5s	remaining: 4m 26s
# 2143:	learn: 0.0209005	test: 0.0208344	best: 0.0208344 (2143)	total: 2m 5s	remaining: 4m 26s
# 2144:	learn: 0.0209004	test: 0.0208344	best: 0.0208344 (2144)	total: 2m 5s	remaining: 4m 26s
# 2145:	learn: 0.0209004	test: 0.0208343	best: 0.0208343 (2145)	total: 2m 5s	remaining: 4m 26s
# 2146:	learn: 0.0209004	test: 0.0208343	best: 0.0208343 (2146)	total: 2m 5s	remaining: 4m 26s
# 2147:	learn: 0.0209003	test: 0.0208343	best: 0.0208343 (2146)	total: 2m 5s	remaining: 4m 26s
# 2148:	learn: 0.0209003	test: 0.0208343	best: 0.0208343 (2146)	total: 2m 5s	remaining: 4m 26s
# 2149:	learn: 0.0209002	test: 0.0208342	best: 0.0208342 (2149)	total: 2m 5s	remaining: 4m 26s
# 2150:	learn: 0.0209002	test: 0.0208342	best: 0.0208342 (2150)	total: 2m 5s	remaining: 4m 26s
# 2151:	learn: 0.0209001	test: 0.0208341	best: 0.0208341 (2151)	total: 2m 6s	remaining: 4m 26s
# 2152:	learn: 0.0209001	test: 0.0208341	best: 0.0208341 (2152)	total: 2m 6s	remaining: 4m 26s
# 2153:	learn: 0.0209000	test: 0.0208341	best: 0.0208341 (2152)	total: 2m 6s	remaining: 4m 26s
# 2154:	learn: 0.0209000	test: 0.0208340	best: 0.0208340 (2154)	total: 2m 6s	remaining: 4m 26s
# 2155:	learn: 0.0209000	test: 0.0208340	best: 0.0208340 (2154)	total: 2m 6s	remaining: 4m 26s
# 2156:	learn: 0.0208999	test: 0.0208339	best: 0.0208339 (2156)	total: 2m 6s	remaining: 4m 26s
# 2157:	learn: 0.0208999	test: 0.0208338	best: 0.0208338 (2157)	total: 2m 6s	remaining: 4m 26s
# 2158:	learn: 0.0208998	test: 0.0208338	best: 0.0208338 (2158)	total: 2m 6s	remaining: 4m 26s
# 2159:	learn: 0.0208998	test: 0.0208337	best: 0.0208337 (2159)	total: 2m 6s	remaining: 4m 26s
# 2160:	learn: 0.0208997	test: 0.0208337	best: 0.0208337 (2159)	total: 2m 6s	remaining: 4m 26s
# 2161:	learn: 0.0208997	test: 0.0208336	best: 0.0208336 (2161)	total: 2m 7s	remaining: 4m 26s
# 2162:	learn: 0.0208996	test: 0.0208336	best: 0.0208336 (2162)	total: 2m 7s	remaining: 4m 26s
# 2163:	learn: 0.0208996	test: 0.0208335	best: 0.0208335 (2163)	total: 2m 7s	remaining: 4m 26s
# 2164:	learn: 0.0208996	test: 0.0208335	best: 0.0208335 (2163)	total: 2m 7s	remaining: 4m 26s
# 2165:	learn: 0.0208995	test: 0.0208335	best: 0.0208335 (2165)	total: 2m 7s	remaining: 4m 26s
# 2166:	learn: 0.0208995	test: 0.0208334	best: 0.0208334 (2166)	total: 2m 7s	remaining: 4m 26s
# 2167:	learn: 0.0208994	test: 0.0208333	best: 0.0208333 (2167)	total: 2m 7s	remaining: 4m 26s
# 2168:	learn: 0.0208994	test: 0.0208333	best: 0.0208333 (2167)	total: 2m 7s	remaining: 4m 26s
# 2169:	learn: 0.0208993	test: 0.0208333	best: 0.0208333 (2167)	total: 2m 7s	remaining: 4m 26s
# 2170:	learn: 0.0208993	test: 0.0208332	best: 0.0208332 (2170)	total: 2m 7s	remaining: 4m 26s
# 2171:	learn: 0.0208992	test: 0.0208332	best: 0.0208332 (2171)	total: 2m 7s	remaining: 4m 26s
# 2172:	learn: 0.0208992	test: 0.0208332	best: 0.0208332 (2172)	total: 2m 7s	remaining: 4m 26s
# 2173:	learn: 0.0208992	test: 0.0208331	best: 0.0208331 (2173)	total: 2m 7s	remaining: 4m 26s
# 2174:	learn: 0.0208991	test: 0.0208330	best: 0.0208330 (2174)	total: 2m 7s	remaining: 4m 26s
# 2175:	learn: 0.0208991	test: 0.0208330	best: 0.0208330 (2175)	total: 2m 7s	remaining: 4m 26s
# 2176:	learn: 0.0208990	test: 0.0208330	best: 0.0208330 (2176)	total: 2m 7s	remaining: 4m 26s
# 2177:	learn: 0.0208990	test: 0.0208329	best: 0.0208329 (2177)	total: 2m 8s	remaining: 4m 25s
# 2178:	learn: 0.0208989	test: 0.0208329	best: 0.0208329 (2178)	total: 2m 8s	remaining: 4m 25s
# 2179:	learn: 0.0208989	test: 0.0208328	best: 0.0208328 (2179)	total: 2m 8s	remaining: 4m 25s
# 2180:	learn: 0.0208989	test: 0.0208328	best: 0.0208328 (2180)	total: 2m 8s	remaining: 4m 25s
# 2181:	learn: 0.0208988	test: 0.0208328	best: 0.0208328 (2181)	total: 2m 8s	remaining: 4m 25s
# 2182:	learn: 0.0208988	test: 0.0208327	best: 0.0208327 (2182)	total: 2m 8s	remaining: 4m 25s
# 2183:	learn: 0.0208987	test: 0.0208327	best: 0.0208327 (2183)	total: 2m 8s	remaining: 4m 25s
# 2184:	learn: 0.0208987	test: 0.0208326	best: 0.0208326 (2184)	total: 2m 8s	remaining: 4m 25s
# 2185:	learn: 0.0208986	test: 0.0208326	best: 0.0208326 (2185)	total: 2m 8s	remaining: 4m 25s
# 2186:	learn: 0.0208986	test: 0.0208326	best: 0.0208326 (2186)	total: 2m 8s	remaining: 4m 25s
# 2187:	learn: 0.0208986	test: 0.0208325	best: 0.0208325 (2187)	total: 2m 8s	remaining: 4m 25s
# 2188:	learn: 0.0208985	test: 0.0208325	best: 0.0208325 (2187)	total: 2m 8s	remaining: 4m 25s
# 2189:	learn: 0.0208985	test: 0.0208325	best: 0.0208325 (2189)	total: 2m 8s	remaining: 4m 25s
# 2190:	learn: 0.0208984	test: 0.0208324	best: 0.0208324 (2190)	total: 2m 8s	remaining: 4m 25s
# 2191:	learn: 0.0208984	test: 0.0208323	best: 0.0208323 (2191)	total: 2m 8s	remaining: 4m 24s
# 2192:	learn: 0.0208983	test: 0.0208324	best: 0.0208323 (2191)	total: 2m 8s	remaining: 4m 24s
# 2193:	learn: 0.0208983	test: 0.0208323	best: 0.0208323 (2193)	total: 2m 8s	remaining: 4m 24s
# 2194:	learn: 0.0208983	test: 0.0208323	best: 0.0208323 (2193)	total: 2m 8s	remaining: 4m 24s
# 2195:	learn: 0.0208982	test: 0.0208322	best: 0.0208322 (2195)	total: 2m 8s	remaining: 4m 24s
# 2196:	learn: 0.0208982	test: 0.0208322	best: 0.0208322 (2196)	total: 2m 9s	remaining: 4m 24s
# 2197:	learn: 0.0208981	test: 0.0208321	best: 0.0208321 (2197)	total: 2m 9s	remaining: 4m 24s
# 2198:	learn: 0.0208981	test: 0.0208320	best: 0.0208320 (2198)	total: 2m 9s	remaining: 4m 24s
# 2199:	learn: 0.0208980	test: 0.0208320	best: 0.0208320 (2198)	total: 2m 9s	remaining: 4m 24s
# 2200:	learn: 0.0208980	test: 0.0208320	best: 0.0208320 (2200)	total: 2m 9s	remaining: 4m 24s
# 2201:	learn: 0.0208980	test: 0.0208319	best: 0.0208319 (2201)	total: 2m 9s	remaining: 4m 24s
# 2202:	learn: 0.0208979	test: 0.0208319	best: 0.0208319 (2202)	total: 2m 9s	remaining: 4m 24s
# 2203:	learn: 0.0208979	test: 0.0208318	best: 0.0208318 (2203)	total: 2m 9s	remaining: 4m 24s
# 2204:	learn: 0.0208978	test: 0.0208318	best: 0.0208318 (2204)	total: 2m 9s	remaining: 4m 24s
# 2205:	learn: 0.0208978	test: 0.0208317	best: 0.0208317 (2205)	total: 2m 9s	remaining: 4m 23s
# 2206:	learn: 0.0208978	test: 0.0208317	best: 0.0208317 (2206)	total: 2m 9s	remaining: 4m 23s
# 2207:	learn: 0.0208977	test: 0.0208316	best: 0.0208316 (2207)	total: 2m 9s	remaining: 4m 23s
# 2208:	learn: 0.0208977	test: 0.0208316	best: 0.0208316 (2208)	total: 2m 9s	remaining: 4m 23s
# 2209:	learn: 0.0208976	test: 0.0208315	best: 0.0208315 (2209)	total: 2m 9s	remaining: 4m 23s
# 2210:	learn: 0.0208976	test: 0.0208315	best: 0.0208315 (2210)	total: 2m 9s	remaining: 4m 23s
# 2211:	learn: 0.0208975	test: 0.0208315	best: 0.0208315 (2210)	total: 2m 9s	remaining: 4m 23s
# 2212:	learn: 0.0208975	test: 0.0208315	best: 0.0208315 (2212)	total: 2m 9s	remaining: 4m 23s
# 2213:	learn: 0.0208975	test: 0.0208313	best: 0.0208313 (2213)	total: 2m 9s	remaining: 4m 23s
# ...
# 6534:	learn: 0.0208267	test: 0.0207631	best: 0.0207631 (6533)	total: 6m 26s	remaining: 9.92s
# 6535:	learn: 0.0208267	test: 0.0207631	best: 0.0207631 (6535)	total: 6m 26s	remaining: 9.86s
# 6536:	learn: 0.0208267	test: 0.0207631	best: 0.0207631 (6535)	total: 6m 26s	remaining: 9.8s
# 6537:	learn: 0.0208267	test: 0.0207631	best: 0.0207631 (6535)	total: 6m 26s	remaining: 9.74s
# 6538:	learn: 0.0208267	test: 0.0207631	best: 0.0207631 (6538)	total: 6m 26s	remaining: 9.69s
# 6539:	learn: 0.0208267	test: 0.0207631	best: 0.0207631 (6539)	total: 6m 26s	remaining: 9.63s
# 6540:	learn: 0.0208267	test: 0.0207630	best: 0.0207630 (6540)	total: 6m 26s	remaining: 9.57s
# 6541:	learn: 0.0208266	test: 0.0207630	best: 0.0207630 (6541)	total: 6m 26s	remaining: 9.51s
# 6542:	learn: 0.0208266	test: 0.0207630	best: 0.0207630 (6541)	total: 6m 26s	remaining: 9.45s
# 6543:	learn: 0.0208266	test: 0.0207630	best: 0.0207630 (6541)	total: 6m 26s	remaining: 9.39s
# 6544:	learn: 0.0208266	test: 0.0207630	best: 0.0207630 (6544)	total: 6m 26s	remaining: 9.33s
# 6545:	learn: 0.0208266	test: 0.0207630	best: 0.0207630 (6545)	total: 6m 26s	remaining: 9.27s
# 6546:	learn: 0.0208266	test: 0.0207630	best: 0.0207630 (6546)	total: 6m 26s	remaining: 9.21s
# 6547:	learn: 0.0208266	test: 0.0207630	best: 0.0207630 (6546)	total: 6m 26s	remaining: 9.15s
# 6548:	learn: 0.0208266	test: 0.0207630	best: 0.0207630 (6546)	total: 6m 26s	remaining: 9.09s
# 6549:	learn: 0.0208266	test: 0.0207630	best: 0.0207630 (6546)	total: 6m 26s	remaining: 9.04s
# 6550:	learn: 0.0208266	test: 0.0207630	best: 0.0207630 (6550)	total: 6m 26s	remaining: 8.97s
# 6551:	learn: 0.0208266	test: 0.0207630	best: 0.0207630 (6551)	total: 6m 26s	remaining: 8.92s
# 6552:	learn: 0.0208266	test: 0.0207630	best: 0.0207630 (6551)	total: 6m 26s	remaining: 8.86s
# 6553:	learn: 0.0208266	test: 0.0207630	best: 0.0207630 (6551)	total: 6m 27s	remaining: 8.8s
# 6554:	learn: 0.0208266	test: 0.0207630	best: 0.0207630 (6551)	total: 6m 27s	remaining: 8.74s
# 6555:	learn: 0.0208266	test: 0.0207629	best: 0.0207629 (6555)	total: 6m 27s	remaining: 8.68s
# 6556:	learn: 0.0208266	test: 0.0207629	best: 0.0207629 (6555)	total: 6m 27s	remaining: 8.62s
# 6557:	learn: 0.0208266	test: 0.0207629	best: 0.0207629 (6555)	total: 6m 27s	remaining: 8.56s
# 6558:	learn: 0.0208265	test: 0.0207629	best: 0.0207629 (6555)	total: 6m 27s	remaining: 8.5s
# 6559:	learn: 0.0208265	test: 0.0207629	best: 0.0207629 (6559)	total: 6m 27s	remaining: 8.44s
# 6560:	learn: 0.0208265	test: 0.0207629	best: 0.0207629 (6560)	total: 6m 27s	remaining: 8.38s
# 6561:	learn: 0.0208265	test: 0.0207629	best: 0.0207629 (6560)	total: 6m 27s	remaining: 8.32s
# 6562:	learn: 0.0208265	test: 0.0207629	best: 0.0207629 (6560)	total: 6m 27s	remaining: 8.27s
# 6563:	learn: 0.0208265	test: 0.0207629	best: 0.0207629 (6563)	total: 6m 27s	remaining: 8.21s
# 6564:	learn: 0.0208265	test: 0.0207629	best: 0.0207629 (6563)	total: 6m 27s	remaining: 8.15s
# 6565:	learn: 0.0208265	test: 0.0207629	best: 0.0207629 (6563)	total: 6m 27s	remaining: 8.09s
# 6566:	learn: 0.0208265	test: 0.0207629	best: 0.0207629 (6566)	total: 6m 27s	remaining: 8.03s
# 6567:	learn: 0.0208265	test: 0.0207628	best: 0.0207628 (6567)	total: 6m 27s	remaining: 7.97s
# 6568:	learn: 0.0208265	test: 0.0207628	best: 0.0207628 (6567)	total: 6m 27s	remaining: 7.91s
# 6569:	learn: 0.0208265	test: 0.0207628	best: 0.0207628 (6569)	total: 6m 27s	remaining: 7.85s
# 6570:	learn: 0.0208265	test: 0.0207628	best: 0.0207628 (6569)	total: 6m 27s	remaining: 7.79s
# 6571:	learn: 0.0208265	test: 0.0207628	best: 0.0207628 (6569)	total: 6m 27s	remaining: 7.73s
# 6572:	learn: 0.0208265	test: 0.0207628	best: 0.0207628 (6569)	total: 6m 27s	remaining: 7.67s
# 6573:	learn: 0.0208265	test: 0.0207628	best: 0.0207628 (6569)	total: 6m 28s	remaining: 7.61s
# 6574:	learn: 0.0208265	test: 0.0207628	best: 0.0207628 (6574)	total: 6m 28s	remaining: 7.55s
# 6575:	learn: 0.0208265	test: 0.0207628	best: 0.0207628 (6575)	total: 6m 28s	remaining: 7.5s
# 6576:	learn: 0.0208264	test: 0.0207628	best: 0.0207628 (6576)	total: 6m 28s	remaining: 7.44s
# 6577:	learn: 0.0208264	test: 0.0207628	best: 0.0207628 (6577)	total: 6m 28s	remaining: 7.38s
# 6578:	learn: 0.0208264	test: 0.0207628	best: 0.0207628 (6577)	total: 6m 28s	remaining: 7.32s
# 6579:	learn: 0.0208264	test: 0.0207628	best: 0.0207628 (6577)	total: 6m 28s	remaining: 7.26s
# 6580:	learn: 0.0208264	test: 0.0207628	best: 0.0207628 (6580)	total: 6m 28s	remaining: 7.2s
# 6581:	learn: 0.0208264	test: 0.0207628	best: 0.0207628 (6581)	total: 6m 28s	remaining: 7.14s
# 6582:	learn: 0.0208264	test: 0.0207628	best: 0.0207628 (6582)	total: 6m 28s	remaining: 7.08s
# 6583:	learn: 0.0208264	test: 0.0207628	best: 0.0207628 (6583)	total: 6m 28s	remaining: 7.02s
# 6584:	learn: 0.0208264	test: 0.0207627	best: 0.0207627 (6584)	total: 6m 28s	remaining: 6.96s
# 6585:	learn: 0.0208264	test: 0.0207627	best: 0.0207627 (6584)	total: 6m 28s	remaining: 6.9s
# 6586:	learn: 0.0208264	test: 0.0207627	best: 0.0207627 (6584)	total: 6m 28s	remaining: 6.84s
# 6587:	learn: 0.0208264	test: 0.0207627	best: 0.0207627 (6584)	total: 6m 28s	remaining: 6.79s
# 6588:	learn: 0.0208264	test: 0.0207627	best: 0.0207627 (6588)	total: 6m 28s	remaining: 6.73s
# 6589:	learn: 0.0208264	test: 0.0207627	best: 0.0207627 (6589)	total: 6m 28s	remaining: 6.67s
# 6590:	learn: 0.0208264	test: 0.0207627	best: 0.0207627 (6589)	total: 6m 28s	remaining: 6.61s
# 6591:	learn: 0.0208263	test: 0.0207627	best: 0.0207627 (6589)	total: 6m 28s	remaining: 6.55s
# 6592:	learn: 0.0208263	test: 0.0207627	best: 0.0207627 (6592)	total: 6m 29s	remaining: 6.49s
# 6593:	learn: 0.0208263	test: 0.0207627	best: 0.0207627 (6592)	total: 6m 29s	remaining: 6.43s
# 6594:	learn: 0.0208263	test: 0.0207626	best: 0.0207626 (6594)	total: 6m 29s	remaining: 6.37s
# 6595:	learn: 0.0208263	test: 0.0207626	best: 0.0207626 (6595)	total: 6m 29s	remaining: 6.31s
# 6596:	learn: 0.0208263	test: 0.0207626	best: 0.0207626 (6596)	total: 6m 29s	remaining: 6.25s
# 6597:	learn: 0.0208263	test: 0.0207626	best: 0.0207626 (6596)	total: 6m 29s	remaining: 6.2s
# 6598:	learn: 0.0208263	test: 0.0207627	best: 0.0207626 (6596)	total: 6m 29s	remaining: 6.14s
# 6599:	learn: 0.0208263	test: 0.0207626	best: 0.0207626 (6596)	total: 6m 29s	remaining: 6.08s
# 6600:	learn: 0.0208263	test: 0.0207626	best: 0.0207626 (6596)	total: 6m 29s	remaining: 6.02s
# 6601:	learn: 0.0208263	test: 0.0207626	best: 0.0207626 (6601)	total: 6m 29s	remaining: 5.96s
# 6602:	learn: 0.0208263	test: 0.0207626	best: 0.0207626 (6602)	total: 6m 29s	remaining: 5.9s
# 6603:	learn: 0.0208263	test: 0.0207626	best: 0.0207626 (6603)	total: 6m 29s	remaining: 5.84s
# 6604:	learn: 0.0208263	test: 0.0207626	best: 0.0207626 (6604)	total: 6m 29s	remaining: 5.78s
# 6605:	learn: 0.0208263	test: 0.0207626	best: 0.0207626 (6605)	total: 6m 29s	remaining: 5.72s
# 6606:	learn: 0.0208263	test: 0.0207626	best: 0.0207626 (6606)	total: 6m 29s	remaining: 5.66s
# 6607:	learn: 0.0208263	test: 0.0207626	best: 0.0207626 (6606)	total: 6m 29s	remaining: 5.6s
# 6608:	learn: 0.0208262	test: 0.0207626	best: 0.0207626 (6606)	total: 6m 29s	remaining: 5.54s
# 6609:	learn: 0.0208262	test: 0.0207626	best: 0.0207626 (6606)	total: 6m 29s	remaining: 5.49s
# 6610:	learn: 0.0208262	test: 0.0207626	best: 0.0207626 (6606)	total: 6m 29s	remaining: 5.43s
# 6611:	learn: 0.0208262	test: 0.0207626	best: 0.0207626 (6606)	total: 6m 30s	remaining: 5.37s
# 6612:	learn: 0.0208262	test: 0.0207626	best: 0.0207626 (6606)	total: 6m 30s	remaining: 5.31s
# 6613:	learn: 0.0208262	test: 0.0207626	best: 0.0207626 (6606)	total: 6m 30s	remaining: 5.25s
# 6614:	learn: 0.0208262	test: 0.0207626	best: 0.0207626 (6614)	total: 6m 30s	remaining: 5.19s
# 6615:	learn: 0.0208262	test: 0.0207626	best: 0.0207626 (6615)	total: 6m 30s	remaining: 5.13s
# 6616:	learn: 0.0208262	test: 0.0207625	best: 0.0207625 (6616)	total: 6m 30s	remaining: 5.07s
# 6617:	learn: 0.0208262	test: 0.0207625	best: 0.0207625 (6616)	total: 6m 30s	remaining: 5.01s
# 6618:	learn: 0.0208262	test: 0.0207625	best: 0.0207625 (6618)	total: 6m 30s	remaining: 4.95s
# 6619:	learn: 0.0208262	test: 0.0207625	best: 0.0207625 (6619)	total: 6m 30s	remaining: 4.89s
# 6620:	learn: 0.0208262	test: 0.0207625	best: 0.0207625 (6620)	total: 6m 30s	remaining: 4.84s
# 6621:	learn: 0.0208262	test: 0.0207625	best: 0.0207625 (6621)	total: 6m 30s	remaining: 4.78s
# 6622:	learn: 0.0208262	test: 0.0207625	best: 0.0207625 (6622)	total: 6m 30s	remaining: 4.72s
# 6623:	learn: 0.0208262	test: 0.0207625	best: 0.0207625 (6623)	total: 6m 30s	remaining: 4.66s
# 6624:	learn: 0.0208262	test: 0.0207625	best: 0.0207625 (6624)	total: 6m 30s	remaining: 4.6s
# 6625:	learn: 0.0208262	test: 0.0207625	best: 0.0207625 (6624)	total: 6m 30s	remaining: 4.54s
# 6626:	learn: 0.0208262	test: 0.0207625	best: 0.0207625 (6626)	total: 6m 30s	remaining: 4.48s
# 6627:	learn: 0.0208261	test: 0.0207624	best: 0.0207624 (6627)	total: 6m 30s	remaining: 4.42s
# 6628:	learn: 0.0208261	test: 0.0207625	best: 0.0207624 (6627)	total: 6m 30s	remaining: 4.36s
# 6629:	learn: 0.0208261	test: 0.0207625	best: 0.0207624 (6627)	total: 6m 30s	remaining: 4.3s
# 6630:	learn: 0.0208261	test: 0.0207625	best: 0.0207624 (6627)	total: 6m 31s	remaining: 4.25s
# 6631:	learn: 0.0208261	test: 0.0207625	best: 0.0207624 (6627)	total: 6m 31s	remaining: 4.19s
# 6632:	learn: 0.0208261	test: 0.0207625	best: 0.0207624 (6627)	total: 6m 31s	remaining: 4.13s
# 6633:	learn: 0.0208261	test: 0.0207624	best: 0.0207624 (6633)	total: 6m 31s	remaining: 4.07s
# 6634:	learn: 0.0208261	test: 0.0207624	best: 0.0207624 (6634)	total: 6m 31s	remaining: 4.01s
# 6635:	learn: 0.0208261	test: 0.0207624	best: 0.0207624 (6634)	total: 6m 31s	remaining: 3.95s
# 6636:	learn: 0.0208261	test: 0.0207624	best: 0.0207624 (6634)	total: 6m 31s	remaining: 3.89s
# 6637:	learn: 0.0208261	test: 0.0207624	best: 0.0207624 (6634)	total: 6m 31s	remaining: 3.83s
# 6638:	learn: 0.0208261	test: 0.0207624	best: 0.0207624 (6634)	total: 6m 31s	remaining: 3.78s
# 6639:	learn: 0.0208261	test: 0.0207624	best: 0.0207624 (6634)	total: 6m 31s	remaining: 3.72s
# 6640:	learn: 0.0208261	test: 0.0207624	best: 0.0207624 (6634)	total: 6m 31s	remaining: 3.66s
# 6641:	learn: 0.0208261	test: 0.0207624	best: 0.0207624 (6634)	total: 6m 32s	remaining: 3.6s
# 6642:	learn: 0.0208261	test: 0.0207624	best: 0.0207624 (6634)	total: 6m 32s	remaining: 3.54s
# 6643:	learn: 0.0208261	test: 0.0207624	best: 0.0207624 (6643)	total: 6m 32s	remaining: 3.48s
# 6644:	learn: 0.0208261	test: 0.0207624	best: 0.0207624 (6644)	total: 6m 32s	remaining: 3.42s
# 6645:	learn: 0.0208260	test: 0.0207623	best: 0.0207623 (6645)	total: 6m 32s	remaining: 3.37s
# 6646:	learn: 0.0208260	test: 0.0207623	best: 0.0207623 (6645)	total: 6m 32s	remaining: 3.31s
# 6647:	learn: 0.0208260	test: 0.0207624	best: 0.0207623 (6645)	total: 6m 32s	remaining: 3.25s
# 6648:	learn: 0.0208260	test: 0.0207624	best: 0.0207623 (6645)	total: 6m 32s	remaining: 3.19s
# 6649:	learn: 0.0208260	test: 0.0207624	best: 0.0207623 (6645)	total: 6m 32s	remaining: 3.13s
# 6650:	learn: 0.0208260	test: 0.0207623	best: 0.0207623 (6650)	total: 6m 32s	remaining: 3.07s
# 6651:	learn: 0.0208260	test: 0.0207623	best: 0.0207623 (6651)	total: 6m 32s	remaining: 3.01s
# 6652:	learn: 0.0208260	test: 0.0207623	best: 0.0207623 (6651)	total: 6m 33s	remaining: 2.95s
# 6653:	learn: 0.0208260	test: 0.0207623	best: 0.0207623 (6651)	total: 6m 33s	remaining: 2.89s
# 6654:	learn: 0.0208260	test: 0.0207623	best: 0.0207623 (6651)	total: 6m 33s	remaining: 2.84s
# 6655:	learn: 0.0208260	test: 0.0207623	best: 0.0207623 (6651)	total: 6m 33s	remaining: 2.78s
# 6656:	learn: 0.0208260	test: 0.0207623	best: 0.0207623 (6651)	total: 6m 33s	remaining: 2.72s
# 6657:	learn: 0.0208260	test: 0.0207623	best: 0.0207623 (6657)	total: 6m 33s	remaining: 2.66s
# 6658:	learn: 0.0208260	test: 0.0207623	best: 0.0207623 (6658)	total: 6m 33s	remaining: 2.6s
# 6659:	learn: 0.0208260	test: 0.0207623	best: 0.0207623 (6659)	total: 6m 33s	remaining: 2.54s
# 6660:	learn: 0.0208260	test: 0.0207623	best: 0.0207623 (6659)	total: 6m 33s	remaining: 2.48s
# 6661:	learn: 0.0208259	test: 0.0207623	best: 0.0207623 (6659)	total: 6m 33s	remaining: 2.42s
# 6662:	learn: 0.0208259	test: 0.0207623	best: 0.0207623 (6659)	total: 6m 33s	remaining: 2.37s
# 6663:	learn: 0.0208259	test: 0.0207623	best: 0.0207623 (6663)	total: 6m 34s	remaining: 2.31s
# 6664:	learn: 0.0208259	test: 0.0207623	best: 0.0207623 (6664)	total: 6m 34s	remaining: 2.25s
# 6665:	learn: 0.0208259	test: 0.0207623	best: 0.0207623 (6664)	total: 6m 34s	remaining: 2.19s
# 6666:	learn: 0.0208259	test: 0.0207623	best: 0.0207623 (6664)	total: 6m 34s	remaining: 2.13s
# 6667:	learn: 0.0208259	test: 0.0207622	best: 0.0207622 (6667)	total: 6m 34s	remaining: 2.07s
# 6668:	learn: 0.0208259	test: 0.0207622	best: 0.0207622 (6667)	total: 6m 34s	remaining: 2.01s
# 6669:	learn: 0.0208259	test: 0.0207622	best: 0.0207622 (6667)	total: 6m 34s	remaining: 1.95s
# 6670:	learn: 0.0208259	test: 0.0207622	best: 0.0207622 (6667)	total: 6m 34s	remaining: 1.89s
# 6671:	learn: 0.0208259	test: 0.0207623	best: 0.0207622 (6667)	total: 6m 34s	remaining: 1.83s
# 6672:	learn: 0.0208259	test: 0.0207622	best: 0.0207622 (6667)	total: 6m 34s	remaining: 1.77s
# 6673:	learn: 0.0208259	test: 0.0207622	best: 0.0207622 (6667)	total: 6m 34s	remaining: 1.72s
# 6674:	learn: 0.0208259	test: 0.0207622	best: 0.0207622 (6667)	total: 6m 34s	remaining: 1.66s
# 6675:	learn: 0.0208259	test: 0.0207622	best: 0.0207622 (6675)	total: 6m 34s	remaining: 1.6s
# 6676:	learn: 0.0208259	test: 0.0207622	best: 0.0207622 (6676)	total: 6m 34s	remaining: 1.54s
# 6677:	learn: 0.0208259	test: 0.0207622	best: 0.0207622 (6677)	total: 6m 34s	remaining: 1.48s
# 6678:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6678)	total: 6m 35s	remaining: 1.42s
# 6679:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6678)	total: 6m 35s	remaining: 1.36s
# 6680:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6678)	total: 6m 35s	remaining: 1.3s
# 6681:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6678)	total: 6m 35s	remaining: 1.24s
# 6682:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6678)	total: 6m 35s	remaining: 1.18s
# 6683:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6678)	total: 6m 35s	remaining: 1.12s
# 6684:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6678)	total: 6m 35s	remaining: 1.06s
# 6685:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6678)	total: 6m 35s	remaining: 1s
# 6686:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6686)	total: 6m 35s	remaining: 946ms
# 6687:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6687)	total: 6m 35s	remaining: 887ms
# 6688:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6688)	total: 6m 35s	remaining: 828ms
# 6689:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6689)	total: 6m 35s	remaining: 769ms
# 6690:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6689)	total: 6m 35s	remaining: 710ms
# 6691:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6689)	total: 6m 35s	remaining: 650ms
# 6692:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6689)	total: 6m 35s	remaining: 591ms
# 6693:	learn: 0.0208258	test: 0.0207622	best: 0.0207622 (6689)	total: 6m 35s	remaining: 532ms
# 6694:	learn: 0.0208258	test: 0.0207621	best: 0.0207621 (6694)	total: 6m 35s	remaining: 473ms
# 6695:	learn: 0.0208258	test: 0.0207621	best: 0.0207621 (6695)	total: 6m 35s	remaining: 414ms
# 6696:	learn: 0.0208258	test: 0.0207621	best: 0.0207621 (6696)	total: 6m 36s	remaining: 355ms
# 6697:	learn: 0.0208258	test: 0.0207621	best: 0.0207621 (6696)	total: 6m 36s	remaining: 296ms
# 6698:	learn: 0.0208258	test: 0.0207621	best: 0.0207621 (6696)	total: 6m 36s	remaining: 237ms
# 6699:	learn: 0.0208257	test: 0.0207621	best: 0.0207621 (6696)	total: 6m 36s	remaining: 177ms
# 6700:	learn: 0.0208257	test: 0.0207621	best: 0.0207621 (6700)	total: 6m 36s	remaining: 118ms
# 6701:	learn: 0.0208257	test: 0.0207621	best: 0.0207621 (6701)	total: 6m 36s	remaining: 59.1ms
# 6702:	learn: 0.0208257	test: 0.0207621	best: 0.0207621 (6702)	total: 6m 36s	remaining: 0us
#
# bestTest = 0.02076206294
# bestIteration = 6702
# [I 2023-05-07 08:51:17,025] Trial 0 finished with value: 0.00043106325559699244 and parameters: {'learning_rate': 0.034885205571560766, 'depth': 1, 'iteration': 6703, 'l2_leaf_reg': 23}. Best is trial 0 with value: 0.00043106325559699244.

# %% [markdown]
# - 'learning_rate': 0.08078050781072783, 'depth': 14, 'iteration': 3688, 'l2_leaf_reg': 11
#
# - 'learning_rate': 0.005332517900175726, 'depth': 2, 'iteration': 3118, 'l2_leaf_reg': 24
#
# - 'learning_rate': 0.08140568960274255, 'depth': 1, 'iteration': 6703, 'l2_leaf_reg': 23
#
# - 'learning_rate': 0.034885205571560766, 'depth': 1, 'iteration': 6703, 'l2_leaf_reg': 23 (highest! 0.90, 0.86, 0.85)

# %%
model = CatBoostRegressor(learning_rate=0.034885205571560766, depth=1, iterations=6703, l2_leaf_reg=23)

model.fit(x, y)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 1703:	learn: 0.0208488	total: 1m 17s	remaining: 3m 48s
# 1704:	learn: 0.0208487	total: 1m 17s	remaining: 3m 48s
# 1705:	learn: 0.0208487	total: 1m 17s	remaining: 3m 48s
# 1706:	learn: 0.0208486	total: 1m 18s	remaining: 3m 48s
# 1707:	learn: 0.0208485	total: 1m 18s	remaining: 3m 48s
# 1708:	learn: 0.0208484	total: 1m 18s	remaining: 3m 48s
# 1709:	learn: 0.0208484	total: 1m 18s	remaining: 3m 48s
# 1710:	learn: 0.0208483	total: 1m 18s	remaining: 3m 48s
# 1711:	learn: 0.0208482	total: 1m 18s	remaining: 3m 48s
# 1712:	learn: 0.0208481	total: 1m 18s	remaining: 3m 48s
# 1713:	learn: 0.0208480	total: 1m 18s	remaining: 3m 47s
# 1714:	learn: 0.0208480	total: 1m 18s	remaining: 3m 47s
# 1715:	learn: 0.0208479	total: 1m 18s	remaining: 3m 47s
# 1716:	learn: 0.0208478	total: 1m 18s	remaining: 3m 47s
# 1717:	learn: 0.0208477	total: 1m 18s	remaining: 3m 47s
# 1718:	learn: 0.0208477	total: 1m 18s	remaining: 3m 47s
# 1719:	learn: 0.0208476	total: 1m 18s	remaining: 3m 47s
# 1720:	learn: 0.0208475	total: 1m 18s	remaining: 3m 47s
# 1721:	learn: 0.0208474	total: 1m 18s	remaining: 3m 47s
# 1722:	learn: 0.0208474	total: 1m 18s	remaining: 3m 47s
# 1723:	learn: 0.0208473	total: 1m 18s	remaining: 3m 47s
# 1724:	learn: 0.0208472	total: 1m 18s	remaining: 3m 47s
# 1725:	learn: 0.0208471	total: 1m 18s	remaining: 3m 47s
# 1726:	learn: 0.0208471	total: 1m 18s	remaining: 3m 47s
# 1727:	learn: 0.0208470	total: 1m 18s	remaining: 3m 47s
# 1728:	learn: 0.0208469	total: 1m 18s	remaining: 3m 47s
# 1729:	learn: 0.0208469	total: 1m 18s	remaining: 3m 46s
# 1730:	learn: 0.0208468	total: 1m 19s	remaining: 3m 46s
# 1731:	learn: 0.0208467	total: 1m 19s	remaining: 3m 46s
# 1732:	learn: 0.0208466	total: 1m 19s	remaining: 3m 46s
# 1733:	learn: 0.0208466	total: 1m 19s	remaining: 3m 46s
# 1734:	learn: 0.0208465	total: 1m 19s	remaining: 3m 46s
# 1735:	learn: 0.0208464	total: 1m 19s	remaining: 3m 46s
# 1736:	learn: 0.0208463	total: 1m 19s	remaining: 3m 46s
# 1737:	learn: 0.0208463	total: 1m 19s	remaining: 3m 46s
# 1738:	learn: 0.0208462	total: 1m 19s	remaining: 3m 46s
# 1739:	learn: 0.0208461	total: 1m 19s	remaining: 3m 46s
# 1740:	learn: 0.0208460	total: 1m 19s	remaining: 3m 46s
# 1741:	learn: 0.0208460	total: 1m 19s	remaining: 3m 46s
# 1742:	learn: 0.0208459	total: 1m 19s	remaining: 3m 46s
# 1743:	learn: 0.0208458	total: 1m 19s	remaining: 3m 46s
# 1744:	learn: 0.0208457	total: 1m 19s	remaining: 3m 46s
# 1745:	learn: 0.0208457	total: 1m 19s	remaining: 3m 46s
# 1746:	learn: 0.0208456	total: 1m 19s	remaining: 3m 45s
# 1747:	learn: 0.0208455	total: 1m 19s	remaining: 3m 45s
# 1748:	learn: 0.0208454	total: 1m 19s	remaining: 3m 45s
# 1749:	learn: 0.0208454	total: 1m 19s	remaining: 3m 45s
# 1750:	learn: 0.0208453	total: 1m 19s	remaining: 3m 45s
# 1751:	learn: 0.0208452	total: 1m 19s	remaining: 3m 45s
# 1752:	learn: 0.0208452	total: 1m 19s	remaining: 3m 45s
# 1753:	learn: 0.0208451	total: 1m 19s	remaining: 3m 45s
# 1754:	learn: 0.0208450	total: 1m 19s	remaining: 3m 45s
# 1755:	learn: 0.0208449	total: 1m 20s	remaining: 3m 45s
# 1756:	learn: 0.0208449	total: 1m 20s	remaining: 3m 45s
# 1757:	learn: 0.0208448	total: 1m 20s	remaining: 3m 45s
# 1758:	learn: 0.0208447	total: 1m 20s	remaining: 3m 45s
# 1759:	learn: 0.0208446	total: 1m 20s	remaining: 3m 45s
# 1760:	learn: 0.0208446	total: 1m 20s	remaining: 3m 45s
# 1761:	learn: 0.0208445	total: 1m 20s	remaining: 3m 45s
# 1762:	learn: 0.0208444	total: 1m 20s	remaining: 3m 45s
# 1763:	learn: 0.0208443	total: 1m 20s	remaining: 3m 45s
# 1764:	learn: 0.0208443	total: 1m 20s	remaining: 3m 44s
# 1765:	learn: 0.0208442	total: 1m 20s	remaining: 3m 44s
# 1766:	learn: 0.0208441	total: 1m 20s	remaining: 3m 44s
# 1767:	learn: 0.0208441	total: 1m 20s	remaining: 3m 44s
# 1768:	learn: 0.0208440	total: 1m 20s	remaining: 3m 44s
# 1769:	learn: 0.0208439	total: 1m 20s	remaining: 3m 44s
# 1770:	learn: 0.0208438	total: 1m 20s	remaining: 3m 44s
# 1771:	learn: 0.0208438	total: 1m 20s	remaining: 3m 44s
# 1772:	learn: 0.0208437	total: 1m 20s	remaining: 3m 44s
# 1773:	learn: 0.0208436	total: 1m 20s	remaining: 3m 44s
# 1774:	learn: 0.0208435	total: 1m 20s	remaining: 3m 44s
# 1775:	learn: 0.0208435	total: 1m 20s	remaining: 3m 44s
# 1776:	learn: 0.0208434	total: 1m 20s	remaining: 3m 44s
# 1777:	learn: 0.0208433	total: 1m 20s	remaining: 3m 44s
# 1778:	learn: 0.0208433	total: 1m 20s	remaining: 3m 44s
# 1779:	learn: 0.0208432	total: 1m 21s	remaining: 3m 44s
# 1780:	learn: 0.0208431	total: 1m 21s	remaining: 3m 43s
# 1781:	learn: 0.0208430	total: 1m 21s	remaining: 3m 44s
# 1782:	learn: 0.0208430	total: 1m 21s	remaining: 3m 44s
# 1783:	learn: 0.0208429	total: 1m 21s	remaining: 3m 44s
# 1784:	learn: 0.0208428	total: 1m 21s	remaining: 3m 44s
# 1785:	learn: 0.0208428	total: 1m 21s	remaining: 3m 44s
# 1786:	learn: 0.0208427	total: 1m 21s	remaining: 3m 44s
# 1787:	learn: 0.0208426	total: 1m 21s	remaining: 3m 44s
# 1788:	learn: 0.0208426	total: 1m 21s	remaining: 3m 44s
# 1789:	learn: 0.0208425	total: 1m 21s	remaining: 3m 44s
# 1790:	learn: 0.0208424	total: 1m 21s	remaining: 3m 44s
# 1791:	learn: 0.0208423	total: 1m 21s	remaining: 3m 44s
# 1792:	learn: 0.0208423	total: 1m 21s	remaining: 3m 44s
# 1793:	learn: 0.0208422	total: 1m 21s	remaining: 3m 44s
# 1794:	learn: 0.0208421	total: 1m 22s	remaining: 3m 44s
# 1795:	learn: 0.0208421	total: 1m 22s	remaining: 3m 44s
# 1796:	learn: 0.0208420	total: 1m 22s	remaining: 3m 44s
# 1797:	learn: 0.0208419	total: 1m 22s	remaining: 3m 44s
# 1798:	learn: 0.0208418	total: 1m 22s	remaining: 3m 44s
# 1799:	learn: 0.0208418	total: 1m 22s	remaining: 3m 44s
# 1800:	learn: 0.0208417	total: 1m 22s	remaining: 3m 44s
# 1801:	learn: 0.0208417	total: 1m 22s	remaining: 3m 44s
# 1802:	learn: 0.0208416	total: 1m 22s	remaining: 3m 44s
# 1803:	learn: 0.0208415	total: 1m 22s	remaining: 3m 44s
# 1804:	learn: 0.0208414	total: 1m 22s	remaining: 3m 44s
# 1805:	learn: 0.0208414	total: 1m 22s	remaining: 3m 44s
# 1806:	learn: 0.0208413	total: 1m 22s	remaining: 3m 44s
# 1807:	learn: 0.0208412	total: 1m 23s	remaining: 3m 44s
# 1808:	learn: 0.0208412	total: 1m 23s	remaining: 3m 44s
# 1809:	learn: 0.0208411	total: 1m 23s	remaining: 3m 44s
# 1810:	learn: 0.0208410	total: 1m 23s	remaining: 3m 44s
# 1811:	learn: 0.0208410	total: 1m 23s	remaining: 3m 44s
# 1812:	learn: 0.0208409	total: 1m 23s	remaining: 3m 44s
# 1813:	learn: 0.0208408	total: 1m 23s	remaining: 3m 44s
# 1814:	learn: 0.0208408	total: 1m 23s	remaining: 3m 44s
# 1815:	learn: 0.0208407	total: 1m 23s	remaining: 3m 44s
# 1816:	learn: 0.0208406	total: 1m 23s	remaining: 3m 44s
# 1817:	learn: 0.0208406	total: 1m 23s	remaining: 3m 44s
# 1818:	learn: 0.0208405	total: 1m 23s	remaining: 3m 44s
# 1819:	learn: 0.0208404	total: 1m 23s	remaining: 3m 45s
# 1820:	learn: 0.0208404	total: 1m 23s	remaining: 3m 45s
# 1821:	learn: 0.0208403	total: 1m 24s	remaining: 3m 45s
# 1822:	learn: 0.0208402	total: 1m 24s	remaining: 3m 45s
# 1823:	learn: 0.0208401	total: 1m 24s	remaining: 3m 45s
# 1824:	learn: 0.0208401	total: 1m 24s	remaining: 3m 45s
# 1825:	learn: 0.0208400	total: 1m 24s	remaining: 3m 45s
# 1826:	learn: 0.0208399	total: 1m 24s	remaining: 3m 45s
# 1827:	learn: 0.0208399	total: 1m 24s	remaining: 3m 45s
# 1828:	learn: 0.0208398	total: 1m 24s	remaining: 3m 45s
# 1829:	learn: 0.0208397	total: 1m 24s	remaining: 3m 44s
# 1830:	learn: 0.0208397	total: 1m 24s	remaining: 3m 44s
# 1831:	learn: 0.0208396	total: 1m 24s	remaining: 3m 44s
# 1832:	learn: 0.0208395	total: 1m 24s	remaining: 3m 44s
# 1833:	learn: 0.0208395	total: 1m 24s	remaining: 3m 44s
# 1834:	learn: 0.0208394	total: 1m 24s	remaining: 3m 44s
# 1835:	learn: 0.0208393	total: 1m 24s	remaining: 3m 44s
# 1836:	learn: 0.0208393	total: 1m 24s	remaining: 3m 44s
# 1837:	learn: 0.0208392	total: 1m 24s	remaining: 3m 44s
# 1838:	learn: 0.0208391	total: 1m 24s	remaining: 3m 44s
# 1839:	learn: 0.0208390	total: 1m 24s	remaining: 3m 44s
# 1840:	learn: 0.0208390	total: 1m 24s	remaining: 3m 44s
# 1841:	learn: 0.0208389	total: 1m 24s	remaining: 3m 44s
# 1842:	learn: 0.0208388	total: 1m 25s	remaining: 3m 44s
# 1843:	learn: 0.0208388	total: 1m 25s	remaining: 3m 44s
# 1844:	learn: 0.0208387	total: 1m 25s	remaining: 3m 44s
# 1845:	learn: 0.0208386	total: 1m 25s	remaining: 3m 43s
# 1846:	learn: 0.0208386	total: 1m 25s	remaining: 3m 43s
# 1847:	learn: 0.0208385	total: 1m 25s	remaining: 3m 43s
# 1848:	learn: 0.0208384	total: 1m 25s	remaining: 3m 43s
# 1849:	learn: 0.0208384	total: 1m 25s	remaining: 3m 43s
# 1850:	learn: 0.0208383	total: 1m 25s	remaining: 3m 43s
# 1851:	learn: 0.0208382	total: 1m 25s	remaining: 3m 43s
# 1852:	learn: 0.0208382	total: 1m 25s	remaining: 3m 43s
# 1853:	learn: 0.0208381	total: 1m 25s	remaining: 3m 43s
# 1854:	learn: 0.0208380	total: 1m 25s	remaining: 3m 43s
# 1855:	learn: 0.0208380	total: 1m 25s	remaining: 3m 43s
# 1856:	learn: 0.0208379	total: 1m 25s	remaining: 3m 43s
# 1857:	learn: 0.0208378	total: 1m 25s	remaining: 3m 43s
# 1858:	learn: 0.0208377	total: 1m 25s	remaining: 3m 43s
# 1859:	learn: 0.0208377	total: 1m 25s	remaining: 3m 43s
# 1860:	learn: 0.0208376	total: 1m 25s	remaining: 3m 43s
# 1861:	learn: 0.0208375	total: 1m 25s	remaining: 3m 43s
# 1862:	learn: 0.0208375	total: 1m 25s	remaining: 3m 42s
# 1863:	learn: 0.0208374	total: 1m 25s	remaining: 3m 42s
# 1864:	learn: 0.0208373	total: 1m 25s	remaining: 3m 42s
# 1865:	learn: 0.0208373	total: 1m 25s	remaining: 3m 42s
# 1866:	learn: 0.0208372	total: 1m 25s	remaining: 3m 42s
# 1867:	learn: 0.0208371	total: 1m 26s	remaining: 3m 42s
# 1868:	learn: 0.0208371	total: 1m 26s	remaining: 3m 42s
# 1869:	learn: 0.0208370	total: 1m 26s	remaining: 3m 42s
# 1870:	learn: 0.0208369	total: 1m 26s	remaining: 3m 42s
# 1871:	learn: 0.0208369	total: 1m 26s	remaining: 3m 42s
# 1872:	learn: 0.0208368	total: 1m 26s	remaining: 3m 42s
# 1873:	learn: 0.0208367	total: 1m 26s	remaining: 3m 42s
# 1874:	learn: 0.0208367	total: 1m 26s	remaining: 3m 42s
# 1875:	learn: 0.0208366	total: 1m 26s	remaining: 3m 42s
# 1876:	learn: 0.0208365	total: 1m 26s	remaining: 3m 42s
# 1877:	learn: 0.0208365	total: 1m 26s	remaining: 3m 42s
# 1878:	learn: 0.0208364	total: 1m 26s	remaining: 3m 42s
# 1879:	learn: 0.0208363	total: 1m 26s	remaining: 3m 41s
# 1880:	learn: 0.0208363	total: 1m 26s	remaining: 3m 41s
# 1881:	learn: 0.0208362	total: 1m 26s	remaining: 3m 41s
# 1882:	learn: 0.0208361	total: 1m 26s	remaining: 3m 41s
# 1883:	learn: 0.0208361	total: 1m 26s	remaining: 3m 41s
# 1884:	learn: 0.0208360	total: 1m 26s	remaining: 3m 41s
# 1885:	learn: 0.0208359	total: 1m 26s	remaining: 3m 41s
# 1886:	learn: 0.0208359	total: 1m 26s	remaining: 3m 41s
# 1887:	learn: 0.0208358	total: 1m 26s	remaining: 3m 41s
# 1888:	learn: 0.0208357	total: 1m 26s	remaining: 3m 41s
# 1889:	learn: 0.0208357	total: 1m 26s	remaining: 3m 41s
# 1890:	learn: 0.0208356	total: 1m 26s	remaining: 3m 41s
# 1891:	learn: 0.0208355	total: 1m 27s	remaining: 3m 41s
# 1892:	learn: 0.0208355	total: 1m 27s	remaining: 3m 41s
# 1893:	learn: 0.0208354	total: 1m 27s	remaining: 3m 41s
# 1894:	learn: 0.0208353	total: 1m 27s	remaining: 3m 41s
# 1895:	learn: 0.0208353	total: 1m 27s	remaining: 3m 41s
# 1896:	learn: 0.0208352	total: 1m 27s	remaining: 3m 40s
# 1897:	learn: 0.0208351	total: 1m 27s	remaining: 3m 40s
# 1898:	learn: 0.0208351	total: 1m 27s	remaining: 3m 40s
# 1899:	learn: 0.0208350	total: 1m 27s	remaining: 3m 40s
# 1900:	learn: 0.0208349	total: 1m 27s	remaining: 3m 40s
# 1901:	learn: 0.0208349	total: 1m 27s	remaining: 3m 40s
# 1902:	learn: 0.0208348	total: 1m 27s	remaining: 3m 40s
# 1903:	learn: 0.0208347	total: 1m 27s	remaining: 3m 40s
# 1904:	learn: 0.0208347	total: 1m 27s	remaining: 3m 40s
# 1905:	learn: 0.0208346	total: 1m 27s	remaining: 3m 40s
# 1906:	learn: 0.0208345	total: 1m 27s	remaining: 3m 40s
# 1907:	learn: 0.0208345	total: 1m 27s	remaining: 3m 40s
# 1908:	learn: 0.0208344	total: 1m 27s	remaining: 3m 40s
# 1909:	learn: 0.0208344	total: 1m 27s	remaining: 3m 40s
# 1910:	learn: 0.0208343	total: 1m 27s	remaining: 3m 40s
# 1911:	learn: 0.0208342	total: 1m 27s	remaining: 3m 40s
# 1912:	learn: 0.0208342	total: 1m 27s	remaining: 3m 39s
# 1913:	learn: 0.0208341	total: 1m 27s	remaining: 3m 39s
# 1914:	learn: 0.0208340	total: 1m 27s	remaining: 3m 39s
# 1915:	learn: 0.0208340	total: 1m 27s	remaining: 3m 39s
# 1916:	learn: 0.0208339	total: 1m 28s	remaining: 3m 39s
# 1917:	learn: 0.0208338	total: 1m 28s	remaining: 3m 39s
# 1918:	learn: 0.0208338	total: 1m 28s	remaining: 3m 39s
# 1919:	learn: 0.0208337	total: 1m 28s	remaining: 3m 39s
# 1920:	learn: 0.0208336	total: 1m 28s	remaining: 3m 39s
# 1921:	learn: 0.0208336	total: 1m 28s	remaining: 3m 39s
# 1922:	learn: 0.0208335	total: 1m 28s	remaining: 3m 39s
# 1923:	learn: 0.0208334	total: 1m 28s	remaining: 3m 39s
# 1924:	learn: 0.0208334	total: 1m 28s	remaining: 3m 39s
# 1925:	learn: 0.0208333	total: 1m 28s	remaining: 3m 39s
# 1926:	learn: 0.0208332	total: 1m 28s	remaining: 3m 39s
# 1927:	learn: 0.0208332	total: 1m 28s	remaining: 3m 39s
# 1928:	learn: 0.0208331	total: 1m 28s	remaining: 3m 39s
# 1929:	learn: 0.0208331	total: 1m 28s	remaining: 3m 38s
# 1930:	learn: 0.0208330	total: 1m 28s	remaining: 3m 38s
# 1931:	learn: 0.0208329	total: 1m 28s	remaining: 3m 38s
# 1932:	learn: 0.0208329	total: 1m 28s	remaining: 3m 38s
# 1933:	learn: 0.0208328	total: 1m 28s	remaining: 3m 38s
# 1934:	learn: 0.0208327	total: 1m 28s	remaining: 3m 38s
# 1935:	learn: 0.0208327	total: 1m 28s	remaining: 3m 38s
# 1936:	learn: 0.0208326	total: 1m 28s	remaining: 3m 38s
# 1937:	learn: 0.0208325	total: 1m 28s	remaining: 3m 38s
# 1938:	learn: 0.0208325	total: 1m 28s	remaining: 3m 38s
# 1939:	learn: 0.0208324	total: 1m 28s	remaining: 3m 38s
# 1940:	learn: 0.0208324	total: 1m 28s	remaining: 3m 38s
# 1941:	learn: 0.0208323	total: 1m 29s	remaining: 3m 38s
# 1942:	learn: 0.0208322	total: 1m 29s	remaining: 3m 38s
# 1943:	learn: 0.0208322	total: 1m 29s	remaining: 3m 38s
# 1944:	learn: 0.0208321	total: 1m 29s	remaining: 3m 38s
# 1945:	learn: 0.0208320	total: 1m 29s	remaining: 3m 38s
# 1946:	learn: 0.0208320	total: 1m 29s	remaining: 3m 37s
# 1947:	learn: 0.0208319	total: 1m 29s	remaining: 3m 37s
# 1948:	learn: 0.0208319	total: 1m 29s	remaining: 3m 37s
# 1949:	learn: 0.0208318	total: 1m 29s	remaining: 3m 37s
# 1950:	learn: 0.0208317	total: 1m 29s	remaining: 3m 37s
# 1951:	learn: 0.0208317	total: 1m 29s	remaining: 3m 37s
# 1952:	learn: 0.0208316	total: 1m 29s	remaining: 3m 37s
# 1953:	learn: 0.0208315	total: 1m 29s	remaining: 3m 37s
# 1954:	learn: 0.0208315	total: 1m 29s	remaining: 3m 37s
# 1955:	learn: 0.0208314	total: 1m 29s	remaining: 3m 37s
# 1956:	learn: 0.0208313	total: 1m 29s	remaining: 3m 37s
# 1957:	learn: 0.0208313	total: 1m 29s	remaining: 3m 37s
# 1958:	learn: 0.0208312	total: 1m 29s	remaining: 3m 37s
# 1959:	learn: 0.0208312	total: 1m 29s	remaining: 3m 37s
# 1960:	learn: 0.0208311	total: 1m 29s	remaining: 3m 37s
# 1961:	learn: 0.0208310	total: 1m 29s	remaining: 3m 37s
# 1962:	learn: 0.0208310	total: 1m 29s	remaining: 3m 37s
# 1963:	learn: 0.0208309	total: 1m 29s	remaining: 3m 36s
# 1964:	learn: 0.0208308	total: 1m 29s	remaining: 3m 36s
# 1965:	learn: 0.0208308	total: 1m 29s	remaining: 3m 36s
# 1966:	learn: 0.0208307	total: 1m 30s	remaining: 3m 36s
# 1967:	learn: 0.0208307	total: 1m 30s	remaining: 3m 36s
# 1968:	learn: 0.0208306	total: 1m 30s	remaining: 3m 36s
# 1969:	learn: 0.0208305	total: 1m 30s	remaining: 3m 36s
# 1970:	learn: 0.0208305	total: 1m 30s	remaining: 3m 36s
# 1971:	learn: 0.0208304	total: 1m 30s	remaining: 3m 36s
# 1972:	learn: 0.0208303	total: 1m 30s	remaining: 3m 36s
# 1973:	learn: 0.0208303	total: 1m 30s	remaining: 3m 36s
# 1974:	learn: 0.0208302	total: 1m 30s	remaining: 3m 36s
# 1975:	learn: 0.0208302	total: 1m 30s	remaining: 3m 36s
# 1976:	learn: 0.0208301	total: 1m 30s	remaining: 3m 36s
# 1977:	learn: 0.0208300	total: 1m 30s	remaining: 3m 36s
# 1978:	learn: 0.0208300	total: 1m 30s	remaining: 3m 36s
# 1979:	learn: 0.0208299	total: 1m 30s	remaining: 3m 36s
# 1980:	learn: 0.0208298	total: 1m 30s	remaining: 3m 35s
# 1981:	learn: 0.0208298	total: 1m 30s	remaining: 3m 35s
# 1982:	learn: 0.0208297	total: 1m 30s	remaining: 3m 35s
# 1983:	learn: 0.0208297	total: 1m 30s	remaining: 3m 35s
# 1984:	learn: 0.0208296	total: 1m 30s	remaining: 3m 35s
# 1985:	learn: 0.0208295	total: 1m 30s	remaining: 3m 35s
# 1986:	learn: 0.0208295	total: 1m 30s	remaining: 3m 35s
# 1987:	learn: 0.0208294	total: 1m 30s	remaining: 3m 35s
# 1988:	learn: 0.0208293	total: 1m 30s	remaining: 3m 35s
# 1989:	learn: 0.0208293	total: 1m 30s	remaining: 3m 35s
# 1990:	learn: 0.0208292	total: 1m 31s	remaining: 3m 35s
# 1991:	learn: 0.0208292	total: 1m 31s	remaining: 3m 35s
# 1992:	learn: 0.0208291	total: 1m 31s	remaining: 3m 35s
# 1993:	learn: 0.0208290	total: 1m 31s	remaining: 3m 35s
# 1994:	learn: 0.0208290	total: 1m 31s	remaining: 3m 35s
# 1995:	learn: 0.0208289	total: 1m 31s	remaining: 3m 35s
# 1996:	learn: 0.0208289	total: 1m 31s	remaining: 3m 35s
# 1997:	learn: 0.0208288	total: 1m 31s	remaining: 3m 34s
# 1998:	learn: 0.0208287	total: 1m 31s	remaining: 3m 34s
# 1999:	learn: 0.0208287	total: 1m 31s	remaining: 3m 34s
# 2000:	learn: 0.0208286	total: 1m 31s	remaining: 3m 34s
# 2001:	learn: 0.0208285	total: 1m 31s	remaining: 3m 34s
# 2002:	learn: 0.0208285	total: 1m 31s	remaining: 3m 34s
# 2003:	learn: 0.0208284	total: 1m 31s	remaining: 3m 34s
# 2004:	learn: 0.0208284	total: 1m 31s	remaining: 3m 34s
# 2005:	learn: 0.0208283	total: 1m 31s	remaining: 3m 34s
# 2006:	learn: 0.0208282	total: 1m 31s	remaining: 3m 34s
# 2007:	learn: 0.0208282	total: 1m 31s	remaining: 3m 34s
# 2008:	learn: 0.0208281	total: 1m 31s	remaining: 3m 34s
# 2009:	learn: 0.0208281	total: 1m 31s	remaining: 3m 34s
# 2010:	learn: 0.0208280	total: 1m 31s	remaining: 3m 34s
# 2011:	learn: 0.0208279	total: 1m 31s	remaining: 3m 34s
# 2012:	learn: 0.0208279	total: 1m 31s	remaining: 3m 34s
# 2013:	learn: 0.0208278	total: 1m 31s	remaining: 3m 34s
# 2014:	learn: 0.0208278	total: 1m 31s	remaining: 3m 33s
# 2015:	learn: 0.0208277	total: 1m 32s	remaining: 3m 33s
# 2016:	learn: 0.0208276	total: 1m 32s	remaining: 3m 33s
# 2017:	learn: 0.0208276	total: 1m 32s	remaining: 3m 33s
# 2018:	learn: 0.0208275	total: 1m 32s	remaining: 3m 33s
# 2019:	learn: 0.0208275	total: 1m 32s	remaining: 3m 33s
# 2020:	learn: 0.0208274	total: 1m 32s	remaining: 3m 33s
# 2021:	learn: 0.0208273	total: 1m 32s	remaining: 3m 33s
# 2022:	learn: 0.0208273	total: 1m 32s	remaining: 3m 33s
# 2023:	learn: 0.0208272	total: 1m 32s	remaining: 3m 33s
# 2024:	learn: 0.0208272	total: 1m 32s	remaining: 3m 33s
# 2025:	learn: 0.0208271	total: 1m 32s	remaining: 3m 33s
# 2026:	learn: 0.0208271	total: 1m 32s	remaining: 3m 33s
# 2027:	learn: 0.0208270	total: 1m 32s	remaining: 3m 33s
# 2028:	learn: 0.0208269	total: 1m 32s	remaining: 3m 33s
# 2029:	learn: 0.0208269	total: 1m 32s	remaining: 3m 33s
# 2030:	learn: 0.0208268	total: 1m 32s	remaining: 3m 33s
# 2031:	learn: 0.0208268	total: 1m 32s	remaining: 3m 33s
# 2032:	learn: 0.0208267	total: 1m 32s	remaining: 3m 32s
# 2033:	learn: 0.0208266	total: 1m 32s	remaining: 3m 32s
# 2034:	learn: 0.0208266	total: 1m 32s	remaining: 3m 32s
# 2035:	learn: 0.0208265	total: 1m 32s	remaining: 3m 32s
# 2036:	learn: 0.0208264	total: 1m 32s	remaining: 3m 32s
# 2037:	learn: 0.0208264	total: 1m 32s	remaining: 3m 32s
# 2038:	learn: 0.0208263	total: 1m 32s	remaining: 3m 32s
# 2039:	learn: 0.0208263	total: 1m 33s	remaining: 3m 32s
# 2040:	learn: 0.0208262	total: 1m 33s	remaining: 3m 32s
# 2041:	learn: 0.0208261	total: 1m 33s	remaining: 3m 32s
# 2042:	learn: 0.0208261	total: 1m 33s	remaining: 3m 32s
# 2043:	learn: 0.0208260	total: 1m 33s	remaining: 3m 32s
# 2044:	learn: 0.0208260	total: 1m 33s	remaining: 3m 32s
# 2045:	learn: 0.0208259	total: 1m 33s	remaining: 3m 32s
# 2046:	learn: 0.0208259	total: 1m 33s	remaining: 3m 32s
# 2047:	learn: 0.0208258	total: 1m 33s	remaining: 3m 32s
# 2048:	learn: 0.0208257	total: 1m 33s	remaining: 3m 32s
# 2049:	learn: 0.0208257	total: 1m 33s	remaining: 3m 32s
# 2050:	learn: 0.0208256	total: 1m 33s	remaining: 3m 31s
# 2051:	learn: 0.0208256	total: 1m 33s	remaining: 3m 31s
# 2052:	learn: 0.0208255	total: 1m 33s	remaining: 3m 31s
# 2053:	learn: 0.0208255	total: 1m 33s	remaining: 3m 31s
# 2054:	learn: 0.0208254	total: 1m 33s	remaining: 3m 31s
# 2055:	learn: 0.0208253	total: 1m 33s	remaining: 3m 31s
# 2056:	learn: 0.0208253	total: 1m 33s	remaining: 3m 31s
# 2057:	learn: 0.0208252	total: 1m 33s	remaining: 3m 31s
# 2058:	learn: 0.0208252	total: 1m 33s	remaining: 3m 31s
# 2059:	learn: 0.0208251	total: 1m 33s	remaining: 3m 31s
# 2060:	learn: 0.0208250	total: 1m 33s	remaining: 3m 31s
# 2061:	learn: 0.0208250	total: 1m 33s	remaining: 3m 31s
# 2062:	learn: 0.0208249	total: 1m 33s	remaining: 3m 31s
# 2063:	learn: 0.0208249	total: 1m 33s	remaining: 3m 31s
# 2064:	learn: 0.0208248	total: 1m 34s	remaining: 3m 31s
# 2065:	learn: 0.0208248	total: 1m 34s	remaining: 3m 31s
# 2066:	learn: 0.0208247	total: 1m 34s	remaining: 3m 31s
# 2067:	learn: 0.0208246	total: 1m 34s	remaining: 3m 31s
# 2068:	learn: 0.0208246	total: 1m 34s	remaining: 3m 30s
# 2069:	learn: 0.0208245	total: 1m 34s	remaining: 3m 30s
# 2070:	learn: 0.0208245	total: 1m 34s	remaining: 3m 30s
# 2071:	learn: 0.0208244	total: 1m 34s	remaining: 3m 30s
# 2072:	learn: 0.0208243	total: 1m 34s	remaining: 3m 30s
# 2073:	learn: 0.0208243	total: 1m 34s	remaining: 3m 30s
# 2074:	learn: 0.0208242	total: 1m 34s	remaining: 3m 30s
# 2075:	learn: 0.0208242	total: 1m 34s	remaining: 3m 30s
# 2076:	learn: 0.0208241	total: 1m 34s	remaining: 3m 30s
# 2077:	learn: 0.0208241	total: 1m 34s	remaining: 3m 30s
# 2078:	learn: 0.0208240	total: 1m 34s	remaining: 3m 30s
# 2079:	learn: 0.0208239	total: 1m 34s	remaining: 3m 30s
# 2080:	learn: 0.0208239	total: 1m 34s	remaining: 3m 30s
# 2081:	learn: 0.0208238	total: 1m 35s	remaining: 3m 30s
# 2082:	learn: 0.0208238	total: 1m 35s	remaining: 3m 30s
# 2083:	learn: 0.0208237	total: 1m 35s	remaining: 3m 30s
# 2084:	learn: 0.0208236	total: 1m 35s	remaining: 3m 30s
# 2085:	learn: 0.0208236	total: 1m 35s	remaining: 3m 30s
# 2086:	learn: 0.0208235	total: 1m 35s	remaining: 3m 31s
# 2087:	learn: 0.0208235	total: 1m 35s	remaining: 3m 31s
# 2088:	learn: 0.0208234	total: 1m 35s	remaining: 3m 31s
# 2089:	learn: 0.0208234	total: 1m 35s	remaining: 3m 31s
# 2090:	learn: 0.0208233	total: 1m 35s	remaining: 3m 31s
# 2091:	learn: 0.0208232	total: 1m 35s	remaining: 3m 31s
# 2092:	learn: 0.0208232	total: 1m 35s	remaining: 3m 31s
# 2093:	learn: 0.0208231	total: 1m 35s	remaining: 3m 31s
# 2094:	learn: 0.0208231	total: 1m 36s	remaining: 3m 31s
# 2095:	learn: 0.0208230	total: 1m 36s	remaining: 3m 31s
# 2096:	learn: 0.0208230	total: 1m 36s	remaining: 3m 31s
# 2097:	learn: 0.0208229	total: 1m 36s	remaining: 3m 31s
# 2098:	learn: 0.0208228	total: 1m 36s	remaining: 3m 31s
# 2099:	learn: 0.0208228	total: 1m 36s	remaining: 3m 31s
# 2100:	learn: 0.0208227	total: 1m 36s	remaining: 3m 31s
# 2101:	learn: 0.0208227	total: 1m 36s	remaining: 3m 31s
# 2102:	learn: 0.0208226	total: 1m 36s	remaining: 3m 31s
# 2103:	learn: 0.0208226	total: 1m 36s	remaining: 3m 31s
# 2104:	learn: 0.0208225	total: 1m 36s	remaining: 3m 31s
# 2105:	learn: 0.0208224	total: 1m 36s	remaining: 3m 31s
# 2106:	learn: 0.0208224	total: 1m 36s	remaining: 3m 31s
# 2107:	learn: 0.0208223	total: 1m 36s	remaining: 3m 31s
# 2108:	learn: 0.0208223	total: 1m 37s	remaining: 3m 31s
# 2109:	learn: 0.0208222	total: 1m 37s	remaining: 3m 31s
# 2110:	learn: 0.0208222	total: 1m 37s	remaining: 3m 31s
# 2111:	learn: 0.0208221	total: 1m 37s	remaining: 3m 31s
# 2112:	learn: 0.0208220	total: 1m 37s	remaining: 3m 31s
# 2113:	learn: 0.0208220	total: 1m 37s	remaining: 3m 31s
# 2114:	learn: 0.0208219	total: 1m 37s	remaining: 3m 31s
# 2115:	learn: 0.0208219	total: 1m 37s	remaining: 3m 31s
# 2116:	learn: 0.0208218	total: 1m 37s	remaining: 3m 31s
# 2117:	learn: 0.0208217	total: 1m 37s	remaining: 3m 31s
# 2118:	learn: 0.0208217	total: 1m 37s	remaining: 3m 31s
# 2119:	learn: 0.0208216	total: 1m 37s	remaining: 3m 31s
# 2120:	learn: 0.0208216	total: 1m 37s	remaining: 3m 31s
# 2121:	learn: 0.0208215	total: 1m 37s	remaining: 3m 31s
# 2122:	learn: 0.0208215	total: 1m 37s	remaining: 3m 31s
# 2123:	learn: 0.0208214	total: 1m 37s	remaining: 3m 31s
# 2124:	learn: 0.0208214	total: 1m 37s	remaining: 3m 30s
# 2125:	learn: 0.0208213	total: 1m 37s	remaining: 3m 30s
# 2126:	learn: 0.0208212	total: 1m 38s	remaining: 3m 30s
# 2127:	learn: 0.0208212	total: 1m 38s	remaining: 3m 30s
# 2128:	learn: 0.0208211	total: 1m 38s	remaining: 3m 30s
# 2129:	learn: 0.0208211	total: 1m 38s	remaining: 3m 30s
# 2130:	learn: 0.0208210	total: 1m 38s	remaining: 3m 30s
# 2131:	learn: 0.0208210	total: 1m 38s	remaining: 3m 30s
# 2132:	learn: 0.0208209	total: 1m 38s	remaining: 3m 30s
# 2133:	learn: 0.0208208	total: 1m 38s	remaining: 3m 30s
# 2134:	learn: 0.0208208	total: 1m 38s	remaining: 3m 30s
# 2135:	learn: 0.0208207	total: 1m 38s	remaining: 3m 30s
# 2136:	learn: 0.0208207	total: 1m 38s	remaining: 3m 30s
# 2137:	learn: 0.0208206	total: 1m 38s	remaining: 3m 30s
# 2138:	learn: 0.0208206	total: 1m 38s	remaining: 3m 30s
# 2139:	learn: 0.0208205	total: 1m 38s	remaining: 3m 30s
# 2140:	learn: 0.0208205	total: 1m 38s	remaining: 3m 30s
# 2141:	learn: 0.0208204	total: 1m 38s	remaining: 3m 29s
# 2142:	learn: 0.0208204	total: 1m 38s	remaining: 3m 29s
# 2143:	learn: 0.0208203	total: 1m 38s	remaining: 3m 29s
# 2144:	learn: 0.0208203	total: 1m 38s	remaining: 3m 29s
# 2145:	learn: 0.0208202	total: 1m 38s	remaining: 3m 29s
# 2146:	learn: 0.0208201	total: 1m 38s	remaining: 3m 29s
# 2147:	learn: 0.0208201	total: 1m 38s	remaining: 3m 29s
# 2148:	learn: 0.0208200	total: 1m 38s	remaining: 3m 29s
# 2149:	learn: 0.0208200	total: 1m 38s	remaining: 3m 29s
# 2150:	learn: 0.0208199	total: 1m 38s	remaining: 3m 29s
# 2151:	learn: 0.0208199	total: 1m 39s	remaining: 3m 29s
# 2152:	learn: 0.0208198	total: 1m 39s	remaining: 3m 29s
# 2153:	learn: 0.0208198	total: 1m 39s	remaining: 3m 29s
# 2154:	learn: 0.0208197	total: 1m 39s	remaining: 3m 29s
# 2155:	learn: 0.0208196	total: 1m 39s	remaining: 3m 29s
# 2156:	learn: 0.0208196	total: 1m 39s	remaining: 3m 29s
# 2157:	learn: 0.0208195	total: 1m 39s	remaining: 3m 29s
# 2158:	learn: 0.0208195	total: 1m 39s	remaining: 3m 28s
# 2159:	learn: 0.0208194	total: 1m 39s	remaining: 3m 28s
# 2160:	learn: 0.0208194	total: 1m 39s	remaining: 3m 28s
# 2161:	learn: 0.0208193	total: 1m 39s	remaining: 3m 28s
# 2162:	learn: 0.0208193	total: 1m 39s	remaining: 3m 28s
# 2163:	learn: 0.0208192	total: 1m 39s	remaining: 3m 28s
# 2164:	learn: 0.0208192	total: 1m 39s	remaining: 3m 28s
# 2165:	learn: 0.0208191	total: 1m 39s	remaining: 3m 28s
# 2166:	learn: 0.0208190	total: 1m 39s	remaining: 3m 28s
# 2167:	learn: 0.0208190	total: 1m 39s	remaining: 3m 28s
# 2168:	learn: 0.0208189	total: 1m 39s	remaining: 3m 28s
# 2169:	learn: 0.0208189	total: 1m 39s	remaining: 3m 28s
# 2170:	learn: 0.0208188	total: 1m 39s	remaining: 3m 28s
# 2171:	learn: 0.0208188	total: 1m 39s	remaining: 3m 28s
# 2172:	learn: 0.0208187	total: 1m 39s	remaining: 3m 28s
# 2173:	learn: 0.0208187	total: 1m 39s	remaining: 3m 28s
# 2174:	learn: 0.0208186	total: 1m 39s	remaining: 3m 28s
# 2175:	learn: 0.0208185	total: 1m 39s	remaining: 3m 27s
# 2176:	learn: 0.0208185	total: 1m 40s	remaining: 3m 27s
# 2177:	learn: 0.0208184	total: 1m 40s	remaining: 3m 27s
# 2178:	learn: 0.0208184	total: 1m 40s	remaining: 3m 27s
# 2179:	learn: 0.0208183	total: 1m 40s	remaining: 3m 27s
# 2180:	learn: 0.0208183	total: 1m 40s	remaining: 3m 27s
# 2181:	learn: 0.0208182	total: 1m 40s	remaining: 3m 27s
# 2182:	learn: 0.0208182	total: 1m 40s	remaining: 3m 27s
# 2183:	learn: 0.0208181	total: 1m 40s	remaining: 3m 27s
# 2184:	learn: 0.0208181	total: 1m 40s	remaining: 3m 27s
# 2185:	learn: 0.0208180	total: 1m 40s	remaining: 3m 27s
# 2186:	learn: 0.0208179	total: 1m 40s	remaining: 3m 27s
# 2187:	learn: 0.0208179	total: 1m 40s	remaining: 3m 27s
# 2188:	learn: 0.0208178	total: 1m 40s	remaining: 3m 27s
# 2189:	learn: 0.0208178	total: 1m 40s	remaining: 3m 27s
# 2190:	learn: 0.0208177	total: 1m 40s	remaining: 3m 27s
# 2191:	learn: 0.0208177	total: 1m 40s	remaining: 3m 27s
# 2192:	learn: 0.0208176	total: 1m 40s	remaining: 3m 26s
# 2193:	learn: 0.0208176	total: 1m 40s	remaining: 3m 26s
# 2194:	learn: 0.0208175	total: 1m 40s	remaining: 3m 26s
# 2195:	learn: 0.0208175	total: 1m 40s	remaining: 3m 26s
# 2196:	learn: 0.0208174	total: 1m 40s	remaining: 3m 26s
# 2197:	learn: 0.0208173	total: 1m 40s	remaining: 3m 26s
# 2198:	learn: 0.0208173	total: 1m 40s	remaining: 3m 26s
# 2199:	learn: 0.0208172	total: 1m 40s	remaining: 3m 26s
# 2200:	learn: 0.0208172	total: 1m 40s	remaining: 3m 26s
# 2201:	learn: 0.0208171	total: 1m 41s	remaining: 3m 26s
# 2202:	learn: 0.0208171	total: 1m 41s	remaining: 3m 26s
# 2203:	learn: 0.0208170	total: 1m 41s	remaining: 3m 26s
# 2204:	learn: 0.0208170	total: 1m 41s	remaining: 3m 26s
# 2205:	learn: 0.0208169	total: 1m 41s	remaining: 3m 26s
# 2206:	learn: 0.0208169	total: 1m 41s	remaining: 3m 26s
# 2207:	learn: 0.0208168	total: 1m 41s	remaining: 3m 26s
# 2208:	learn: 0.0208168	total: 1m 41s	remaining: 3m 26s
# 2209:	learn: 0.0208167	total: 1m 41s	remaining: 3m 26s
# 2210:	learn: 0.0208166	total: 1m 41s	remaining: 3m 25s
# 2211:	learn: 0.0208166	total: 1m 41s	remaining: 3m 25s
# 2212:	learn: 0.0208165	total: 1m 41s	remaining: 3m 25s
# 2213:	learn: 0.0208165	total: 1m 41s	remaining: 3m 25s
# 2214:	learn: 0.0208164	total: 1m 41s	remaining: 3m 25s
# 2215:	learn: 0.0208164	total: 1m 41s	remaining: 3m 25s
# 2216:	learn: 0.0208163	total: 1m 41s	remaining: 3m 25s
# 2217:	learn: 0.0208163	total: 1m 41s	remaining: 3m 25s
# 2218:	learn: 0.0208162	total: 1m 41s	remaining: 3m 25s
# 2219:	learn: 0.0208162	total: 1m 41s	remaining: 3m 25s
# 2220:	learn: 0.0208161	total: 1m 41s	remaining: 3m 25s
# 2221:	learn: 0.0208161	total: 1m 41s	remaining: 3m 25s
# 2222:	learn: 0.0208160	total: 1m 41s	remaining: 3m 25s
# 2223:	learn: 0.0208159	total: 1m 41s	remaining: 3m 25s
# 2224:	learn: 0.0208159	total: 1m 41s	remaining: 3m 25s
# 2225:	learn: 0.0208158	total: 1m 41s	remaining: 3m 25s
# 2226:	learn: 0.0208158	total: 1m 42s	remaining: 3m 25s
# 2227:	learn: 0.0208157	total: 1m 42s	remaining: 3m 24s
# 2228:	learn: 0.0208157	total: 1m 42s	remaining: 3m 24s
# 2229:	learn: 0.0208156	total: 1m 42s	remaining: 3m 24s
# 2230:	learn: 0.0208156	total: 1m 42s	remaining: 3m 24s
# 2231:	learn: 0.0208155	total: 1m 42s	remaining: 3m 24s
# 2232:	learn: 0.0208155	total: 1m 42s	remaining: 3m 24s
# 2233:	learn: 0.0208154	total: 1m 42s	remaining: 3m 24s
# 2234:	learn: 0.0208154	total: 1m 42s	remaining: 3m 24s
# 2235:	learn: 0.0208153	total: 1m 42s	remaining: 3m 24s
# 2236:	learn: 0.0208153	total: 1m 42s	remaining: 3m 24s
# 2237:	learn: 0.0208152	total: 1m 42s	remaining: 3m 24s
# 2238:	learn: 0.0208152	total: 1m 42s	remaining: 3m 24s
# 2239:	learn: 0.0208151	total: 1m 42s	remaining: 3m 24s
# 2240:	learn: 0.0208150	total: 1m 42s	remaining: 3m 24s
# 2241:	learn: 0.0208150	total: 1m 42s	remaining: 3m 24s
# 2242:	learn: 0.0208149	total: 1m 42s	remaining: 3m 24s
# 2243:	learn: 0.0208149	total: 1m 42s	remaining: 3m 24s
# 2244:	learn: 0.0208148	total: 1m 42s	remaining: 3m 24s
# 2245:	learn: 0.0208148	total: 1m 42s	remaining: 3m 23s
# 2246:	learn: 0.0208147	total: 1m 42s	remaining: 3m 23s
# 2247:	learn: 0.0208147	total: 1m 42s	remaining: 3m 23s
# 2248:	learn: 0.0208146	total: 1m 42s	remaining: 3m 23s
# 2249:	learn: 0.0208146	total: 1m 42s	remaining: 3m 23s
# 2250:	learn: 0.0208145	total: 1m 42s	remaining: 3m 23s
# 2251:	learn: 0.0208145	total: 1m 43s	remaining: 3m 23s
# 2252:	learn: 0.0208144	total: 1m 43s	remaining: 3m 23s
# 2253:	learn: 0.0208144	total: 1m 43s	remaining: 3m 23s
# 2254:	learn: 0.0208143	total: 1m 43s	remaining: 3m 23s
# 2255:	learn: 0.0208143	total: 1m 43s	remaining: 3m 23s
# 2256:	learn: 0.0208142	total: 1m 43s	remaining: 3m 23s
# 2257:	learn: 0.0208142	total: 1m 43s	remaining: 3m 23s
# 2258:	learn: 0.0208141	total: 1m 43s	remaining: 3m 23s
# 2259:	learn: 0.0208141	total: 1m 43s	remaining: 3m 23s
# 2260:	learn: 0.0208140	total: 1m 43s	remaining: 3m 23s
# 2261:	learn: 0.0208140	total: 1m 43s	remaining: 3m 23s
# 2262:	learn: 0.0208139	total: 1m 43s	remaining: 3m 23s
# 2263:	learn: 0.0208139	total: 1m 43s	remaining: 3m 22s
# 2264:	learn: 0.0208138	total: 1m 43s	remaining: 3m 22s
# 2265:	learn: 0.0208138	total: 1m 43s	remaining: 3m 22s
# 2266:	learn: 0.0208137	total: 1m 43s	remaining: 3m 22s
# 2267:	learn: 0.0208137	total: 1m 43s	remaining: 3m 22s
# 2268:	learn: 0.0208136	total: 1m 43s	remaining: 3m 22s
# 2269:	learn: 0.0208135	total: 1m 43s	remaining: 3m 22s
# 2270:	learn: 0.0208135	total: 1m 43s	remaining: 3m 22s
# 2271:	learn: 0.0208134	total: 1m 43s	remaining: 3m 22s
# 2272:	learn: 0.0208134	total: 1m 43s	remaining: 3m 22s
# 2273:	learn: 0.0208133	total: 1m 43s	remaining: 3m 22s
# 2274:	learn: 0.0208133	total: 1m 43s	remaining: 3m 22s
# 2275:	learn: 0.0208132	total: 1m 43s	remaining: 3m 22s
# 2276:	learn: 0.0208132	total: 1m 44s	remaining: 3m 22s
# 2277:	learn: 0.0208131	total: 1m 44s	remaining: 3m 22s
# 2278:	learn: 0.0208131	total: 1m 44s	remaining: 3m 22s
# 2279:	learn: 0.0208130	total: 1m 44s	remaining: 3m 22s
# 2280:	learn: 0.0208130	total: 1m 44s	remaining: 3m 21s
# 2281:	learn: 0.0208129	total: 1m 44s	remaining: 3m 21s
# 2282:	learn: 0.0208129	total: 1m 44s	remaining: 3m 21s
# 2283:	learn: 0.0208128	total: 1m 44s	remaining: 3m 21s
# 2284:	learn: 0.0208128	total: 1m 44s	remaining: 3m 21s
# 2285:	learn: 0.0208127	total: 1m 44s	remaining: 3m 21s
# 2286:	learn: 0.0208127	total: 1m 44s	remaining: 3m 21s
# 2287:	learn: 0.0208126	total: 1m 44s	remaining: 3m 21s
# 2288:	learn: 0.0208126	total: 1m 44s	remaining: 3m 21s
# 2289:	learn: 0.0208125	total: 1m 44s	remaining: 3m 21s
# 2290:	learn: 0.0208125	total: 1m 44s	remaining: 3m 21s
# 2291:	learn: 0.0208124	total: 1m 44s	remaining: 3m 21s
# 2292:	learn: 0.0208124	total: 1m 44s	remaining: 3m 21s
# 2293:	learn: 0.0208123	total: 1m 44s	remaining: 3m 21s
# 2294:	learn: 0.0208123	total: 1m 44s	remaining: 3m 21s
# 2295:	learn: 0.0208122	total: 1m 44s	remaining: 3m 21s
# 2296:	learn: 0.0208122	total: 1m 44s	remaining: 3m 21s
# 2297:	learn: 0.0208121	total: 1m 44s	remaining: 3m 21s
# 2298:	learn: 0.0208121	total: 1m 44s	remaining: 3m 20s
# 2299:	learn: 0.0208120	total: 1m 44s	remaining: 3m 20s
# 2300:	learn: 0.0208120	total: 1m 45s	remaining: 3m 20s
# 2301:	learn: 0.0208119	total: 1m 45s	remaining: 3m 20s
# 2302:	learn: 0.0208118	total: 1m 45s	remaining: 3m 20s
# 2303:	learn: 0.0208118	total: 1m 45s	remaining: 3m 20s
# 2304:	learn: 0.0208117	total: 1m 45s	remaining: 3m 20s
# 2305:	learn: 0.0208117	total: 1m 45s	remaining: 3m 20s
# 2306:	learn: 0.0208116	total: 1m 45s	remaining: 3m 20s
# 2307:	learn: 0.0208116	total: 1m 45s	remaining: 3m 20s
# 2308:	learn: 0.0208115	total: 1m 45s	remaining: 3m 20s
# 2309:	learn: 0.0208115	total: 1m 45s	remaining: 3m 20s
# 2310:	learn: 0.0208114	total: 1m 45s	remaining: 3m 20s
# 2311:	learn: 0.0208114	total: 1m 45s	remaining: 3m 20s
# 2312:	learn: 0.0208113	total: 1m 45s	remaining: 3m 20s
# 2313:	learn: 0.0208113	total: 1m 45s	remaining: 3m 20s
# 2314:	learn: 0.0208112	total: 1m 45s	remaining: 3m 20s
# 2315:	learn: 0.0208112	total: 1m 45s	remaining: 3m 20s
# 2316:	learn: 0.0208111	total: 1m 45s	remaining: 3m 19s
# 2317:	learn: 0.0208111	total: 1m 45s	remaining: 3m 19s
# 2318:	learn: 0.0208110	total: 1m 45s	remaining: 3m 19s
# 2319:	learn: 0.0208110	total: 1m 45s	remaining: 3m 19s
# 2320:	learn: 0.0208109	total: 1m 45s	remaining: 3m 19s
# 2321:	learn: 0.0208109	total: 1m 45s	remaining: 3m 19s
# 2322:	learn: 0.0208108	total: 1m 45s	remaining: 3m 19s
# 2323:	learn: 0.0208108	total: 1m 45s	remaining: 3m 19s
# 2324:	learn: 0.0208107	total: 1m 45s	remaining: 3m 19s
# 2325:	learn: 0.0208107	total: 1m 46s	remaining: 3m 19s
# 2326:	learn: 0.0208106	total: 1m 46s	remaining: 3m 19s
# 2327:	learn: 0.0208106	total: 1m 46s	remaining: 3m 19s
# 2328:	learn: 0.0208105	total: 1m 46s	remaining: 3m 19s
# 2329:	learn: 0.0208105	total: 1m 46s	remaining: 3m 19s
# 2330:	learn: 0.0208104	total: 1m 46s	remaining: 3m 19s
# 2331:	learn: 0.0208104	total: 1m 46s	remaining: 3m 19s
# 2332:	learn: 0.0208103	total: 1m 46s	remaining: 3m 19s
# 2333:	learn: 0.0208103	total: 1m 46s	remaining: 3m 19s
# 2334:	learn: 0.0208102	total: 1m 46s	remaining: 3m 18s
# 2335:	learn: 0.0208102	total: 1m 46s	remaining: 3m 18s
# 2336:	learn: 0.0208101	total: 1m 46s	remaining: 3m 18s
# 2337:	learn: 0.0208101	total: 1m 46s	remaining: 3m 18s
# 2338:	learn: 0.0208100	total: 1m 46s	remaining: 3m 18s
# 2339:	learn: 0.0208100	total: 1m 46s	remaining: 3m 18s
# 2340:	learn: 0.0208099	total: 1m 46s	remaining: 3m 18s
# 2341:	learn: 0.0208099	total: 1m 46s	remaining: 3m 18s
# 2342:	learn: 0.0208098	total: 1m 46s	remaining: 3m 18s
# 2343:	learn: 0.0208098	total: 1m 46s	remaining: 3m 18s
# 2344:	learn: 0.0208097	total: 1m 46s	remaining: 3m 18s
# 2345:	learn: 0.0208097	total: 1m 46s	remaining: 3m 18s
# 2346:	learn: 0.0208096	total: 1m 46s	remaining: 3m 18s
# 2347:	learn: 0.0208096	total: 1m 46s	remaining: 3m 18s
# 2348:	learn: 0.0208095	total: 1m 46s	remaining: 3m 18s
# 2349:	learn: 0.0208095	total: 1m 46s	remaining: 3m 18s
# 2350:	learn: 0.0208094	total: 1m 47s	remaining: 3m 18s
# 2351:	learn: 0.0208094	total: 1m 47s	remaining: 3m 18s
# 2352:	learn: 0.0208093	total: 1m 47s	remaining: 3m 18s
# 2353:	learn: 0.0208093	total: 1m 47s	remaining: 3m 17s
# 2354:	learn: 0.0208092	total: 1m 47s	remaining: 3m 17s
# 2355:	learn: 0.0208092	total: 1m 47s	remaining: 3m 17s
# 2356:	learn: 0.0208091	total: 1m 47s	remaining: 3m 17s
# 2357:	learn: 0.0208091	total: 1m 47s	remaining: 3m 17s
# 2358:	learn: 0.0208090	total: 1m 47s	remaining: 3m 17s
# 2359:	learn: 0.0208090	total: 1m 47s	remaining: 3m 17s
# 2360:	learn: 0.0208089	total: 1m 47s	remaining: 3m 17s
# 2361:	learn: 0.0208089	total: 1m 47s	remaining: 3m 17s
# 2362:	learn: 0.0208088	total: 1m 47s	remaining: 3m 17s
# 2363:	learn: 0.0208088	total: 1m 47s	remaining: 3m 17s
# 2364:	learn: 0.0208088	total: 1m 47s	remaining: 3m 17s
# 2365:	learn: 0.0208087	total: 1m 47s	remaining: 3m 17s
# 2366:	learn: 0.0208087	total: 1m 47s	remaining: 3m 17s
# 2367:	learn: 0.0208086	total: 1m 47s	remaining: 3m 17s
# 2368:	learn: 0.0208086	total: 1m 47s	remaining: 3m 17s
# 2369:	learn: 0.0208085	total: 1m 48s	remaining: 3m 17s
# 2370:	learn: 0.0208085	total: 1m 48s	remaining: 3m 17s
# 2371:	learn: 0.0208084	total: 1m 48s	remaining: 3m 17s
# 2372:	learn: 0.0208084	total: 1m 48s	remaining: 3m 17s
# 2373:	learn: 0.0208083	total: 1m 48s	remaining: 3m 17s
# 2374:	learn: 0.0208083	total: 1m 48s	remaining: 3m 17s
# 2375:	learn: 0.0208082	total: 1m 48s	remaining: 3m 17s
# 2376:	learn: 0.0208082	total: 1m 48s	remaining: 3m 17s
# 2377:	learn: 0.0208081	total: 1m 48s	remaining: 3m 17s
# 2378:	learn: 0.0208081	total: 1m 48s	remaining: 3m 17s
# 2379:	learn: 0.0208080	total: 1m 48s	remaining: 3m 17s
# 2380:	learn: 0.0208080	total: 1m 48s	remaining: 3m 17s
# 2381:	learn: 0.0208079	total: 1m 48s	remaining: 3m 17s
# 2382:	learn: 0.0208079	total: 1m 49s	remaining: 3m 17s
# 2383:	learn: 0.0208078	total: 1m 49s	remaining: 3m 17s
# 2384:	learn: 0.0208078	total: 1m 49s	remaining: 3m 17s
# 2385:	learn: 0.0208077	total: 1m 49s	remaining: 3m 17s
# 2386:	learn: 0.0208077	total: 1m 49s	remaining: 3m 17s
# 2387:	learn: 0.0208076	total: 1m 49s	remaining: 3m 17s
# 2388:	learn: 0.0208076	total: 1m 49s	remaining: 3m 17s
# 2389:	learn: 0.0208075	total: 1m 49s	remaining: 3m 17s
# 2390:	learn: 0.0208075	total: 1m 49s	remaining: 3m 17s
# 2391:	learn: 0.0208074	total: 1m 49s	remaining: 3m 17s
# 2392:	learn: 0.0208074	total: 1m 49s	remaining: 3m 17s
# 2393:	learn: 0.0208073	total: 1m 49s	remaining: 3m 17s
# 2394:	learn: 0.0208073	total: 1m 49s	remaining: 3m 17s
# 2395:	learn: 0.0208073	total: 1m 50s	remaining: 3m 17s
# 2396:	learn: 0.0208072	total: 1m 50s	remaining: 3m 17s
# 2397:	learn: 0.0208072	total: 1m 50s	remaining: 3m 17s
# 2398:	learn: 0.0208071	total: 1m 50s	remaining: 3m 17s
# 2399:	learn: 0.0208071	total: 1m 50s	remaining: 3m 17s
# 2400:	learn: 0.0208070	total: 1m 50s	remaining: 3m 17s
# 2401:	learn: 0.0208070	total: 1m 50s	remaining: 3m 17s
# 2402:	learn: 0.0208069	total: 1m 50s	remaining: 3m 17s
# 2403:	learn: 0.0208069	total: 1m 50s	remaining: 3m 17s
# 2404:	learn: 0.0208068	total: 1m 50s	remaining: 3m 17s
# 2405:	learn: 0.0208068	total: 1m 50s	remaining: 3m 17s
# 2406:	learn: 0.0208067	total: 1m 50s	remaining: 3m 17s
# 2407:	learn: 0.0208067	total: 1m 50s	remaining: 3m 17s
# 2408:	learn: 0.0208066	total: 1m 50s	remaining: 3m 17s
# 2409:	learn: 0.0208066	total: 1m 50s	remaining: 3m 17s
# 2410:	learn: 0.0208065	total: 1m 51s	remaining: 3m 17s
# 2411:	learn: 0.0208065	total: 1m 51s	remaining: 3m 17s
# 2412:	learn: 0.0208064	total: 1m 51s	remaining: 3m 17s
# 2413:	learn: 0.0208064	total: 1m 51s	remaining: 3m 17s
# 2414:	learn: 0.0208063	total: 1m 51s	remaining: 3m 17s
# 2415:	learn: 0.0208063	total: 1m 51s	remaining: 3m 17s
# 2416:	learn: 0.0208062	total: 1m 51s	remaining: 3m 17s
# 2417:	learn: 0.0208062	total: 1m 51s	remaining: 3m 17s
# 2418:	learn: 0.0208061	total: 1m 51s	remaining: 3m 17s
# 2419:	learn: 0.0208061	total: 1m 51s	remaining: 3m 17s
# 2420:	learn: 0.0208060	total: 1m 51s	remaining: 3m 17s
# 2421:	learn: 0.0208060	total: 1m 51s	remaining: 3m 17s
# 2422:	learn: 0.0208060	total: 1m 51s	remaining: 3m 16s
# 2423:	learn: 0.0208059	total: 1m 51s	remaining: 3m 16s
# 2424:	learn: 0.0208059	total: 1m 51s	remaining: 3m 16s
# 2425:	learn: 0.0208058	total: 1m 51s	remaining: 3m 16s
# 2426:	learn: 0.0208058	total: 1m 51s	remaining: 3m 16s
# 2427:	learn: 0.0208057	total: 1m 51s	remaining: 3m 16s
# 2428:	learn: 0.0208057	total: 1m 51s	remaining: 3m 16s
# 2429:	learn: 0.0208056	total: 1m 51s	remaining: 3m 16s
# 2430:	learn: 0.0208056	total: 1m 51s	remaining: 3m 16s
# 2431:	learn: 0.0208055	total: 1m 51s	remaining: 3m 16s
# 2432:	learn: 0.0208055	total: 1m 51s	remaining: 3m 16s
# 2433:	learn: 0.0208054	total: 1m 51s	remaining: 3m 16s
# 2434:	learn: 0.0208054	total: 1m 51s	remaining: 3m 16s
# 2435:	learn: 0.0208053	total: 1m 52s	remaining: 3m 16s
# 2436:	learn: 0.0208053	total: 1m 52s	remaining: 3m 16s
# 2437:	learn: 0.0208052	total: 1m 52s	remaining: 3m 16s
# 2438:	learn: 0.0208052	total: 1m 52s	remaining: 3m 16s
# 2439:	learn: 0.0208051	total: 1m 52s	remaining: 3m 16s
# 2440:	learn: 0.0208051	total: 1m 52s	remaining: 3m 15s
# 2441:	learn: 0.0208050	total: 1m 52s	remaining: 3m 15s
# 2442:	learn: 0.0208050	total: 1m 52s	remaining: 3m 15s
# 2443:	learn: 0.0208050	total: 1m 52s	remaining: 3m 15s
# 2444:	learn: 0.0208049	total: 1m 52s	remaining: 3m 15s
# 2445:	learn: 0.0208049	total: 1m 52s	remaining: 3m 15s
# 2446:	learn: 0.0208048	total: 1m 52s	remaining: 3m 15s
# 2447:	learn: 0.0208048	total: 1m 52s	remaining: 3m 15s
# 2448:	learn: 0.0208047	total: 1m 52s	remaining: 3m 15s
# 2449:	learn: 0.0208047	total: 1m 52s	remaining: 3m 15s
# 2450:	learn: 0.0208046	total: 1m 52s	remaining: 3m 15s
# 2451:	learn: 0.0208046	total: 1m 52s	remaining: 3m 15s
# 2452:	learn: 0.0208045	total: 1m 52s	remaining: 3m 15s
# 2453:	learn: 0.0208045	total: 1m 52s	remaining: 3m 15s
# 2454:	learn: 0.0208044	total: 1m 52s	remaining: 3m 15s
# 2455:	learn: 0.0208044	total: 1m 52s	remaining: 3m 15s
# 2456:	learn: 0.0208043	total: 1m 52s	remaining: 3m 15s
# 2457:	learn: 0.0208043	total: 1m 52s	remaining: 3m 14s
# 2458:	learn: 0.0208042	total: 1m 52s	remaining: 3m 14s
# 2459:	learn: 0.0208042	total: 1m 52s	remaining: 3m 14s
# 2460:	learn: 0.0208042	total: 1m 53s	remaining: 3m 14s
# 2461:	learn: 0.0208041	total: 1m 53s	remaining: 3m 14s
# 2462:	learn: 0.0208041	total: 1m 53s	remaining: 3m 14s
# 2463:	learn: 0.0208040	total: 1m 53s	remaining: 3m 14s
# 2464:	learn: 0.0208040	total: 1m 53s	remaining: 3m 14s
# 2465:	learn: 0.0208039	total: 1m 53s	remaining: 3m 14s
# 2466:	learn: 0.0208039	total: 1m 53s	remaining: 3m 14s
# 2467:	learn: 0.0208038	total: 1m 53s	remaining: 3m 14s
# 2468:	learn: 0.0208038	total: 1m 53s	remaining: 3m 14s
# 2469:	learn: 0.0208037	total: 1m 53s	remaining: 3m 14s
# 2470:	learn: 0.0208037	total: 1m 53s	remaining: 3m 14s
# 2471:	learn: 0.0208036	total: 1m 53s	remaining: 3m 14s
# 2472:	learn: 0.0208036	total: 1m 53s	remaining: 3m 14s
# 2473:	learn: 0.0208035	total: 1m 53s	remaining: 3m 14s
# 2474:	learn: 0.0208035	total: 1m 53s	remaining: 3m 14s
# 2475:	learn: 0.0208035	total: 1m 53s	remaining: 3m 13s
# 2476:	learn: 0.0208034	total: 1m 53s	remaining: 3m 13s
# 2477:	learn: 0.0208034	total: 1m 53s	remaining: 3m 13s
# 2478:	learn: 0.0208033	total: 1m 53s	remaining: 3m 13s
# 2479:	learn: 0.0208033	total: 1m 53s	remaining: 3m 13s
# 2480:	learn: 0.0208032	total: 1m 53s	remaining: 3m 13s
# 2481:	learn: 0.0208032	total: 1m 53s	remaining: 3m 13s
# 2482:	learn: 0.0208031	total: 1m 53s	remaining: 3m 13s
# 2483:	learn: 0.0208031	total: 1m 53s	remaining: 3m 13s
# 2484:	learn: 0.0208030	total: 1m 53s	remaining: 3m 13s
# 2485:	learn: 0.0208030	total: 1m 54s	remaining: 3m 13s
# 2486:	learn: 0.0208029	total: 1m 54s	remaining: 3m 13s
# 2487:	learn: 0.0208029	total: 1m 54s	remaining: 3m 13s
# 2488:	learn: 0.0208029	total: 1m 54s	remaining: 3m 13s
# 2489:	learn: 0.0208028	total: 1m 54s	remaining: 3m 13s
# 2490:	learn: 0.0208028	total: 1m 54s	remaining: 3m 13s
# 2491:	learn: 0.0208027	total: 1m 54s	remaining: 3m 13s
# 2492:	learn: 0.0208027	total: 1m 54s	remaining: 3m 13s
# 2493:	learn: 0.0208026	total: 1m 54s	remaining: 3m 13s
# 2494:	learn: 0.0208026	total: 1m 54s	remaining: 3m 12s
# 2495:	learn: 0.0208025	total: 1m 54s	remaining: 3m 12s
# 2496:	learn: 0.0208025	total: 1m 54s	remaining: 3m 12s
# 2497:	learn: 0.0208024	total: 1m 54s	remaining: 3m 12s
# 2498:	learn: 0.0208024	total: 1m 54s	remaining: 3m 12s
# 2499:	learn: 0.0208024	total: 1m 54s	remaining: 3m 12s
# 2500:	learn: 0.0208023	total: 1m 54s	remaining: 3m 12s
# 2501:	learn: 0.0208023	total: 1m 54s	remaining: 3m 12s
# 2502:	learn: 0.0208022	total: 1m 54s	remaining: 3m 12s
# 2503:	learn: 0.0208022	total: 1m 54s	remaining: 3m 12s
# 2504:	learn: 0.0208021	total: 1m 54s	remaining: 3m 12s
# 2505:	learn: 0.0208021	total: 1m 54s	remaining: 3m 12s
# 2506:	learn: 0.0208020	total: 1m 54s	remaining: 3m 12s
# 2507:	learn: 0.0208020	total: 1m 54s	remaining: 3m 12s
# 2508:	learn: 0.0208020	total: 1m 54s	remaining: 3m 12s
# 2509:	learn: 0.0208019	total: 1m 54s	remaining: 3m 12s
# 2510:	learn: 0.0208019	total: 1m 55s	remaining: 3m 12s
# 2511:	learn: 0.0208018	total: 1m 55s	remaining: 3m 11s
# 2512:	learn: 0.0208018	total: 1m 55s	remaining: 3m 11s
# 2513:	learn: 0.0208017	total: 1m 55s	remaining: 3m 11s
# 2514:	learn: 0.0208017	total: 1m 55s	remaining: 3m 11s
# 2515:	learn: 0.0208016	total: 1m 55s	remaining: 3m 11s
# 2516:	learn: 0.0208016	total: 1m 55s	remaining: 3m 11s
# 2517:	learn: 0.0208015	total: 1m 55s	remaining: 3m 11s
# 2518:	learn: 0.0208015	total: 1m 55s	remaining: 3m 11s
# 2519:	learn: 0.0208015	total: 1m 55s	remaining: 3m 11s
# 2520:	learn: 0.0208014	total: 1m 55s	remaining: 3m 11s
# 2521:	learn: 0.0208014	total: 1m 55s	remaining: 3m 11s
# 2522:	learn: 0.0208013	total: 1m 55s	remaining: 3m 11s
# 2523:	learn: 0.0208013	total: 1m 55s	remaining: 3m 11s
# 2524:	learn: 0.0208012	total: 1m 55s	remaining: 3m 11s
# 2525:	learn: 0.0208012	total: 1m 55s	remaining: 3m 11s
# 2526:	learn: 0.0208011	total: 1m 55s	remaining: 3m 11s
# 2527:	learn: 0.0208011	total: 1m 55s	remaining: 3m 11s
# 2528:	learn: 0.0208010	total: 1m 55s	remaining: 3m 11s
# 2529:	learn: 0.0208010	total: 1m 55s	remaining: 3m 11s
# 2530:	learn: 0.0208010	total: 1m 55s	remaining: 3m 10s
# 2531:	learn: 0.0208009	total: 1m 55s	remaining: 3m 10s
# 2532:	learn: 0.0208009	total: 1m 55s	remaining: 3m 10s
# 2533:	learn: 0.0208008	total: 1m 55s	remaining: 3m 10s
# 2534:	learn: 0.0208008	total: 1m 55s	remaining: 3m 10s
# 2535:	learn: 0.0208007	total: 1m 56s	remaining: 3m 10s
# 2536:	learn: 0.0208007	total: 1m 56s	remaining: 3m 10s
# 2537:	learn: 0.0208006	total: 1m 56s	remaining: 3m 10s
# 2538:	learn: 0.0208006	total: 1m 56s	remaining: 3m 10s
# 2539:	learn: 0.0208006	total: 1m 56s	remaining: 3m 10s
# 2540:	learn: 0.0208005	total: 1m 56s	remaining: 3m 10s
# 2541:	learn: 0.0208005	total: 1m 56s	remaining: 3m 10s
# 2542:	learn: 0.0208004	total: 1m 56s	remaining: 3m 10s
# 2543:	learn: 0.0208004	total: 1m 56s	remaining: 3m 10s
# 2544:	learn: 0.0208003	total: 1m 56s	remaining: 3m 10s
# 2545:	learn: 0.0208003	total: 1m 56s	remaining: 3m 10s
# 2546:	learn: 0.0208002	total: 1m 56s	remaining: 3m 10s
# 2547:	learn: 0.0208002	total: 1m 56s	remaining: 3m 10s
# 2548:	learn: 0.0208002	total: 1m 56s	remaining: 3m 9s
# 2549:	learn: 0.0208001	total: 1m 56s	remaining: 3m 9s
# 2550:	learn: 0.0208001	total: 1m 56s	remaining: 3m 9s
# 2551:	learn: 0.0208000	total: 1m 56s	remaining: 3m 9s
# 2552:	learn: 0.0208000	total: 1m 56s	remaining: 3m 9s
# 2553:	learn: 0.0207999	total: 1m 56s	remaining: 3m 9s
# 2554:	learn: 0.0207999	total: 1m 56s	remaining: 3m 9s
# 2555:	learn: 0.0207998	total: 1m 56s	remaining: 3m 9s
# 2556:	learn: 0.0207998	total: 1m 56s	remaining: 3m 9s
# 2557:	learn: 0.0207998	total: 1m 56s	remaining: 3m 9s
# 2558:	learn: 0.0207997	total: 1m 56s	remaining: 3m 9s
# 2559:	learn: 0.0207997	total: 1m 57s	remaining: 3m 9s
# 2560:	learn: 0.0207996	total: 1m 57s	remaining: 3m 9s
# 2561:	learn: 0.0207996	total: 1m 57s	remaining: 3m 9s
# 2562:	learn: 0.0207995	total: 1m 57s	remaining: 3m 9s
# 2563:	learn: 0.0207995	total: 1m 57s	remaining: 3m 9s
# 2564:	learn: 0.0207994	total: 1m 57s	remaining: 3m 9s
# 2565:	learn: 0.0207994	total: 1m 57s	remaining: 3m 9s
# 2566:	learn: 0.0207994	total: 1m 57s	remaining: 3m 9s
# 2567:	learn: 0.0207993	total: 1m 57s	remaining: 3m 8s
# 2568:	learn: 0.0207993	total: 1m 57s	remaining: 3m 8s
# 2569:	learn: 0.0207992	total: 1m 57s	remaining: 3m 8s
# 2570:	learn: 0.0207992	total: 1m 57s	remaining: 3m 8s
# 2571:	learn: 0.0207991	total: 1m 57s	remaining: 3m 8s
# 2572:	learn: 0.0207991	total: 1m 57s	remaining: 3m 8s
# 2573:	learn: 0.0207990	total: 1m 57s	remaining: 3m 8s
# 2574:	learn: 0.0207990	total: 1m 57s	remaining: 3m 8s
# ...
# 6402:	learn: 0.0207153	total: 4m 53s	remaining: 13.7s
# 6403:	learn: 0.0207153	total: 4m 53s	remaining: 13.7s
# 6404:	learn: 0.0207153	total: 4m 53s	remaining: 13.6s
# 6405:	learn: 0.0207152	total: 4m 53s	remaining: 13.6s
# 6406:	learn: 0.0207152	total: 4m 53s	remaining: 13.6s
# 6407:	learn: 0.0207152	total: 4m 53s	remaining: 13.5s
# 6408:	learn: 0.0207152	total: 4m 53s	remaining: 13.5s
# 6409:	learn: 0.0207152	total: 4m 53s	remaining: 13.4s
# 6410:	learn: 0.0207152	total: 4m 53s	remaining: 13.4s
# 6411:	learn: 0.0207152	total: 4m 53s	remaining: 13.3s
# 6412:	learn: 0.0207152	total: 4m 53s	remaining: 13.3s
# 6413:	learn: 0.0207152	total: 4m 53s	remaining: 13.2s
# 6414:	learn: 0.0207151	total: 4m 53s	remaining: 13.2s
# 6415:	learn: 0.0207151	total: 4m 53s	remaining: 13.1s
# 6416:	learn: 0.0207151	total: 4m 53s	remaining: 13.1s
# 6417:	learn: 0.0207151	total: 4m 53s	remaining: 13s
# 6418:	learn: 0.0207151	total: 4m 53s	remaining: 13s
# 6419:	learn: 0.0207151	total: 4m 53s	remaining: 13s
# 6420:	learn: 0.0207151	total: 4m 54s	remaining: 12.9s
# 6421:	learn: 0.0207151	total: 4m 54s	remaining: 12.9s
# 6422:	learn: 0.0207151	total: 4m 54s	remaining: 12.8s
# 6423:	learn: 0.0207150	total: 4m 54s	remaining: 12.8s
# 6424:	learn: 0.0207150	total: 4m 54s	remaining: 12.7s
# 6425:	learn: 0.0207150	total: 4m 54s	remaining: 12.7s
# 6426:	learn: 0.0207150	total: 4m 54s	remaining: 12.6s
# 6427:	learn: 0.0207150	total: 4m 54s	remaining: 12.6s
# 6428:	learn: 0.0207150	total: 4m 54s	remaining: 12.6s
# 6429:	learn: 0.0207150	total: 4m 54s	remaining: 12.5s
# 6430:	learn: 0.0207150	total: 4m 54s	remaining: 12.5s
# 6431:	learn: 0.0207150	total: 4m 54s	remaining: 12.4s
# 6432:	learn: 0.0207149	total: 4m 54s	remaining: 12.4s
# 6433:	learn: 0.0207149	total: 4m 54s	remaining: 12.3s
# 6434:	learn: 0.0207149	total: 4m 55s	remaining: 12.3s
# 6435:	learn: 0.0207149	total: 4m 55s	remaining: 12.2s
# 6436:	learn: 0.0207149	total: 4m 55s	remaining: 12.2s
# 6437:	learn: 0.0207149	total: 4m 55s	remaining: 12.2s
# 6438:	learn: 0.0207149	total: 4m 55s	remaining: 12.1s
# 6439:	learn: 0.0207149	total: 4m 55s	remaining: 12.1s
# 6440:	learn: 0.0207149	total: 4m 55s	remaining: 12s
# 6441:	learn: 0.0207148	total: 4m 55s	remaining: 12s
# 6442:	learn: 0.0207148	total: 4m 55s	remaining: 11.9s
# 6443:	learn: 0.0207148	total: 4m 55s	remaining: 11.9s
# 6444:	learn: 0.0207148	total: 4m 55s	remaining: 11.8s
# 6445:	learn: 0.0207148	total: 4m 55s	remaining: 11.8s
# 6446:	learn: 0.0207148	total: 4m 55s	remaining: 11.8s
# 6447:	learn: 0.0207148	total: 4m 56s	remaining: 11.7s
# 6448:	learn: 0.0207148	total: 4m 56s	remaining: 11.7s
# 6449:	learn: 0.0207148	total: 4m 56s	remaining: 11.6s
# 6450:	learn: 0.0207147	total: 4m 56s	remaining: 11.6s
# 6451:	learn: 0.0207147	total: 4m 56s	remaining: 11.5s
# 6452:	learn: 0.0207147	total: 4m 56s	remaining: 11.5s
# 6453:	learn: 0.0207147	total: 4m 56s	remaining: 11.4s
# 6454:	learn: 0.0207147	total: 4m 56s	remaining: 11.4s
# 6455:	learn: 0.0207147	total: 4m 56s	remaining: 11.3s
# 6456:	learn: 0.0207147	total: 4m 56s	remaining: 11.3s
# 6457:	learn: 0.0207147	total: 4m 56s	remaining: 11.3s
# 6458:	learn: 0.0207147	total: 4m 56s	remaining: 11.2s
# 6459:	learn: 0.0207146	total: 4m 56s	remaining: 11.2s
# 6460:	learn: 0.0207146	total: 4m 56s	remaining: 11.1s
# 6461:	learn: 0.0207146	total: 4m 57s	remaining: 11.1s
# 6462:	learn: 0.0207146	total: 4m 57s	remaining: 11s
# 6463:	learn: 0.0207146	total: 4m 57s	remaining: 11s
# 6464:	learn: 0.0207146	total: 4m 57s	remaining: 10.9s
# 6465:	learn: 0.0207146	total: 4m 57s	remaining: 10.9s
# 6466:	learn: 0.0207146	total: 4m 57s	remaining: 10.9s
# 6467:	learn: 0.0207146	total: 4m 57s	remaining: 10.8s
# 6468:	learn: 0.0207145	total: 4m 57s	remaining: 10.8s
# 6469:	learn: 0.0207145	total: 4m 57s	remaining: 10.7s
# 6470:	learn: 0.0207145	total: 4m 57s	remaining: 10.7s
# 6471:	learn: 0.0207145	total: 4m 57s	remaining: 10.6s
# 6472:	learn: 0.0207145	total: 4m 57s	remaining: 10.6s
# 6473:	learn: 0.0207145	total: 4m 57s	remaining: 10.5s
# 6474:	learn: 0.0207145	total: 4m 57s	remaining: 10.5s
# 6475:	learn: 0.0207145	total: 4m 57s	remaining: 10.4s
# 6476:	learn: 0.0207145	total: 4m 57s	remaining: 10.4s
# 6477:	learn: 0.0207144	total: 4m 57s	remaining: 10.3s
# 6478:	learn: 0.0207144	total: 4m 57s	remaining: 10.3s
# 6479:	learn: 0.0207144	total: 4m 57s	remaining: 10.3s
# 6480:	learn: 0.0207144	total: 4m 57s	remaining: 10.2s
# 6481:	learn: 0.0207144	total: 4m 58s	remaining: 10.2s
# 6482:	learn: 0.0207144	total: 4m 58s	remaining: 10.1s
# 6483:	learn: 0.0207144	total: 4m 58s	remaining: 10.1s
# 6484:	learn: 0.0207144	total: 4m 58s	remaining: 10s
# 6485:	learn: 0.0207144	total: 4m 58s	remaining: 9.98s
# 6486:	learn: 0.0207143	total: 4m 58s	remaining: 9.93s
# 6487:	learn: 0.0207143	total: 4m 58s	remaining: 9.88s
# 6488:	learn: 0.0207143	total: 4m 58s	remaining: 9.84s
# 6489:	learn: 0.0207143	total: 4m 58s	remaining: 9.79s
# 6490:	learn: 0.0207143	total: 4m 58s	remaining: 9.74s
# 6491:	learn: 0.0207143	total: 4m 58s	remaining: 9.7s
# 6492:	learn: 0.0207143	total: 4m 58s	remaining: 9.65s
# 6493:	learn: 0.0207143	total: 4m 58s	remaining: 9.61s
# 6494:	learn: 0.0207143	total: 4m 58s	remaining: 9.56s
# 6495:	learn: 0.0207142	total: 4m 58s	remaining: 9.51s
# 6496:	learn: 0.0207142	total: 4m 58s	remaining: 9.47s
# 6497:	learn: 0.0207142	total: 4m 58s	remaining: 9.42s
# 6498:	learn: 0.0207142	total: 4m 58s	remaining: 9.38s
# 6499:	learn: 0.0207142	total: 4m 58s	remaining: 9.33s
# 6500:	learn: 0.0207142	total: 4m 58s	remaining: 9.28s
# 6501:	learn: 0.0207142	total: 4m 58s	remaining: 9.24s
# 6502:	learn: 0.0207142	total: 4m 58s	remaining: 9.19s
# 6503:	learn: 0.0207142	total: 4m 58s	remaining: 9.14s
# 6504:	learn: 0.0207141	total: 4m 58s	remaining: 9.1s
# 6505:	learn: 0.0207141	total: 4m 58s	remaining: 9.05s
# 6506:	learn: 0.0207141	total: 4m 59s	remaining: 9.01s
# 6507:	learn: 0.0207141	total: 4m 59s	remaining: 8.96s
# 6508:	learn: 0.0207141	total: 4m 59s	remaining: 8.91s
# 6509:	learn: 0.0207141	total: 4m 59s	remaining: 8.87s
# 6510:	learn: 0.0207141	total: 4m 59s	remaining: 8.82s
# 6511:	learn: 0.0207141	total: 4m 59s	remaining: 8.78s
# 6512:	learn: 0.0207141	total: 4m 59s	remaining: 8.73s
# 6513:	learn: 0.0207140	total: 4m 59s	remaining: 8.68s
# 6514:	learn: 0.0207140	total: 4m 59s	remaining: 8.64s
# 6515:	learn: 0.0207140	total: 4m 59s	remaining: 8.59s
# 6516:	learn: 0.0207140	total: 4m 59s	remaining: 8.55s
# 6517:	learn: 0.0207140	total: 4m 59s	remaining: 8.5s
# 6518:	learn: 0.0207140	total: 4m 59s	remaining: 8.45s
# 6519:	learn: 0.0207140	total: 4m 59s	remaining: 8.41s
# 6520:	learn: 0.0207140	total: 4m 59s	remaining: 8.36s
# 6521:	learn: 0.0207140	total: 4m 59s	remaining: 8.31s
# 6522:	learn: 0.0207139	total: 4m 59s	remaining: 8.27s
# 6523:	learn: 0.0207139	total: 4m 59s	remaining: 8.22s
# 6524:	learn: 0.0207139	total: 4m 59s	remaining: 8.18s
# 6525:	learn: 0.0207139	total: 4m 59s	remaining: 8.13s
# 6526:	learn: 0.0207139	total: 4m 59s	remaining: 8.09s
# 6527:	learn: 0.0207139	total: 4m 59s	remaining: 8.04s
# 6528:	learn: 0.0207139	total: 4m 59s	remaining: 7.99s
# 6529:	learn: 0.0207139	total: 4m 59s	remaining: 7.95s
# 6530:	learn: 0.0207139	total: 5m	remaining: 7.9s
# 6531:	learn: 0.0207138	total: 5m	remaining: 7.86s
# 6532:	learn: 0.0207138	total: 5m	remaining: 7.81s
# 6533:	learn: 0.0207138	total: 5m	remaining: 7.76s
# 6534:	learn: 0.0207138	total: 5m	remaining: 7.72s
# 6535:	learn: 0.0207138	total: 5m	remaining: 7.67s
# 6536:	learn: 0.0207138	total: 5m	remaining: 7.62s
# 6537:	learn: 0.0207138	total: 5m	remaining: 7.58s
# 6538:	learn: 0.0207138	total: 5m	remaining: 7.53s
# 6539:	learn: 0.0207138	total: 5m	remaining: 7.49s
# 6540:	learn: 0.0207137	total: 5m	remaining: 7.44s
# 6541:	learn: 0.0207137	total: 5m	remaining: 7.39s
# 6542:	learn: 0.0207137	total: 5m	remaining: 7.35s
# 6543:	learn: 0.0207137	total: 5m	remaining: 7.3s
# 6544:	learn: 0.0207137	total: 5m	remaining: 7.26s
# 6545:	learn: 0.0207137	total: 5m	remaining: 7.21s
# 6546:	learn: 0.0207137	total: 5m	remaining: 7.16s
# 6547:	learn: 0.0207137	total: 5m	remaining: 7.12s
# 6548:	learn: 0.0207137	total: 5m	remaining: 7.07s
# 6549:	learn: 0.0207137	total: 5m	remaining: 7.03s
# 6550:	learn: 0.0207136	total: 5m	remaining: 6.98s
# 6551:	learn: 0.0207136	total: 5m	remaining: 6.93s
# 6552:	learn: 0.0207136	total: 5m	remaining: 6.89s
# 6553:	learn: 0.0207136	total: 5m	remaining: 6.84s
# 6554:	learn: 0.0207136	total: 5m 1s	remaining: 6.8s
# 6555:	learn: 0.0207136	total: 5m 1s	remaining: 6.75s
# 6556:	learn: 0.0207136	total: 5m 1s	remaining: 6.7s
# 6557:	learn: 0.0207136	total: 5m 1s	remaining: 6.66s
# 6558:	learn: 0.0207136	total: 5m 1s	remaining: 6.61s
# 6559:	learn: 0.0207135	total: 5m 1s	remaining: 6.57s
# 6560:	learn: 0.0207135	total: 5m 1s	remaining: 6.52s
# 6561:	learn: 0.0207135	total: 5m 1s	remaining: 6.47s
# 6562:	learn: 0.0207135	total: 5m 1s	remaining: 6.43s
# 6563:	learn: 0.0207135	total: 5m 1s	remaining: 6.38s
# 6564:	learn: 0.0207135	total: 5m 1s	remaining: 6.34s
# 6565:	learn: 0.0207135	total: 5m 1s	remaining: 6.29s
# 6566:	learn: 0.0207135	total: 5m 1s	remaining: 6.24s
# 6567:	learn: 0.0207135	total: 5m 1s	remaining: 6.2s
# 6568:	learn: 0.0207134	total: 5m 1s	remaining: 6.15s
# 6569:	learn: 0.0207134	total: 5m 1s	remaining: 6.11s
# 6570:	learn: 0.0207134	total: 5m 1s	remaining: 6.06s
# 6571:	learn: 0.0207134	total: 5m 1s	remaining: 6.01s
# 6572:	learn: 0.0207134	total: 5m 1s	remaining: 5.97s
# 6573:	learn: 0.0207134	total: 5m 1s	remaining: 5.92s
# 6574:	learn: 0.0207134	total: 5m 1s	remaining: 5.88s
# 6575:	learn: 0.0207134	total: 5m 1s	remaining: 5.83s
# 6576:	learn: 0.0207134	total: 5m 1s	remaining: 5.79s
# 6577:	learn: 0.0207133	total: 5m 2s	remaining: 5.74s
# 6578:	learn: 0.0207133	total: 5m 2s	remaining: 5.69s
# 6579:	learn: 0.0207133	total: 5m 2s	remaining: 5.65s
# 6580:	learn: 0.0207133	total: 5m 2s	remaining: 5.6s
# 6581:	learn: 0.0207133	total: 5m 2s	remaining: 5.55s
# 6582:	learn: 0.0207133	total: 5m 2s	remaining: 5.51s
# 6583:	learn: 0.0207133	total: 5m 2s	remaining: 5.46s
# 6584:	learn: 0.0207133	total: 5m 2s	remaining: 5.42s
# 6585:	learn: 0.0207133	total: 5m 2s	remaining: 5.37s
# 6586:	learn: 0.0207132	total: 5m 2s	remaining: 5.32s
# 6587:	learn: 0.0207132	total: 5m 2s	remaining: 5.28s
# 6588:	learn: 0.0207132	total: 5m 2s	remaining: 5.23s
# 6589:	learn: 0.0207132	total: 5m 2s	remaining: 5.19s
# 6590:	learn: 0.0207132	total: 5m 2s	remaining: 5.14s
# 6591:	learn: 0.0207132	total: 5m 2s	remaining: 5.09s
# 6592:	learn: 0.0207132	total: 5m 2s	remaining: 5.05s
# 6593:	learn: 0.0207132	total: 5m 2s	remaining: 5s
# 6594:	learn: 0.0207132	total: 5m 2s	remaining: 4.96s
# 6595:	learn: 0.0207132	total: 5m 2s	remaining: 4.91s
# 6596:	learn: 0.0207131	total: 5m 2s	remaining: 4.87s
# 6597:	learn: 0.0207131	total: 5m 2s	remaining: 4.82s
# 6598:	learn: 0.0207131	total: 5m 2s	remaining: 4.77s
# 6599:	learn: 0.0207131	total: 5m 2s	remaining: 4.73s
# 6600:	learn: 0.0207131	total: 5m 2s	remaining: 4.68s
# 6601:	learn: 0.0207131	total: 5m 3s	remaining: 4.63s
# 6602:	learn: 0.0207131	total: 5m 3s	remaining: 4.59s
# 6603:	learn: 0.0207131	total: 5m 3s	remaining: 4.54s
# 6604:	learn: 0.0207131	total: 5m 3s	remaining: 4.5s
# 6605:	learn: 0.0207130	total: 5m 3s	remaining: 4.45s
# 6606:	learn: 0.0207130	total: 5m 3s	remaining: 4.41s
# 6607:	learn: 0.0207130	total: 5m 3s	remaining: 4.36s
# 6608:	learn: 0.0207130	total: 5m 3s	remaining: 4.31s
# 6609:	learn: 0.0207130	total: 5m 3s	remaining: 4.27s
# 6610:	learn: 0.0207130	total: 5m 3s	remaining: 4.22s
# 6611:	learn: 0.0207130	total: 5m 3s	remaining: 4.17s
# 6612:	learn: 0.0207130	total: 5m 3s	remaining: 4.13s
# 6613:	learn: 0.0207130	total: 5m 3s	remaining: 4.08s
# 6614:	learn: 0.0207130	total: 5m 3s	remaining: 4.04s
# 6615:	learn: 0.0207129	total: 5m 3s	remaining: 3.99s
# 6616:	learn: 0.0207129	total: 5m 3s	remaining: 3.94s
# 6617:	learn: 0.0207129	total: 5m 3s	remaining: 3.9s
# 6618:	learn: 0.0207129	total: 5m 3s	remaining: 3.85s
# 6619:	learn: 0.0207129	total: 5m 3s	remaining: 3.81s
# 6620:	learn: 0.0207129	total: 5m 3s	remaining: 3.76s
# 6621:	learn: 0.0207129	total: 5m 3s	remaining: 3.72s
# 6622:	learn: 0.0207129	total: 5m 3s	remaining: 3.67s
# 6623:	learn: 0.0207129	total: 5m 3s	remaining: 3.62s
# 6624:	learn: 0.0207128	total: 5m 3s	remaining: 3.58s
# 6625:	learn: 0.0207128	total: 5m 3s	remaining: 3.53s
# 6626:	learn: 0.0207128	total: 5m 4s	remaining: 3.49s
# 6627:	learn: 0.0207128	total: 5m 4s	remaining: 3.44s
# 6628:	learn: 0.0207128	total: 5m 4s	remaining: 3.39s
# 6629:	learn: 0.0207128	total: 5m 4s	remaining: 3.35s
# 6630:	learn: 0.0207128	total: 5m 4s	remaining: 3.3s
# 6631:	learn: 0.0207128	total: 5m 4s	remaining: 3.26s
# 6632:	learn: 0.0207128	total: 5m 4s	remaining: 3.21s
# 6633:	learn: 0.0207127	total: 5m 4s	remaining: 3.17s
# 6634:	learn: 0.0207127	total: 5m 4s	remaining: 3.12s
# 6635:	learn: 0.0207127	total: 5m 4s	remaining: 3.07s
# 6636:	learn: 0.0207127	total: 5m 4s	remaining: 3.03s
# 6637:	learn: 0.0207127	total: 5m 4s	remaining: 2.98s
# 6638:	learn: 0.0207127	total: 5m 4s	remaining: 2.94s
# 6639:	learn: 0.0207127	total: 5m 4s	remaining: 2.89s
# 6640:	learn: 0.0207127	total: 5m 4s	remaining: 2.84s
# 6641:	learn: 0.0207127	total: 5m 4s	remaining: 2.8s
# 6642:	learn: 0.0207127	total: 5m 4s	remaining: 2.75s
# 6643:	learn: 0.0207126	total: 5m 4s	remaining: 2.71s
# 6644:	learn: 0.0207126	total: 5m 4s	remaining: 2.66s
# 6645:	learn: 0.0207126	total: 5m 4s	remaining: 2.61s
# 6646:	learn: 0.0207126	total: 5m 4s	remaining: 2.57s
# 6647:	learn: 0.0207126	total: 5m 4s	remaining: 2.52s
# 6648:	learn: 0.0207126	total: 5m 4s	remaining: 2.48s
# 6649:	learn: 0.0207126	total: 5m 4s	remaining: 2.43s
# 6650:	learn: 0.0207126	total: 5m 5s	remaining: 2.38s
# 6651:	learn: 0.0207126	total: 5m 5s	remaining: 2.34s
# 6652:	learn: 0.0207125	total: 5m 5s	remaining: 2.29s
# 6653:	learn: 0.0207125	total: 5m 5s	remaining: 2.25s
# 6654:	learn: 0.0207125	total: 5m 5s	remaining: 2.2s
# 6655:	learn: 0.0207125	total: 5m 5s	remaining: 2.15s
# 6656:	learn: 0.0207125	total: 5m 5s	remaining: 2.11s
# 6657:	learn: 0.0207125	total: 5m 5s	remaining: 2.06s
# 6658:	learn: 0.0207125	total: 5m 5s	remaining: 2.02s
# 6659:	learn: 0.0207125	total: 5m 5s	remaining: 1.97s
# 6660:	learn: 0.0207125	total: 5m 5s	remaining: 1.93s
# 6661:	learn: 0.0207125	total: 5m 5s	remaining: 1.88s
# 6662:	learn: 0.0207124	total: 5m 5s	remaining: 1.83s
# 6663:	learn: 0.0207124	total: 5m 5s	remaining: 1.79s
# 6664:	learn: 0.0207124	total: 5m 5s	remaining: 1.74s
# 6665:	learn: 0.0207124	total: 5m 5s	remaining: 1.7s
# 6666:	learn: 0.0207124	total: 5m 5s	remaining: 1.65s
# 6667:	learn: 0.0207124	total: 5m 5s	remaining: 1.6s
# 6668:	learn: 0.0207124	total: 5m 5s	remaining: 1.56s
# 6669:	learn: 0.0207124	total: 5m 5s	remaining: 1.51s
# 6670:	learn: 0.0207124	total: 5m 5s	remaining: 1.47s
# 6671:	learn: 0.0207123	total: 5m 5s	remaining: 1.42s
# 6672:	learn: 0.0207123	total: 5m 5s	remaining: 1.38s
# 6673:	learn: 0.0207123	total: 5m 5s	remaining: 1.33s
# 6674:	learn: 0.0207123	total: 5m 6s	remaining: 1.28s
# 6675:	learn: 0.0207123	total: 5m 6s	remaining: 1.24s
# 6676:	learn: 0.0207123	total: 5m 6s	remaining: 1.19s
# 6677:	learn: 0.0207123	total: 5m 6s	remaining: 1.15s
# 6678:	learn: 0.0207123	total: 5m 6s	remaining: 1.1s
# 6679:	learn: 0.0207123	total: 5m 6s	remaining: 1.05s
# 6680:	learn: 0.0207123	total: 5m 6s	remaining: 1.01s
# 6681:	learn: 0.0207122	total: 5m 6s	remaining: 963ms
# 6682:	learn: 0.0207122	total: 5m 6s	remaining: 917ms
# 6683:	learn: 0.0207122	total: 5m 6s	remaining: 871ms
# 6684:	learn: 0.0207122	total: 5m 6s	remaining: 825ms
# 6685:	learn: 0.0207122	total: 5m 6s	remaining: 779ms
# 6686:	learn: 0.0207122	total: 5m 6s	remaining: 733ms
# 6687:	learn: 0.0207122	total: 5m 6s	remaining: 688ms
# 6688:	learn: 0.0207122	total: 5m 6s	remaining: 642ms
# 6689:	learn: 0.0207122	total: 5m 6s	remaining: 596ms
# 6690:	learn: 0.0207121	total: 5m 6s	remaining: 550ms
# 6691:	learn: 0.0207121	total: 5m 6s	remaining: 504ms
# 6692:	learn: 0.0207121	total: 5m 6s	remaining: 458ms
# 6693:	learn: 0.0207121	total: 5m 6s	remaining: 412ms
# 6694:	learn: 0.0207121	total: 5m 6s	remaining: 367ms
# 6695:	learn: 0.0207121	total: 5m 6s	remaining: 321ms
# 6696:	learn: 0.0207121	total: 5m 6s	remaining: 275ms
# 6697:	learn: 0.0207121	total: 5m 6s	remaining: 229ms
# 6698:	learn: 0.0207121	total: 5m 6s	remaining: 183ms
# 6699:	learn: 0.0207121	total: 5m 7s	remaining: 137ms
# 6700:	learn: 0.0207120	total: 5m 7s	remaining: 91.7ms
# 6701:	learn: 0.0207120	total: 5m 7s	remaining: 45.8ms
# 6702:	learn: 0.0207120	total: 5m 7s	remaining: 0us

# %%
import joblib
joblib.dump(model, '/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/model.pkl')
# Out:
# ['/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/model.pkl']

# %% [markdown]
# ### test 데이터 전처리

# %% [markdown]
# ##### test AWS 전처리 및 병합

# %%
# test aws : 년, 월, 일, 시 컬럼 생성 / 연도, 일시 컬럼 삭제
def datetime_testaws(data):
    for i in range(len(data)):
        data.loc[i, '년'] = 2021
    for i in range(len(data)):
        data.loc[i, '월'] = int(str(data.loc[i, '일시'])[:2])
    for i in range(len(data)):
        data.loc[i, '일'] = int(str(data.loc[i, '일시'])[3:5])
    for i in range(len(data)):
        data.loc[i, '시'] = int(str(data.loc[i, '일시'])[6:8])

    data.drop(['지점', '연도', '일시'], axis=1, inplace=True)
    return data

# 결측치 처리 : KNNimputer
def imputation(data):
    imputer = KNNImputer(n_neighbors=5)
    return pd.DataFrame(imputer.fit_transform(data))

# %%
# test_aws 날짜 칼럼 생성, 결측치 처리
datetime_testaws(test_aws_오월드)
test_aws_오월드 = imputation(test_aws_오월드)
test_aws_오월드['지점'] = '오월드'

datetime_testaws(test_aws_세천)
test_aws_세천 = imputation(test_aws_세천)
test_aws_세천['지점'] = '세천'

datetime_testaws(test_aws_장동)
test_aws_장동 = imputation(test_aws_장동)
test_aws_장동['지점'] = '장동'

datetime_testaws(test_aws_세종고운)
test_aws_세종고운 = imputation(test_aws_세종고운)
test_aws_세종고운['지점'] = '세종고운'

datetime_testaws(test_aws_세종금남)
test_aws_세종금남 = imputation(test_aws_세종금남)
test_aws_세종금남['지점'] = '세종금남'

datetime_testaws(test_aws_세종연서)
test_aws_세종연서 = imputation(test_aws_세종연서)
test_aws_세종연서['지점'] = '세종연서'

datetime_testaws(test_aws_세종전의)
test_aws_세종전의 = imputation(test_aws_세종전의)
test_aws_세종전의['지점'] = '세종전의'

datetime_testaws(test_aws_북격렬비도)
test_aws_북격렬비도 = imputation(test_aws_북격렬비도)
test_aws_북격렬비도['지점'] = '북격렬비도'

datetime_testaws(test_aws_호도)
test_aws_호도 = imputation(test_aws_호도)
test_aws_호도['지점'] = '호도'

datetime_testaws(test_aws_대산)
test_aws_대산 = imputation(test_aws_대산)
test_aws_대산['지점'] = '대산'

datetime_testaws(test_aws_홍북)
test_aws_홍북 = imputation(test_aws_홍북)
test_aws_홍북['지점'] = '홍북'

datetime_testaws(test_aws_홍성죽도)
test_aws_홍성죽도 = imputation(test_aws_홍성죽도)
test_aws_홍성죽도['지점'] = '홍성죽도'

datetime_testaws(test_aws_공주)
test_aws_공주 = imputation(test_aws_공주)
test_aws_공주['지점'] = '공주'

datetime_testaws(test_aws_서천)
test_aws_서천 = imputation(test_aws_서천)
test_aws_서천['지점'] = '서천'

datetime_testaws(test_aws_논산)
test_aws_논산 = imputation(test_aws_논산)
test_aws_논산['지점'] = '논산'

datetime_testaws(test_aws_당진)
test_aws_당진 = imputation(test_aws_당진)
test_aws_당진['지점'] = '당진'

datetime_testaws(test_aws_성거)
test_aws_성거 = imputation(test_aws_성거)
test_aws_성거['지점'] = '성거'

datetime_testaws(test_aws_청양)
test_aws_청양 = imputation(test_aws_청양)
test_aws_청양['지점'] = '청양'

datetime_testaws(test_aws_태안)
test_aws_태안 = imputation(test_aws_태안)
test_aws_태안['지점'] = '태안'

datetime_testaws(test_aws_예산)
test_aws_예산 = imputation(test_aws_예산)
test_aws_예산['지점'] = '예산'

datetime_testaws(test_aws_유구)
test_aws_유구 = imputation(test_aws_유구)
test_aws_유구['지점'] = '유구'

datetime_testaws(test_aws_정안)
test_aws_정안 = imputation(test_aws_정안)
test_aws_정안['지점'] = '정안'

datetime_testaws(test_aws_아산)
test_aws_아산 = imputation(test_aws_아산)
test_aws_아산['지점'] = '아산'

datetime_testaws(test_aws_양화)
test_aws_양화 = imputation(test_aws_양화)
test_aws_양화['지점'] = '양화'

datetime_testaws(test_aws_계룡)
test_aws_계룡 = imputation(test_aws_계룡)
test_aws_계룡['지점'] = '계룡'

datetime_testaws(test_aws_춘장대)
test_aws_춘장대 = imputation(test_aws_춘장대)
test_aws_춘장대['지점'] = '춘장대'

datetime_testaws(test_aws_대천항)
test_aws_대천항 = imputation(test_aws_대천항)
test_aws_대천항['지점'] = '대천항'

datetime_testaws(test_aws_안도)
test_aws_안도 = imputation(test_aws_안도)
test_aws_안도['지점'] = '안도'

datetime_testaws(test_aws_옹도)
test_aws_옹도 = imputation(test_aws_옹도)
test_aws_옹도['지점'] = '옹도'

datetime_testaws(test_aws_정산)
test_aws_정산 = imputation(test_aws_정산)
test_aws_정산['지점'] = '정산'

# %%
# test aws 합치기
test_aws = pd.concat([test_aws_오월드, test_aws_세천, test_aws_장동, test_aws_세종고운, test_aws_세종금남, test_aws_세종연서, test_aws_세종전의, test_aws_북격렬비도,
                      test_aws_호도, test_aws_대산, test_aws_홍북, test_aws_홍성죽도, test_aws_공주, test_aws_서천, test_aws_논산, test_aws_당진, test_aws_성거,
                      test_aws_청양, test_aws_태안, test_aws_예산, test_aws_유구, test_aws_정안, test_aws_아산, test_aws_양화, test_aws_계룡, test_aws_춘장대,
                      test_aws_대천항, test_aws_안도, test_aws_옹도, test_aws_정산])

# %%
test_aws.columns = ['기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '지점']

# %%
test_aws.to_csv('test_aws.csv')

# %%
test_aws.isna().sum()
# Out:
# 기온     0
# 풍향     0
# 풍속     0
# 강수량    0
# 습도     0
# 년      0
# 월      0
# 일      0
# 시      0
# 지점     0
# dtype: int64

# %%
# test_aws 불러오기
test_aws = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA/test_aws.csv')
test_aws.set_index('Unnamed: 0', inplace=True)

# %% [markdown]
# ##### test PM 전처리 및 데이터 생성 + 모델 예측

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
# %config InlineBackend.figure_format='retina'
pd.set_option('display.max_columns', None)

from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder

test_pm_공주 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/공주.csv')
test_pm_노은동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/노은동.csv')
test_pm_논산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/논산.csv')
test_pm_대천2동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/대천2동.csv')
test_pm_독곶리 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/독곶리.csv')
test_pm_동문동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/동문동.csv')
test_pm_모종동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/모종동.csv')
test_pm_문창동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/문창동.csv')
test_pm_성성동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/성성동.csv')
test_pm_신방동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/신방동.csv')
test_pm_신흥동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/신흥동.csv')
test_pm_아름동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/아름동.csv')
test_pm_예산군 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/예산군.csv')
test_pm_읍내동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/읍내동.csv')
test_pm_이원면 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/이원면.csv')
test_pm_정림동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/정림동.csv')
test_pm_홍성읍 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/홍성읍.csv')
pm_aws = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling1/pm_aws.csv', index_col='Location')
test_aws = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling1/test_aws.csv', index_col='Unnamed: 0')

import joblib
model = joblib.load('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_24hour/model.pkl')

# %%
# PM : 년, 월, 일, 시 컬럼 생성 / 연도, 일시 컬럼 삭제
def datetime_testpm(data):
    for i in range(len(data)):
        data.loc[i, '년'] = 2021
        data.loc[i, '월'] = int(str(data.loc[i, '일시'])[:2])
        data.loc[i, '일'] = int(str(data.loc[i, '일시'])[3:5])
        data.loc[i, '시'] = int(str(data.loc[i, '일시'])[6:8])

    data.drop(['측정소', '연도', '일시'], axis=1, inplace=True)
    return data

# PM2.5_1, 2017, 2018, 2019, 2020, 2021 칼럼 생성 / 월, 일, 시, 측정소 타입 object 변환
def new_columns(data):
    # 1시간 전 PM2.5 칼럼
    data['PM2.5_1'] = data['PM2.5'].shift(periods=1, fill_value=np.NaN)

    # 2시간 전 PM2.5 칼럼
    data['PM2.5_2'] = data['PM2.5'].shift(periods=2, fill_value=np.NaN)

    # 24시간 전 PM2.5 칼럼
    data['PM2.5_24'] = data['PM2.5'].shift(periods=24, fill_value=np.NaN)

    # '년' 범주화
    for i in range(2017, 2022):
        data[f'{i}'] = np.where(data['년']==i, 1, 0)
    data.drop('년', axis=1, inplace=True)

    # object 타입으로 변경
    data['월'] = data['월'].astype('str')
    data['일'] = data['일'].astype('str')
    data['시'] = data['시'].astype('str')
    data['측정소'] = data['측정소'].astype('str')
    return data

# cat_features 적용할 변수
cat_features = ['월', '일', '시', '측정소']

# PM 라벨링 딕셔너리
pm_dict = {'아름동': 11, '신흥동': 10, '노은동': 1, '문창동': 7, '읍내동': 13, '정림동': 15, '공주': 0, '논산': 2, '대천2동': 3, '독곶리': 4,
           '동문동': 5, '모종동': 6, '신방동': 9, '예산군': 12, '이원면': 14, '홍성읍': 16, '성성동': 8}

# %% [markdown]
# ###### 1. 공주

# %%
# PM2.5 모델 예측 데이터
predict_공주 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_공주 = (1 / pm_aws.loc['공주']) / (1 / pm_aws.loc['공주']).sum()
# 2. 가중치 * aws
test_공주 = test_pm_공주.copy()

for i in range(len(test_pm_공주)):
    test_공주.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_공주.values).sum()
    test_공주.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_공주.values).sum()
    test_공주.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_공주.values).sum()
    test_공주.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_공주.values).sum()
    test_공주.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_공주.values).sum()

datetime_testpm(test_공주)
test_공주['측정소'] = pm_dict['공주']
test_공주.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_공주[test_공주['PM2.5'].isna()]), len(test_공주[test_공주['기온'].isna()]))

test_공주 = new_columns(test_공주)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_공주) ):
    if np.isnan(test_공주.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_공주 = test_공주.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_공주.iloc[i, 0] = model.predict(x_공주) # i행 결측치 채우기
        predict_공주['PM2.5'].append(model.predict(x_공주)) # i행의 PM2.5 predict
        test_공주.iloc[i+1, 10] = model.predict(x_공주) # i+1행의 PM2.5_1 채우기
        test_공주.iloc[i+2, 11] = model.predict(x_공주) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_공주.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_공주.iloc[i+1, 12] = test_공주.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_공주['PM2.5']), np.isnan(predict_공주['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_공주 = pd.DataFrame(predict_공주)
predict_공주.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_공주.csv', index=False)

# %% [markdown]
# ###### 2. 노은동

# %%
# PM2.5 모델 예측 데이터
predict_노은동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_노은동 = (1 / pm_aws.loc['노은동']) / (1 / pm_aws.loc['노은동']).sum()
# 2. 가중치 * aws
test_노은동 = test_pm_노은동.copy()

for i in range(len(test_pm_노은동)):
    test_노은동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_노은동.values).sum()
    test_노은동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_노은동.values).sum()
    test_노은동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_노은동.values).sum()
    test_노은동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_노은동.values).sum()
    test_노은동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_노은동.values).sum()

datetime_testpm(test_노은동)
test_노은동['측정소'] = pm_dict['노은동']
test_노은동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_노은동[test_노은동['PM2.5'].isna()]), len(test_노은동[test_노은동['기온'].isna()]))

test_노은동 = new_columns(test_노은동)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_노은동) ):
    if np.isnan(test_노은동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_노은동 = test_노은동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_노은동.iloc[i, 0] = model.predict(x_노은동) # i행 결측치 채우기
        predict_노은동['PM2.5'].append(model.predict(x_노은동)) # i행의 PM2.5 predict
        test_노은동.iloc[i+1, 10] = model.predict(x_노은동) # i+1행의 PM2.5_1 채우기
        test_노은동.iloc[i+2, 11] = model.predict(x_노은동) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_노은동.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_노은동.iloc[i+1, 12] = test_노은동.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_노은동['PM2.5']), np.isnan(predict_노은동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_노은동 = pd.DataFrame(predict_노은동)
predict_노은동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_노은동.csv', index=False)

# %% [markdown]
# ###### 3. 논산

# %%
# PM2.5 모델 예측 데이터
predict_논산 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_논산 = (1 / pm_aws.loc['논산']) / (1 / pm_aws.loc['논산']).sum()
# 2. 가중치 * aws
test_논산 = test_pm_논산.copy()

for i in range(len(test_pm_논산)):
    test_논산.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_논산.values).sum()
    test_논산.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_논산.values).sum()
    test_논산.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_논산.values).sum()
    test_논산.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_논산.values).sum()
    test_논산.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_논산.values).sum()

datetime_testpm(test_논산)
test_논산['측정소'] = pm_dict['논산']
test_논산.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_논산[test_논산['PM2.5'].isna()]), len(test_논산[test_논산['기온'].isna()]))

test_논산 = new_columns(test_논산)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_논산) ):
    if np.isnan(test_논산.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_논산 = test_논산.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_논산.iloc[i, 0] = model.predict(x_논산) # i행 결측치 채우기
        predict_논산['PM2.5'].append(model.predict(x_논산)) # i행의 PM2.5 predict
        test_논산.iloc[i+1, 10] = model.predict(x_논산) # i+1행의 PM2.5_1 채우기
        test_논산.iloc[i+2, 11] = model.predict(x_논산) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_논산.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_논산.iloc[i+1, 12] = test_논산.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_논산['PM2.5']), np.isnan(predict_논산['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_논산 = pd.DataFrame(predict_논산)
predict_논산.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_논산.csv', index=False)

# %% [markdown]
# ###### 4. 대천2동

# %%
# PM2.5 모델 예측 데이터
predict_대천2동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_대천2동 = (1 / pm_aws.loc['대천2동']) / (1 / pm_aws.loc['대천2동']).sum()
# 2. 가중치 * aws
test_대천2동 = test_pm_대천2동.copy()

for i in range(len(test_pm_대천2동)):
    test_대천2동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_대천2동.values).sum()
    test_대천2동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_대천2동.values).sum()
    test_대천2동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_대천2동.values).sum()
    test_대천2동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_대천2동.values).sum()
    test_대천2동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_대천2동.values).sum()

datetime_testpm(test_대천2동)
test_대천2동['측정소'] = pm_dict['대천2동']
test_대천2동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_대천2동[test_대천2동['PM2.5'].isna()]), len(test_대천2동[test_대천2동['기온'].isna()]))

test_대천2동 = new_columns(test_대천2동)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_대천2동) ):
    if np.isnan(test_대천2동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_대천2동 = test_대천2동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_대천2동.iloc[i, 0] = model.predict(x_대천2동) # i행 결측치 채우기
        predict_대천2동['PM2.5'].append(model.predict(x_대천2동)) # i행의 PM2.5 predict
        test_대천2동.iloc[i+1, 10] = model.predict(x_대천2동) # i+1행의 PM2.5_1 채우기
        test_대천2동.iloc[i+2, 11] = model.predict(x_대천2동) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_대천2동.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_대천2동.iloc[i+1, 12] = test_대천2동.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_대천2동['PM2.5']), np.isnan(predict_대천2동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_대천2동 = pd.DataFrame(predict_대천2동)
predict_대천2동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_대천2동.csv', index=False)

# %% [markdown]
# ###### 5. 독곶리

# %%
# PM2.5 모델 예측 데이터
predict_독곶리 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_독곶리 = (1 / pm_aws.loc['독곶리']) / (1 / pm_aws.loc['독곶리']).sum()
# 2. 가중치 * aws
test_독곶리 = test_pm_독곶리.copy()

for i in range(len(test_pm_독곶리)):
    test_독곶리.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_독곶리.values).sum()
    test_독곶리.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_독곶리.values).sum()
    test_독곶리.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_독곶리.values).sum()
    test_독곶리.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_독곶리.values).sum()
    test_독곶리.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_독곶리.values).sum()

datetime_testpm(test_독곶리)
test_독곶리['측정소'] = pm_dict['독곶리']
test_독곶리.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_독곶리[test_독곶리['PM2.5'].isna()]), len(test_독곶리[test_독곶리['기온'].isna()]))

test_독곶리 = new_columns(test_독곶리)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_독곶리) ):
    if np.isnan(test_독곶리.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_독곶리 = test_독곶리.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_독곶리.iloc[i, 0] = model.predict(x_독곶리) # i행 결측치 채우기
        predict_독곶리['PM2.5'].append(model.predict(x_독곶리)) # i행의 PM2.5 predict
        test_독곶리.iloc[i+1, 10] = model.predict(x_독곶리) # i+1행의 PM2.5_1 채우기
        test_독곶리.iloc[i+2, 11] = model.predict(x_독곶리) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_독곶리.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_독곶리.iloc[i+1, 12] = test_독곶리.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_독곶리['PM2.5']), np.isnan(predict_독곶리['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_독곶리 = pd.DataFrame(predict_독곶리)
predict_독곶리.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_독곶리.csv', index=False)

# %% [markdown]
# ###### 6. 동문동

# %%
# PM2.5 모델 예측 데이터
predict_동문동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_동문동 = (1 / pm_aws.loc['동문동']) / (1 / pm_aws.loc['동문동']).sum()
# 2. 가중치 * aws
test_동문동 = test_pm_동문동.copy()

for i in range(len(test_pm_동문동)):
    test_동문동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_동문동.values).sum()
    test_동문동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_동문동.values).sum()
    test_동문동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_동문동.values).sum()
    test_동문동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_동문동.values).sum()
    test_동문동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_동문동.values).sum()

datetime_testpm(test_동문동)
test_동문동['측정소'] = pm_dict['동문동']
test_동문동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_동문동[test_동문동['PM2.5'].isna()]), len(test_동문동[test_동문동['기온'].isna()]))

test_동문동 = new_columns(test_동문동)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_동문동) ):
    if np.isnan(test_동문동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_동문동 = test_동문동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_동문동.iloc[i, 0] = model.predict(x_동문동) # i행 결측치 채우기
        predict_동문동['PM2.5'].append(model.predict(x_동문동)) # i행의 PM2.5 predict
        test_동문동.iloc[i+1, 10] = model.predict(x_동문동) # i+1행의 PM2.5_1 채우기
        test_동문동.iloc[i+2, 11] = model.predict(x_동문동) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_동문동.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_동문동.iloc[i+1, 12] = test_동문동.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_동문동['PM2.5']), np.isnan(predict_동문동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_동문동 = pd.DataFrame(predict_동문동)
predict_동문동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_동문동.csv', index=False)

# %% [markdown]
# ###### 7. 모종동

# %%
# PM2.5 모델 예측 데이터
predict_모종동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_모종동 = (1 / pm_aws.loc['모종동']) / (1 / pm_aws.loc['모종동']).sum()
# 2. 가중치 * aws
test_모종동 = test_pm_모종동.copy()

for i in range(len(test_pm_모종동)):
    test_모종동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_모종동.values).sum()
    test_모종동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_모종동.values).sum()
    test_모종동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_모종동.values).sum()
    test_모종동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_모종동.values).sum()
    test_모종동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_모종동.values).sum()

datetime_testpm(test_모종동)
test_모종동['측정소'] = pm_dict['모종동']
test_모종동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_모종동[test_모종동['PM2.5'].isna()]), len(test_모종동[test_모종동['기온'].isna()]))

test_모종동 = new_columns(test_모종동)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_모종동) ):
    if np.isnan(test_모종동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_모종동 = test_모종동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_모종동.iloc[i, 0] = model.predict(x_모종동) # i행 결측치 채우기
        predict_모종동['PM2.5'].append(model.predict(x_모종동)) # i행의 PM2.5 predict
        test_모종동.iloc[i+1, 10] = model.predict(x_모종동) # i+1행의 PM2.5_1 채우기
        test_모종동.iloc[i+2, 11] = model.predict(x_모종동) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_모종동.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_모종동.iloc[i+1, 12] = test_모종동.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_모종동['PM2.5']), np.isnan(predict_모종동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_모종동 = pd.DataFrame(predict_모종동)
predict_모종동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_모종동.csv', index=False)

# %% [markdown]
# ###### 8. 문창동

# %%
# PM2.5 모델 예측 데이터
predict_문창동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_문창동 = (1 / pm_aws.loc['문창동']) / (1 / pm_aws.loc['문창동']).sum()
# 2. 가중치 * aws
test_문창동 = test_pm_문창동.copy()

for i in range(len(test_pm_문창동)):
    test_문창동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_문창동.values).sum()
    test_문창동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_문창동.values).sum()
    test_문창동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_문창동.values).sum()
    test_문창동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_문창동.values).sum()
    test_문창동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_문창동.values).sum()

datetime_testpm(test_문창동)
test_문창동['측정소'] = pm_dict['문창동']
test_문창동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_문창동[test_문창동['PM2.5'].isna()]), len(test_문창동[test_문창동['기온'].isna()]))

test_문창동 = new_columns(test_문창동)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_문창동) ):
    if np.isnan(test_문창동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_문창동 = test_문창동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_문창동.iloc[i, 0] = model.predict(x_문창동) # i행 결측치 채우기
        predict_문창동['PM2.5'].append(model.predict(x_문창동)) # i행의 PM2.5 predict
        test_문창동.iloc[i+1, 10] = model.predict(x_문창동) # i+1행의 PM2.5_1 채우기
        test_문창동.iloc[i+2, 11] = model.predict(x_문창동) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_문창동.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_문창동.iloc[i+1, 12] = test_문창동.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_문창동['PM2.5']), np.isnan(predict_문창동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_문창동 = pd.DataFrame(predict_문창동)
predict_문창동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_문창동.csv', index=False)

# %% [markdown]
# ###### 9. 성성동

# %%
# PM2.5 모델 예측 데이터
predict_성성동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_성성동 = (1 / pm_aws.loc['성성동']) / (1 / pm_aws.loc['성성동']).sum()
# 2. 가중치 * aws
test_성성동 = test_pm_성성동.copy()

for i in range(len(test_pm_성성동)):
    test_성성동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_성성동.values).sum()
    test_성성동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_성성동.values).sum()
    test_성성동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_성성동.values).sum()
    test_성성동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_성성동.values).sum()
    test_성성동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_성성동.values).sum()

datetime_testpm(test_성성동)
test_성성동['측정소'] = pm_dict['성성동']
test_성성동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_성성동[test_성성동['PM2.5'].isna()]), len(test_성성동[test_성성동['기온'].isna()]))

test_성성동 = new_columns(test_성성동)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_성성동) ):
    if np.isnan(test_성성동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_성성동 = test_성성동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_성성동.iloc[i, 0] = model.predict(x_성성동) # i행 결측치 채우기
        predict_성성동['PM2.5'].append(model.predict(x_성성동)) # i행의 PM2.5 predict
        test_성성동.iloc[i+1, 10] = model.predict(x_성성동) # i+1행의 PM2.5_1 채우기
        test_성성동.iloc[i+2, 11] = model.predict(x_성성동) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_성성동.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_성성동.iloc[i+1, 12] = test_성성동.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_성성동['PM2.5']), np.isnan(predict_성성동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_성성동 = pd.DataFrame(predict_성성동)
predict_성성동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_성성동.csv', index=False)

# %% [markdown]
# ###### 10. 신방동

# %%
# PM2.5 모델 예측 데이터
predict_신방동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_신방동 = (1 / pm_aws.loc['신방동']) / (1 / pm_aws.loc['신방동']).sum()
# 2. 가중치 * aws
test_신방동 = test_pm_신방동.copy()

for i in range(len(test_pm_신방동)):
    test_신방동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_신방동.values).sum()
    test_신방동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_신방동.values).sum()
    test_신방동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_신방동.values).sum()
    test_신방동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_신방동.values).sum()
    test_신방동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_신방동.values).sum()

datetime_testpm(test_신방동)
test_신방동['측정소'] = pm_dict['신방동']
test_신방동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_신방동[test_신방동['PM2.5'].isna()]), len(test_신방동[test_신방동['기온'].isna()]))

test_신방동 = new_columns(test_신방동)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_신방동) ):
    if np.isnan(test_신방동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_신방동 = test_신방동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_신방동.iloc[i, 0] = model.predict(x_신방동) # i행 결측치 채우기
        predict_신방동['PM2.5'].append(model.predict(x_신방동)) # i행의 PM2.5 predict
        test_신방동.iloc[i+1, 10] = model.predict(x_신방동) # i+1행의 PM2.5_1 채우기
        test_신방동.iloc[i+2, 11] = model.predict(x_신방동) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_신방동.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_신방동.iloc[i+1, 12] = test_신방동.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_신방동['PM2.5']), np.isnan(predict_신방동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_신방동 = pd.DataFrame(predict_신방동)
predict_신방동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_신방동.csv', index=False)

# %% [markdown]
# ###### 11. 신흥동

# %%
# PM2.5 모델 예측 데이터
predict_신흥동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_신흥동 = (1 / pm_aws.loc['신흥동']) / (1 / pm_aws.loc['신흥동']).sum()
# 2. 가중치 * aws
test_신흥동 = test_pm_신흥동.copy()

for i in range(len(test_pm_신흥동)):
    test_신흥동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_신흥동.values).sum()
    test_신흥동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_신흥동.values).sum()
    test_신흥동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_신흥동.values).sum()
    test_신흥동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_신흥동.values).sum()
    test_신흥동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_신흥동.values).sum()

datetime_testpm(test_신흥동)
test_신흥동['측정소'] = pm_dict['신흥동']
test_신흥동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_신흥동[test_신흥동['PM2.5'].isna()]), len(test_신흥동[test_신흥동['기온'].isna()]))

test_신흥동 = new_columns(test_신흥동)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_신흥동) ):
    if np.isnan(test_신흥동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_신흥동 = test_신흥동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_신흥동.iloc[i, 0] = model.predict(x_신흥동) # i행 결측치 채우기
        predict_신흥동['PM2.5'].append(model.predict(x_신흥동)) # i행의 PM2.5 predict
        test_신흥동.iloc[i+1, 10] = model.predict(x_신흥동) # i+1행의 PM2.5_1 채우기
        test_신흥동.iloc[i+2, 11] = model.predict(x_신흥동) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_신흥동.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_신흥동.iloc[i+1, 12] = test_신흥동.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_신흥동['PM2.5']), np.isnan(predict_신흥동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_신흥동 = pd.DataFrame(predict_신흥동)
predict_신흥동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_신흥동.csv', index=False)

# %% [markdown]
# ###### 12. 아름동

# %%
# PM2.5 모델 예측 데이터
predict_아름동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_아름동 = (1 / pm_aws.loc['아름동']) / (1 / pm_aws.loc['아름동']).sum()
# 2. 가중치 * aws
test_아름동 = test_pm_아름동.copy()

for i in range(len(test_pm_아름동)):
    test_아름동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_아름동.values).sum()
    test_아름동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_아름동.values).sum()
    test_아름동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_아름동.values).sum()
    test_아름동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_아름동.values).sum()
    test_아름동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_아름동.values).sum()

datetime_testpm(test_아름동)
test_아름동['측정소'] = pm_dict['아름동']
test_아름동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_아름동[test_아름동['PM2.5'].isna()]), len(test_아름동[test_아름동['기온'].isna()]))

test_아름동 = new_columns(test_아름동)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_아름동) ):
    if np.isnan(test_아름동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_아름동 = test_아름동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_아름동.iloc[i, 0] = model.predict(x_아름동) # i행 결측치 채우기
        predict_아름동['PM2.5'].append(model.predict(x_아름동)) # i행의 PM2.5 predict
        test_아름동.iloc[i+1, 10] = model.predict(x_아름동) # i+1행의 PM2.5_1 채우기
        test_아름동.iloc[i+2, 11] = model.predict(x_아름동) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_아름동.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_아름동.iloc[i+1, 12] = test_아름동.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_아름동['PM2.5']), np.isnan(predict_아름동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_아름동 = pd.DataFrame(predict_아름동)
predict_아름동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_아름동.csv', index=False)

# %% [markdown]
# ###### 13. 예산군

# %%
# PM2.5 모델 예측 데이터
predict_예산군 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_예산군 = (1 / pm_aws.loc['예산군']) / (1 / pm_aws.loc['예산군']).sum()
# 2. 가중치 * aws
test_예산군 = test_pm_예산군.copy()

for i in range(len(test_pm_예산군)):
    test_예산군.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_예산군.values).sum()
    test_예산군.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_예산군.values).sum()
    test_예산군.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_예산군.values).sum()
    test_예산군.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_예산군.values).sum()
    test_예산군.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_예산군.values).sum()

datetime_testpm(test_예산군)
test_예산군['측정소'] = pm_dict['예산군']
test_예산군.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_예산군[test_예산군['PM2.5'].isna()]), len(test_예산군[test_예산군['기온'].isna()]))

test_예산군 = new_columns(test_예산군)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_예산군) ):
    if np.isnan(test_예산군.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_예산군 = test_예산군.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_예산군.iloc[i, 0] = model.predict(x_예산군) # i행 결측치 채우기
        predict_예산군['PM2.5'].append(model.predict(x_예산군)) # i행의 PM2.5 predict
        test_예산군.iloc[i+1, 10] = model.predict(x_예산군) # i+1행의 PM2.5_1 채우기
        test_예산군.iloc[i+2, 11] = model.predict(x_예산군) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_예산군.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_예산군.iloc[i+1, 12] = test_예산군.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_예산군['PM2.5']), np.isnan(predict_예산군['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_예산군 = pd.DataFrame(predict_예산군)
predict_예산군.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_예산군.csv', index=False)

# %% [markdown]
# ###### 14. 읍내동

# %%
# PM2.5 모델 예측 데이터
predict_읍내동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_읍내동 = (1 / pm_aws.loc['읍내동']) / (1 / pm_aws.loc['읍내동']).sum()
# 2. 가중치 * aws
test_읍내동 = test_pm_읍내동.copy()

for i in range(len(test_pm_읍내동)):
    test_읍내동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_읍내동.values).sum()
    test_읍내동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_읍내동.values).sum()
    test_읍내동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_읍내동.values).sum()
    test_읍내동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_읍내동.values).sum()
    test_읍내동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_읍내동.values).sum()

datetime_testpm(test_읍내동)
test_읍내동['측정소'] = pm_dict['읍내동']
test_읍내동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_읍내동[test_읍내동['PM2.5'].isna()]), len(test_읍내동[test_읍내동['기온'].isna()]))

test_읍내동 = new_columns(test_읍내동)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_읍내동) ):
    if np.isnan(test_읍내동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_읍내동 = test_읍내동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_읍내동.iloc[i, 0] = model.predict(x_읍내동) # i행 결측치 채우기
        predict_읍내동['PM2.5'].append(model.predict(x_읍내동)) # i행의 PM2.5 predict
        test_읍내동.iloc[i+1, 10] = model.predict(x_읍내동) # i+1행의 PM2.5_1 채우기
        test_읍내동.iloc[i+2, 11] = model.predict(x_읍내동) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_읍내동.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_읍내동.iloc[i+1, 12] = test_읍내동.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_읍내동['PM2.5']), np.isnan(predict_읍내동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_읍내동 = pd.DataFrame(predict_읍내동)
predict_읍내동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_읍내동.csv', index=False)

# %% [markdown]
# ###### 15. 이원면

# %%
# PM2.5 모델 예측 데이터
predict_이원면 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_이원면 = (1 / pm_aws.loc['이원면']) / (1 / pm_aws.loc['이원면']).sum()
# 2. 가중치 * aws
test_이원면 = test_pm_이원면.copy()

for i in range(len(test_pm_이원면)):
    test_이원면.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_이원면.values).sum()
    test_이원면.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_이원면.values).sum()
    test_이원면.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_이원면.values).sum()
    test_이원면.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_이원면.values).sum()
    test_이원면.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_이원면.values).sum()

datetime_testpm(test_이원면)
test_이원면['측정소'] = pm_dict['이원면']
test_이원면.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_이원면[test_이원면['PM2.5'].isna()]), len(test_이원면[test_이원면['기온'].isna()]))

test_이원면 = new_columns(test_이원면)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_이원면) ):
    if np.isnan(test_이원면.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_이원면 = test_이원면.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_이원면.iloc[i, 0] = model.predict(x_이원면) # i행 결측치 채우기
        predict_이원면['PM2.5'].append(model.predict(x_이원면)) # i행의 PM2.5 predict
        test_이원면.iloc[i+1, 10] = model.predict(x_이원면) # i+1행의 PM2.5_1 채우기
        test_이원면.iloc[i+2, 11] = model.predict(x_이원면) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_이원면.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_이원면.iloc[i+1, 12] = test_이원면.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_이원면['PM2.5']), np.isnan(predict_이원면['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_이원면 = pd.DataFrame(predict_이원면)
predict_이원면.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_이원면.csv', index=False)

# %% [markdown]
# ###### 16. 정림동

# %%
# PM2.5 모델 예측 데이터
predict_정림동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_정림동 = (1 / pm_aws.loc['정림동']) / (1 / pm_aws.loc['정림동']).sum()
# 2. 가중치 * aws
test_정림동 = test_pm_정림동.copy()

for i in range(len(test_pm_정림동)):
    test_정림동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_정림동.values).sum()
    test_정림동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_정림동.values).sum()
    test_정림동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_정림동.values).sum()
    test_정림동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_정림동.values).sum()
    test_정림동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_정림동.values).sum()

datetime_testpm(test_정림동)
test_정림동['측정소'] = pm_dict['정림동']
test_정림동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_정림동[test_정림동['PM2.5'].isna()]), len(test_정림동[test_정림동['기온'].isna()]))

test_정림동 = new_columns(test_정림동)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_정림동) ):
    if np.isnan(test_정림동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_정림동 = test_정림동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_정림동.iloc[i, 0] = model.predict(x_정림동) # i행 결측치 채우기
        predict_정림동['PM2.5'].append(model.predict(x_정림동)) # i행의 PM2.5 predict
        test_정림동.iloc[i+1, 10] = model.predict(x_정림동) # i+1행의 PM2.5_1 채우기
        test_정림동.iloc[i+2, 11] = model.predict(x_정림동) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_정림동.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_정림동.iloc[i+1, 12] = test_정림동.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_정림동['PM2.5']), np.isnan(predict_정림동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_정림동 = pd.DataFrame(predict_정림동)
predict_정림동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_정림동.csv', index=False)

# %% [markdown]
# ###### 17. 홍성읍

# %%
# PM2.5 모델 예측 데이터
predict_홍성읍 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_홍성읍 = (1 / pm_aws.loc['홍성읍']) / (1 / pm_aws.loc['홍성읍']).sum()
# 2. 가중치 * aws
test_홍성읍 = test_pm_홍성읍.copy()

for i in range(len(test_pm_홍성읍)):
    test_홍성읍.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_홍성읍.values).sum()
    test_홍성읍.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_홍성읍.values).sum()
    test_홍성읍.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_홍성읍.values).sum()
    test_홍성읍.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_홍성읍.values).sum()
    test_홍성읍.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_홍성읍.values).sum()

datetime_testpm(test_홍성읍)
test_홍성읍['측정소'] = pm_dict['홍성읍']
test_홍성읍.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_홍성읍[test_홍성읍['PM2.5'].isna()]), len(test_홍성읍[test_홍성읍['기온'].isna()]))

test_홍성읍 = new_columns(test_홍성읍)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_홍성읍) ):
    if np.isnan(test_홍성읍.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_홍성읍 = test_홍성읍.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_홍성읍.iloc[i, 0] = model.predict(x_홍성읍) # i행 결측치 채우기
        predict_홍성읍['PM2.5'].append(model.predict(x_홍성읍)) # i행의 PM2.5 predict
        test_홍성읍.iloc[i+1, 10] = model.predict(x_홍성읍) # i+1행의 PM2.5_1 채우기
        test_홍성읍.iloc[i+2, 11] = model.predict(x_홍성읍) # i+2행의 PM2.5_2 채우기
        if np.isnan(test_홍성읍.iloc[i+1, 12]): # i+1행의 PM2.5_24 nan값이면,
            test_홍성읍.iloc[i+1, 12] = test_홍성읍.iloc[i-23, 0] # i-23행의 PM2.5로 채우기
        count += 1

# %%
count, len(predict_홍성읍['PM2.5']), np.isnan(predict_홍성읍['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_홍성읍 = pd.DataFrame(predict_홍성읍)
predict_홍성읍.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_홍성읍.csv', index=False)

# %% [markdown]
# ##### 예측값과 answer file 병합

# %%
predict_아름동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_아름동.csv')
predict_신흥동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_신흥동.csv')
predict_노은동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_노은동.csv')
predict_문창동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_문창동.csv')
predict_읍내동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_읍내동.csv')
predict_정림동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_정림동.csv')
predict_공주 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_공주.csv')
predict_논산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_논산.csv')
predict_대천2동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_대천2동.csv')
predict_독곶리 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_독곶리.csv')
predict_동문동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_동문동.csv')
predict_모종동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_모종동.csv')
predict_신방동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_신방동.csv')
predict_예산군 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_예산군.csv')
predict_이원면 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_이원면.csv')
predict_홍성읍 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_홍성읍.csv')
predict_성성동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict_성성동.csv')

# %%
predict = pd.concat([predict_공주, predict_노은동, predict_논산, predict_대천2동, predict_독곶리, predict_동문동, predict_모종동,
                     predict_문창동, predict_성성동, predict_신방동, predict_신흥동, predict_아름동, predict_예산군, predict_읍내동,
                     predict_이원면, predict_정림동, predict_홍성읍])

# %%
predict.reset_index(drop=True, inplace=True)

# %%
predict.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/predict.csv')

# %%
answer = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/answer_sample.csv')
answer.loc[:,'PM2.5'] = predict.loc[:,'PM2.5']

# %%
answer.head(10)
# Out:
#    연도           일시 측정소     PM2.5
# 0   4  01-03 00:00  공주  0.065700
# 1   4  01-03 01:00  공주  0.073431
# 2   4  01-03 02:00  공주  0.075567
# 3   4  01-03 03:00  공주  0.077353
# 4   4  01-03 04:00  공주  0.078880
# 5   4  01-03 05:00  공주  0.080312
# 6   4  01-03 06:00  공주  0.082814
# 7   4  01-03 07:00  공주  0.085848
# 8   4  01-03 08:00  공주  0.088118
# 9   4  01-03 09:00  공주  0.089611

# %%
answer.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_2hour/answer.csv', index=False)

# %%
len(answer[answer['PM2.5']<0])
# Out:
# 297

# %%
answer[answer['PM2.5']<0]['측정소'].value_counts()
# Out:
# 이원면     91
# 독곶리     61
# 동문동     29
# 예산군     19
# 정림동     18
# 대천2동    13
# 공주      12
# 논산      11
# 노은동     11
# 신방동      7
# 문창동      5
# 신흥동      5
# 모종동      4
# 아름동      4
# 읍내동      4
# 성성동      2
# 홍성읍      1
# Name: 측정소, dtype: int64

# %%
plt.figure(figsize=(50,5))
sns.lineplot(x=answer[answer['측정소']=='이원면'].index, y='PM2.5', data=answer[answer['측정소']=='이원면'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.barh(y=x_train.columns, width=model.feature_importances_)
plt.show()

# %%
fi = pd.DataFrame()
fi['PM2.5'] = model.feature_importances_
fi.index = x_train.columns
fi.sort_values(by='PM2.5', ascending=False)
# Out:
#               PM2.5
# PM2.5_1   99.150164
# 풍속         0.183069
# PM2.5_2    0.179361
# PM2.5_24   0.119926
# 시          0.090039
# 습도         0.080216
# 기온         0.077334
# 강수량        0.057321
# 월          0.038961
# 측정소        0.011078
# 풍향         0.009912
# 일          0.001203
# 2018       0.000908
# 2019       0.000412
# 2020       0.000074
# 2017       0.000022
# 2021       0.000000
