# %% [markdown]
# ### 파일 불러오기, 모듈 설치

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
# %config InlineBackend.figure_format='retina'
pd.set_option('display.max_columns', None)

from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder

# %%
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting koreanize-matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from koreanize-matplotlib) (3.7.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.22.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (23.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)
# Installing collected packages: koreanize-matplotlib
# Successfully installed koreanize-matplotlib-0.1.1

# %%
train_pm_공주 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/공주.csv')
train_pm_노은동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/노은동.csv')
train_pm_논산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/논산.csv')
train_pm_대천2동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/대천2동.csv')
train_pm_독곶리 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/독곶리.csv')
train_pm_동문동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/동문동.csv')
train_pm_모종동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/모종동.csv')
train_pm_문창동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/문창동.csv')
train_pm_성성동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/성성동.csv')
train_pm_신방동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/신방동.csv')
train_pm_신흥동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/신흥동.csv')
train_pm_아름동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/아름동.csv')
train_pm_예산군 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/예산군.csv')
train_pm_읍내동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/읍내동.csv')
train_pm_이원면 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/이원면.csv')
train_pm_정림동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/정림동.csv')
train_pm_홍성읍 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN/홍성읍.csv')

# %%
train_aws_계룡 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/계룡.csv')
train_aws_공주 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/공주.csv')
train_aws_논산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/논산.csv')
train_aws_당진 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/당진.csv')
train_aws_대산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/대산.csv')
train_aws_대천항 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/대천항.csv')
train_aws_북격렬비도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/북격렬비도.csv')
train_aws_서천 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/서천.csv')
train_aws_성거 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/성거.csv')
train_aws_세종고운 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/세종고운.csv')
train_aws_세종금남 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/세종금남.csv')
train_aws_세종연서 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/세종연서.csv')
train_aws_세종전의 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/세종전의.csv')
train_aws_세천 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/세천.csv')
train_aws_아산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/아산.csv')
train_aws_안도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/안도.csv')
train_aws_양화 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/양화.csv')
train_aws_예산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/예산.csv')
train_aws_오월드 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/오월드.csv')
train_aws_옹도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/옹도.csv')
train_aws_유구 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/유구.csv')
train_aws_장동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/장동.csv')
train_aws_정산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/정산.csv')
train_aws_정안 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/정안.csv')
train_aws_청양 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/청양.csv')
train_aws_춘장대 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/춘장대.csv')
train_aws_태안 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/태안.csv')
train_aws_호도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/호도.csv')
train_aws_홍북 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/홍북.csv')
train_aws_홍성죽도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TRAIN_AWS/홍성죽도.csv')

# %%
test_pm_공주 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/공주.csv')
test_pm_노은동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/노은동.csv')
test_pm_논산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/논산.csv')
test_pm_대천2동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/대천2동.csv')
test_pm_독곶리 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/독곶리.csv')
test_pm_동문동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/동문동.csv')
test_pm_모종동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/모종동.csv')
test_pm_문창동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/문창동.csv')
test_pm_성성동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/성성동.csv')
test_pm_신방동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/신방동.csv')
test_pm_신흥동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/신흥동.csv')
test_pm_아름동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/아름동.csv')
test_pm_예산군 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/예산군.csv')
test_pm_읍내동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/읍내동.csv')
test_pm_이원면 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/이원면.csv')
test_pm_정림동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/정림동.csv')
test_pm_홍성읍 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/홍성읍.csv')

# %%
test_aws_계룡 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/계룡.csv')
test_aws_공주 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/공주.csv')
test_aws_논산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/논산.csv')
test_aws_당진 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/당진.csv')
test_aws_대산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/대산.csv')
test_aws_대천항 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/대천항.csv')
test_aws_북격렬비도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/북격렬비도.csv')
test_aws_서천 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/서천.csv')
test_aws_성거 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/성거.csv')
test_aws_세종고운 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/세종고운.csv')
test_aws_세종금남 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/세종금남.csv')
test_aws_세종연서 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/세종연서.csv')
test_aws_세종전의 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/세종전의.csv')
test_aws_세천 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/세천.csv')
test_aws_아산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/아산.csv')
test_aws_안도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/안도.csv')
test_aws_양화 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/양화.csv')
test_aws_예산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/예산.csv')
test_aws_오월드 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/오월드.csv')
test_aws_옹도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/옹도.csv')
test_aws_유구 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/유구.csv')
test_aws_장동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/장동.csv')
test_aws_정산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/정산.csv')
test_aws_정안 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/정안.csv')
test_aws_청양 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/청양.csv')
test_aws_춘장대 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/춘장대.csv')
test_aws_태안 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/태안.csv')
test_aws_호도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/호도.csv')
test_aws_홍북 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/홍북.csv')
test_aws_홍성죽도 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_AWS/홍성죽도.csv')

# %%
awsmap = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/META/awsmap.csv')
pmmap = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/META/pmmap.csv')

# %%
answer = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/answer_sample.csv')

# %%
pm_aws = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling1/pm_aws.csv', index_col='Location')
test_aws = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling1/test_aws.csv', index_col='Unnamed: 0')
train_aws = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling1/train_aws.csv', index_col='Unnamed: 0')
train_pm = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling1/train_pm.csv')

# %%
aws_loc = awsmap['Location'].unique()
pm_loc = pmmap['Location'].unique()

# %% [markdown]
# ### 데이터 생성

# %% [markdown]
# ##### PM위치 - AWS위치 거리 데이터

# %%
print('AWS 측정 위치 : ', awsmap['Location'].unique())
print('PM 측정 위치 : ', pmmap['Location'].unique())
# Out:
# AWS 측정 위치 :  ['오월드' '세천' '장동' '세종고운' '세종금남' '세종연서' '세종전의' '북격렬비도' '호도' '대산' '홍북' '홍성죽도'
#  '공주' '서천' '논산' '당진' '성거' '청양' '태안' '예산' '유구' '정안' '아산' '양화' '계룡' '춘장대'
#  '대천항' '안도' '옹도' '정산']
# PM 측정 위치 :  ['아름동' '신흥동' '노은동' '문창동' '읍내동' '정림동' '공주' '논산' '대천2동' '독곶리' '동문동' '모종동'
#  '신방동' '예산군' '이원면' '홍성읍' '성성동']

# %%
# PM 측정 위치별 PM-AWS 거리 변수 생성
aws_loc = awsmap['Location'].unique()
pm_loc = pmmap['Location'].unique()

pm_aws = {}

for idx_aws, aws in enumerate(aws_loc):
    pm_aws[aws] = []
    for idx_pm, pm in enumerate(pm_loc):
        pm_aws[aws].append(((pmmap.loc[idx_pm, 'Latitude'] - awsmap.loc[idx_aws, 'Latitude'])**2 + (pmmap.loc[idx_pm, 'Longitude'] - awsmap.loc[idx_aws, 'Longitude'])**2)**0.5)

# %%
pm_aws = pd.DataFrame(pm_aws)
pm_aws.index = pmmap['Location']

# %%
pm_aws
# Out:
#                오월드        세천        장동      세종고운      세종금남      세종연서  \
# Location
# 아름동       0.266559  0.301025  0.215384  0.020219  0.058084  0.064092
# 신흥동       0.318804  0.323037  0.231071  0.080419  0.136470  0.028785
# 노은동       0.109138  0.177531  0.127973  0.180890  0.103036  0.202044
# 문창동       0.049288  0.060511  0.096286  0.291232  0.220297  0.294894
# 읍내동       0.083970  0.082615  0.045934  0.238088  0.172019  0.237818
# 정림동       0.031983  0.131993  0.130383  0.259744  0.182555  0.276043
# 공주        0.317467  0.389505  0.320740  0.147933  0.150036  0.200965
# 논산        0.322313  0.430518  0.411393  0.366058  0.316657  0.415351
# 대천2동      0.808534  0.904158  0.850609  0.674859  0.687189  0.723118
# 독곶리       1.221998  1.278197  1.193645  0.963684  1.024343  0.983531
# 동문동       1.060143  1.127944  1.049158  0.823825  0.874879  0.852557
# 모종동       0.621977  0.652249  0.561905  0.337895  0.411968  0.342646
# 신방동       0.563007  0.578662  0.486809  0.278120  0.356192  0.268584
# 예산군       0.669523  0.727719  0.645674  0.417972  0.473516  0.445649
# 이원면       1.256457  1.323814  1.244348  1.017930  1.070437  1.044997
# 홍성읍       0.801666  0.877343  0.804478  0.589240  0.629295  0.626279
# 성성동       0.604974  0.611583  0.519650  0.324240  0.402388  0.306816
#
#               세종전의     북격렬비도        호도        대산        홍북      홍성죽도  \
# Location
# 아름동       0.184451  1.691079  1.002947  0.992823  0.612665  0.804426
# 신흥동       0.134388  1.733355  1.066897  0.996250  0.648385  0.853268
# 노은동       0.343463  1.777696  1.054331  1.130603  0.721653  0.889144
# 문창동       0.442594  1.903440  1.171634  1.258056  0.851360  1.015870
# 읍내동       0.385446  1.875359  1.153612  1.211371  0.813705  0.986421
# 정림동       0.420605  1.835521  1.100447  1.206814  0.790736  0.949144
# 공주        0.257042  1.569884  0.865273  0.923158  0.507395  0.680740
# 논산        0.504511  1.585860  0.827033  1.070903  0.615542  0.720026
# 대천2동      0.697885  1.065601  0.327580  0.687677  0.280079  0.222592
# 독곶리       0.861557  0.907570  0.697735  0.023296  0.440158  0.470323
# 동문동       0.750640  0.908968  0.514862  0.240012  0.243529  0.260472
# 모종동       0.207366  1.463588  0.889837  0.666673  0.400703  0.629631
# 신방동       0.121579  1.568876  0.980396  0.767147  0.499929  0.727088
# 예산군       0.351837  1.290466  0.693519  0.568662  0.209789  0.435925
# 이원면       0.937235  0.761271  0.568696  0.177271  0.437613  0.385376
# 홍성읍       0.553306  1.095938  0.488929  0.491723  0.031645  0.226426
# 성성동       0.160632  1.596806  1.028155  0.772675  0.540271  0.769239
#
#                 공주        서천        논산        당진        성거        청양  \
# Location
# 아름동       0.114154  0.704832  0.331057  0.733738  0.377018  0.475998
# 신흥동       0.190973  0.792202  0.423515  0.737392  0.316262  0.540606
# 노은동       0.215050  0.686267  0.262225  0.873581  0.535192  0.542241
# 문창동       0.343824  0.776680  0.346132  1.000246  0.627753  0.667276
# 읍내동       0.302113  0.777994  0.348785  0.952787  0.569463  0.640672
# 정림동       0.291244  0.705430  0.274707  0.950626  0.611202  0.599621
# 공주        0.039801  0.565790  0.235609  0.669009  0.432824  0.340903
# 논산        0.287867  0.406595  0.024534  0.834803  0.682488  0.381061
# 대천2동      0.561927  0.312339  0.537440  0.536965  0.772302  0.202081
# 독곶리       0.899762  0.976413  1.056199  0.246155  0.772214  0.684149
# 동문동       0.743367  0.759595  0.865835  0.195560  0.707727  0.481638
# 모종동       0.323724  0.784286  0.578718  0.411292  0.170703  0.429355
# 신방동       0.299981  0.831615  0.570887  0.514368  0.102241  0.495168
# 예산군       0.347234  0.631721  0.533099  0.313920  0.366991  0.263129
# 이원면       0.939383  0.911613  1.057453  0.337473  0.875640  0.668980
# 홍성읍       0.494928  0.537412  0.595284  0.294152  0.574204  0.213648
# 성성동       0.357552  0.892499  0.629609  0.526669  0.040504  0.552360
#
#                 태안        예산        유구        정안        아산        양화  \
# Location
# 아름동       0.981773  0.489684  0.314478  0.157844  0.506668  0.542327
# 신흥동       1.009823  0.500891  0.362724  0.203095  0.496409  0.632009
# 노은동       1.094068  0.627602  0.421768  0.289700  0.658300  0.515649
# 문창동       1.223758  0.754444  0.551533  0.415999  0.779149  0.606623
# 읍내동       1.185929  0.707584  0.512538  0.369943  0.727441  0.607170
# 정림동       1.162670  0.704717  0.493386  0.367882  0.737843  0.535122
# 공주        0.879817  0.424289  0.207941  0.107203  0.472757  0.407852
# 논산        0.968441  0.607490  0.374364  0.351948  0.683510  0.236599
# 대천2동      0.500356  0.449175  0.391688  0.541541  0.564533  0.349431
# 독곶리       0.248101  0.488834  0.702415  0.826739  0.494489  0.975554
# 동문동       0.160267  0.361213  0.534985  0.678440  0.415422  0.764372
# 모종동       0.718618  0.204285  0.255199  0.244764  0.162004  0.668867
# 신방동       0.824451  0.308741  0.305501  0.232791  0.262877  0.700607
# 예산군       0.558439  0.073334  0.160802  0.275533  0.169207  0.545614
# 이원면       0.112349  0.548940  0.731295  0.873483  0.585388  0.938311
# 홍성읍       0.393093  0.215035  0.284280  0.441178  0.325267  0.508936
# 성성동       0.849326  0.341792  0.364837  0.293166  0.276431  0.762322
#
#                 계룡       춘장대       대천항        안도        옹도        정산
# Location
# 아름동       0.199145  0.793905  0.768017  1.167242  1.244869  0.316476
# 신흥동       0.284453  0.871295  0.834803  1.182267  1.284416  0.394524
# 노은동       0.095300  0.813503  0.817574  1.292902  1.338671  0.362443
# 문창동       0.197166  0.920518  0.935752  1.422391  1.466233  0.486243
# 읍내동       0.186647  0.911054  0.916870  1.380144  1.435051  0.461420
# 정림동       0.126346  0.848316  0.864873  1.365400  1.400145  0.418310
# 공주        0.180692  0.650680  0.629160  1.079868  1.127900  0.173681
# 논산        0.191336  0.559085  0.598166  1.191999  1.167274  0.228031
# 대천2동      0.652190  0.189229  0.092229  0.737767  0.650851  0.368252
# 독곶리       1.084268  0.824906  0.672310  0.225231  0.511658  0.825038
# 동문동       0.913818  0.610475  0.458165  0.337916  0.465184  0.637579
# 모종동       0.521101  0.778907  0.687536  0.864417  1.014347  0.400735
# 신방동       0.484306  0.848790  0.769511  0.968397  1.119347  0.428761
# 예산군       0.534914  0.596637  0.494864  0.736459  0.840146  0.310435
# 이원면       1.109818  0.738505  0.588624  0.143202  0.350552  0.831123
# 홍성읍       0.651051  0.442084  0.313182  0.606055  0.647714  0.368199
# 성성동       0.536315  0.905510  0.821799  0.980649  1.148757  0.490455

# %%
pm_aws.to_csv('pm_aws.csv')

# %% [markdown]
# ##### train AWS 전처리 및 병합

# %%
pm_loc, aws_loc
# Out:
# (array(['아름동', '신흥동', '노은동', '문창동', '읍내동', '정림동', '공주', '논산', '대천2동',
#         '독곶리', '동문동', '모종동', '신방동', '예산군', '이원면', '홍성읍', '성성동'],
#        dtype=object),
#  array(['오월드', '세천', '장동', '세종고운', '세종금남', '세종연서', '세종전의', '북격렬비도', '호도',
#         '대산', '홍북', '홍성죽도', '공주', '서천', '논산', '당진', '성거', '청양', '태안', '예산',
#         '유구', '정안', '아산', '양화', '계룡', '춘장대', '대천항', '안도', '옹도', '정산'],
#        dtype=object))

# %%
# 년, 월, 일, 시 컬럼 생성 / 연도, 일시 컬럼 삭제
def datetime(data):
    for i in range(len(data)):
        if data.loc[i, '연도'] == 0:
            data.loc[i, '년'] = 2017
        elif data.loc[i, '연도'] == 1:
            data.loc[i, '년'] = 2018
        elif data.loc[i, '연도'] == 2:
            data.loc[i, '년'] = 2019
        else:
            data.loc[i, '년'] = 2020

    for i in range(len(data)):
        data.loc[i, '월'] = int(str(data.loc[i, '일시'])[:2])
    for i in range(len(data)):
        data.loc[i, '일'] = int(str(data.loc[i, '일시'])[3:5])
    for i in range(len(data)):
        data.loc[i, '시'] = int(str(data.loc[i, '일시'])[6:8])

    data.drop(['지점', '연도', '일시'], axis=1, inplace=True)
    return data

# 결측치 처리 : KNNimputer
def imputation(data):
    imputer = KNNImputer(n_neighbors=5)
    return pd.DataFrame(imputer.fit_transform(data))

# %%
# train_aws 날짜 칼럼 생성, 결측치 처리
datetime(train_aws_오월드)
train_aws_오월드 = imputation(train_aws_오월드)
train_aws_오월드['지점'] = '오월드'

datetime(train_aws_세천)
train_aws_세천 = imputation(train_aws_세천)
train_aws_세천['지점'] = '세천'

datetime(train_aws_장동)
train_aws_장동 = imputation(train_aws_장동)
train_aws_장동['지점'] = '장동'

datetime(train_aws_세종고운)
train_aws_세종고운 = imputation(train_aws_세종고운)
train_aws_세종고운['지점'] = '세종고운'

datetime(train_aws_세종금남)
train_aws_세종금남 = imputation(train_aws_세종금남)
train_aws_세종금남['지점'] = '세종금남'

datetime(train_aws_세종연서)
train_aws_세종연서 = imputation(train_aws_세종연서)
train_aws_세종연서['지점'] = '세종연서'

datetime(train_aws_세종전의)
train_aws_세종전의 = imputation(train_aws_세종전의)
train_aws_세종전의['지점'] = '세종전의'

datetime(train_aws_북격렬비도)
train_aws_북격렬비도 = imputation(train_aws_북격렬비도)
train_aws_북격렬비도['지점'] = '북격렬비도'

datetime(train_aws_호도)
train_aws_호도 = imputation(train_aws_호도)
train_aws_호도['지점'] = '호도'

datetime(train_aws_대산)
train_aws_대산 = imputation(train_aws_대산)
train_aws_대산['지점'] = '대산'

datetime(train_aws_홍북)
train_aws_홍북 = imputation(train_aws_홍북)
train_aws_홍북['지점'] = '홍북'

datetime(train_aws_홍성죽도)
train_aws_홍성죽도 = imputation(train_aws_홍성죽도)
train_aws_홍성죽도['지점'] = '홍성죽도'

datetime(train_aws_공주)
train_aws_공주 = imputation(train_aws_공주)
train_aws_공주['지점'] = '공주'

datetime(train_aws_서천)
train_aws_서천 = imputation(train_aws_서천)
train_aws_서천['지점'] = '서천'

datetime(train_aws_논산)
train_aws_논산 = imputation(train_aws_논산)
train_aws_논산['지점'] = '논산'

datetime(train_aws_당진)
train_aws_당진 = imputation(train_aws_당진)
train_aws_당진['지점'] = '당진'

datetime(train_aws_성거)
train_aws_성거 = imputation(train_aws_성거)
train_aws_성거['지점'] = '성거'

datetime(train_aws_청양)
train_aws_청양 = imputation(train_aws_청양)
train_aws_청양['지점'] = '청양'

datetime(train_aws_태안)
train_aws_태안 = imputation(train_aws_태안)
train_aws_태안['지점'] = '태안'

datetime(train_aws_예산)
train_aws_예산 = imputation(train_aws_예산)
train_aws_예산['지점'] = '예산'

datetime(train_aws_유구)
train_aws_유구 = imputation(train_aws_유구)
train_aws_유구['지점'] = '유구'

datetime(train_aws_정안)
train_aws_정안 = imputation(train_aws_정안)
train_aws_정안['지점'] = '정안'

datetime(train_aws_아산)
train_aws_아산 = imputation(train_aws_아산)
train_aws_아산['지점'] = '아산'

datetime(train_aws_양화)
train_aws_양화 = imputation(train_aws_양화)
train_aws_양화['지점'] = '양화'

datetime(train_aws_계룡)
train_aws_계룡 = imputation(train_aws_계룡)
train_aws_계룡['지점'] = '계룡'

datetime(train_aws_춘장대)
train_aws_춘장대 = imputation(train_aws_춘장대)
train_aws_춘장대['지점'] = '춘장대'

datetime(train_aws_대천항)
train_aws_대천항 = imputation(train_aws_대천항)
train_aws_대천항['지점'] = '대천항'

datetime(train_aws_안도)
train_aws_안도 = imputation(train_aws_안도)
train_aws_안도['지점'] = '안도'

datetime(train_aws_옹도)
train_aws_옹도 = imputation(train_aws_옹도)
train_aws_옹도['지점'] = '옹도'

datetime(train_aws_정산)
train_aws_정산 = imputation(train_aws_정산)
train_aws_정산['지점'] = '정산'
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-ea41f2b8a64d> in <cell line: 18>()
#      16 train_aws_세종고운['지점'] = '세종고운'
#      17
# ---> 18 datetime(train_aws_세종금남)
#      19 train_aws_세종금남 = imputation(train_aws_세종금남)
#      20 train_aws_세종금남['지점'] = '세종금남'
#
# <ipython-input-14-0abeb448ba52> in datetime(data)
#      14         data.loc[i, '월'] = int(str(data.loc[i, '일시'])[:2])
#      15     for i in range(len(data)):
# ---> 16         data.loc[i, '일'] = int(str(data.loc[i, '일시'])[3:5])
#      17     for i in range(len(data)):
#      18         data.loc[i, '시'] = int(str(data.loc[i, '일시'])[6:8])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1064             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1065             if self._is_scalar_access(key):
# -> 1066                 return self.obj._get_value(*key, takeable=self._takeable)
#    1067             return self._getitem_tuple(key)
#    1068         else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    3915             return series._values[index]
#    3916
# -> 3917         series = self._get_item_cache(col)
#    3918         engine = self.index._engine
#    3919
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _get_item_cache(self, item)
#    4286
#    4287             # for a chain
# -> 4288             res._is_copy = self._is_copy
#    4289         return res
#    4290
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5913         try:
#    5914             object.__getattribute__(self, name)
# -> 5915             return object.__setattr__(self, name, value)
#    5916         except AttributeError:
#    5917             pass
#
# KeyboardInterrupt:

# %%
# trian aws 합치기
train_aws = pd.concat([train_aws_오월드, train_aws_세천, train_aws_장동, train_aws_세종고운, train_aws_세종금남, train_aws_세종연서, train_aws_세종전의, train_aws_북격렬비도, train_aws_호도, 
                       train_aws_대산, train_aws_홍북, train_aws_홍성죽도, train_aws_공주, train_aws_서천, train_aws_논산, train_aws_당진, train_aws_성거, train_aws_청양, train_aws_태안,
                       train_aws_예산, train_aws_유구, train_aws_정안, train_aws_아산, train_aws_양화, train_aws_계룡, train_aws_춘장대, train_aws_대천항, train_aws_안도, train_aws_옹도,
                       train_aws_정산])

# %%
train_aws.columns = ['기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '지점']

# %%
train_aws.head()
# Out:
#          기온        풍향        풍속  강수량     습도       년    월    일    시   지점
# 0  0.211690  0.953056  0.033248  0.0  0.791  2017.0  1.0  1.0  0.0  오월드
# 1  0.205371  0.045556  0.028133  0.0  0.771  2017.0  1.0  1.0  1.0  오월드
# 2  0.199052  0.890833  0.028133  0.0  0.733  2017.0  1.0  1.0  2.0  오월드
# 3  0.194313  0.114167  0.043478  0.0  0.774  2017.0  1.0  1.0  3.0  오월드
# 4  0.194313  0.130833  0.025575  0.0  0.700  2017.0  1.0  1.0  4.0  오월드

# %% [markdown]
# #### train PM 전처리 및 데이터 생성
# - PM 측정 위치별로 전처리 및 데이터 생성
# - PM 위치별 데이터 모두 병합
# - 병합한 데이터로 모델 학습

# %%
pm_loc
# Out:
# array(['아름동', '신흥동', '노은동', '문창동', '읍내동', '정림동', '공주', '논산', '대천2동',
#        '독곶리', '동문동', '모종동', '신방동', '예산군', '이원면', '홍성읍', '성성동'],
#       dtype=object)

# %%
# PM : 년, 월, 일, 시 컬럼 생성 / 연도, 일시 컬럼 삭제
def datetime_pm(data):
    for i in range(len(data)):
        if data.loc[i, '연도'] == 0:
            data.loc[i, '년'] = 2017
        elif data.loc[i, '연도'] == 1:
            data.loc[i, '년'] = 2018
        elif data.loc[i, '연도'] == 2:
            data.loc[i, '년'] = 2019
        else:
            data.loc[i, '년'] = 2020

    for i in range(len(data)):
        data.loc[i, '월'] = int(str(data.loc[i, '일시'])[:2])
    for i in range(len(data)):
        data.loc[i, '일'] = int(str(data.loc[i, '일시'])[3:5])
    for i in range(len(data)):
        data.loc[i, '시'] = int(str(data.loc[i, '일시'])[6:8])

    data.drop(['측정소', '연도', '일시'], axis=1, inplace=True)
    return data

# %% [markdown]
# ##### 1. 아름동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_아름동 = (1 / pm_aws.loc['아름동']) / (1 / pm_aws.loc['아름동']).sum()
# 2. 가중치 * aws
train_아름동 = train_pm_아름동.copy()

for i in range(len(train_pm_공주)):
    train_아름동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_아름동.values).sum()
    train_아름동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_아름동.values).sum()
    train_아름동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_아름동.values).sum()
    train_아름동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_아름동.values).sum()
    train_아름동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_아름동.values).sum()

# %%
datetime_pm(train_아름동)
train_아름동 = imputation(train_아름동)
train_아름동['측정소'] = '아름동'
train_아름동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_아름동[train_아름동['PM2.5'].isna()]), len(train_아름동[train_아름동['기온'].isna()]))
# Out:
# 0 0

# %%
train_아름동.to_csv('train_아름동.csv', index=False)

# %% [markdown]
# ##### 2. 신흥동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_신흥동 = (1 / pm_aws.loc['신흥동']) / (1 / pm_aws.loc['신흥동']).sum()
# 2. 가중치 * aws
train_신흥동 = train_pm_신흥동.copy()

for i in range(len(train_pm_신흥동)):
    train_신흥동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_신흥동.values).sum()
    train_신흥동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_신흥동.values).sum()
    train_신흥동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_신흥동.values).sum()
    train_신흥동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_신흥동.values).sum()
    train_신흥동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_신흥동.values).sum()

# %%
datetime_pm(train_신흥동)
train_신흥동 = imputation(train_신흥동)
train_신흥동['측정소'] = '신흥동'
train_신흥동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_신흥동[train_신흥동['PM2.5'].isna()]), len(train_신흥동[train_신흥동['기온'].isna()]))
# Out:
# 0 0

# %%
train_신흥동.to_csv('train_신흥동.csv', index=False)

# %% [markdown]
# ##### 3. 노은동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_노은동 = (1 / pm_aws.loc['노은동']) / (1 / pm_aws.loc['노은동']).sum()
# 2. 가중치 * aws
train_노은동 = train_pm_노은동.copy()

for i in range(len(train_pm_노은동)):
    train_노은동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_노은동.values).sum()
    train_노은동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_노은동.values).sum()
    train_노은동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_노은동.values).sum()
    train_노은동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_노은동.values).sum()
    train_노은동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_노은동.values).sum()

# %%
datetime_pm(train_노은동)
train_노은동 = imputation(train_노은동)
train_노은동['측정소'] = '노은동'
train_노은동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_노은동[train_노은동['PM2.5'].isna()]), len(train_노은동[train_노은동['기온'].isna()]))
# Out:
# 0 0

# %%
train_노은동.to_csv('train_노은동.csv', index=False)

# %% [markdown]
# ##### 4. 문창동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_문창동 = (1 / pm_aws.loc['문창동']) / (1 / pm_aws.loc['문창동']).sum()
# 2. 가중치 * aws
train_문창동 = train_pm_문창동.copy()

for i in range(len(train_pm_문창동)):
    train_문창동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_문창동.values).sum()
    train_문창동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_문창동.values).sum()
    train_문창동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_문창동.values).sum()
    train_문창동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_문창동.values).sum()
    train_문창동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_문창동.values).sum()

# %%
datetime_pm(train_문창동)
train_문창동 = imputation(train_문창동)
train_문창동['측정소'] = '문창동'
train_문창동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_문창동[train_문창동['PM2.5'].isna()]), len(train_문창동[train_문창동['기온'].isna()]))
# Out:
# 0 0

# %%
train_문창동.to_csv('train_문창동.csv', index=False)

# %% [markdown]
# ##### 5. 읍내동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_읍내동 = (1 / pm_aws.loc['읍내동']) / (1 / pm_aws.loc['읍내동']).sum()
# 2. 가중치 * aws
train_읍내동 = train_pm_읍내동.copy()

for i in range(len(train_pm_읍내동)):
    train_읍내동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_읍내동.values).sum()
    train_읍내동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_읍내동.values).sum()
    train_읍내동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_읍내동.values).sum()
    train_읍내동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_읍내동.values).sum()
    train_읍내동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_읍내동.values).sum()

# %%
datetime_pm(train_읍내동)
train_읍내동 = imputation(train_읍내동)
train_읍내동['측정소'] = '읍내동'
train_읍내동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_읍내동[train_읍내동['PM2.5'].isna()]), len(train_읍내동[train_읍내동['기온'].isna()]))
# Out:
# 0 0

# %%
train_읍내동.to_csv('train_읍내동.csv', index=False)

# %% [markdown]
# ##### 6. 정림동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_정림동 = (1 / pm_aws.loc['정림동']) / (1 / pm_aws.loc['정림동']).sum()
# 2. 가중치 * aws
train_정림동 = train_pm_정림동.copy()

for i in range(len(train_pm_정림동)):
    train_정림동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_정림동.values).sum()
    train_정림동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_정림동.values).sum()
    train_정림동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_정림동.values).sum()
    train_정림동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_정림동.values).sum()
    train_정림동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_정림동.values).sum()

# %%
datetime_pm(train_정림동)
train_정림동 = imputation(train_정림동)
train_정림동['측정소'] = '정림동'
train_정림동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_정림동[train_정림동['PM2.5'].isna()]), len(train_정림동[train_정림동['기온'].isna()]))
# Out:
# 0 0

# %%
train_정림동.to_csv('train_정림동.csv', index=False)

# %% [markdown]
# ##### 7. 공주

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_공주 = (1 / pm_aws.loc['공주']) / (1 / pm_aws.loc['공주']).sum()
# 2. 가중치 * aws
train_공주 = train_pm_공주.copy()

for i in range(len(train_pm_공주)):
    train_공주.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_공주.values).sum()
    train_공주.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_공주.values).sum()
    train_공주.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_공주.values).sum()
    train_공주.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_공주.values).sum()
    train_공주.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_공주.values).sum()

# %%
datetime_pm(train_공주)
train_공주 = imputation(train_공주)
train_공주['측정소'] = '공주'

# %%
train_공주.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']

# %%
len(train_공주[train_공주['PM2.5'].isna()]), len(train_공주[train_공주['기온'].isna()])
# Out:
# (0, 0)

# %%
#train_공주.to_csv('train_공주.csv', index=False)

# %% [markdown]
# ##### 8. 논산

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_논산 = (1 / pm_aws.loc['논산']) / (1 / pm_aws.loc['논산']).sum()
# 2. 가중치 * aws
train_논산 = train_pm_논산.copy()

for i in range(len(train_pm_논산)):
    train_논산.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_논산.values).sum()
    train_논산.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_논산.values).sum()
    train_논산.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_논산.values).sum()
    train_논산.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_논산.values).sum()
    train_논산.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_논산.values).sum()

# %%
datetime_pm(train_논산)
train_논산 = imputation(train_논산)
train_논산['측정소'] = '논산'
train_논산.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_논산[train_논산['PM2.5'].isna()]), len(train_논산[train_논산['기온'].isna()]))
# Out:
# 0 0

# %%
train_논산.to_csv('train_논산.csv', index=False)

# %% [markdown]
# ##### 9. 대천2동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_대천2동 = (1 / pm_aws.loc['대천2동']) / (1 / pm_aws.loc['대천2동']).sum()
# 2. 가중치 * aws
train_대천2동 = train_pm_대천2동.copy()

for i in range(len(train_pm_대천2동)):
    train_대천2동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_대천2동.values).sum()
    train_대천2동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_대천2동.values).sum()
    train_대천2동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_대천2동.values).sum()
    train_대천2동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_대천2동.values).sum()
    train_대천2동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_대천2동.values).sum()

# %%
datetime_pm(train_대천2동)
train_대천2동 = imputation(train_대천2동)
train_대천2동['측정소'] = '대천2동'
train_대천2동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_대천2동[train_대천2동['PM2.5'].isna()]), len(train_대천2동[train_대천2동['기온'].isna()]))
# Out:
# 0 0

# %%
train_대천2동.to_csv('train_대천2동.csv', index=False)

# %% [markdown]
# ##### 10. 독곶리

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_독곶리 = (1 / pm_aws.loc['독곶리']) / (1 / pm_aws.loc['독곶리']).sum()
# 2. 가중치 * aws
train_독곶리 = train_pm_독곶리.copy()

for i in range(len(train_pm_독곶리)):
    train_독곶리.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_독곶리.values).sum()
    train_독곶리.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_독곶리.values).sum()
    train_독곶리.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_독곶리.values).sum()
    train_독곶리.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_독곶리.values).sum()
    train_독곶리.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_독곶리.values).sum()

# %%
datetime_pm(train_독곶리)
train_독곶리 = imputation(train_독곶리)
train_독곶리['측정소'] = '독곶리'
train_독곶리.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_독곶리[train_독곶리['PM2.5'].isna()]), len(train_독곶리[train_독곶리['기온'].isna()]))
# Out:
# 0 0

# %%
train_독곶리.to_csv('train_독곶리.csv', index=False)

# %% [markdown]
# ##### 11. 동문동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_동문동 = (1 / pm_aws.loc['동문동']) / (1 / pm_aws.loc['동문동']).sum()
# 2. 가중치 * aws
train_동문동 = train_pm_동문동.copy()

for i in range(len(train_pm_동문동)):
    train_동문동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_동문동.values).sum()
    train_동문동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_동문동.values).sum()
    train_동문동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_동문동.values).sum()
    train_동문동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_동문동.values).sum()
    train_동문동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_동문동.values).sum()

# %%
datetime_pm(train_동문동)
train_동문동 = imputation(train_동문동)
train_동문동['측정소'] = '동문동'
train_동문동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_동문동[train_동문동['PM2.5'].isna()]), len(train_동문동[train_동문동['기온'].isna()]))
# Out:
# 0 0

# %%
train_동문동.to_csv('train_동문동.csv', index=False)

# %% [markdown]
# ##### 12. 모종동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_모종동 = (1 / pm_aws.loc['모종동']) / (1 / pm_aws.loc['모종동']).sum()
# 2. 가중치 * aws
train_모종동 = train_pm_모종동.copy()

for i in range(len(train_pm_모종동)):
    train_모종동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_모종동.values).sum()
    train_모종동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_모종동.values).sum()
    train_모종동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_모종동.values).sum()
    train_모종동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_모종동.values).sum()
    train_모종동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_모종동.values).sum()

# %%
datetime_pm(train_모종동)
train_모종동 = imputation(train_모종동)
train_모종동['측정소'] = '모종동'
train_모종동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_모종동[train_모종동['PM2.5'].isna()]), len(train_모종동[train_모종동['기온'].isna()]))
# Out:
# 0 0

# %%
train_모종동.to_csv('train_모종동.csv', index=False)

# %% [markdown]
# ##### 13. 신방동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_신방동 = (1 / pm_aws.loc['신방동']) / (1 / pm_aws.loc['신방동']).sum()
# 2. 가중치 * aws
train_신방동 = train_pm_신방동.copy()

for i in range(len(train_pm_신방동)):
    train_신방동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_신방동.values).sum()
    train_신방동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_신방동.values).sum()
    train_신방동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_신방동.values).sum()
    train_신방동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_신방동.values).sum()
    train_신방동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_신방동.values).sum()

# %%
datetime_pm(train_신방동)
train_신방동 = imputation(train_신방동)
train_신방동['측정소'] = '신방동'
train_신방동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_신방동[train_신방동['PM2.5'].isna()]), len(train_신방동[train_신방동['기온'].isna()]))
# Out:
# 0 0

# %%
train_신방동.to_csv('train_신방동.csv', index=False)

# %% [markdown]
# ##### 14. 예산군

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_예산군 = (1 / pm_aws.loc['예산군']) / (1 / pm_aws.loc['예산군']).sum()
# 2. 가중치 * aws
train_예산군 = train_pm_예산군.copy()

for i in range(len(train_pm_예산군)):
    train_예산군.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_예산군.values).sum()
    train_예산군.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_예산군.values).sum()
    train_예산군.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_예산군.values).sum()
    train_예산군.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_예산군.values).sum()
    train_예산군.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_예산군.values).sum()

# %%
datetime_pm(train_예산군)
train_예산군 = imputation(train_예산군)
train_예산군['측정소'] = '예산군'
train_예산군.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_예산군[train_예산군['PM2.5'].isna()]), len(train_예산군[train_예산군['기온'].isna()]))
# Out:
# 0 0

# %%
train_예산군.to_csv('train_예산군.csv', index=False)

# %% [markdown]
# ##### 15. 이원면

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_이원면 = (1 / pm_aws.loc['이원면']) / (1 / pm_aws.loc['이원면']).sum()
# 2. 가중치 * aws
train_이원면 = train_pm_이원면.copy()

for i in range(len(train_pm_이원면)):
    train_이원면.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_이원면.values).sum()
    train_이원면.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_이원면.values).sum()
    train_이원면.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_이원면.values).sum()
    train_이원면.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_이원면.values).sum()
    train_이원면.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_이원면.values).sum()

# %%
datetime_pm(train_이원면)
train_이원면 = imputation(train_이원면)
train_이원면['측정소'] = '이원면'
train_이원면.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_이원면[train_이원면['PM2.5'].isna()]), len(train_이원면[train_이원면['기온'].isna()]))
# Out:
# 0 0

# %%
train_이원면.to_csv('train_이원면.csv', index=False)

# %% [markdown]
# ##### 16. 홍성읍

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_홍성읍 = (1 / pm_aws.loc['홍성읍']) / (1 / pm_aws.loc['홍성읍']).sum()
# 2. 가중치 * aws
train_홍성읍 = train_pm_홍성읍.copy()

for i in range(len(train_pm_홍성읍)):
    train_홍성읍.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_홍성읍.values).sum()
    train_홍성읍.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_홍성읍.values).sum()
    train_홍성읍.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_홍성읍.values).sum()
    train_홍성읍.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_홍성읍.values).sum()
    train_홍성읍.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_홍성읍.values).sum()

# %%
datetime_pm(train_홍성읍)
train_홍성읍 = imputation(train_홍성읍)
train_홍성읍['측정소'] = '홍성읍'
train_홍성읍.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_홍성읍[train_홍성읍['PM2.5'].isna()]), len(train_홍성읍[train_홍성읍['기온'].isna()]))
# Out:
# 0 0

# %%
train_홍성읍.to_csv('train_홍성읍.csv', index=False)

# %% [markdown]
# ##### 17. 성성동

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_성성동 = (1 / pm_aws.loc['성성동']) / (1 / pm_aws.loc['성성동']).sum()
# 2. 가중치 * aws
train_성성동 = train_pm_성성동.copy()

for i in range(len(train_pm_성성동)):
    train_성성동.loc[i, '기온'] = (train_aws.loc[i]['기온'] * weight_성성동.values).sum()
    train_성성동.loc[i, '풍향'] = (train_aws.loc[i]['풍향'] * weight_성성동.values).sum()
    train_성성동.loc[i, '풍속'] = (train_aws.loc[i]['풍속'] * weight_성성동.values).sum()
    train_성성동.loc[i, '강수량'] = (train_aws.loc[i]['강수량'] * weight_성성동.values).sum()
    train_성성동.loc[i, '습도'] = (train_aws.loc[i]['습도'] * weight_성성동.values).sum()

# %%
datetime_pm(train_성성동)
train_성성동 = imputation(train_성성동)
train_성성동['측정소'] = '성성동'
train_성성동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(train_성성동[train_성성동['PM2.5'].isna()]), len(train_성성동[train_성성동['기온'].isna()]))
# Out:
# 0 0

# %%
train_성성동.to_csv('train_성성동.csv', index=False)

# %% [markdown]
# ##### train PM 병합

# %%
# trian pm 합치기
train_pm = pd.concat([train_아름동, train_신흥동, train_노은동, train_문창동, train_읍내동, train_정림동, train_공주, train_논산, train_대천2동,
                      train_독곶리, train_동문동, train_모종동, train_신방동, train_예산군, train_이원면, train_홍성읍, train_성성동])

# %%
# 측정소 라벨링
le = LabelEncoder()
train_pm['측정소'] = le.fit_transform(train_pm['측정소'])

# %%
train_pm['측정소'].unique()
# Out:
# array([11, 10,  1,  7, 13, 15,  0,  2,  3,  4,  5,  6,  9, 12, 14, 16,  8])

# %%
train_pm.tail()
# Out:
#         PM2.5        기온        풍향        풍속  강수량        습도       년     월  \
# 596083  0.052  0.284019  0.783190  0.075672  0.0  0.592138  2020.0  12.0
# 596084  0.064  0.275426  0.802148  0.070671  0.0  0.614577  2020.0  12.0
# 596085  0.064  0.265070  0.441289  0.063398  0.0  0.618624  2020.0  12.0
# 596086  0.068  0.257490  0.337988  0.056784  0.0  0.618259  2020.0  12.0
# 596087  0.068  0.250238  0.393590  0.051147  0.0  0.614556  2020.0  12.0
#
#            일     시  측정소
# 596083  31.0  19.0    8
# 596084  31.0  20.0    8
# 596085  31.0  21.0    8
# 596086  31.0  22.0    8
# 596087  31.0  23.0    8

# %%
train_pm.to_csv('train_pm.csv', index=False)

# %% [markdown]
# ### 모델링 2 : lgbm

# %%
# !pip install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting catboost
#   Downloading catboost-1.2-cp310-cp310-manylinux2014_x86_64.whl (98.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.13.1)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.2)
# Installing collected packages: catboost
# Successfully installed catboost-1.2

# %%
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.1.1-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.10.4-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 24.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.10.4 cmaes-0.9.1 colorlog-6.7.0 optuna-3.1.1

# %%
train_pm_shift = train_pm.copy()

# 한 시간 전 PM2.5 칼럼 추가
train_pm_shift['PM2.5_1'] = train_pm_shift['PM2.5'].shift(periods=1, fill_value=0)

# '년' 범주화
for i in range(2017, 2022):
    train_pm_shift[f'{i}'] = np.where(train_pm_shift['년']==i, 1, 0)
train_pm_shift.drop('년', axis=1, inplace=True)

# object 타입으로 변경
train_pm_shift['월'] = train_pm_shift['월'].astype('str')
train_pm_shift['일'] = train_pm_shift['일'].astype('str')
train_pm_shift['시'] = train_pm_shift['시'].astype('str')
train_pm_shift['측정소'] = train_pm_shift['측정소'].astype('str')

# object 변수 cat features 이용
cat_features = ['월', '일', '시', '측정소']

# %%
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import optuna 
from optuna import Trial, visualization
from optuna.samplers import TPESampler


x = train_pm_shift.drop('PM2.5', axis=1)
y = train_pm_shift.loc[:, 'PM2.5']

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=2023, stratify=train_pm_shift['측정소'])

# %%
# random sampler
sampler = TPESampler(seed=10)

def objectiveCat(trial: Trial):
    params = {
        'learning_rate' : trial.suggest_loguniform('learning_rate', 0.001, 0.1),
        "depth": trial.suggest_int("depth", 1, 15),
        "iterations": trial.suggest_int("iteration", 1000, 10000),
        "l2_leaf_reg" : trial.suggest_int("l2_leaf_reg", 2, 30),
    }

    model = CatBoostRegressor(**params)
    model.fit(x_train, y_train, eval_set=[(x_val, y_val)], early_stopping_rounds=25, cat_features=['월', '일', '시', '측정소'], verbose=1)

    y_pred = model.predict(x_val)
    mse = mean_squared_error(y_val, y_pred)
    return mse

# MSE가 최소가 되는 방향으로 학습을 진행
studyCat = optuna.create_study(direction='minimize', sampler=sampler)

# n_trials 지정
studyCat.optimize(objectiveCat, n_trials=1)
# Out:
# [I 2023-05-06 12:53:32,631] A new study created in memory with name: no-name-94275429-1095-4186-adec-e778dcb6b843
# <ipython-input-37-d31f8aeb9165>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate' : trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# 0:	learn: 0.0697946	test: 0.0695856	best: 0.0695856 (0)	total: 130ms	remaining: 14m 29s
# 1:	learn: 0.0685256	test: 0.0683200	best: 0.0683200 (1)	total: 209ms	remaining: 11m 39s
# 2:	learn: 0.0673201	test: 0.0671184	best: 0.0671184 (2)	total: 282ms	remaining: 10m 30s
# 3:	learn: 0.0661622	test: 0.0659703	best: 0.0659703 (3)	total: 331ms	remaining: 9m 13s
# 4:	learn: 0.0650449	test: 0.0648528	best: 0.0648528 (4)	total: 380ms	remaining: 8m 28s
# 5:	learn: 0.0639737	test: 0.0637917	best: 0.0637917 (5)	total: 429ms	remaining: 7m 59s
# 6:	learn: 0.0629340	test: 0.0627496	best: 0.0627496 (6)	total: 475ms	remaining: 7m 34s
# 7:	learn: 0.0619347	test: 0.0617594	best: 0.0617594 (7)	total: 521ms	remaining: 7m 16s
# 8:	learn: 0.0609648	test: 0.0607876	best: 0.0607876 (8)	total: 608ms	remaining: 7m 32s
# 9:	learn: 0.0600325	test: 0.0598651	best: 0.0598651 (9)	total: 711ms	remaining: 7m 55s
# 10:	learn: 0.0591274	test: 0.0589571	best: 0.0589571 (10)	total: 799ms	remaining: 8m 6s
# 11:	learn: 0.0582468	test: 0.0580874	best: 0.0580874 (11)	total: 888ms	remaining: 8m 15s
# 12:	learn: 0.0574000	test: 0.0572383	best: 0.0572383 (12)	total: 971ms	remaining: 8m 19s
# 13:	learn: 0.0565744	test: 0.0564263	best: 0.0564263 (13)	total: 1.05s	remaining: 8m 24s
# 14:	learn: 0.0557684	test: 0.0556186	best: 0.0556186 (14)	total: 1.15s	remaining: 8m 30s
# 15:	learn: 0.0549928	test: 0.0548538	best: 0.0548538 (15)	total: 1.23s	remaining: 8m 33s
# 16:	learn: 0.0542351	test: 0.0540944	best: 0.0540944 (16)	total: 1.31s	remaining: 8m 37s
# 17:	learn: 0.0535004	test: 0.0533660	best: 0.0533660 (17)	total: 1.41s	remaining: 8m 42s
# 18:	learn: 0.0527933	test: 0.0526571	best: 0.0526571 (18)	total: 1.49s	remaining: 8m 44s
# 19:	learn: 0.0520853	test: 0.0519612	best: 0.0519612 (19)	total: 1.58s	remaining: 8m 48s
# 20:	learn: 0.0514163	test: 0.0513053	best: 0.0513053 (20)	total: 1.68s	remaining: 8m 53s
# 21:	learn: 0.0507524	test: 0.0506396	best: 0.0506396 (21)	total: 1.76s	remaining: 8m 55s
# 22:	learn: 0.0501070	test: 0.0499944	best: 0.0499944 (22)	total: 1.85s	remaining: 8m 58s
# 23:	learn: 0.0494839	test: 0.0493787	best: 0.0493787 (23)	total: 1.94s	remaining: 9m 1s
# 24:	learn: 0.0488787	test: 0.0487717	best: 0.0487717 (24)	total: 2.03s	remaining: 9m 1s
# 25:	learn: 0.0482766	test: 0.0481782	best: 0.0481782 (25)	total: 2.12s	remaining: 9m 5s
# 26:	learn: 0.0477031	test: 0.0476052	best: 0.0476052 (26)	total: 2.21s	remaining: 9m 5s
# 27:	learn: 0.0471412	test: 0.0470518	best: 0.0470518 (27)	total: 2.29s	remaining: 9m 6s
# 28:	learn: 0.0465839	test: 0.0464927	best: 0.0464927 (28)	total: 2.37s	remaining: 9m 5s
# 29:	learn: 0.0460496	test: 0.0459658	best: 0.0459658 (29)	total: 2.46s	remaining: 9m 7s
# 30:	learn: 0.0455227	test: 0.0454373	best: 0.0454373 (30)	total: 2.54s	remaining: 9m 7s
# 31:	learn: 0.0450189	test: 0.0449313	best: 0.0449313 (31)	total: 2.62s	remaining: 9m 6s
# 32:	learn: 0.0445139	test: 0.0444369	best: 0.0444369 (32)	total: 2.73s	remaining: 9m 11s
# 33:	learn: 0.0440241	test: 0.0439513	best: 0.0439513 (33)	total: 2.82s	remaining: 9m 13s
# 34:	learn: 0.0435528	test: 0.0434783	best: 0.0434783 (34)	total: 2.9s	remaining: 9m 13s
# 35:	learn: 0.0430852	test: 0.0430208	best: 0.0430208 (35)	total: 2.99s	remaining: 9m 13s
# 36:	learn: 0.0426301	test: 0.0425648	best: 0.0425648 (36)	total: 3.07s	remaining: 9m 13s
# 37:	learn: 0.0421909	test: 0.0421233	best: 0.0421233 (37)	total: 3.16s	remaining: 9m 14s
# 38:	learn: 0.0417544	test: 0.0416935	best: 0.0416935 (38)	total: 3.25s	remaining: 9m 14s
# 39:	learn: 0.0413340	test: 0.0412779	best: 0.0412779 (39)	total: 3.34s	remaining: 9m 15s
# 40:	learn: 0.0409187	test: 0.0408605	best: 0.0408605 (40)	total: 3.41s	remaining: 9m 13s
# 41:	learn: 0.0405145	test: 0.0404594	best: 0.0404594 (41)	total: 3.49s	remaining: 9m 13s
# 42:	learn: 0.0401177	test: 0.0400607	best: 0.0400607 (42)	total: 3.57s	remaining: 9m 13s
# 43:	learn: 0.0397393	test: 0.0396851	best: 0.0396851 (43)	total: 3.63s	remaining: 9m 9s
# 44:	learn: 0.0393537	test: 0.0392980	best: 0.0392980 (44)	total: 3.68s	remaining: 9m 3s
# 45:	learn: 0.0389870	test: 0.0389357	best: 0.0389357 (45)	total: 3.73s	remaining: 8m 59s
# 46:	learn: 0.0386246	test: 0.0385717	best: 0.0385717 (46)	total: 3.78s	remaining: 8m 55s
# 47:	learn: 0.0382736	test: 0.0382190	best: 0.0382190 (47)	total: 3.83s	remaining: 8m 51s
# 48:	learn: 0.0379250	test: 0.0378753	best: 0.0378753 (48)	total: 3.88s	remaining: 8m 46s
# 49:	learn: 0.0375839	test: 0.0375349	best: 0.0375349 (49)	total: 3.92s	remaining: 8m 42s
# 50:	learn: 0.0372571	test: 0.0372063	best: 0.0372063 (50)	total: 3.97s	remaining: 8m 38s
# 51:	learn: 0.0369320	test: 0.0368840	best: 0.0368840 (51)	total: 4.02s	remaining: 8m 33s
# 52:	learn: 0.0366137	test: 0.0365696	best: 0.0365696 (52)	total: 4.07s	remaining: 8m 30s
# 53:	learn: 0.0363034	test: 0.0362577	best: 0.0362577 (53)	total: 4.11s	remaining: 8m 26s
# 54:	learn: 0.0360048	test: 0.0359623	best: 0.0359623 (54)	total: 4.16s	remaining: 8m 22s
# 55:	learn: 0.0357097	test: 0.0356644	best: 0.0356644 (55)	total: 4.21s	remaining: 8m 19s
# 56:	learn: 0.0354229	test: 0.0353762	best: 0.0353762 (56)	total: 4.25s	remaining: 8m 16s
# 57:	learn: 0.0351355	test: 0.0350924	best: 0.0350924 (57)	total: 4.3s	remaining: 8m 12s
# 58:	learn: 0.0348565	test: 0.0348176	best: 0.0348176 (58)	total: 4.35s	remaining: 8m 10s
# 59:	learn: 0.0345874	test: 0.0345470	best: 0.0345470 (59)	total: 4.4s	remaining: 8m 7s
# 60:	learn: 0.0343212	test: 0.0342818	best: 0.0342818 (60)	total: 4.45s	remaining: 8m 4s
# 61:	learn: 0.0340612	test: 0.0340203	best: 0.0340203 (61)	total: 4.49s	remaining: 8m 1s
# 62:	learn: 0.0338034	test: 0.0337611	best: 0.0337611 (62)	total: 4.54s	remaining: 7m 58s
# 63:	learn: 0.0335534	test: 0.0335125	best: 0.0335125 (63)	total: 4.59s	remaining: 7m 55s
# 64:	learn: 0.0333110	test: 0.0332720	best: 0.0332720 (64)	total: 4.63s	remaining: 7m 53s
# 65:	learn: 0.0330695	test: 0.0330292	best: 0.0330292 (65)	total: 4.68s	remaining: 7m 51s
# 66:	learn: 0.0328357	test: 0.0327978	best: 0.0327978 (66)	total: 4.73s	remaining: 7m 48s
# 67:	learn: 0.0326070	test: 0.0325680	best: 0.0325680 (67)	total: 4.79s	remaining: 7m 47s
# 68:	learn: 0.0323829	test: 0.0323481	best: 0.0323481 (68)	total: 4.83s	remaining: 7m 44s
# 69:	learn: 0.0321678	test: 0.0321340	best: 0.0321340 (69)	total: 4.88s	remaining: 7m 42s
# 70:	learn: 0.0319518	test: 0.0319166	best: 0.0319166 (70)	total: 4.93s	remaining: 7m 40s
# 71:	learn: 0.0317370	test: 0.0317007	best: 0.0317007 (71)	total: 4.97s	remaining: 7m 38s
# 72:	learn: 0.0315339	test: 0.0314952	best: 0.0314952 (72)	total: 5.02s	remaining: 7m 35s
# 73:	learn: 0.0313325	test: 0.0312959	best: 0.0312959 (73)	total: 5.07s	remaining: 7m 33s
# 74:	learn: 0.0311360	test: 0.0311028	best: 0.0311028 (74)	total: 5.11s	remaining: 7m 31s
# 75:	learn: 0.0309384	test: 0.0309040	best: 0.0309040 (75)	total: 5.17s	remaining: 7m 30s
# 76:	learn: 0.0307504	test: 0.0307179	best: 0.0307179 (76)	total: 5.21s	remaining: 7m 28s
# 77:	learn: 0.0305663	test: 0.0305327	best: 0.0305327 (77)	total: 5.26s	remaining: 7m 26s
# 78:	learn: 0.0303827	test: 0.0303538	best: 0.0303538 (78)	total: 5.31s	remaining: 7m 25s
# 79:	learn: 0.0302074	test: 0.0301797	best: 0.0301797 (79)	total: 5.35s	remaining: 7m 23s
# 80:	learn: 0.0300304	test: 0.0300016	best: 0.0300016 (80)	total: 5.41s	remaining: 7m 21s
# 81:	learn: 0.0298607	test: 0.0298304	best: 0.0298304 (81)	total: 5.45s	remaining: 7m 20s
# 82:	learn: 0.0296936	test: 0.0296644	best: 0.0296644 (82)	total: 5.5s	remaining: 7m 18s
# 83:	learn: 0.0295308	test: 0.0295031	best: 0.0295031 (83)	total: 5.54s	remaining: 7m 16s
# 84:	learn: 0.0293703	test: 0.0293414	best: 0.0293414 (84)	total: 5.59s	remaining: 7m 15s
# 85:	learn: 0.0292136	test: 0.0291890	best: 0.0291890 (85)	total: 5.64s	remaining: 7m 13s
# 86:	learn: 0.0290580	test: 0.0290321	best: 0.0290321 (86)	total: 5.69s	remaining: 7m 12s
# 87:	learn: 0.0289062	test: 0.0288792	best: 0.0288792 (87)	total: 5.74s	remaining: 7m 11s
# 88:	learn: 0.0287593	test: 0.0287349	best: 0.0287349 (88)	total: 5.79s	remaining: 7m 9s
# 89:	learn: 0.0286160	test: 0.0285954	best: 0.0285954 (89)	total: 5.83s	remaining: 7m 8s
# 90:	learn: 0.0284730	test: 0.0284510	best: 0.0284510 (90)	total: 5.88s	remaining: 7m 7s
# 91:	learn: 0.0283350	test: 0.0283120	best: 0.0283120 (91)	total: 5.93s	remaining: 7m 6s
# 92:	learn: 0.0281994	test: 0.0281785	best: 0.0281785 (92)	total: 5.97s	remaining: 7m 4s
# 93:	learn: 0.0280639	test: 0.0280429	best: 0.0280429 (93)	total: 6.02s	remaining: 7m 3s
# 94:	learn: 0.0279351	test: 0.0279162	best: 0.0279162 (94)	total: 6.06s	remaining: 7m 1s
# 95:	learn: 0.0278057	test: 0.0277859	best: 0.0277859 (95)	total: 6.11s	remaining: 7m
# 96:	learn: 0.0276811	test: 0.0276630	best: 0.0276630 (96)	total: 6.16s	remaining: 6m 59s
# 97:	learn: 0.0275582	test: 0.0275386	best: 0.0275386 (97)	total: 6.22s	remaining: 6m 59s
# 98:	learn: 0.0274408	test: 0.0274244	best: 0.0274244 (98)	total: 6.27s	remaining: 6m 58s
# 99:	learn: 0.0273208	test: 0.0273036	best: 0.0273036 (99)	total: 6.31s	remaining: 6m 56s
# 100:	learn: 0.0272059	test: 0.0271888	best: 0.0271888 (100)	total: 6.36s	remaining: 6m 55s
# 101:	learn: 0.0270918	test: 0.0270755	best: 0.0270755 (101)	total: 6.42s	remaining: 6m 55s
# 102:	learn: 0.0269806	test: 0.0269634	best: 0.0269634 (102)	total: 6.47s	remaining: 6m 54s
# 103:	learn: 0.0268722	test: 0.0268536	best: 0.0268536 (103)	total: 6.51s	remaining: 6m 53s
# 104:	learn: 0.0267653	test: 0.0267462	best: 0.0267462 (104)	total: 6.56s	remaining: 6m 52s
# 105:	learn: 0.0266607	test: 0.0266425	best: 0.0266425 (105)	total: 6.61s	remaining: 6m 51s
# 106:	learn: 0.0265585	test: 0.0265388	best: 0.0265388 (106)	total: 6.66s	remaining: 6m 50s
# 107:	learn: 0.0264575	test: 0.0264366	best: 0.0264366 (107)	total: 6.7s	remaining: 6m 49s
# 108:	learn: 0.0263605	test: 0.0263400	best: 0.0263400 (108)	total: 6.75s	remaining: 6m 48s
# 109:	learn: 0.0262639	test: 0.0262417	best: 0.0262417 (109)	total: 6.79s	remaining: 6m 47s
# 110:	learn: 0.0261703	test: 0.0261481	best: 0.0261481 (110)	total: 6.85s	remaining: 6m 46s
# 111:	learn: 0.0260765	test: 0.0260532	best: 0.0260532 (111)	total: 6.9s	remaining: 6m 46s
# 112:	learn: 0.0259859	test: 0.0259631	best: 0.0259631 (112)	total: 6.95s	remaining: 6m 45s
# 113:	learn: 0.0258969	test: 0.0258737	best: 0.0258737 (113)	total: 7s	remaining: 6m 44s
# 114:	learn: 0.0258100	test: 0.0257860	best: 0.0257860 (114)	total: 7.04s	remaining: 6m 43s
# 115:	learn: 0.0257253	test: 0.0256998	best: 0.0256998 (115)	total: 7.09s	remaining: 6m 42s
# 116:	learn: 0.0256417	test: 0.0256150	best: 0.0256150 (116)	total: 7.14s	remaining: 6m 42s
# 117:	learn: 0.0255611	test: 0.0255354	best: 0.0255354 (117)	total: 7.19s	remaining: 6m 41s
# 118:	learn: 0.0254807	test: 0.0254553	best: 0.0254553 (118)	total: 7.24s	remaining: 6m 40s
# 119:	learn: 0.0253996	test: 0.0253731	best: 0.0253731 (119)	total: 7.3s	remaining: 6m 40s
# 120:	learn: 0.0253229	test: 0.0252964	best: 0.0252964 (120)	total: 7.35s	remaining: 6m 39s
# 121:	learn: 0.0252494	test: 0.0252233	best: 0.0252233 (121)	total: 7.39s	remaining: 6m 38s
# 122:	learn: 0.0251746	test: 0.0251470	best: 0.0251470 (122)	total: 7.44s	remaining: 6m 38s
# 123:	learn: 0.0250999	test: 0.0250713	best: 0.0250713 (123)	total: 7.5s	remaining: 6m 37s
# 124:	learn: 0.0250295	test: 0.0250000	best: 0.0250000 (124)	total: 7.54s	remaining: 6m 37s
# 125:	learn: 0.0249595	test: 0.0249287	best: 0.0249287 (125)	total: 7.59s	remaining: 6m 36s
# 126:	learn: 0.0248904	test: 0.0248584	best: 0.0248584 (126)	total: 7.64s	remaining: 6m 35s
# 127:	learn: 0.0248237	test: 0.0247920	best: 0.0247920 (127)	total: 7.68s	remaining: 6m 34s
# 128:	learn: 0.0247576	test: 0.0247253	best: 0.0247253 (128)	total: 7.73s	remaining: 6m 33s
# 129:	learn: 0.0246946	test: 0.0246629	best: 0.0246629 (129)	total: 7.78s	remaining: 6m 33s
# 130:	learn: 0.0246299	test: 0.0245972	best: 0.0245972 (130)	total: 7.82s	remaining: 6m 32s
# 131:	learn: 0.0245674	test: 0.0245329	best: 0.0245329 (131)	total: 7.88s	remaining: 6m 32s
# 132:	learn: 0.0245070	test: 0.0244708	best: 0.0244708 (132)	total: 7.92s	remaining: 6m 31s
# 133:	learn: 0.0244474	test: 0.0244104	best: 0.0244104 (133)	total: 7.97s	remaining: 6m 30s
# 134:	learn: 0.0243908	test: 0.0243539	best: 0.0243539 (134)	total: 8.02s	remaining: 6m 30s
# 135:	learn: 0.0243328	test: 0.0242950	best: 0.0242950 (135)	total: 8.06s	remaining: 6m 29s
# 136:	learn: 0.0242758	test: 0.0242371	best: 0.0242371 (136)	total: 8.11s	remaining: 6m 28s
# 137:	learn: 0.0242210	test: 0.0241825	best: 0.0241825 (137)	total: 8.16s	remaining: 6m 28s
# 138:	learn: 0.0241679	test: 0.0241302	best: 0.0241302 (138)	total: 8.2s	remaining: 6m 27s
# 139:	learn: 0.0241173	test: 0.0240796	best: 0.0240796 (139)	total: 8.25s	remaining: 6m 26s
# 140:	learn: 0.0240646	test: 0.0240258	best: 0.0240258 (140)	total: 8.3s	remaining: 6m 26s
# 141:	learn: 0.0240128	test: 0.0239731	best: 0.0239731 (141)	total: 8.34s	remaining: 6m 25s
# 142:	learn: 0.0239631	test: 0.0239233	best: 0.0239233 (142)	total: 8.39s	remaining: 6m 24s
# 143:	learn: 0.0239139	test: 0.0238732	best: 0.0238732 (143)	total: 8.44s	remaining: 6m 24s
# 144:	learn: 0.0238662	test: 0.0238238	best: 0.0238238 (144)	total: 8.49s	remaining: 6m 23s
# 145:	learn: 0.0238205	test: 0.0237774	best: 0.0237774 (145)	total: 8.53s	remaining: 6m 23s
# 146:	learn: 0.0237750	test: 0.0237310	best: 0.0237310 (146)	total: 8.58s	remaining: 6m 22s
# 147:	learn: 0.0237295	test: 0.0236853	best: 0.0236853 (147)	total: 8.62s	remaining: 6m 21s
# 148:	learn: 0.0236866	test: 0.0236426	best: 0.0236426 (148)	total: 8.67s	remaining: 6m 21s
# 149:	learn: 0.0236424	test: 0.0235974	best: 0.0235974 (149)	total: 8.72s	remaining: 6m 20s
# 150:	learn: 0.0235995	test: 0.0235543	best: 0.0235543 (150)	total: 8.76s	remaining: 6m 20s
# 151:	learn: 0.0235584	test: 0.0235122	best: 0.0235122 (151)	total: 8.81s	remaining: 6m 19s
# 152:	learn: 0.0235187	test: 0.0234725	best: 0.0234725 (152)	total: 8.86s	remaining: 6m 19s
# 153:	learn: 0.0234785	test: 0.0234315	best: 0.0234315 (153)	total: 8.91s	remaining: 6m 18s
# 154:	learn: 0.0234408	test: 0.0233931	best: 0.0233931 (154)	total: 8.96s	remaining: 6m 18s
# 155:	learn: 0.0234018	test: 0.0233542	best: 0.0233542 (155)	total: 9s	remaining: 6m 17s
# 156:	learn: 0.0233645	test: 0.0233153	best: 0.0233153 (156)	total: 9.05s	remaining: 6m 17s
# 157:	learn: 0.0233271	test: 0.0232773	best: 0.0232773 (157)	total: 9.09s	remaining: 6m 16s
# 158:	learn: 0.0232903	test: 0.0232390	best: 0.0232390 (158)	total: 9.14s	remaining: 6m 16s
# 159:	learn: 0.0232554	test: 0.0232039	best: 0.0232039 (159)	total: 9.2s	remaining: 6m 16s
# 160:	learn: 0.0232199	test: 0.0231677	best: 0.0231677 (160)	total: 9.25s	remaining: 6m 15s
# 161:	learn: 0.0231867	test: 0.0231340	best: 0.0231340 (161)	total: 9.3s	remaining: 6m 15s
# 162:	learn: 0.0231532	test: 0.0230993	best: 0.0230993 (162)	total: 9.36s	remaining: 6m 15s
# 163:	learn: 0.0231217	test: 0.0230674	best: 0.0230674 (163)	total: 9.41s	remaining: 6m 15s
# 164:	learn: 0.0230890	test: 0.0230341	best: 0.0230341 (164)	total: 9.46s	remaining: 6m 14s
# 165:	learn: 0.0230573	test: 0.0230025	best: 0.0230025 (165)	total: 9.51s	remaining: 6m 14s
# 166:	learn: 0.0230265	test: 0.0229720	best: 0.0229720 (166)	total: 9.56s	remaining: 6m 14s
# 167:	learn: 0.0229958	test: 0.0229405	best: 0.0229405 (167)	total: 9.61s	remaining: 6m 13s
# 168:	learn: 0.0229665	test: 0.0229110	best: 0.0229110 (168)	total: 9.66s	remaining: 6m 13s
# 169:	learn: 0.0229380	test: 0.0228821	best: 0.0228821 (169)	total: 9.71s	remaining: 6m 13s
# 170:	learn: 0.0229088	test: 0.0228519	best: 0.0228519 (170)	total: 9.76s	remaining: 6m 12s
# 171:	learn: 0.0228818	test: 0.0228246	best: 0.0228246 (171)	total: 9.81s	remaining: 6m 12s
# 172:	learn: 0.0228531	test: 0.0227953	best: 0.0227953 (172)	total: 9.85s	remaining: 6m 11s
# 173:	learn: 0.0228261	test: 0.0227676	best: 0.0227676 (173)	total: 9.91s	remaining: 6m 11s
# 174:	learn: 0.0227992	test: 0.0227398	best: 0.0227398 (174)	total: 9.96s	remaining: 6m 11s
# 175:	learn: 0.0227740	test: 0.0227146	best: 0.0227146 (175)	total: 10s	remaining: 6m 10s
# 176:	learn: 0.0227482	test: 0.0226882	best: 0.0226882 (176)	total: 10.1s	remaining: 6m 10s
# 177:	learn: 0.0227228	test: 0.0226619	best: 0.0226619 (177)	total: 10.1s	remaining: 6m 10s
# 178:	learn: 0.0226985	test: 0.0226372	best: 0.0226372 (178)	total: 10.1s	remaining: 6m 9s
# 179:	learn: 0.0226747	test: 0.0226124	best: 0.0226124 (179)	total: 10.2s	remaining: 6m 9s
# 180:	learn: 0.0226517	test: 0.0225894	best: 0.0225894 (180)	total: 10.2s	remaining: 6m 9s
# 181:	learn: 0.0226285	test: 0.0225659	best: 0.0225659 (181)	total: 10.3s	remaining: 6m 8s
# 182:	learn: 0.0226062	test: 0.0225426	best: 0.0225426 (182)	total: 10.3s	remaining: 6m 8s
# 183:	learn: 0.0225842	test: 0.0225209	best: 0.0225209 (183)	total: 10.4s	remaining: 6m 7s
# 184:	learn: 0.0225625	test: 0.0224987	best: 0.0224987 (184)	total: 10.4s	remaining: 6m 7s
# 185:	learn: 0.0225401	test: 0.0224758	best: 0.0224758 (185)	total: 10.5s	remaining: 6m 7s
# 186:	learn: 0.0225198	test: 0.0224556	best: 0.0224556 (186)	total: 10.5s	remaining: 6m 6s
# 187:	learn: 0.0224993	test: 0.0224340	best: 0.0224340 (187)	total: 10.6s	remaining: 6m 6s
# 188:	learn: 0.0224786	test: 0.0224128	best: 0.0224128 (188)	total: 10.6s	remaining: 6m 5s
# 189:	learn: 0.0224590	test: 0.0223932	best: 0.0223932 (189)	total: 10.7s	remaining: 6m 5s
# 190:	learn: 0.0224394	test: 0.0223729	best: 0.0223729 (190)	total: 10.7s	remaining: 6m 5s
# 191:	learn: 0.0224208	test: 0.0223544	best: 0.0223544 (191)	total: 10.8s	remaining: 6m 4s
# 192:	learn: 0.0224019	test: 0.0223350	best: 0.0223350 (192)	total: 10.8s	remaining: 6m 4s
# 193:	learn: 0.0223835	test: 0.0223162	best: 0.0223162 (193)	total: 10.8s	remaining: 6m 4s
# 194:	learn: 0.0223656	test: 0.0222979	best: 0.0222979 (194)	total: 10.9s	remaining: 6m 3s
# 195:	learn: 0.0223483	test: 0.0222809	best: 0.0222809 (195)	total: 10.9s	remaining: 6m 3s
# 196:	learn: 0.0223308	test: 0.0222626	best: 0.0222626 (196)	total: 11s	remaining: 6m 3s
# 197:	learn: 0.0223139	test: 0.0222455	best: 0.0222455 (197)	total: 11s	remaining: 6m 2s
# 198:	learn: 0.0222980	test: 0.0222299	best: 0.0222299 (198)	total: 11.1s	remaining: 6m 2s
# 199:	learn: 0.0222814	test: 0.0222129	best: 0.0222129 (199)	total: 11.1s	remaining: 6m 2s
# 200:	learn: 0.0222656	test: 0.0221966	best: 0.0221966 (200)	total: 11.2s	remaining: 6m 1s
# 201:	learn: 0.0222499	test: 0.0221811	best: 0.0221811 (201)	total: 11.2s	remaining: 6m 1s
# 202:	learn: 0.0222343	test: 0.0221651	best: 0.0221651 (202)	total: 11.3s	remaining: 6m 1s
# 203:	learn: 0.0222199	test: 0.0221508	best: 0.0221508 (203)	total: 11.3s	remaining: 6m
# 204:	learn: 0.0222049	test: 0.0221350	best: 0.0221350 (204)	total: 11.4s	remaining: 6m
# 205:	learn: 0.0221897	test: 0.0221200	best: 0.0221200 (205)	total: 11.4s	remaining: 6m
# 206:	learn: 0.0221744	test: 0.0221043	best: 0.0221043 (206)	total: 11.5s	remaining: 5m 59s
# 207:	learn: 0.0221599	test: 0.0220896	best: 0.0220896 (207)	total: 11.5s	remaining: 5m 59s
# 208:	learn: 0.0221461	test: 0.0220760	best: 0.0220760 (208)	total: 11.6s	remaining: 5m 59s
# 209:	learn: 0.0221320	test: 0.0220614	best: 0.0220614 (209)	total: 11.6s	remaining: 5m 58s
# 210:	learn: 0.0221188	test: 0.0220484	best: 0.0220484 (210)	total: 11.7s	remaining: 5m 58s
# 211:	learn: 0.0221053	test: 0.0220345	best: 0.0220345 (211)	total: 11.7s	remaining: 5m 58s
# 212:	learn: 0.0220923	test: 0.0220216	best: 0.0220216 (212)	total: 11.8s	remaining: 5m 58s
# 213:	learn: 0.0220794	test: 0.0220081	best: 0.0220081 (213)	total: 11.8s	remaining: 5m 57s
# 214:	learn: 0.0220670	test: 0.0219959	best: 0.0219959 (214)	total: 11.8s	remaining: 5m 57s
# 215:	learn: 0.0220550	test: 0.0219839	best: 0.0219839 (215)	total: 11.9s	remaining: 5m 57s
# 216:	learn: 0.0220426	test: 0.0219712	best: 0.0219712 (216)	total: 11.9s	remaining: 5m 57s
# 217:	learn: 0.0220309	test: 0.0219600	best: 0.0219600 (217)	total: 12s	remaining: 5m 56s
# 218:	learn: 0.0220182	test: 0.0219469	best: 0.0219469 (218)	total: 12s	remaining: 5m 56s
# 219:	learn: 0.0220065	test: 0.0219349	best: 0.0219349 (219)	total: 12.1s	remaining: 5m 56s
# 220:	learn: 0.0219949	test: 0.0219233	best: 0.0219233 (220)	total: 12.1s	remaining: 5m 56s
# 221:	learn: 0.0219843	test: 0.0219135	best: 0.0219135 (221)	total: 12.2s	remaining: 5m 55s
# 222:	learn: 0.0219733	test: 0.0219028	best: 0.0219028 (222)	total: 12.2s	remaining: 5m 55s
# 223:	learn: 0.0219620	test: 0.0218911	best: 0.0218911 (223)	total: 12.3s	remaining: 5m 55s
# 224:	learn: 0.0219512	test: 0.0218802	best: 0.0218802 (224)	total: 12.3s	remaining: 5m 54s
# 225:	learn: 0.0219407	test: 0.0218697	best: 0.0218697 (225)	total: 12.4s	remaining: 5m 54s
# 226:	learn: 0.0219297	test: 0.0218579	best: 0.0218579 (226)	total: 12.4s	remaining: 5m 54s
# 227:	learn: 0.0219188	test: 0.0218466	best: 0.0218466 (227)	total: 12.5s	remaining: 5m 54s
# 228:	learn: 0.0219092	test: 0.0218374	best: 0.0218374 (228)	total: 12.5s	remaining: 5m 53s
# 229:	learn: 0.0218991	test: 0.0218268	best: 0.0218268 (229)	total: 12.6s	remaining: 5m 53s
# 230:	learn: 0.0218893	test: 0.0218171	best: 0.0218171 (230)	total: 12.6s	remaining: 5m 53s
# 231:	learn: 0.0218794	test: 0.0218072	best: 0.0218072 (231)	total: 12.7s	remaining: 5m 52s
# 232:	learn: 0.0218697	test: 0.0217972	best: 0.0217972 (232)	total: 12.7s	remaining: 5m 52s
# 233:	learn: 0.0218600	test: 0.0217872	best: 0.0217872 (233)	total: 12.7s	remaining: 5m 52s
# 234:	learn: 0.0218507	test: 0.0217780	best: 0.0217780 (234)	total: 12.8s	remaining: 5m 52s
# 235:	learn: 0.0218416	test: 0.0217689	best: 0.0217689 (235)	total: 12.8s	remaining: 5m 51s
# 236:	learn: 0.0218323	test: 0.0217593	best: 0.0217593 (236)	total: 12.9s	remaining: 5m 51s
# 237:	learn: 0.0218237	test: 0.0217514	best: 0.0217514 (237)	total: 12.9s	remaining: 5m 51s
# 238:	learn: 0.0218149	test: 0.0217422	best: 0.0217422 (238)	total: 13s	remaining: 5m 51s
# 239:	learn: 0.0218060	test: 0.0217334	best: 0.0217334 (239)	total: 13s	remaining: 5m 51s
# 240:	learn: 0.0217977	test: 0.0217252	best: 0.0217252 (240)	total: 13.1s	remaining: 5m 50s
# 241:	learn: 0.0217894	test: 0.0217170	best: 0.0217170 (241)	total: 13.1s	remaining: 5m 50s
# 242:	learn: 0.0217816	test: 0.0217099	best: 0.0217099 (242)	total: 13.2s	remaining: 5m 50s
# 243:	learn: 0.0217734	test: 0.0217017	best: 0.0217017 (243)	total: 13.2s	remaining: 5m 50s
# 244:	learn: 0.0217656	test: 0.0216941	best: 0.0216941 (244)	total: 13.3s	remaining: 5m 49s
# 245:	learn: 0.0217574	test: 0.0216857	best: 0.0216857 (245)	total: 13.3s	remaining: 5m 49s
# 246:	learn: 0.0217495	test: 0.0216771	best: 0.0216771 (246)	total: 13.4s	remaining: 5m 49s
# 247:	learn: 0.0217415	test: 0.0216688	best: 0.0216688 (247)	total: 13.4s	remaining: 5m 49s
# 248:	learn: 0.0217339	test: 0.0216612	best: 0.0216612 (248)	total: 13.5s	remaining: 5m 49s
# 249:	learn: 0.0217267	test: 0.0216547	best: 0.0216547 (249)	total: 13.5s	remaining: 5m 48s
# 250:	learn: 0.0217195	test: 0.0216476	best: 0.0216476 (250)	total: 13.6s	remaining: 5m 48s
# 251:	learn: 0.0217124	test: 0.0216406	best: 0.0216406 (251)	total: 13.6s	remaining: 5m 49s
# 252:	learn: 0.0217048	test: 0.0216327	best: 0.0216327 (252)	total: 13.7s	remaining: 5m 50s
# 253:	learn: 0.0216982	test: 0.0216262	best: 0.0216262 (253)	total: 13.8s	remaining: 5m 50s
# 254:	learn: 0.0216910	test: 0.0216188	best: 0.0216188 (254)	total: 13.9s	remaining: 5m 51s
# 255:	learn: 0.0216841	test: 0.0216119	best: 0.0216119 (255)	total: 14s	remaining: 5m 52s
# 256:	learn: 0.0216772	test: 0.0216048	best: 0.0216048 (256)	total: 14.1s	remaining: 5m 53s
# 257:	learn: 0.0216714	test: 0.0215997	best: 0.0215997 (257)	total: 14.2s	remaining: 5m 53s
# 258:	learn: 0.0216646	test: 0.0215926	best: 0.0215926 (258)	total: 14.3s	remaining: 5m 54s
# 259:	learn: 0.0216580	test: 0.0215858	best: 0.0215858 (259)	total: 14.4s	remaining: 5m 55s
# 260:	learn: 0.0216517	test: 0.0215794	best: 0.0215794 (260)	total: 14.4s	remaining: 5m 56s
# 261:	learn: 0.0216452	test: 0.0215731	best: 0.0215731 (261)	total: 14.5s	remaining: 5m 56s
# 262:	learn: 0.0216393	test: 0.0215677	best: 0.0215677 (262)	total: 14.6s	remaining: 5m 57s
# 263:	learn: 0.0216334	test: 0.0215618	best: 0.0215618 (263)	total: 14.7s	remaining: 5m 57s
# 264:	learn: 0.0216274	test: 0.0215559	best: 0.0215559 (264)	total: 14.8s	remaining: 5m 58s
# 265:	learn: 0.0216214	test: 0.0215492	best: 0.0215492 (265)	total: 14.8s	remaining: 5m 59s
# 266:	learn: 0.0216157	test: 0.0215427	best: 0.0215427 (266)	total: 14.9s	remaining: 5m 59s
# 267:	learn: 0.0216096	test: 0.0215365	best: 0.0215365 (267)	total: 15s	remaining: 6m
# 268:	learn: 0.0216045	test: 0.0215320	best: 0.0215320 (268)	total: 15.1s	remaining: 6m 1s
# 269:	learn: 0.0215989	test: 0.0215259	best: 0.0215259 (269)	total: 15.2s	remaining: 6m 1s
# 270:	learn: 0.0215931	test: 0.0215200	best: 0.0215200 (270)	total: 15.3s	remaining: 6m 2s
# 271:	learn: 0.0215881	test: 0.0215150	best: 0.0215150 (271)	total: 15.4s	remaining: 6m 2s
# 272:	learn: 0.0215825	test: 0.0215096	best: 0.0215096 (272)	total: 15.4s	remaining: 6m 3s
# 273:	learn: 0.0215774	test: 0.0215046	best: 0.0215046 (273)	total: 15.5s	remaining: 6m 3s
# 274:	learn: 0.0215722	test: 0.0214991	best: 0.0214991 (274)	total: 15.6s	remaining: 6m 4s
# 275:	learn: 0.0215670	test: 0.0214935	best: 0.0214935 (275)	total: 15.7s	remaining: 6m 4s
# 276:	learn: 0.0215619	test: 0.0214884	best: 0.0214884 (276)	total: 15.8s	remaining: 6m 5s
# 277:	learn: 0.0215572	test: 0.0214839	best: 0.0214839 (277)	total: 15.8s	remaining: 6m 5s
# 278:	learn: 0.0215522	test: 0.0214785	best: 0.0214785 (278)	total: 15.9s	remaining: 6m 6s
# 279:	learn: 0.0215474	test: 0.0214738	best: 0.0214738 (279)	total: 16s	remaining: 6m 6s
# 280:	learn: 0.0215431	test: 0.0214696	best: 0.0214696 (280)	total: 16.1s	remaining: 6m 7s
# 281:	learn: 0.0215381	test: 0.0214645	best: 0.0214645 (281)	total: 16.2s	remaining: 6m 8s
# 282:	learn: 0.0215334	test: 0.0214598	best: 0.0214598 (282)	total: 16.3s	remaining: 6m 9s
# 283:	learn: 0.0215288	test: 0.0214555	best: 0.0214555 (283)	total: 16.4s	remaining: 6m 9s
# 284:	learn: 0.0215248	test: 0.0214520	best: 0.0214520 (284)	total: 16.4s	remaining: 6m 10s
# 285:	learn: 0.0215202	test: 0.0214473	best: 0.0214473 (285)	total: 16.5s	remaining: 6m 11s
# 286:	learn: 0.0215158	test: 0.0214429	best: 0.0214429 (286)	total: 16.6s	remaining: 6m 11s
# 287:	learn: 0.0215111	test: 0.0214380	best: 0.0214380 (287)	total: 16.7s	remaining: 6m 11s
# 288:	learn: 0.0215073	test: 0.0214347	best: 0.0214347 (288)	total: 16.7s	remaining: 6m 11s
# 289:	learn: 0.0215032	test: 0.0214307	best: 0.0214307 (289)	total: 16.8s	remaining: 6m 10s
# 290:	learn: 0.0214989	test: 0.0214258	best: 0.0214258 (290)	total: 16.8s	remaining: 6m 10s
# 291:	learn: 0.0214947	test: 0.0214212	best: 0.0214212 (291)	total: 16.9s	remaining: 6m 10s
# 292:	learn: 0.0214905	test: 0.0214169	best: 0.0214169 (292)	total: 16.9s	remaining: 6m 9s
# 293:	learn: 0.0214862	test: 0.0214124	best: 0.0214124 (293)	total: 17s	remaining: 6m 9s
# 294:	learn: 0.0214822	test: 0.0214086	best: 0.0214086 (294)	total: 17s	remaining: 6m 9s
# 295:	learn: 0.0214783	test: 0.0214044	best: 0.0214044 (295)	total: 17.1s	remaining: 6m 9s
# 296:	learn: 0.0214745	test: 0.0214006	best: 0.0214006 (296)	total: 17.1s	remaining: 6m 9s
# 297:	learn: 0.0214707	test: 0.0213966	best: 0.0213966 (297)	total: 17.2s	remaining: 6m 8s
# 298:	learn: 0.0214670	test: 0.0213929	best: 0.0213929 (298)	total: 17.2s	remaining: 6m 8s
# 299:	learn: 0.0214633	test: 0.0213890	best: 0.0213890 (299)	total: 17.3s	remaining: 6m 8s
# 300:	learn: 0.0214599	test: 0.0213858	best: 0.0213858 (300)	total: 17.3s	remaining: 6m 7s
# 301:	learn: 0.0214565	test: 0.0213822	best: 0.0213822 (301)	total: 17.4s	remaining: 6m 7s
# 302:	learn: 0.0214527	test: 0.0213786	best: 0.0213786 (302)	total: 17.4s	remaining: 6m 7s
# 303:	learn: 0.0214493	test: 0.0213752	best: 0.0213752 (303)	total: 17.4s	remaining: 6m 7s
# 304:	learn: 0.0214457	test: 0.0213714	best: 0.0213714 (304)	total: 17.5s	remaining: 6m 6s
# 305:	learn: 0.0214424	test: 0.0213685	best: 0.0213685 (305)	total: 17.5s	remaining: 6m 6s
# 306:	learn: 0.0214390	test: 0.0213653	best: 0.0213653 (306)	total: 17.6s	remaining: 6m 6s
# 307:	learn: 0.0214356	test: 0.0213619	best: 0.0213619 (307)	total: 17.6s	remaining: 6m 5s
# 308:	learn: 0.0214322	test: 0.0213583	best: 0.0213583 (308)	total: 17.7s	remaining: 6m 5s
# 309:	learn: 0.0214289	test: 0.0213548	best: 0.0213548 (309)	total: 17.7s	remaining: 6m 5s
# 310:	learn: 0.0214259	test: 0.0213522	best: 0.0213522 (310)	total: 17.8s	remaining: 6m 5s
# 311:	learn: 0.0214229	test: 0.0213495	best: 0.0213495 (311)	total: 17.8s	remaining: 6m 5s
# 312:	learn: 0.0214196	test: 0.0213461	best: 0.0213461 (312)	total: 17.9s	remaining: 6m 4s
# 313:	learn: 0.0214164	test: 0.0213428	best: 0.0213428 (313)	total: 17.9s	remaining: 6m 4s
# 314:	learn: 0.0214134	test: 0.0213399	best: 0.0213399 (314)	total: 18s	remaining: 6m 4s
# 315:	learn: 0.0214104	test: 0.0213368	best: 0.0213368 (315)	total: 18s	remaining: 6m 4s
# 316:	learn: 0.0214073	test: 0.0213335	best: 0.0213335 (316)	total: 18.1s	remaining: 6m 4s
# 317:	learn: 0.0214044	test: 0.0213305	best: 0.0213305 (317)	total: 18.1s	remaining: 6m 4s
# 318:	learn: 0.0214014	test: 0.0213273	best: 0.0213273 (318)	total: 18.2s	remaining: 6m 3s
# 319:	learn: 0.0213988	test: 0.0213251	best: 0.0213251 (319)	total: 18.2s	remaining: 6m 3s
# 320:	learn: 0.0213959	test: 0.0213223	best: 0.0213223 (320)	total: 18.3s	remaining: 6m 3s
# 321:	learn: 0.0213921	test: 0.0213184	best: 0.0213184 (321)	total: 18.3s	remaining: 6m 3s
# 322:	learn: 0.0213885	test: 0.0213147	best: 0.0213147 (322)	total: 18.4s	remaining: 6m 2s
# 323:	learn: 0.0213852	test: 0.0213112	best: 0.0213112 (323)	total: 18.4s	remaining: 6m 2s
# 324:	learn: 0.0213822	test: 0.0213080	best: 0.0213080 (324)	total: 18.5s	remaining: 6m 2s
# 325:	learn: 0.0213793	test: 0.0213054	best: 0.0213054 (325)	total: 18.5s	remaining: 6m 2s
# 326:	learn: 0.0213764	test: 0.0213023	best: 0.0213023 (326)	total: 18.6s	remaining: 6m 1s
# 327:	learn: 0.0213736	test: 0.0212998	best: 0.0212998 (327)	total: 18.6s	remaining: 6m 1s
# 328:	learn: 0.0213708	test: 0.0212964	best: 0.0212964 (328)	total: 18.7s	remaining: 6m 1s
# 329:	learn: 0.0213682	test: 0.0212941	best: 0.0212941 (329)	total: 18.7s	remaining: 6m 1s
# 330:	learn: 0.0213655	test: 0.0212913	best: 0.0212913 (330)	total: 18.8s	remaining: 6m 1s
# 331:	learn: 0.0213632	test: 0.0212893	best: 0.0212893 (331)	total: 18.8s	remaining: 6m
# 332:	learn: 0.0213606	test: 0.0212865	best: 0.0212865 (332)	total: 18.9s	remaining: 6m
# 333:	learn: 0.0213578	test: 0.0212836	best: 0.0212836 (333)	total: 18.9s	remaining: 6m
# 334:	learn: 0.0213551	test: 0.0212810	best: 0.0212810 (334)	total: 18.9s	remaining: 6m
# 335:	learn: 0.0213527	test: 0.0212783	best: 0.0212783 (335)	total: 19s	remaining: 5m 59s
# 336:	learn: 0.0213501	test: 0.0212757	best: 0.0212757 (336)	total: 19s	remaining: 5m 59s
# 337:	learn: 0.0213480	test: 0.0212740	best: 0.0212740 (337)	total: 19.1s	remaining: 5m 59s
# 338:	learn: 0.0213455	test: 0.0212714	best: 0.0212714 (338)	total: 19.1s	remaining: 5m 59s
# 339:	learn: 0.0213429	test: 0.0212689	best: 0.0212689 (339)	total: 19.2s	remaining: 5m 59s
# 340:	learn: 0.0213405	test: 0.0212665	best: 0.0212665 (340)	total: 19.2s	remaining: 5m 58s
# 341:	learn: 0.0213380	test: 0.0212638	best: 0.0212638 (341)	total: 19.3s	remaining: 5m 58s
# 342:	learn: 0.0213355	test: 0.0212615	best: 0.0212615 (342)	total: 19.3s	remaining: 5m 58s
# 343:	learn: 0.0213331	test: 0.0212594	best: 0.0212594 (343)	total: 19.4s	remaining: 5m 58s
# 344:	learn: 0.0213307	test: 0.0212570	best: 0.0212570 (344)	total: 19.4s	remaining: 5m 58s
# 345:	learn: 0.0213289	test: 0.0212553	best: 0.0212553 (345)	total: 19.5s	remaining: 5m 57s
# 346:	learn: 0.0213267	test: 0.0212532	best: 0.0212532 (346)	total: 19.5s	remaining: 5m 57s
# 347:	learn: 0.0213245	test: 0.0212511	best: 0.0212511 (347)	total: 19.6s	remaining: 5m 57s
# 348:	learn: 0.0213222	test: 0.0212488	best: 0.0212488 (348)	total: 19.6s	remaining: 5m 57s
# 349:	learn: 0.0213199	test: 0.0212463	best: 0.0212463 (349)	total: 19.7s	remaining: 5m 56s
# 350:	learn: 0.0213180	test: 0.0212447	best: 0.0212447 (350)	total: 19.7s	remaining: 5m 57s
# 351:	learn: 0.0213159	test: 0.0212424	best: 0.0212424 (351)	total: 19.8s	remaining: 5m 56s
# 352:	learn: 0.0213137	test: 0.0212404	best: 0.0212404 (352)	total: 19.8s	remaining: 5m 56s
# 353:	learn: 0.0213114	test: 0.0212379	best: 0.0212379 (353)	total: 19.9s	remaining: 5m 56s
# 354:	learn: 0.0213092	test: 0.0212355	best: 0.0212355 (354)	total: 19.9s	remaining: 5m 56s
# 355:	learn: 0.0213076	test: 0.0212339	best: 0.0212339 (355)	total: 20s	remaining: 5m 55s
# 356:	learn: 0.0213054	test: 0.0212315	best: 0.0212315 (356)	total: 20s	remaining: 5m 55s
# 357:	learn: 0.0213033	test: 0.0212296	best: 0.0212296 (357)	total: 20.1s	remaining: 5m 55s
# 358:	learn: 0.0213012	test: 0.0212275	best: 0.0212275 (358)	total: 20.1s	remaining: 5m 55s
# 359:	learn: 0.0212991	test: 0.0212253	best: 0.0212253 (359)	total: 20.2s	remaining: 5m 55s
# 360:	learn: 0.0212973	test: 0.0212237	best: 0.0212237 (360)	total: 20.2s	remaining: 5m 55s
# 361:	learn: 0.0212953	test: 0.0212216	best: 0.0212216 (361)	total: 20.3s	remaining: 5m 54s
# 362:	learn: 0.0212933	test: 0.0212199	best: 0.0212199 (362)	total: 20.3s	remaining: 5m 54s
# 363:	learn: 0.0212913	test: 0.0212177	best: 0.0212177 (363)	total: 20.4s	remaining: 5m 54s
# 364:	learn: 0.0212899	test: 0.0212163	best: 0.0212163 (364)	total: 20.4s	remaining: 5m 54s
# 365:	learn: 0.0212879	test: 0.0212143	best: 0.0212143 (365)	total: 20.4s	remaining: 5m 54s
# 366:	learn: 0.0212860	test: 0.0212124	best: 0.0212124 (366)	total: 20.5s	remaining: 5m 53s
# 367:	learn: 0.0212841	test: 0.0212107	best: 0.0212107 (367)	total: 20.5s	remaining: 5m 53s
# 368:	learn: 0.0212822	test: 0.0212086	best: 0.0212086 (368)	total: 20.6s	remaining: 5m 53s
# 369:	learn: 0.0212803	test: 0.0212065	best: 0.0212065 (369)	total: 20.6s	remaining: 5m 53s
# 370:	learn: 0.0212785	test: 0.0212046	best: 0.0212046 (370)	total: 20.7s	remaining: 5m 53s
# 371:	learn: 0.0212767	test: 0.0212027	best: 0.0212027 (371)	total: 20.7s	remaining: 5m 52s
# 372:	learn: 0.0212753	test: 0.0212013	best: 0.0212013 (372)	total: 20.8s	remaining: 5m 52s
# 373:	learn: 0.0212734	test: 0.0211997	best: 0.0211997 (373)	total: 20.8s	remaining: 5m 52s
# 374:	learn: 0.0212717	test: 0.0211978	best: 0.0211978 (374)	total: 20.9s	remaining: 5m 52s
# 375:	learn: 0.0212699	test: 0.0211962	best: 0.0211962 (375)	total: 20.9s	remaining: 5m 52s
# 376:	learn: 0.0212682	test: 0.0211944	best: 0.0211944 (376)	total: 21s	remaining: 5m 51s
# 377:	learn: 0.0212670	test: 0.0211931	best: 0.0211931 (377)	total: 21s	remaining: 5m 51s
# 378:	learn: 0.0212652	test: 0.0211916	best: 0.0211916 (378)	total: 21.1s	remaining: 5m 51s
# 379:	learn: 0.0212635	test: 0.0211898	best: 0.0211898 (379)	total: 21.1s	remaining: 5m 51s
# 380:	learn: 0.0212619	test: 0.0211882	best: 0.0211882 (380)	total: 21.2s	remaining: 5m 51s
# 381:	learn: 0.0212602	test: 0.0211868	best: 0.0211868 (381)	total: 21.2s	remaining: 5m 50s
# 382:	learn: 0.0212586	test: 0.0211852	best: 0.0211852 (382)	total: 21.3s	remaining: 5m 50s
# 383:	learn: 0.0212569	test: 0.0211833	best: 0.0211833 (383)	total: 21.3s	remaining: 5m 50s
# 384:	learn: 0.0212552	test: 0.0211815	best: 0.0211815 (384)	total: 21.4s	remaining: 5m 50s
# 385:	learn: 0.0212540	test: 0.0211802	best: 0.0211802 (385)	total: 21.4s	remaining: 5m 50s
# 386:	learn: 0.0212524	test: 0.0211788	best: 0.0211788 (386)	total: 21.5s	remaining: 5m 50s
# 387:	learn: 0.0212508	test: 0.0211771	best: 0.0211771 (387)	total: 21.5s	remaining: 5m 49s
# 388:	learn: 0.0212493	test: 0.0211756	best: 0.0211756 (388)	total: 21.5s	remaining: 5m 49s
# 389:	learn: 0.0212480	test: 0.0211745	best: 0.0211745 (389)	total: 21.6s	remaining: 5m 49s
# 390:	learn: 0.0212465	test: 0.0211727	best: 0.0211727 (390)	total: 21.6s	remaining: 5m 49s
# 391:	learn: 0.0212450	test: 0.0211715	best: 0.0211715 (391)	total: 21.7s	remaining: 5m 49s
# 392:	learn: 0.0212435	test: 0.0211700	best: 0.0211700 (392)	total: 21.7s	remaining: 5m 48s
# 393:	learn: 0.0212419	test: 0.0211682	best: 0.0211682 (393)	total: 21.8s	remaining: 5m 48s
# 394:	learn: 0.0212404	test: 0.0211666	best: 0.0211666 (394)	total: 21.8s	remaining: 5m 48s
# 395:	learn: 0.0212389	test: 0.0211654	best: 0.0211654 (395)	total: 21.9s	remaining: 5m 48s
# 396:	learn: 0.0212375	test: 0.0211639	best: 0.0211639 (396)	total: 21.9s	remaining: 5m 48s
# 397:	learn: 0.0212360	test: 0.0211623	best: 0.0211623 (397)	total: 22s	remaining: 5m 48s
# 398:	learn: 0.0212346	test: 0.0211608	best: 0.0211608 (398)	total: 22s	remaining: 5m 47s
# 399:	learn: 0.0212332	test: 0.0211594	best: 0.0211594 (399)	total: 22.1s	remaining: 5m 47s
# 400:	learn: 0.0212321	test: 0.0211583	best: 0.0211583 (400)	total: 22.1s	remaining: 5m 47s
# 401:	learn: 0.0212307	test: 0.0211571	best: 0.0211571 (401)	total: 22.2s	remaining: 5m 47s
# 402:	learn: 0.0212297	test: 0.0211560	best: 0.0211560 (402)	total: 22.2s	remaining: 5m 47s
# 403:	learn: 0.0212283	test: 0.0211543	best: 0.0211543 (403)	total: 22.3s	remaining: 5m 47s
# 404:	learn: 0.0212270	test: 0.0211528	best: 0.0211528 (404)	total: 22.3s	remaining: 5m 46s
# 405:	learn: 0.0212257	test: 0.0211513	best: 0.0211513 (405)	total: 22.4s	remaining: 5m 46s
# 406:	learn: 0.0212243	test: 0.0211502	best: 0.0211502 (406)	total: 22.4s	remaining: 5m 46s
# 407:	learn: 0.0212231	test: 0.0211490	best: 0.0211490 (407)	total: 22.4s	remaining: 5m 46s
# 408:	learn: 0.0212218	test: 0.0211476	best: 0.0211476 (408)	total: 22.5s	remaining: 5m 46s
# 409:	learn: 0.0212205	test: 0.0211462	best: 0.0211462 (409)	total: 22.5s	remaining: 5m 45s
# 410:	learn: 0.0212191	test: 0.0211449	best: 0.0211449 (410)	total: 22.6s	remaining: 5m 45s
# 411:	learn: 0.0212178	test: 0.0211434	best: 0.0211434 (411)	total: 22.6s	remaining: 5m 45s
# 412:	learn: 0.0212169	test: 0.0211424	best: 0.0211424 (412)	total: 22.7s	remaining: 5m 45s
# 413:	learn: 0.0212158	test: 0.0211410	best: 0.0211410 (413)	total: 22.7s	remaining: 5m 45s
# 414:	learn: 0.0212149	test: 0.0211401	best: 0.0211401 (414)	total: 22.8s	remaining: 5m 45s
# 415:	learn: 0.0212136	test: 0.0211390	best: 0.0211390 (415)	total: 22.8s	remaining: 5m 44s
# 416:	learn: 0.0212124	test: 0.0211378	best: 0.0211378 (416)	total: 22.9s	remaining: 5m 44s
# 417:	learn: 0.0212112	test: 0.0211367	best: 0.0211367 (417)	total: 22.9s	remaining: 5m 44s
# 418:	learn: 0.0212099	test: 0.0211354	best: 0.0211354 (418)	total: 23s	remaining: 5m 44s
# 419:	learn: 0.0212087	test: 0.0211340	best: 0.0211340 (419)	total: 23s	remaining: 5m 44s
# 420:	learn: 0.0212076	test: 0.0211331	best: 0.0211331 (420)	total: 23.1s	remaining: 5m 44s
# 421:	learn: 0.0212067	test: 0.0211322	best: 0.0211322 (421)	total: 23.1s	remaining: 5m 43s
# 422:	learn: 0.0212056	test: 0.0211309	best: 0.0211309 (422)	total: 23.2s	remaining: 5m 43s
# 423:	learn: 0.0212048	test: 0.0211301	best: 0.0211301 (423)	total: 23.2s	remaining: 5m 43s
# 424:	learn: 0.0212036	test: 0.0211288	best: 0.0211288 (424)	total: 23.3s	remaining: 5m 43s
# 425:	learn: 0.0212025	test: 0.0211277	best: 0.0211277 (425)	total: 23.3s	remaining: 5m 43s
# 426:	learn: 0.0212013	test: 0.0211264	best: 0.0211264 (426)	total: 23.3s	remaining: 5m 43s
# 427:	learn: 0.0212002	test: 0.0211254	best: 0.0211254 (427)	total: 23.4s	remaining: 5m 43s
# 428:	learn: 0.0211994	test: 0.0211246	best: 0.0211246 (428)	total: 23.4s	remaining: 5m 42s
# 429:	learn: 0.0211984	test: 0.0211233	best: 0.0211233 (429)	total: 23.5s	remaining: 5m 42s
# 430:	learn: 0.0211973	test: 0.0211224	best: 0.0211224 (430)	total: 23.5s	remaining: 5m 42s
# 431:	learn: 0.0211962	test: 0.0211212	best: 0.0211212 (431)	total: 23.6s	remaining: 5m 42s
# 432:	learn: 0.0211954	test: 0.0211204	best: 0.0211204 (432)	total: 23.6s	remaining: 5m 42s
# 433:	learn: 0.0211944	test: 0.0211194	best: 0.0211194 (433)	total: 23.7s	remaining: 5m 42s
# 434:	learn: 0.0211933	test: 0.0211183	best: 0.0211183 (434)	total: 23.7s	remaining: 5m 41s
# 435:	learn: 0.0211923	test: 0.0211172	best: 0.0211172 (435)	total: 23.8s	remaining: 5m 41s
# 436:	learn: 0.0211912	test: 0.0211160	best: 0.0211160 (436)	total: 23.8s	remaining: 5m 41s
# 437:	learn: 0.0211902	test: 0.0211152	best: 0.0211152 (437)	total: 23.9s	remaining: 5m 41s
# 438:	learn: 0.0211891	test: 0.0211141	best: 0.0211141 (438)	total: 23.9s	remaining: 5m 41s
# 439:	learn: 0.0211881	test: 0.0211132	best: 0.0211132 (439)	total: 24s	remaining: 5m 41s
# 440:	learn: 0.0211872	test: 0.0211124	best: 0.0211124 (440)	total: 24s	remaining: 5m 40s
# 441:	learn: 0.0211862	test: 0.0211113	best: 0.0211113 (441)	total: 24.1s	remaining: 5m 40s
# 442:	learn: 0.0211852	test: 0.0211104	best: 0.0211104 (442)	total: 24.1s	remaining: 5m 40s
# 443:	learn: 0.0211842	test: 0.0211094	best: 0.0211094 (443)	total: 24.2s	remaining: 5m 40s
# 444:	learn: 0.0211832	test: 0.0211085	best: 0.0211085 (444)	total: 24.2s	remaining: 5m 40s
# 445:	learn: 0.0211823	test: 0.0211075	best: 0.0211075 (445)	total: 24.3s	remaining: 5m 40s
# 446:	learn: 0.0211816	test: 0.0211068	best: 0.0211068 (446)	total: 24.3s	remaining: 5m 40s
# 447:	learn: 0.0211807	test: 0.0211057	best: 0.0211057 (447)	total: 24.4s	remaining: 5m 40s
# 448:	learn: 0.0211797	test: 0.0211049	best: 0.0211049 (448)	total: 24.4s	remaining: 5m 39s
# 449:	learn: 0.0211788	test: 0.0211038	best: 0.0211038 (449)	total: 24.5s	remaining: 5m 39s
# 450:	learn: 0.0211779	test: 0.0211028	best: 0.0211028 (450)	total: 24.5s	remaining: 5m 39s
# 451:	learn: 0.0211770	test: 0.0211021	best: 0.0211021 (451)	total: 24.5s	remaining: 5m 39s
# 452:	learn: 0.0211760	test: 0.0211011	best: 0.0211011 (452)	total: 24.6s	remaining: 5m 39s
# 453:	learn: 0.0211751	test: 0.0211002	best: 0.0211002 (453)	total: 24.6s	remaining: 5m 39s
# 454:	learn: 0.0211744	test: 0.0210996	best: 0.0210996 (454)	total: 24.7s	remaining: 5m 39s
# 455:	learn: 0.0211735	test: 0.0210988	best: 0.0210988 (455)	total: 24.7s	remaining: 5m 38s
# 456:	learn: 0.0211726	test: 0.0210978	best: 0.0210978 (456)	total: 24.8s	remaining: 5m 38s
# 457:	learn: 0.0211717	test: 0.0210968	best: 0.0210968 (457)	total: 24.8s	remaining: 5m 38s
# 458:	learn: 0.0211708	test: 0.0210960	best: 0.0210960 (458)	total: 24.9s	remaining: 5m 38s
# 459:	learn: 0.0211700	test: 0.0210952	best: 0.0210952 (459)	total: 24.9s	remaining: 5m 38s
# 460:	learn: 0.0211691	test: 0.0210944	best: 0.0210944 (460)	total: 25s	remaining: 5m 38s
# 461:	learn: 0.0211683	test: 0.0210933	best: 0.0210933 (461)	total: 25s	remaining: 5m 37s
# 462:	learn: 0.0211675	test: 0.0210924	best: 0.0210924 (462)	total: 25.1s	remaining: 5m 37s
# 463:	learn: 0.0211666	test: 0.0210915	best: 0.0210915 (463)	total: 25.1s	remaining: 5m 37s
# 464:	learn: 0.0211658	test: 0.0210907	best: 0.0210907 (464)	total: 25.2s	remaining: 5m 37s
# 465:	learn: 0.0211650	test: 0.0210898	best: 0.0210898 (465)	total: 25.2s	remaining: 5m 37s
# 466:	learn: 0.0211642	test: 0.0210891	best: 0.0210891 (466)	total: 25.3s	remaining: 5m 37s
# 467:	learn: 0.0211633	test: 0.0210883	best: 0.0210883 (467)	total: 25.3s	remaining: 5m 37s
# 468:	learn: 0.0211626	test: 0.0210877	best: 0.0210877 (468)	total: 25.4s	remaining: 5m 37s
# 469:	learn: 0.0211620	test: 0.0210871	best: 0.0210871 (469)	total: 25.4s	remaining: 5m 37s
# 470:	learn: 0.0211612	test: 0.0210864	best: 0.0210864 (470)	total: 25.5s	remaining: 5m 36s
# 471:	learn: 0.0211605	test: 0.0210857	best: 0.0210857 (471)	total: 25.5s	remaining: 5m 36s
# 472:	learn: 0.0211597	test: 0.0210849	best: 0.0210849 (472)	total: 25.6s	remaining: 5m 36s
# 473:	learn: 0.0211589	test: 0.0210840	best: 0.0210840 (473)	total: 25.6s	remaining: 5m 36s
# 474:	learn: 0.0211582	test: 0.0210831	best: 0.0210831 (474)	total: 25.7s	remaining: 5m 36s
# 475:	learn: 0.0211574	test: 0.0210821	best: 0.0210821 (475)	total: 25.7s	remaining: 5m 36s
# 476:	learn: 0.0211567	test: 0.0210813	best: 0.0210813 (476)	total: 25.7s	remaining: 5m 36s
# 477:	learn: 0.0211559	test: 0.0210807	best: 0.0210807 (477)	total: 25.8s	remaining: 5m 35s
# 478:	learn: 0.0211551	test: 0.0210799	best: 0.0210799 (478)	total: 25.8s	remaining: 5m 35s
# 479:	learn: 0.0211542	test: 0.0210790	best: 0.0210790 (479)	total: 25.9s	remaining: 5m 35s
# 480:	learn: 0.0211535	test: 0.0210783	best: 0.0210783 (480)	total: 25.9s	remaining: 5m 35s
# 481:	learn: 0.0211529	test: 0.0210778	best: 0.0210778 (481)	total: 26s	remaining: 5m 35s
# 482:	learn: 0.0211522	test: 0.0210770	best: 0.0210770 (482)	total: 26s	remaining: 5m 35s
# 483:	learn: 0.0211514	test: 0.0210765	best: 0.0210765 (483)	total: 26.1s	remaining: 5m 35s
# 484:	learn: 0.0211507	test: 0.0210758	best: 0.0210758 (484)	total: 26.1s	remaining: 5m 34s
# 485:	learn: 0.0211500	test: 0.0210750	best: 0.0210750 (485)	total: 26.2s	remaining: 5m 34s
# 486:	learn: 0.0211493	test: 0.0210743	best: 0.0210743 (486)	total: 26.2s	remaining: 5m 34s
# 487:	learn: 0.0211487	test: 0.0210738	best: 0.0210738 (487)	total: 26.3s	remaining: 5m 34s
# 488:	learn: 0.0211480	test: 0.0210731	best: 0.0210731 (488)	total: 26.3s	remaining: 5m 34s
# 489:	learn: 0.0211473	test: 0.0210724	best: 0.0210724 (489)	total: 26.4s	remaining: 5m 34s
# 490:	learn: 0.0211466	test: 0.0210717	best: 0.0210717 (490)	total: 26.4s	remaining: 5m 34s
# 491:	learn: 0.0211460	test: 0.0210712	best: 0.0210712 (491)	total: 26.5s	remaining: 5m 34s
# 492:	learn: 0.0211453	test: 0.0210704	best: 0.0210704 (492)	total: 26.5s	remaining: 5m 33s
# 493:	learn: 0.0211448	test: 0.0210699	best: 0.0210699 (493)	total: 26.6s	remaining: 5m 33s
# 494:	learn: 0.0211442	test: 0.0210691	best: 0.0210691 (494)	total: 26.6s	remaining: 5m 33s
# 495:	learn: 0.0211435	test: 0.0210685	best: 0.0210685 (495)	total: 26.7s	remaining: 5m 34s
# 496:	learn: 0.0211429	test: 0.0210679	best: 0.0210679 (496)	total: 26.8s	remaining: 5m 34s
# 497:	learn: 0.0211422	test: 0.0210672	best: 0.0210672 (497)	total: 26.9s	remaining: 5m 34s
# 498:	learn: 0.0211418	test: 0.0210667	best: 0.0210667 (498)	total: 27s	remaining: 5m 35s
# 499:	learn: 0.0211411	test: 0.0210662	best: 0.0210662 (499)	total: 27.1s	remaining: 5m 35s
# 500:	learn: 0.0211405	test: 0.0210655	best: 0.0210655 (500)	total: 27.1s	remaining: 5m 36s
# 501:	learn: 0.0211398	test: 0.0210650	best: 0.0210650 (501)	total: 27.2s	remaining: 5m 36s
# 502:	learn: 0.0211392	test: 0.0210643	best: 0.0210643 (502)	total: 27.3s	remaining: 5m 36s
# 503:	learn: 0.0211386	test: 0.0210638	best: 0.0210638 (503)	total: 27.4s	remaining: 5m 37s
# 504:	learn: 0.0211380	test: 0.0210630	best: 0.0210630 (504)	total: 27.5s	remaining: 5m 37s
# 505:	learn: 0.0211374	test: 0.0210624	best: 0.0210624 (505)	total: 27.6s	remaining: 5m 37s
# 506:	learn: 0.0211368	test: 0.0210618	best: 0.0210618 (506)	total: 27.7s	remaining: 5m 38s
# 507:	learn: 0.0211362	test: 0.0210611	best: 0.0210611 (507)	total: 27.8s	remaining: 5m 38s
# 508:	learn: 0.0211358	test: 0.0210606	best: 0.0210606 (508)	total: 27.9s	remaining: 5m 38s
# 509:	learn: 0.0211352	test: 0.0210601	best: 0.0210601 (509)	total: 27.9s	remaining: 5m 39s
# 510:	learn: 0.0211347	test: 0.0210594	best: 0.0210594 (510)	total: 28s	remaining: 5m 39s
# 511:	learn: 0.0211341	test: 0.0210589	best: 0.0210589 (511)	total: 28.1s	remaining: 5m 39s
# 512:	learn: 0.0211335	test: 0.0210583	best: 0.0210583 (512)	total: 28.2s	remaining: 5m 40s
# 513:	learn: 0.0211330	test: 0.0210577	best: 0.0210577 (513)	total: 28.3s	remaining: 5m 40s
# 514:	learn: 0.0211324	test: 0.0210572	best: 0.0210572 (514)	total: 28.4s	remaining: 5m 40s
# 515:	learn: 0.0211318	test: 0.0210567	best: 0.0210567 (515)	total: 28.4s	remaining: 5m 41s
# 516:	learn: 0.0211312	test: 0.0210562	best: 0.0210562 (516)	total: 28.6s	remaining: 5m 41s
# 517:	learn: 0.0211307	test: 0.0210555	best: 0.0210555 (517)	total: 28.6s	remaining: 5m 41s
# 518:	learn: 0.0211301	test: 0.0210551	best: 0.0210551 (518)	total: 28.7s	remaining: 5m 42s
# 519:	learn: 0.0211296	test: 0.0210546	best: 0.0210546 (519)	total: 28.8s	remaining: 5m 42s
# 520:	learn: 0.0211291	test: 0.0210540	best: 0.0210540 (520)	total: 28.9s	remaining: 5m 42s
# 521:	learn: 0.0211287	test: 0.0210535	best: 0.0210535 (521)	total: 29s	remaining: 5m 43s
# 522:	learn: 0.0211281	test: 0.0210529	best: 0.0210529 (522)	total: 29.1s	remaining: 5m 43s
# 523:	learn: 0.0211276	test: 0.0210523	best: 0.0210523 (523)	total: 29.2s	remaining: 5m 43s
# 524:	learn: 0.0211271	test: 0.0210518	best: 0.0210518 (524)	total: 29.2s	remaining: 5m 44s
# 525:	learn: 0.0211266	test: 0.0210513	best: 0.0210513 (525)	total: 29.3s	remaining: 5m 44s
# 526:	learn: 0.0211261	test: 0.0210509	best: 0.0210509 (526)	total: 29.4s	remaining: 5m 44s
# ...
# 4383:	learn: 0.0209868	test: 0.0209135	best: 0.0209135 (4376)	total: 3m 56s	remaining: 2m 5s
# 4384:	learn: 0.0209868	test: 0.0209135	best: 0.0209135 (4384)	total: 3m 56s	remaining: 2m 4s
# 4385:	learn: 0.0209868	test: 0.0209135	best: 0.0209135 (4385)	total: 3m 56s	remaining: 2m 4s
# 4386:	learn: 0.0209868	test: 0.0209135	best: 0.0209135 (4386)	total: 3m 56s	remaining: 2m 4s
# 4387:	learn: 0.0209868	test: 0.0209135	best: 0.0209135 (4387)	total: 3m 56s	remaining: 2m 4s
# 4388:	learn: 0.0209868	test: 0.0209135	best: 0.0209135 (4387)	total: 3m 56s	remaining: 2m 4s
# 4389:	learn: 0.0209868	test: 0.0209134	best: 0.0209134 (4389)	total: 3m 56s	remaining: 2m 4s
# 4390:	learn: 0.0209868	test: 0.0209134	best: 0.0209134 (4390)	total: 3m 56s	remaining: 2m 4s
# 4391:	learn: 0.0209868	test: 0.0209134	best: 0.0209134 (4391)	total: 3m 57s	remaining: 2m 4s
# 4392:	learn: 0.0209868	test: 0.0209135	best: 0.0209134 (4391)	total: 3m 57s	remaining: 2m 4s
# 4393:	learn: 0.0209868	test: 0.0209135	best: 0.0209134 (4391)	total: 3m 57s	remaining: 2m 4s
# 4394:	learn: 0.0209867	test: 0.0209135	best: 0.0209134 (4391)	total: 3m 57s	remaining: 2m 4s
# 4395:	learn: 0.0209867	test: 0.0209135	best: 0.0209134 (4391)	total: 3m 57s	remaining: 2m 4s
# 4396:	learn: 0.0209867	test: 0.0209135	best: 0.0209134 (4391)	total: 3m 57s	remaining: 2m 4s
# 4397:	learn: 0.0209867	test: 0.0209135	best: 0.0209134 (4391)	total: 3m 57s	remaining: 2m 4s
# 4398:	learn: 0.0209867	test: 0.0209135	best: 0.0209134 (4391)	total: 3m 57s	remaining: 2m 4s
# 4399:	learn: 0.0209867	test: 0.0209135	best: 0.0209134 (4391)	total: 3m 57s	remaining: 2m 4s
# 4400:	learn: 0.0209867	test: 0.0209135	best: 0.0209134 (4391)	total: 3m 57s	remaining: 2m 4s
# 4401:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4401)	total: 3m 57s	remaining: 2m 4s
# 4402:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4401)	total: 3m 57s	remaining: 2m 4s
# 4403:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4403)	total: 3m 58s	remaining: 2m 4s
# 4404:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4404)	total: 3m 58s	remaining: 2m 4s
# 4405:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4405)	total: 3m 58s	remaining: 2m 4s
# 4406:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4405)	total: 3m 58s	remaining: 2m 4s
# 4407:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4405)	total: 3m 58s	remaining: 2m 4s
# 4408:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4405)	total: 3m 58s	remaining: 2m 4s
# 4409:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4405)	total: 3m 58s	remaining: 2m 4s
# 4410:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4405)	total: 3m 58s	remaining: 2m 4s
# 4411:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4405)	total: 3m 58s	remaining: 2m 3s
# 4412:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4412)	total: 3m 58s	remaining: 2m 3s
# 4413:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4413)	total: 3m 58s	remaining: 2m 3s
# 4414:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4414)	total: 3m 59s	remaining: 2m 3s
# 4415:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4414)	total: 3m 59s	remaining: 2m 3s
# 4416:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4414)	total: 3m 59s	remaining: 2m 3s
# 4417:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4414)	total: 3m 59s	remaining: 2m 3s
# 4418:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4414)	total: 3m 59s	remaining: 2m 3s
# 4419:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4419)	total: 3m 59s	remaining: 2m 3s
# 4420:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4420)	total: 3m 59s	remaining: 2m 3s
# 4421:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4421)	total: 3m 59s	remaining: 2m 3s
# 4422:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4422)	total: 3m 59s	remaining: 2m 3s
# 4423:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4423)	total: 3m 59s	remaining: 2m 3s
# 4424:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4423)	total: 3m 59s	remaining: 2m 3s
# 4425:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4425)	total: 3m 59s	remaining: 2m 3s
# 4426:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4425)	total: 3m 59s	remaining: 2m 3s
# 4427:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4425)	total: 3m 59s	remaining: 2m 3s
# 4428:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4425)	total: 3m 59s	remaining: 2m 3s
# 4429:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4429)	total: 3m 59s	remaining: 2m 3s
# 4430:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4430)	total: 3m 59s	remaining: 2m 3s
# 4431:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4430)	total: 3m 59s	remaining: 2m 2s
# 4432:	learn: 0.0209867	test: 0.0209134	best: 0.0209134 (4430)	total: 4m	remaining: 2m 2s
# 4433:	learn: 0.0209866	test: 0.0209134	best: 0.0209134 (4433)	total: 4m	remaining: 2m 2s
# 4434:	learn: 0.0209866	test: 0.0209134	best: 0.0209134 (4434)	total: 4m	remaining: 2m 2s
# 4435:	learn: 0.0209866	test: 0.0209134	best: 0.0209134 (4434)	total: 4m	remaining: 2m 2s
# 4436:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4436)	total: 4m	remaining: 2m 2s
# 4437:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4437)	total: 4m	remaining: 2m 2s
# 4438:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4438)	total: 4m	remaining: 2m 2s
# 4439:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4439)	total: 4m	remaining: 2m 2s
# 4440:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4440)	total: 4m	remaining: 2m 2s
# 4441:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4440)	total: 4m	remaining: 2m 2s
# 4442:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4440)	total: 4m	remaining: 2m 2s
# 4443:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4440)	total: 4m	remaining: 2m 2s
# 4444:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4440)	total: 4m	remaining: 2m 2s
# 4445:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4445)	total: 4m	remaining: 2m 2s
# 4446:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4445)	total: 4m	remaining: 2m 2s
# 4447:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4447)	total: 4m	remaining: 2m 2s
# 4448:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4448)	total: 4m	remaining: 2m 1s
# 4449:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4448)	total: 4m	remaining: 2m 1s
# 4450:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4448)	total: 4m	remaining: 2m 1s
# 4451:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4448)	total: 4m	remaining: 2m 1s
# 4452:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4448)	total: 4m 1s	remaining: 2m 1s
# 4453:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4448)	total: 4m 1s	remaining: 2m 1s
# 4454:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4454)	total: 4m 1s	remaining: 2m 1s
# 4455:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4455)	total: 4m 1s	remaining: 2m 1s
# 4456:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4456)	total: 4m 1s	remaining: 2m 1s
# 4457:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4457)	total: 4m 1s	remaining: 2m 1s
# 4458:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4457)	total: 4m 1s	remaining: 2m 1s
# 4459:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4457)	total: 4m 1s	remaining: 2m 1s
# 4460:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4460)	total: 4m 1s	remaining: 2m 1s
# 4461:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4460)	total: 4m 1s	remaining: 2m 1s
# 4462:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4460)	total: 4m 1s	remaining: 2m 1s
# 4463:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4460)	total: 4m 1s	remaining: 2m 1s
# 4464:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4460)	total: 4m 1s	remaining: 2m 1s
# 4465:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4460)	total: 4m 1s	remaining: 2m 1s
# 4466:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4466)	total: 4m 1s	remaining: 2m
# 4467:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4467)	total: 4m 1s	remaining: 2m
# 4468:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4467)	total: 4m 1s	remaining: 2m
# 4469:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4467)	total: 4m 1s	remaining: 2m
# 4470:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4467)	total: 4m 1s	remaining: 2m
# 4471:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4467)	total: 4m 1s	remaining: 2m
# 4472:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4467)	total: 4m 2s	remaining: 2m
# 4473:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4467)	total: 4m 2s	remaining: 2m
# 4474:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4474)	total: 4m 2s	remaining: 2m
# 4475:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4475)	total: 4m 2s	remaining: 2m
# 4476:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4476)	total: 4m 2s	remaining: 2m
# 4477:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4476)	total: 4m 2s	remaining: 2m
# 4478:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4478)	total: 4m 2s	remaining: 2m
# 4479:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4479)	total: 4m 2s	remaining: 2m
# 4480:	learn: 0.0209866	test: 0.0209133	best: 0.0209133 (4479)	total: 4m 2s	remaining: 2m
# 4481:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4479)	total: 4m 2s	remaining: 2m
# 4482:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4479)	total: 4m 2s	remaining: 2m
# 4483:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4479)	total: 4m 2s	remaining: 2m
# 4484:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4484)	total: 4m 2s	remaining: 1m 59s
# 4485:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4485)	total: 4m 2s	remaining: 1m 59s
# 4486:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4485)	total: 4m 2s	remaining: 1m 59s
# 4487:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4485)	total: 4m 2s	remaining: 1m 59s
# 4488:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4485)	total: 4m 2s	remaining: 1m 59s
# 4489:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4485)	total: 4m 2s	remaining: 1m 59s
# 4490:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4490)	total: 4m 2s	remaining: 1m 59s
# 4491:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4491)	total: 4m 2s	remaining: 1m 59s
# 4492:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4492)	total: 4m 2s	remaining: 1m 59s
# 4493:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4493)	total: 4m 3s	remaining: 1m 59s
# 4494:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4494)	total: 4m 3s	remaining: 1m 59s
# 4495:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4494)	total: 4m 3s	remaining: 1m 59s
# 4496:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4496)	total: 4m 3s	remaining: 1m 59s
# 4497:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4497)	total: 4m 3s	remaining: 1m 59s
# 4498:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4498)	total: 4m 3s	remaining: 1m 59s
# 4499:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4498)	total: 4m 3s	remaining: 1m 59s
# 4500:	learn: 0.0209865	test: 0.0209133	best: 0.0209133 (4498)	total: 4m 3s	remaining: 1m 59s
# 4501:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4501)	total: 4m 3s	remaining: 1m 59s
# 4502:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4502)	total: 4m 3s	remaining: 1m 58s
# 4503:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4503)	total: 4m 3s	remaining: 1m 58s
# 4504:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4504)	total: 4m 3s	remaining: 1m 58s
# 4505:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4504)	total: 4m 3s	remaining: 1m 58s
# 4506:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4506)	total: 4m 3s	remaining: 1m 58s
# 4507:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4507)	total: 4m 3s	remaining: 1m 58s
# 4508:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4508)	total: 4m 3s	remaining: 1m 58s
# 4509:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4509)	total: 4m 3s	remaining: 1m 58s
# 4510:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4510)	total: 4m 3s	remaining: 1m 58s
# 4511:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4511)	total: 4m 3s	remaining: 1m 58s
# 4512:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4511)	total: 4m 3s	remaining: 1m 58s
# 4513:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4511)	total: 4m 4s	remaining: 1m 58s
# 4514:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4511)	total: 4m 4s	remaining: 1m 58s
# 4515:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4511)	total: 4m 4s	remaining: 1m 58s
# 4516:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4511)	total: 4m 4s	remaining: 1m 58s
# 4517:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4511)	total: 4m 4s	remaining: 1m 58s
# 4518:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4511)	total: 4m 4s	remaining: 1m 58s
# 4519:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4511)	total: 4m 4s	remaining: 1m 57s
# 4520:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4511)	total: 4m 4s	remaining: 1m 57s
# 4521:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4511)	total: 4m 4s	remaining: 1m 57s
# 4522:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4511)	total: 4m 4s	remaining: 1m 57s
# 4523:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4523)	total: 4m 4s	remaining: 1m 57s
# 4524:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4523)	total: 4m 4s	remaining: 1m 57s
# 4525:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4525)	total: 4m 4s	remaining: 1m 57s
# 4526:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 4s	remaining: 1m 57s
# 4527:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 4s	remaining: 1m 57s
# 4528:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 4s	remaining: 1m 57s
# 4529:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 4s	remaining: 1m 57s
# 4530:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 4s	remaining: 1m 57s
# 4531:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 4s	remaining: 1m 57s
# 4532:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 4s	remaining: 1m 57s
# 4533:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 4s	remaining: 1m 57s
# 4534:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 57s
# 4535:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 57s
# 4536:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 57s
# 4537:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 56s
# 4538:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 56s
# 4539:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 56s
# 4540:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 56s
# 4541:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 56s
# 4542:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 56s
# 4543:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 56s
# 4544:	learn: 0.0209865	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 56s
# 4545:	learn: 0.0209864	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 56s
# 4546:	learn: 0.0209864	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 56s
# 4547:	learn: 0.0209864	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 56s
# 4548:	learn: 0.0209864	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 56s
# 4549:	learn: 0.0209864	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 56s
# 4550:	learn: 0.0209864	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 56s
# 4551:	learn: 0.0209864	test: 0.0209132	best: 0.0209132 (4526)	total: 4m 5s	remaining: 1m 56s
# Stopped by overfitting detector  (25 iterations wait)
#
# bestTest = 0.02091320091
# bestIteration = 4526
#
# Shrink model to first 4527 iterations.
# [I 2023-05-06 12:57:41,448] Trial 0 finished with value: 0.00043736197045199236 and parameters: {'learning_rate': 0.034885205571560766, 'depth': 1, 'iteration': 6703, 'l2_leaf_reg': 23}. Best is trial 0 with value: 0.00043736197045199236.

# %% [markdown]
# - 'learning_rate': 0.08078050781072783, 'depth': 14, 'iteration': 3688, 'l2_leaf_reg': 11
#
# - 'learning_rate': 0.005332517900175726, 'depth': 2, 'iteration': 3118, 'l2_leaf_reg': 24
#
# - 'learning_rate': 0.08140568960274255, 'depth': 1, 'iteration': 6703, 'l2_leaf_reg': 23
#
# - 'learning_rate': 0.034885205571560766, 'depth': 1, 'iteration': 6703, 'l2_leaf_reg': 23

# %%
model = CatBoostRegressor(learning_rate=0.034885205571560766, depth=1, iterations=6703, l2_leaf_reg=23)

model.fit(x, y)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 1703:	learn: 0.0209157	total: 1m 12s	remaining: 3m 32s
# 1704:	learn: 0.0209157	total: 1m 12s	remaining: 3m 32s
# 1705:	learn: 0.0209156	total: 1m 12s	remaining: 3m 32s
# 1706:	learn: 0.0209156	total: 1m 12s	remaining: 3m 32s
# 1707:	learn: 0.0209156	total: 1m 12s	remaining: 3m 32s
# 1708:	learn: 0.0209155	total: 1m 12s	remaining: 3m 32s
# 1709:	learn: 0.0209154	total: 1m 12s	remaining: 3m 32s
# 1710:	learn: 0.0209154	total: 1m 12s	remaining: 3m 32s
# 1711:	learn: 0.0209154	total: 1m 12s	remaining: 3m 32s
# 1712:	learn: 0.0209153	total: 1m 12s	remaining: 3m 32s
# 1713:	learn: 0.0209153	total: 1m 12s	remaining: 3m 32s
# 1714:	learn: 0.0209152	total: 1m 12s	remaining: 3m 32s
# 1715:	learn: 0.0209152	total: 1m 12s	remaining: 3m 32s
# 1716:	learn: 0.0209151	total: 1m 13s	remaining: 3m 32s
# 1717:	learn: 0.0209151	total: 1m 13s	remaining: 3m 31s
# 1718:	learn: 0.0209150	total: 1m 13s	remaining: 3m 31s
# 1719:	learn: 0.0209150	total: 1m 13s	remaining: 3m 31s
# 1720:	learn: 0.0209149	total: 1m 13s	remaining: 3m 31s
# 1721:	learn: 0.0209149	total: 1m 13s	remaining: 3m 31s
# 1722:	learn: 0.0209148	total: 1m 13s	remaining: 3m 31s
# 1723:	learn: 0.0209148	total: 1m 13s	remaining: 3m 31s
# 1724:	learn: 0.0209147	total: 1m 13s	remaining: 3m 31s
# 1725:	learn: 0.0209147	total: 1m 13s	remaining: 3m 31s
# 1726:	learn: 0.0209146	total: 1m 13s	remaining: 3m 31s
# 1727:	learn: 0.0209146	total: 1m 13s	remaining: 3m 31s
# 1728:	learn: 0.0209145	total: 1m 13s	remaining: 3m 31s
# 1729:	learn: 0.0209145	total: 1m 13s	remaining: 3m 31s
# 1730:	learn: 0.0209144	total: 1m 13s	remaining: 3m 31s
# 1731:	learn: 0.0209144	total: 1m 13s	remaining: 3m 31s
# 1732:	learn: 0.0209143	total: 1m 13s	remaining: 3m 31s
# 1733:	learn: 0.0209143	total: 1m 13s	remaining: 3m 31s
# 1734:	learn: 0.0209142	total: 1m 13s	remaining: 3m 31s
# 1735:	learn: 0.0209142	total: 1m 13s	remaining: 3m 30s
# 1736:	learn: 0.0209141	total: 1m 13s	remaining: 3m 30s
# 1737:	learn: 0.0209141	total: 1m 13s	remaining: 3m 30s
# 1738:	learn: 0.0209140	total: 1m 13s	remaining: 3m 30s
# 1739:	learn: 0.0209140	total: 1m 13s	remaining: 3m 30s
# 1740:	learn: 0.0209139	total: 1m 13s	remaining: 3m 30s
# 1741:	learn: 0.0209139	total: 1m 13s	remaining: 3m 30s
# 1742:	learn: 0.0209139	total: 1m 13s	remaining: 3m 30s
# 1743:	learn: 0.0209138	total: 1m 14s	remaining: 3m 30s
# 1744:	learn: 0.0209138	total: 1m 14s	remaining: 3m 30s
# 1745:	learn: 0.0209137	total: 1m 14s	remaining: 3m 30s
# 1746:	learn: 0.0209137	total: 1m 14s	remaining: 3m 30s
# 1747:	learn: 0.0209136	total: 1m 14s	remaining: 3m 30s
# 1748:	learn: 0.0209136	total: 1m 14s	remaining: 3m 30s
# 1749:	learn: 0.0209135	total: 1m 14s	remaining: 3m 30s
# 1750:	learn: 0.0209135	total: 1m 14s	remaining: 3m 30s
# 1751:	learn: 0.0209134	total: 1m 14s	remaining: 3m 30s
# 1752:	learn: 0.0209134	total: 1m 14s	remaining: 3m 29s
# 1753:	learn: 0.0209133	total: 1m 14s	remaining: 3m 29s
# 1754:	learn: 0.0209133	total: 1m 14s	remaining: 3m 29s
# 1755:	learn: 0.0209133	total: 1m 14s	remaining: 3m 29s
# 1756:	learn: 0.0209132	total: 1m 14s	remaining: 3m 29s
# 1757:	learn: 0.0209132	total: 1m 14s	remaining: 3m 29s
# 1758:	learn: 0.0209131	total: 1m 14s	remaining: 3m 29s
# 1759:	learn: 0.0209131	total: 1m 14s	remaining: 3m 29s
# 1760:	learn: 0.0209130	total: 1m 14s	remaining: 3m 29s
# 1761:	learn: 0.0209130	total: 1m 14s	remaining: 3m 29s
# 1762:	learn: 0.0209129	total: 1m 14s	remaining: 3m 29s
# 1763:	learn: 0.0209129	total: 1m 14s	remaining: 3m 29s
# 1764:	learn: 0.0209128	total: 1m 14s	remaining: 3m 29s
# 1765:	learn: 0.0209128	total: 1m 14s	remaining: 3m 29s
# 1766:	learn: 0.0209127	total: 1m 14s	remaining: 3m 29s
# 1767:	learn: 0.0209127	total: 1m 14s	remaining: 3m 29s
# 1768:	learn: 0.0209126	total: 1m 14s	remaining: 3m 29s
# 1769:	learn: 0.0209126	total: 1m 15s	remaining: 3m 29s
# 1770:	learn: 0.0209126	total: 1m 15s	remaining: 3m 28s
# 1771:	learn: 0.0209125	total: 1m 15s	remaining: 3m 28s
# 1772:	learn: 0.0209125	total: 1m 15s	remaining: 3m 28s
# 1773:	learn: 0.0209124	total: 1m 15s	remaining: 3m 28s
# 1774:	learn: 0.0209124	total: 1m 15s	remaining: 3m 28s
# 1775:	learn: 0.0209123	total: 1m 15s	remaining: 3m 28s
# 1776:	learn: 0.0209123	total: 1m 15s	remaining: 3m 28s
# 1777:	learn: 0.0209122	total: 1m 15s	remaining: 3m 28s
# 1778:	learn: 0.0209122	total: 1m 15s	remaining: 3m 28s
# 1779:	learn: 0.0209121	total: 1m 15s	remaining: 3m 28s
# 1780:	learn: 0.0209121	total: 1m 15s	remaining: 3m 28s
# 1781:	learn: 0.0209120	total: 1m 15s	remaining: 3m 28s
# 1782:	learn: 0.0209120	total: 1m 15s	remaining: 3m 28s
# 1783:	learn: 0.0209120	total: 1m 15s	remaining: 3m 28s
# 1784:	learn: 0.0209119	total: 1m 15s	remaining: 3m 28s
# 1785:	learn: 0.0209119	total: 1m 15s	remaining: 3m 28s
# 1786:	learn: 0.0209118	total: 1m 15s	remaining: 3m 28s
# 1787:	learn: 0.0209118	total: 1m 15s	remaining: 3m 27s
# 1788:	learn: 0.0209117	total: 1m 15s	remaining: 3m 27s
# 1789:	learn: 0.0209117	total: 1m 15s	remaining: 3m 27s
# 1790:	learn: 0.0209116	total: 1m 15s	remaining: 3m 27s
# 1791:	learn: 0.0209116	total: 1m 15s	remaining: 3m 27s
# 1792:	learn: 0.0209116	total: 1m 15s	remaining: 3m 27s
# 1793:	learn: 0.0209115	total: 1m 15s	remaining: 3m 27s
# 1794:	learn: 0.0209115	total: 1m 15s	remaining: 3m 27s
# 1795:	learn: 0.0209114	total: 1m 15s	remaining: 3m 27s
# 1796:	learn: 0.0209114	total: 1m 15s	remaining: 3m 27s
# 1797:	learn: 0.0209113	total: 1m 16s	remaining: 3m 27s
# 1798:	learn: 0.0209113	total: 1m 16s	remaining: 3m 27s
# 1799:	learn: 0.0209112	total: 1m 16s	remaining: 3m 27s
# 1800:	learn: 0.0209112	total: 1m 16s	remaining: 3m 27s
# 1801:	learn: 0.0209112	total: 1m 16s	remaining: 3m 27s
# 1802:	learn: 0.0209111	total: 1m 16s	remaining: 3m 27s
# 1803:	learn: 0.0209111	total: 1m 16s	remaining: 3m 27s
# 1804:	learn: 0.0209110	total: 1m 16s	remaining: 3m 27s
# 1805:	learn: 0.0209110	total: 1m 16s	remaining: 3m 26s
# 1806:	learn: 0.0209109	total: 1m 16s	remaining: 3m 26s
# 1807:	learn: 0.0209109	total: 1m 16s	remaining: 3m 26s
# 1808:	learn: 0.0209108	total: 1m 16s	remaining: 3m 26s
# 1809:	learn: 0.0209108	total: 1m 16s	remaining: 3m 26s
# 1810:	learn: 0.0209108	total: 1m 16s	remaining: 3m 26s
# 1811:	learn: 0.0209107	total: 1m 16s	remaining: 3m 26s
# 1812:	learn: 0.0209107	total: 1m 16s	remaining: 3m 26s
# 1813:	learn: 0.0209106	total: 1m 16s	remaining: 3m 26s
# 1814:	learn: 0.0209106	total: 1m 16s	remaining: 3m 26s
# 1815:	learn: 0.0209105	total: 1m 16s	remaining: 3m 26s
# 1816:	learn: 0.0209105	total: 1m 16s	remaining: 3m 26s
# 1817:	learn: 0.0209104	total: 1m 16s	remaining: 3m 26s
# 1818:	learn: 0.0209104	total: 1m 16s	remaining: 3m 26s
# 1819:	learn: 0.0209104	total: 1m 16s	remaining: 3m 26s
# 1820:	learn: 0.0209103	total: 1m 16s	remaining: 3m 26s
# 1821:	learn: 0.0209103	total: 1m 16s	remaining: 3m 26s
# 1822:	learn: 0.0209102	total: 1m 16s	remaining: 3m 26s
# 1823:	learn: 0.0209102	total: 1m 17s	remaining: 3m 26s
# 1824:	learn: 0.0209101	total: 1m 17s	remaining: 3m 25s
# 1825:	learn: 0.0209101	total: 1m 17s	remaining: 3m 25s
# 1826:	learn: 0.0209101	total: 1m 17s	remaining: 3m 25s
# 1827:	learn: 0.0209100	total: 1m 17s	remaining: 3m 25s
# 1828:	learn: 0.0209100	total: 1m 17s	remaining: 3m 25s
# 1829:	learn: 0.0209099	total: 1m 17s	remaining: 3m 25s
# 1830:	learn: 0.0209099	total: 1m 17s	remaining: 3m 25s
# 1831:	learn: 0.0209099	total: 1m 17s	remaining: 3m 25s
# 1832:	learn: 0.0209098	total: 1m 17s	remaining: 3m 25s
# 1833:	learn: 0.0209098	total: 1m 17s	remaining: 3m 25s
# 1834:	learn: 0.0209097	total: 1m 17s	remaining: 3m 25s
# 1835:	learn: 0.0209097	total: 1m 17s	remaining: 3m 25s
# 1836:	learn: 0.0209096	total: 1m 17s	remaining: 3m 25s
# 1837:	learn: 0.0209096	total: 1m 17s	remaining: 3m 25s
# 1838:	learn: 0.0209096	total: 1m 17s	remaining: 3m 25s
# 1839:	learn: 0.0209095	total: 1m 17s	remaining: 3m 25s
# 1840:	learn: 0.0209095	total: 1m 17s	remaining: 3m 25s
# 1841:	learn: 0.0209094	total: 1m 17s	remaining: 3m 24s
# 1842:	learn: 0.0209094	total: 1m 17s	remaining: 3m 24s
# 1843:	learn: 0.0209093	total: 1m 17s	remaining: 3m 24s
# 1844:	learn: 0.0209093	total: 1m 17s	remaining: 3m 24s
# 1845:	learn: 0.0209093	total: 1m 17s	remaining: 3m 24s
# 1846:	learn: 0.0209092	total: 1m 17s	remaining: 3m 24s
# 1847:	learn: 0.0209092	total: 1m 17s	remaining: 3m 24s
# 1848:	learn: 0.0209091	total: 1m 17s	remaining: 3m 24s
# 1849:	learn: 0.0209091	total: 1m 17s	remaining: 3m 24s
# 1850:	learn: 0.0209091	total: 1m 18s	remaining: 3m 24s
# 1851:	learn: 0.0209090	total: 1m 18s	remaining: 3m 24s
# 1852:	learn: 0.0209090	total: 1m 18s	remaining: 3m 24s
# 1853:	learn: 0.0209089	total: 1m 18s	remaining: 3m 24s
# 1854:	learn: 0.0209089	total: 1m 18s	remaining: 3m 24s
# 1855:	learn: 0.0209088	total: 1m 18s	remaining: 3m 24s
# 1856:	learn: 0.0209088	total: 1m 18s	remaining: 3m 24s
# 1857:	learn: 0.0209088	total: 1m 18s	remaining: 3m 24s
# 1858:	learn: 0.0209087	total: 1m 18s	remaining: 3m 24s
# 1859:	learn: 0.0209087	total: 1m 18s	remaining: 3m 24s
# 1860:	learn: 0.0209086	total: 1m 18s	remaining: 3m 24s
# 1861:	learn: 0.0209086	total: 1m 18s	remaining: 3m 24s
# 1862:	learn: 0.0209085	total: 1m 18s	remaining: 3m 24s
# 1863:	learn: 0.0209085	total: 1m 18s	remaining: 3m 24s
# 1864:	learn: 0.0209085	total: 1m 19s	remaining: 3m 24s
# 1865:	learn: 0.0209084	total: 1m 19s	remaining: 3m 25s
# 1866:	learn: 0.0209084	total: 1m 19s	remaining: 3m 25s
# 1867:	learn: 0.0209083	total: 1m 19s	remaining: 3m 25s
# 1868:	learn: 0.0209083	total: 1m 19s	remaining: 3m 25s
# 1869:	learn: 0.0209083	total: 1m 19s	remaining: 3m 25s
# 1870:	learn: 0.0209082	total: 1m 19s	remaining: 3m 25s
# 1871:	learn: 0.0209082	total: 1m 19s	remaining: 3m 25s
# 1872:	learn: 0.0209081	total: 1m 19s	remaining: 3m 25s
# 1873:	learn: 0.0209081	total: 1m 19s	remaining: 3m 25s
# 1874:	learn: 0.0209081	total: 1m 19s	remaining: 3m 25s
# 1875:	learn: 0.0209080	total: 1m 19s	remaining: 3m 25s
# 1876:	learn: 0.0209080	total: 1m 19s	remaining: 3m 25s
# 1877:	learn: 0.0209079	total: 1m 19s	remaining: 3m 25s
# 1878:	learn: 0.0209079	total: 1m 19s	remaining: 3m 25s
# 1879:	learn: 0.0209078	total: 1m 19s	remaining: 3m 25s
# 1880:	learn: 0.0209078	total: 1m 20s	remaining: 3m 25s
# 1881:	learn: 0.0209078	total: 1m 20s	remaining: 3m 25s
# 1882:	learn: 0.0209077	total: 1m 20s	remaining: 3m 25s
# 1883:	learn: 0.0209077	total: 1m 20s	remaining: 3m 25s
# 1884:	learn: 0.0209076	total: 1m 20s	remaining: 3m 25s
# 1885:	learn: 0.0209076	total: 1m 20s	remaining: 3m 25s
# 1886:	learn: 0.0209076	total: 1m 20s	remaining: 3m 25s
# 1887:	learn: 0.0209075	total: 1m 20s	remaining: 3m 25s
# 1888:	learn: 0.0209075	total: 1m 20s	remaining: 3m 25s
# 1889:	learn: 0.0209074	total: 1m 20s	remaining: 3m 25s
# 1890:	learn: 0.0209074	total: 1m 20s	remaining: 3m 25s
# 1891:	learn: 0.0209074	total: 1m 20s	remaining: 3m 25s
# 1892:	learn: 0.0209073	total: 1m 20s	remaining: 3m 25s
# 1893:	learn: 0.0209073	total: 1m 20s	remaining: 3m 25s
# 1894:	learn: 0.0209072	total: 1m 21s	remaining: 3m 25s
# 1895:	learn: 0.0209072	total: 1m 21s	remaining: 3m 25s
# 1896:	learn: 0.0209072	total: 1m 21s	remaining: 3m 25s
# 1897:	learn: 0.0209071	total: 1m 21s	remaining: 3m 25s
# 1898:	learn: 0.0209071	total: 1m 21s	remaining: 3m 25s
# 1899:	learn: 0.0209070	total: 1m 21s	remaining: 3m 25s
# 1900:	learn: 0.0209070	total: 1m 21s	remaining: 3m 25s
# 1901:	learn: 0.0209070	total: 1m 21s	remaining: 3m 25s
# 1902:	learn: 0.0209069	total: 1m 21s	remaining: 3m 25s
# 1903:	learn: 0.0209069	total: 1m 21s	remaining: 3m 25s
# 1904:	learn: 0.0209068	total: 1m 21s	remaining: 3m 25s
# 1905:	learn: 0.0209068	total: 1m 21s	remaining: 3m 24s
# 1906:	learn: 0.0209068	total: 1m 21s	remaining: 3m 24s
# 1907:	learn: 0.0209067	total: 1m 21s	remaining: 3m 24s
# 1908:	learn: 0.0209067	total: 1m 21s	remaining: 3m 24s
# 1909:	learn: 0.0209066	total: 1m 21s	remaining: 3m 24s
# 1910:	learn: 0.0209066	total: 1m 21s	remaining: 3m 24s
# 1911:	learn: 0.0209066	total: 1m 21s	remaining: 3m 24s
# 1912:	learn: 0.0209065	total: 1m 21s	remaining: 3m 24s
# 1913:	learn: 0.0209065	total: 1m 21s	remaining: 3m 24s
# 1914:	learn: 0.0209064	total: 1m 21s	remaining: 3m 24s
# 1915:	learn: 0.0209064	total: 1m 21s	remaining: 3m 24s
# 1916:	learn: 0.0209064	total: 1m 21s	remaining: 3m 24s
# 1917:	learn: 0.0209063	total: 1m 21s	remaining: 3m 24s
# 1918:	learn: 0.0209063	total: 1m 21s	remaining: 3m 24s
# 1919:	learn: 0.0209062	total: 1m 21s	remaining: 3m 24s
# 1920:	learn: 0.0209062	total: 1m 21s	remaining: 3m 24s
# 1921:	learn: 0.0209062	total: 1m 22s	remaining: 3m 24s
# 1922:	learn: 0.0209061	total: 1m 22s	remaining: 3m 23s
# 1923:	learn: 0.0209061	total: 1m 22s	remaining: 3m 23s
# 1924:	learn: 0.0209061	total: 1m 22s	remaining: 3m 23s
# 1925:	learn: 0.0209060	total: 1m 22s	remaining: 3m 23s
# 1926:	learn: 0.0209060	total: 1m 22s	remaining: 3m 23s
# 1927:	learn: 0.0209059	total: 1m 22s	remaining: 3m 23s
# 1928:	learn: 0.0209059	total: 1m 22s	remaining: 3m 23s
# 1929:	learn: 0.0209059	total: 1m 22s	remaining: 3m 23s
# 1930:	learn: 0.0209058	total: 1m 22s	remaining: 3m 23s
# 1931:	learn: 0.0209058	total: 1m 22s	remaining: 3m 23s
# 1932:	learn: 0.0209057	total: 1m 22s	remaining: 3m 23s
# 1933:	learn: 0.0209057	total: 1m 22s	remaining: 3m 23s
# 1934:	learn: 0.0209057	total: 1m 22s	remaining: 3m 23s
# 1935:	learn: 0.0209056	total: 1m 22s	remaining: 3m 23s
# 1936:	learn: 0.0209056	total: 1m 22s	remaining: 3m 23s
# 1937:	learn: 0.0209056	total: 1m 22s	remaining: 3m 23s
# 1938:	learn: 0.0209055	total: 1m 22s	remaining: 3m 23s
# 1939:	learn: 0.0209055	total: 1m 22s	remaining: 3m 22s
# 1940:	learn: 0.0209054	total: 1m 22s	remaining: 3m 22s
# 1941:	learn: 0.0209054	total: 1m 22s	remaining: 3m 22s
# 1942:	learn: 0.0209054	total: 1m 22s	remaining: 3m 22s
# 1943:	learn: 0.0209053	total: 1m 22s	remaining: 3m 22s
# 1944:	learn: 0.0209053	total: 1m 22s	remaining: 3m 22s
# 1945:	learn: 0.0209052	total: 1m 22s	remaining: 3m 22s
# 1946:	learn: 0.0209052	total: 1m 22s	remaining: 3m 22s
# 1947:	learn: 0.0209052	total: 1m 22s	remaining: 3m 22s
# 1948:	learn: 0.0209051	total: 1m 23s	remaining: 3m 22s
# 1949:	learn: 0.0209051	total: 1m 23s	remaining: 3m 22s
# 1950:	learn: 0.0209051	total: 1m 23s	remaining: 3m 22s
# 1951:	learn: 0.0209050	total: 1m 23s	remaining: 3m 22s
# 1952:	learn: 0.0209050	total: 1m 23s	remaining: 3m 22s
# 1953:	learn: 0.0209049	total: 1m 23s	remaining: 3m 22s
# 1954:	learn: 0.0209049	total: 1m 23s	remaining: 3m 22s
# 1955:	learn: 0.0209049	total: 1m 23s	remaining: 3m 22s
# 1956:	learn: 0.0209048	total: 1m 23s	remaining: 3m 22s
# 1957:	learn: 0.0209048	total: 1m 23s	remaining: 3m 21s
# 1958:	learn: 0.0209048	total: 1m 23s	remaining: 3m 21s
# 1959:	learn: 0.0209047	total: 1m 23s	remaining: 3m 21s
# 1960:	learn: 0.0209047	total: 1m 23s	remaining: 3m 21s
# 1961:	learn: 0.0209046	total: 1m 23s	remaining: 3m 21s
# 1962:	learn: 0.0209046	total: 1m 23s	remaining: 3m 21s
# 1963:	learn: 0.0209046	total: 1m 23s	remaining: 3m 21s
# 1964:	learn: 0.0209045	total: 1m 23s	remaining: 3m 21s
# 1965:	learn: 0.0209045	total: 1m 23s	remaining: 3m 21s
# 1966:	learn: 0.0209045	total: 1m 23s	remaining: 3m 21s
# 1967:	learn: 0.0209044	total: 1m 23s	remaining: 3m 21s
# 1968:	learn: 0.0209044	total: 1m 23s	remaining: 3m 21s
# 1969:	learn: 0.0209043	total: 1m 23s	remaining: 3m 21s
# 1970:	learn: 0.0209043	total: 1m 23s	remaining: 3m 21s
# 1971:	learn: 0.0209043	total: 1m 23s	remaining: 3m 21s
# 1972:	learn: 0.0209042	total: 1m 23s	remaining: 3m 21s
# 1973:	learn: 0.0209042	total: 1m 23s	remaining: 3m 21s
# 1974:	learn: 0.0209042	total: 1m 23s	remaining: 3m 21s
# 1975:	learn: 0.0209041	total: 1m 24s	remaining: 3m 20s
# 1976:	learn: 0.0209041	total: 1m 24s	remaining: 3m 20s
# 1977:	learn: 0.0209041	total: 1m 24s	remaining: 3m 20s
# 1978:	learn: 0.0209040	total: 1m 24s	remaining: 3m 20s
# 1979:	learn: 0.0209040	total: 1m 24s	remaining: 3m 20s
# 1980:	learn: 0.0209039	total: 1m 24s	remaining: 3m 20s
# 1981:	learn: 0.0209039	total: 1m 24s	remaining: 3m 20s
# 1982:	learn: 0.0209039	total: 1m 24s	remaining: 3m 20s
# 1983:	learn: 0.0209038	total: 1m 24s	remaining: 3m 20s
# 1984:	learn: 0.0209038	total: 1m 24s	remaining: 3m 20s
# 1985:	learn: 0.0209038	total: 1m 24s	remaining: 3m 20s
# 1986:	learn: 0.0209037	total: 1m 24s	remaining: 3m 20s
# 1987:	learn: 0.0209037	total: 1m 24s	remaining: 3m 20s
# 1988:	learn: 0.0209037	total: 1m 24s	remaining: 3m 20s
# 1989:	learn: 0.0209036	total: 1m 24s	remaining: 3m 20s
# 1990:	learn: 0.0209036	total: 1m 24s	remaining: 3m 20s
# 1991:	learn: 0.0209035	total: 1m 24s	remaining: 3m 20s
# 1992:	learn: 0.0209035	total: 1m 24s	remaining: 3m 20s
# 1993:	learn: 0.0209035	total: 1m 24s	remaining: 3m 19s
# 1994:	learn: 0.0209034	total: 1m 24s	remaining: 3m 19s
# 1995:	learn: 0.0209034	total: 1m 24s	remaining: 3m 19s
# 1996:	learn: 0.0209034	total: 1m 24s	remaining: 3m 19s
# 1997:	learn: 0.0209033	total: 1m 24s	remaining: 3m 19s
# 1998:	learn: 0.0209033	total: 1m 24s	remaining: 3m 19s
# 1999:	learn: 0.0209032	total: 1m 24s	remaining: 3m 19s
# 2000:	learn: 0.0209032	total: 1m 24s	remaining: 3m 19s
# 2001:	learn: 0.0209032	total: 1m 24s	remaining: 3m 19s
# 2002:	learn: 0.0209031	total: 1m 25s	remaining: 3m 19s
# 2003:	learn: 0.0209031	total: 1m 25s	remaining: 3m 19s
# 2004:	learn: 0.0209031	total: 1m 25s	remaining: 3m 19s
# 2005:	learn: 0.0209030	total: 1m 25s	remaining: 3m 19s
# 2006:	learn: 0.0209030	total: 1m 25s	remaining: 3m 19s
# 2007:	learn: 0.0209030	total: 1m 25s	remaining: 3m 19s
# 2008:	learn: 0.0209029	total: 1m 25s	remaining: 3m 19s
# 2009:	learn: 0.0209029	total: 1m 25s	remaining: 3m 19s
# 2010:	learn: 0.0209028	total: 1m 25s	remaining: 3m 19s
# 2011:	learn: 0.0209028	total: 1m 25s	remaining: 3m 18s
# 2012:	learn: 0.0209028	total: 1m 25s	remaining: 3m 18s
# 2013:	learn: 0.0209027	total: 1m 25s	remaining: 3m 18s
# 2014:	learn: 0.0209027	total: 1m 25s	remaining: 3m 18s
# 2015:	learn: 0.0209027	total: 1m 25s	remaining: 3m 18s
# 2016:	learn: 0.0209026	total: 1m 25s	remaining: 3m 18s
# 2017:	learn: 0.0209026	total: 1m 25s	remaining: 3m 18s
# 2018:	learn: 0.0209026	total: 1m 25s	remaining: 3m 18s
# 2019:	learn: 0.0209025	total: 1m 25s	remaining: 3m 18s
# 2020:	learn: 0.0209025	total: 1m 25s	remaining: 3m 18s
# 2021:	learn: 0.0209025	total: 1m 25s	remaining: 3m 18s
# 2022:	learn: 0.0209024	total: 1m 25s	remaining: 3m 18s
# 2023:	learn: 0.0209024	total: 1m 25s	remaining: 3m 18s
# 2024:	learn: 0.0209024	total: 1m 25s	remaining: 3m 18s
# 2025:	learn: 0.0209023	total: 1m 25s	remaining: 3m 18s
# 2026:	learn: 0.0209023	total: 1m 25s	remaining: 3m 18s
# 2027:	learn: 0.0209023	total: 1m 25s	remaining: 3m 18s
# 2028:	learn: 0.0209022	total: 1m 25s	remaining: 3m 18s
# 2029:	learn: 0.0209022	total: 1m 26s	remaining: 3m 18s
# 2030:	learn: 0.0209022	total: 1m 26s	remaining: 3m 17s
# 2031:	learn: 0.0209021	total: 1m 26s	remaining: 3m 17s
# 2032:	learn: 0.0209021	total: 1m 26s	remaining: 3m 17s
# 2033:	learn: 0.0209020	total: 1m 26s	remaining: 3m 17s
# 2034:	learn: 0.0209020	total: 1m 26s	remaining: 3m 17s
# 2035:	learn: 0.0209020	total: 1m 26s	remaining: 3m 17s
# 2036:	learn: 0.0209019	total: 1m 26s	remaining: 3m 17s
# 2037:	learn: 0.0209019	total: 1m 26s	remaining: 3m 17s
# 2038:	learn: 0.0209019	total: 1m 26s	remaining: 3m 17s
# 2039:	learn: 0.0209018	total: 1m 26s	remaining: 3m 17s
# 2040:	learn: 0.0209018	total: 1m 26s	remaining: 3m 17s
# 2041:	learn: 0.0209018	total: 1m 26s	remaining: 3m 17s
# 2042:	learn: 0.0209017	total: 1m 26s	remaining: 3m 17s
# 2043:	learn: 0.0209017	total: 1m 26s	remaining: 3m 17s
# 2044:	learn: 0.0209017	total: 1m 26s	remaining: 3m 17s
# 2045:	learn: 0.0209016	total: 1m 26s	remaining: 3m 17s
# 2046:	learn: 0.0209016	total: 1m 26s	remaining: 3m 17s
# 2047:	learn: 0.0209016	total: 1m 26s	remaining: 3m 17s
# 2048:	learn: 0.0209015	total: 1m 26s	remaining: 3m 16s
# 2049:	learn: 0.0209015	total: 1m 26s	remaining: 3m 16s
# 2050:	learn: 0.0209015	total: 1m 26s	remaining: 3m 16s
# 2051:	learn: 0.0209014	total: 1m 26s	remaining: 3m 16s
# 2052:	learn: 0.0209014	total: 1m 26s	remaining: 3m 16s
# 2053:	learn: 0.0209014	total: 1m 26s	remaining: 3m 16s
# 2054:	learn: 0.0209013	total: 1m 26s	remaining: 3m 16s
# 2055:	learn: 0.0209013	total: 1m 26s	remaining: 3m 16s
# 2056:	learn: 0.0209012	total: 1m 27s	remaining: 3m 16s
# 2057:	learn: 0.0209012	total: 1m 27s	remaining: 3m 16s
# 2058:	learn: 0.0209012	total: 1m 27s	remaining: 3m 16s
# 2059:	learn: 0.0209011	total: 1m 27s	remaining: 3m 16s
# 2060:	learn: 0.0209011	total: 1m 27s	remaining: 3m 16s
# 2061:	learn: 0.0209011	total: 1m 27s	remaining: 3m 16s
# 2062:	learn: 0.0209010	total: 1m 27s	remaining: 3m 16s
# 2063:	learn: 0.0209010	total: 1m 27s	remaining: 3m 16s
# 2064:	learn: 0.0209010	total: 1m 27s	remaining: 3m 16s
# 2065:	learn: 0.0209009	total: 1m 27s	remaining: 3m 16s
# 2066:	learn: 0.0209009	total: 1m 27s	remaining: 3m 16s
# 2067:	learn: 0.0209009	total: 1m 27s	remaining: 3m 15s
# 2068:	learn: 0.0209008	total: 1m 27s	remaining: 3m 15s
# 2069:	learn: 0.0209008	total: 1m 27s	remaining: 3m 15s
# 2070:	learn: 0.0209008	total: 1m 27s	remaining: 3m 15s
# 2071:	learn: 0.0209007	total: 1m 27s	remaining: 3m 15s
# 2072:	learn: 0.0209007	total: 1m 27s	remaining: 3m 15s
# 2073:	learn: 0.0209007	total: 1m 27s	remaining: 3m 15s
# 2074:	learn: 0.0209006	total: 1m 27s	remaining: 3m 15s
# 2075:	learn: 0.0209006	total: 1m 27s	remaining: 3m 15s
# 2076:	learn: 0.0209006	total: 1m 27s	remaining: 3m 15s
# 2077:	learn: 0.0209005	total: 1m 27s	remaining: 3m 15s
# 2078:	learn: 0.0209005	total: 1m 27s	remaining: 3m 15s
# 2079:	learn: 0.0209005	total: 1m 27s	remaining: 3m 15s
# 2080:	learn: 0.0209004	total: 1m 27s	remaining: 3m 15s
# 2081:	learn: 0.0209004	total: 1m 27s	remaining: 3m 15s
# 2082:	learn: 0.0209004	total: 1m 28s	remaining: 3m 15s
# 2083:	learn: 0.0209003	total: 1m 28s	remaining: 3m 15s
# 2084:	learn: 0.0209003	total: 1m 28s	remaining: 3m 15s
# 2085:	learn: 0.0209003	total: 1m 28s	remaining: 3m 15s
# 2086:	learn: 0.0209002	total: 1m 28s	remaining: 3m 14s
# 2087:	learn: 0.0209002	total: 1m 28s	remaining: 3m 14s
# 2088:	learn: 0.0209002	total: 1m 28s	remaining: 3m 14s
# 2089:	learn: 0.0209001	total: 1m 28s	remaining: 3m 14s
# 2090:	learn: 0.0209001	total: 1m 28s	remaining: 3m 14s
# 2091:	learn: 0.0209001	total: 1m 28s	remaining: 3m 14s
# 2092:	learn: 0.0209000	total: 1m 28s	remaining: 3m 14s
# 2093:	learn: 0.0209000	total: 1m 28s	remaining: 3m 14s
# 2094:	learn: 0.0209000	total: 1m 28s	remaining: 3m 14s
# 2095:	learn: 0.0208999	total: 1m 28s	remaining: 3m 14s
# 2096:	learn: 0.0208999	total: 1m 28s	remaining: 3m 14s
# 2097:	learn: 0.0208999	total: 1m 28s	remaining: 3m 14s
# 2098:	learn: 0.0208998	total: 1m 28s	remaining: 3m 14s
# 2099:	learn: 0.0208998	total: 1m 28s	remaining: 3m 14s
# 2100:	learn: 0.0208998	total: 1m 28s	remaining: 3m 14s
# 2101:	learn: 0.0208997	total: 1m 28s	remaining: 3m 14s
# 2102:	learn: 0.0208997	total: 1m 28s	remaining: 3m 14s
# 2103:	learn: 0.0208997	total: 1m 28s	remaining: 3m 14s
# 2104:	learn: 0.0208996	total: 1m 28s	remaining: 3m 14s
# 2105:	learn: 0.0208996	total: 1m 28s	remaining: 3m 13s
# 2106:	learn: 0.0208996	total: 1m 28s	remaining: 3m 13s
# 2107:	learn: 0.0208995	total: 1m 28s	remaining: 3m 13s
# 2108:	learn: 0.0208995	total: 1m 28s	remaining: 3m 13s
# 2109:	learn: 0.0208995	total: 1m 29s	remaining: 3m 13s
# 2110:	learn: 0.0208995	total: 1m 29s	remaining: 3m 13s
# 2111:	learn: 0.0208994	total: 1m 29s	remaining: 3m 13s
# 2112:	learn: 0.0208994	total: 1m 29s	remaining: 3m 13s
# 2113:	learn: 0.0208994	total: 1m 29s	remaining: 3m 13s
# 2114:	learn: 0.0208993	total: 1m 29s	remaining: 3m 13s
# 2115:	learn: 0.0208993	total: 1m 29s	remaining: 3m 13s
# 2116:	learn: 0.0208993	total: 1m 29s	remaining: 3m 13s
# 2117:	learn: 0.0208992	total: 1m 29s	remaining: 3m 13s
# 2118:	learn: 0.0208992	total: 1m 29s	remaining: 3m 13s
# 2119:	learn: 0.0208992	total: 1m 29s	remaining: 3m 13s
# 2120:	learn: 0.0208991	total: 1m 29s	remaining: 3m 13s
# 2121:	learn: 0.0208991	total: 1m 29s	remaining: 3m 13s
# 2122:	learn: 0.0208991	total: 1m 29s	remaining: 3m 13s
# 2123:	learn: 0.0208990	total: 1m 29s	remaining: 3m 12s
# 2124:	learn: 0.0208990	total: 1m 29s	remaining: 3m 12s
# 2125:	learn: 0.0208990	total: 1m 29s	remaining: 3m 12s
# 2126:	learn: 0.0208989	total: 1m 29s	remaining: 3m 12s
# 2127:	learn: 0.0208989	total: 1m 29s	remaining: 3m 12s
# 2128:	learn: 0.0208989	total: 1m 29s	remaining: 3m 12s
# 2129:	learn: 0.0208988	total: 1m 29s	remaining: 3m 12s
# 2130:	learn: 0.0208988	total: 1m 29s	remaining: 3m 12s
# 2131:	learn: 0.0208988	total: 1m 29s	remaining: 3m 12s
# 2132:	learn: 0.0208987	total: 1m 29s	remaining: 3m 12s
# 2133:	learn: 0.0208987	total: 1m 29s	remaining: 3m 12s
# 2134:	learn: 0.0208987	total: 1m 29s	remaining: 3m 12s
# 2135:	learn: 0.0208986	total: 1m 29s	remaining: 3m 12s
# 2136:	learn: 0.0208986	total: 1m 30s	remaining: 3m 12s
# 2137:	learn: 0.0208986	total: 1m 30s	remaining: 3m 12s
# 2138:	learn: 0.0208986	total: 1m 30s	remaining: 3m 12s
# 2139:	learn: 0.0208985	total: 1m 30s	remaining: 3m 12s
# 2140:	learn: 0.0208985	total: 1m 30s	remaining: 3m 12s
# 2141:	learn: 0.0208985	total: 1m 30s	remaining: 3m 12s
# 2142:	learn: 0.0208984	total: 1m 30s	remaining: 3m 11s
# 2143:	learn: 0.0208984	total: 1m 30s	remaining: 3m 11s
# 2144:	learn: 0.0208984	total: 1m 30s	remaining: 3m 11s
# 2145:	learn: 0.0208983	total: 1m 30s	remaining: 3m 11s
# 2146:	learn: 0.0208983	total: 1m 30s	remaining: 3m 11s
# 2147:	learn: 0.0208983	total: 1m 30s	remaining: 3m 11s
# 2148:	learn: 0.0208982	total: 1m 30s	remaining: 3m 11s
# 2149:	learn: 0.0208982	total: 1m 30s	remaining: 3m 11s
# 2150:	learn: 0.0208982	total: 1m 30s	remaining: 3m 11s
# 2151:	learn: 0.0208982	total: 1m 30s	remaining: 3m 11s
# 2152:	learn: 0.0208981	total: 1m 30s	remaining: 3m 11s
# 2153:	learn: 0.0208981	total: 1m 30s	remaining: 3m 11s
# 2154:	learn: 0.0208981	total: 1m 30s	remaining: 3m 11s
# 2155:	learn: 0.0208980	total: 1m 30s	remaining: 3m 11s
# 2156:	learn: 0.0208980	total: 1m 30s	remaining: 3m 11s
# 2157:	learn: 0.0208980	total: 1m 30s	remaining: 3m 11s
# 2158:	learn: 0.0208979	total: 1m 30s	remaining: 3m 11s
# 2159:	learn: 0.0208979	total: 1m 30s	remaining: 3m 11s
# 2160:	learn: 0.0208979	total: 1m 30s	remaining: 3m 11s
# 2161:	learn: 0.0208978	total: 1m 30s	remaining: 3m 10s
# 2162:	learn: 0.0208978	total: 1m 30s	remaining: 3m 10s
# 2163:	learn: 0.0208978	total: 1m 30s	remaining: 3m 10s
# 2164:	learn: 0.0208978	total: 1m 31s	remaining: 3m 10s
# 2165:	learn: 0.0208977	total: 1m 31s	remaining: 3m 10s
# 2166:	learn: 0.0208977	total: 1m 31s	remaining: 3m 10s
# 2167:	learn: 0.0208977	total: 1m 31s	remaining: 3m 10s
# 2168:	learn: 0.0208976	total: 1m 31s	remaining: 3m 10s
# 2169:	learn: 0.0208976	total: 1m 31s	remaining: 3m 10s
# 2170:	learn: 0.0208976	total: 1m 31s	remaining: 3m 10s
# 2171:	learn: 0.0208975	total: 1m 31s	remaining: 3m 10s
# 2172:	learn: 0.0208975	total: 1m 31s	remaining: 3m 10s
# 2173:	learn: 0.0208975	total: 1m 31s	remaining: 3m 10s
# 2174:	learn: 0.0208974	total: 1m 31s	remaining: 3m 11s
# 2175:	learn: 0.0208974	total: 1m 31s	remaining: 3m 11s
# 2176:	learn: 0.0208974	total: 1m 31s	remaining: 3m 11s
# 2177:	learn: 0.0208973	total: 1m 31s	remaining: 3m 11s
# 2178:	learn: 0.0208973	total: 1m 32s	remaining: 3m 11s
# 2179:	learn: 0.0208973	total: 1m 32s	remaining: 3m 11s
# 2180:	learn: 0.0208973	total: 1m 32s	remaining: 3m 11s
# 2181:	learn: 0.0208972	total: 1m 32s	remaining: 3m 11s
# 2182:	learn: 0.0208972	total: 1m 32s	remaining: 3m 11s
# 2183:	learn: 0.0208972	total: 1m 32s	remaining: 3m 11s
# 2184:	learn: 0.0208971	total: 1m 32s	remaining: 3m 11s
# 2185:	learn: 0.0208971	total: 1m 32s	remaining: 3m 11s
# 2186:	learn: 0.0208971	total: 1m 32s	remaining: 3m 11s
# 2187:	learn: 0.0208970	total: 1m 32s	remaining: 3m 11s
# 2188:	learn: 0.0208970	total: 1m 32s	remaining: 3m 11s
# 2189:	learn: 0.0208970	total: 1m 32s	remaining: 3m 11s
# 2190:	learn: 0.0208970	total: 1m 32s	remaining: 3m 11s
# 2191:	learn: 0.0208969	total: 1m 32s	remaining: 3m 11s
# 2192:	learn: 0.0208969	total: 1m 32s	remaining: 3m 11s
# 2193:	learn: 0.0208969	total: 1m 33s	remaining: 3m 11s
# 2194:	learn: 0.0208968	total: 1m 33s	remaining: 3m 11s
# 2195:	learn: 0.0208968	total: 1m 33s	remaining: 3m 11s
# 2196:	learn: 0.0208968	total: 1m 33s	remaining: 3m 11s
# 2197:	learn: 0.0208967	total: 1m 33s	remaining: 3m 11s
# 2198:	learn: 0.0208967	total: 1m 33s	remaining: 3m 11s
# 2199:	learn: 0.0208967	total: 1m 33s	remaining: 3m 11s
# 2200:	learn: 0.0208967	total: 1m 33s	remaining: 3m 11s
# 2201:	learn: 0.0208966	total: 1m 33s	remaining: 3m 11s
# 2202:	learn: 0.0208966	total: 1m 33s	remaining: 3m 11s
# 2203:	learn: 0.0208966	total: 1m 33s	remaining: 3m 11s
# 2204:	learn: 0.0208965	total: 1m 33s	remaining: 3m 11s
# 2205:	learn: 0.0208965	total: 1m 33s	remaining: 3m 11s
# 2206:	learn: 0.0208965	total: 1m 33s	remaining: 3m 11s
# 2207:	learn: 0.0208964	total: 1m 33s	remaining: 3m 11s
# 2208:	learn: 0.0208964	total: 1m 34s	remaining: 3m 11s
# 2209:	learn: 0.0208964	total: 1m 34s	remaining: 3m 11s
# 2210:	learn: 0.0208964	total: 1m 34s	remaining: 3m 11s
# 2211:	learn: 0.0208963	total: 1m 34s	remaining: 3m 11s
# 2212:	learn: 0.0208963	total: 1m 34s	remaining: 3m 11s
# 2213:	learn: 0.0208963	total: 1m 34s	remaining: 3m 11s
# 2214:	learn: 0.0208962	total: 1m 34s	remaining: 3m 11s
# 2215:	learn: 0.0208962	total: 1m 34s	remaining: 3m 10s
# 2216:	learn: 0.0208962	total: 1m 34s	remaining: 3m 10s
# 2217:	learn: 0.0208961	total: 1m 34s	remaining: 3m 10s
# 2218:	learn: 0.0208961	total: 1m 34s	remaining: 3m 10s
# 2219:	learn: 0.0208961	total: 1m 34s	remaining: 3m 10s
# 2220:	learn: 0.0208961	total: 1m 34s	remaining: 3m 10s
# 2221:	learn: 0.0208960	total: 1m 34s	remaining: 3m 10s
# 2222:	learn: 0.0208960	total: 1m 34s	remaining: 3m 10s
# 2223:	learn: 0.0208960	total: 1m 34s	remaining: 3m 10s
# 2224:	learn: 0.0208959	total: 1m 34s	remaining: 3m 10s
# 2225:	learn: 0.0208959	total: 1m 34s	remaining: 3m 10s
# 2226:	learn: 0.0208959	total: 1m 34s	remaining: 3m 10s
# 2227:	learn: 0.0208959	total: 1m 34s	remaining: 3m 10s
# 2228:	learn: 0.0208958	total: 1m 34s	remaining: 3m 10s
# 2229:	learn: 0.0208958	total: 1m 34s	remaining: 3m 10s
# 2230:	learn: 0.0208958	total: 1m 34s	remaining: 3m 10s
# 2231:	learn: 0.0208957	total: 1m 34s	remaining: 3m 10s
# 2232:	learn: 0.0208957	total: 1m 34s	remaining: 3m 10s
# 2233:	learn: 0.0208957	total: 1m 34s	remaining: 3m 10s
# 2234:	learn: 0.0208956	total: 1m 35s	remaining: 3m 9s
# 2235:	learn: 0.0208956	total: 1m 35s	remaining: 3m 9s
# 2236:	learn: 0.0208956	total: 1m 35s	remaining: 3m 9s
# 2237:	learn: 0.0208956	total: 1m 35s	remaining: 3m 9s
# 2238:	learn: 0.0208955	total: 1m 35s	remaining: 3m 9s
# 2239:	learn: 0.0208955	total: 1m 35s	remaining: 3m 9s
# 2240:	learn: 0.0208955	total: 1m 35s	remaining: 3m 9s
# 2241:	learn: 0.0208954	total: 1m 35s	remaining: 3m 9s
# 2242:	learn: 0.0208954	total: 1m 35s	remaining: 3m 9s
# 2243:	learn: 0.0208954	total: 1m 35s	remaining: 3m 9s
# 2244:	learn: 0.0208954	total: 1m 35s	remaining: 3m 9s
# 2245:	learn: 0.0208953	total: 1m 35s	remaining: 3m 9s
# 2246:	learn: 0.0208953	total: 1m 35s	remaining: 3m 9s
# 2247:	learn: 0.0208953	total: 1m 35s	remaining: 3m 9s
# 2248:	learn: 0.0208952	total: 1m 35s	remaining: 3m 9s
# 2249:	learn: 0.0208952	total: 1m 35s	remaining: 3m 9s
# 2250:	learn: 0.0208952	total: 1m 35s	remaining: 3m 9s
# 2251:	learn: 0.0208952	total: 1m 35s	remaining: 3m 9s
# 2252:	learn: 0.0208951	total: 1m 35s	remaining: 3m 9s
# 2253:	learn: 0.0208951	total: 1m 35s	remaining: 3m 8s
# 2254:	learn: 0.0208951	total: 1m 35s	remaining: 3m 8s
# 2255:	learn: 0.0208950	total: 1m 35s	remaining: 3m 8s
# 2256:	learn: 0.0208950	total: 1m 35s	remaining: 3m 8s
# 2257:	learn: 0.0208950	total: 1m 35s	remaining: 3m 8s
# 2258:	learn: 0.0208950	total: 1m 35s	remaining: 3m 8s
# 2259:	learn: 0.0208949	total: 1m 35s	remaining: 3m 8s
# 2260:	learn: 0.0208949	total: 1m 35s	remaining: 3m 8s
# 2261:	learn: 0.0208949	total: 1m 36s	remaining: 3m 8s
# 2262:	learn: 0.0208948	total: 1m 36s	remaining: 3m 8s
# 2263:	learn: 0.0208948	total: 1m 36s	remaining: 3m 8s
# 2264:	learn: 0.0208948	total: 1m 36s	remaining: 3m 8s
# 2265:	learn: 0.0208948	total: 1m 36s	remaining: 3m 8s
# 2266:	learn: 0.0208947	total: 1m 36s	remaining: 3m 8s
# 2267:	learn: 0.0208947	total: 1m 36s	remaining: 3m 8s
# 2268:	learn: 0.0208947	total: 1m 36s	remaining: 3m 8s
# 2269:	learn: 0.0208946	total: 1m 36s	remaining: 3m 8s
# 2270:	learn: 0.0208946	total: 1m 36s	remaining: 3m 8s
# 2271:	learn: 0.0208946	total: 1m 36s	remaining: 3m 8s
# 2272:	learn: 0.0208946	total: 1m 36s	remaining: 3m 7s
# 2273:	learn: 0.0208945	total: 1m 36s	remaining: 3m 7s
# 2274:	learn: 0.0208945	total: 1m 36s	remaining: 3m 7s
# 2275:	learn: 0.0208945	total: 1m 36s	remaining: 3m 7s
# 2276:	learn: 0.0208945	total: 1m 36s	remaining: 3m 7s
# 2277:	learn: 0.0208944	total: 1m 36s	remaining: 3m 7s
# 2278:	learn: 0.0208944	total: 1m 36s	remaining: 3m 7s
# 2279:	learn: 0.0208944	total: 1m 36s	remaining: 3m 7s
# 2280:	learn: 0.0208943	total: 1m 36s	remaining: 3m 7s
# 2281:	learn: 0.0208943	total: 1m 36s	remaining: 3m 7s
# 2282:	learn: 0.0208943	total: 1m 36s	remaining: 3m 7s
# 2283:	learn: 0.0208943	total: 1m 36s	remaining: 3m 7s
# 2284:	learn: 0.0208942	total: 1m 36s	remaining: 3m 7s
# 2285:	learn: 0.0208942	total: 1m 36s	remaining: 3m 7s
# 2286:	learn: 0.0208942	total: 1m 36s	remaining: 3m 7s
# 2287:	learn: 0.0208942	total: 1m 37s	remaining: 3m 7s
# 2288:	learn: 0.0208941	total: 1m 37s	remaining: 3m 7s
# 2289:	learn: 0.0208941	total: 1m 37s	remaining: 3m 7s
# 2290:	learn: 0.0208941	total: 1m 37s	remaining: 3m 7s
# 2291:	learn: 0.0208940	total: 1m 37s	remaining: 3m 7s
# 2292:	learn: 0.0208940	total: 1m 37s	remaining: 3m 6s
# 2293:	learn: 0.0208940	total: 1m 37s	remaining: 3m 6s
# 2294:	learn: 0.0208940	total: 1m 37s	remaining: 3m 6s
# 2295:	learn: 0.0208939	total: 1m 37s	remaining: 3m 6s
# 2296:	learn: 0.0208939	total: 1m 37s	remaining: 3m 6s
# 2297:	learn: 0.0208939	total: 1m 37s	remaining: 3m 6s
# 2298:	learn: 0.0208938	total: 1m 37s	remaining: 3m 6s
# 2299:	learn: 0.0208938	total: 1m 37s	remaining: 3m 6s
# 2300:	learn: 0.0208938	total: 1m 37s	remaining: 3m 6s
# 2301:	learn: 0.0208938	total: 1m 37s	remaining: 3m 6s
# 2302:	learn: 0.0208937	total: 1m 37s	remaining: 3m 6s
# 2303:	learn: 0.0208937	total: 1m 37s	remaining: 3m 6s
# 2304:	learn: 0.0208937	total: 1m 37s	remaining: 3m 6s
# 2305:	learn: 0.0208937	total: 1m 37s	remaining: 3m 6s
# 2306:	learn: 0.0208936	total: 1m 37s	remaining: 3m 6s
# 2307:	learn: 0.0208936	total: 1m 37s	remaining: 3m 6s
# 2308:	learn: 0.0208936	total: 1m 37s	remaining: 3m 6s
# 2309:	learn: 0.0208935	total: 1m 37s	remaining: 3m 6s
# 2310:	learn: 0.0208935	total: 1m 37s	remaining: 3m 6s
# 2311:	learn: 0.0208935	total: 1m 37s	remaining: 3m 5s
# 2312:	learn: 0.0208935	total: 1m 37s	remaining: 3m 5s
# 2313:	learn: 0.0208934	total: 1m 38s	remaining: 3m 5s
# 2314:	learn: 0.0208934	total: 1m 38s	remaining: 3m 5s
# 2315:	learn: 0.0208934	total: 1m 38s	remaining: 3m 5s
# 2316:	learn: 0.0208934	total: 1m 38s	remaining: 3m 5s
# 2317:	learn: 0.0208933	total: 1m 38s	remaining: 3m 5s
# 2318:	learn: 0.0208933	total: 1m 38s	remaining: 3m 5s
# 2319:	learn: 0.0208933	total: 1m 38s	remaining: 3m 5s
# 2320:	learn: 0.0208932	total: 1m 38s	remaining: 3m 5s
# 2321:	learn: 0.0208932	total: 1m 38s	remaining: 3m 5s
# 2322:	learn: 0.0208932	total: 1m 38s	remaining: 3m 5s
# 2323:	learn: 0.0208932	total: 1m 38s	remaining: 3m 5s
# 2324:	learn: 0.0208931	total: 1m 38s	remaining: 3m 5s
# 2325:	learn: 0.0208931	total: 1m 38s	remaining: 3m 5s
# 2326:	learn: 0.0208931	total: 1m 38s	remaining: 3m 5s
# 2327:	learn: 0.0208931	total: 1m 38s	remaining: 3m 5s
# 2328:	learn: 0.0208930	total: 1m 38s	remaining: 3m 5s
# 2329:	learn: 0.0208930	total: 1m 38s	remaining: 3m 5s
# 2330:	learn: 0.0208930	total: 1m 38s	remaining: 3m 5s
# 2331:	learn: 0.0208930	total: 1m 38s	remaining: 3m 5s
# 2332:	learn: 0.0208929	total: 1m 38s	remaining: 3m 4s
# 2333:	learn: 0.0208929	total: 1m 38s	remaining: 3m 4s
# 2334:	learn: 0.0208929	total: 1m 38s	remaining: 3m 4s
# 2335:	learn: 0.0208928	total: 1m 38s	remaining: 3m 4s
# 2336:	learn: 0.0208928	total: 1m 38s	remaining: 3m 4s
# 2337:	learn: 0.0208928	total: 1m 38s	remaining: 3m 4s
# 2338:	learn: 0.0208928	total: 1m 38s	remaining: 3m 4s
# 2339:	learn: 0.0208927	total: 1m 39s	remaining: 3m 4s
# 2340:	learn: 0.0208927	total: 1m 39s	remaining: 3m 4s
# 2341:	learn: 0.0208927	total: 1m 39s	remaining: 3m 4s
# 2342:	learn: 0.0208927	total: 1m 39s	remaining: 3m 4s
# 2343:	learn: 0.0208926	total: 1m 39s	remaining: 3m 4s
# 2344:	learn: 0.0208926	total: 1m 39s	remaining: 3m 4s
# 2345:	learn: 0.0208926	total: 1m 39s	remaining: 3m 4s
# 2346:	learn: 0.0208926	total: 1m 39s	remaining: 3m 4s
# 2347:	learn: 0.0208925	total: 1m 39s	remaining: 3m 4s
# 2348:	learn: 0.0208925	total: 1m 39s	remaining: 3m 4s
# 2349:	learn: 0.0208925	total: 1m 39s	remaining: 3m 4s
# 2350:	learn: 0.0208924	total: 1m 39s	remaining: 3m 4s
# 2351:	learn: 0.0208924	total: 1m 39s	remaining: 3m 3s
# 2352:	learn: 0.0208924	total: 1m 39s	remaining: 3m 3s
# 2353:	learn: 0.0208924	total: 1m 39s	remaining: 3m 3s
# 2354:	learn: 0.0208923	total: 1m 39s	remaining: 3m 3s
# 2355:	learn: 0.0208923	total: 1m 39s	remaining: 3m 3s
# 2356:	learn: 0.0208923	total: 1m 39s	remaining: 3m 3s
# 2357:	learn: 0.0208923	total: 1m 39s	remaining: 3m 3s
# 2358:	learn: 0.0208922	total: 1m 39s	remaining: 3m 3s
# 2359:	learn: 0.0208922	total: 1m 39s	remaining: 3m 3s
# 2360:	learn: 0.0208922	total: 1m 39s	remaining: 3m 3s
# 2361:	learn: 0.0208922	total: 1m 39s	remaining: 3m 3s
# 2362:	learn: 0.0208921	total: 1m 39s	remaining: 3m 3s
# 2363:	learn: 0.0208921	total: 1m 39s	remaining: 3m 3s
# 2364:	learn: 0.0208921	total: 1m 39s	remaining: 3m 3s
# 2365:	learn: 0.0208921	total: 1m 39s	remaining: 3m 3s
# 2366:	learn: 0.0208920	total: 1m 40s	remaining: 3m 3s
# 2367:	learn: 0.0208920	total: 1m 40s	remaining: 3m 3s
# 2368:	learn: 0.0208920	total: 1m 40s	remaining: 3m 3s
# 2369:	learn: 0.0208920	total: 1m 40s	remaining: 3m 3s
# 2370:	learn: 0.0208919	total: 1m 40s	remaining: 3m 3s
# 2371:	learn: 0.0208919	total: 1m 40s	remaining: 3m 2s
# 2372:	learn: 0.0208919	total: 1m 40s	remaining: 3m 2s
# 2373:	learn: 0.0208919	total: 1m 40s	remaining: 3m 2s
# 2374:	learn: 0.0208918	total: 1m 40s	remaining: 3m 2s
# 2375:	learn: 0.0208918	total: 1m 40s	remaining: 3m 2s
# 2376:	learn: 0.0208918	total: 1m 40s	remaining: 3m 2s
# 2377:	learn: 0.0208918	total: 1m 40s	remaining: 3m 2s
# 2378:	learn: 0.0208917	total: 1m 40s	remaining: 3m 2s
# 2379:	learn: 0.0208917	total: 1m 40s	remaining: 3m 2s
# 2380:	learn: 0.0208917	total: 1m 40s	remaining: 3m 2s
# 2381:	learn: 0.0208917	total: 1m 40s	remaining: 3m 2s
# 2382:	learn: 0.0208916	total: 1m 40s	remaining: 3m 2s
# 2383:	learn: 0.0208916	total: 1m 40s	remaining: 3m 2s
# 2384:	learn: 0.0208916	total: 1m 40s	remaining: 3m 2s
# 2385:	learn: 0.0208915	total: 1m 40s	remaining: 3m 2s
# 2386:	learn: 0.0208915	total: 1m 40s	remaining: 3m 2s
# 2387:	learn: 0.0208915	total: 1m 40s	remaining: 3m 2s
# 2388:	learn: 0.0208915	total: 1m 40s	remaining: 3m 2s
# 2389:	learn: 0.0208914	total: 1m 40s	remaining: 3m 2s
# 2390:	learn: 0.0208914	total: 1m 40s	remaining: 3m 2s
# 2391:	learn: 0.0208914	total: 1m 40s	remaining: 3m 1s
# 2392:	learn: 0.0208914	total: 1m 41s	remaining: 3m 1s
# 2393:	learn: 0.0208913	total: 1m 41s	remaining: 3m 1s
# 2394:	learn: 0.0208913	total: 1m 41s	remaining: 3m 1s
# 2395:	learn: 0.0208913	total: 1m 41s	remaining: 3m 1s
# 2396:	learn: 0.0208913	total: 1m 41s	remaining: 3m 1s
# 2397:	learn: 0.0208912	total: 1m 41s	remaining: 3m 1s
# 2398:	learn: 0.0208912	total: 1m 41s	remaining: 3m 1s
# 2399:	learn: 0.0208912	total: 1m 41s	remaining: 3m 1s
# 2400:	learn: 0.0208912	total: 1m 41s	remaining: 3m 1s
# 2401:	learn: 0.0208911	total: 1m 41s	remaining: 3m 1s
# 2402:	learn: 0.0208911	total: 1m 41s	remaining: 3m 1s
# 2403:	learn: 0.0208911	total: 1m 41s	remaining: 3m 1s
# 2404:	learn: 0.0208911	total: 1m 41s	remaining: 3m 1s
# 2405:	learn: 0.0208910	total: 1m 41s	remaining: 3m 1s
# 2406:	learn: 0.0208910	total: 1m 41s	remaining: 3m 1s
# 2407:	learn: 0.0208910	total: 1m 41s	remaining: 3m 1s
# 2408:	learn: 0.0208910	total: 1m 41s	remaining: 3m 1s
# 2409:	learn: 0.0208909	total: 1m 41s	remaining: 3m 1s
# 2410:	learn: 0.0208909	total: 1m 41s	remaining: 3m 1s
# 2411:	learn: 0.0208909	total: 1m 41s	remaining: 3m
# 2412:	learn: 0.0208909	total: 1m 41s	remaining: 3m
# 2413:	learn: 0.0208908	total: 1m 41s	remaining: 3m
# 2414:	learn: 0.0208908	total: 1m 41s	remaining: 3m
# 2415:	learn: 0.0208908	total: 1m 41s	remaining: 3m
# 2416:	learn: 0.0208908	total: 1m 41s	remaining: 3m
# 2417:	learn: 0.0208907	total: 1m 41s	remaining: 3m
# 2418:	learn: 0.0208907	total: 1m 41s	remaining: 3m
# 2419:	learn: 0.0208907	total: 1m 42s	remaining: 3m
# 2420:	learn: 0.0208907	total: 1m 42s	remaining: 3m
# 2421:	learn: 0.0208906	total: 1m 42s	remaining: 3m
# 2422:	learn: 0.0208906	total: 1m 42s	remaining: 3m
# 2423:	learn: 0.0208906	total: 1m 42s	remaining: 3m
# 2424:	learn: 0.0208906	total: 1m 42s	remaining: 3m
# 2425:	learn: 0.0208905	total: 1m 42s	remaining: 3m
# 2426:	learn: 0.0208905	total: 1m 42s	remaining: 3m
# 2427:	learn: 0.0208905	total: 1m 42s	remaining: 3m
# 2428:	learn: 0.0208905	total: 1m 42s	remaining: 3m
# 2429:	learn: 0.0208904	total: 1m 42s	remaining: 3m
# 2430:	learn: 0.0208904	total: 1m 42s	remaining: 2m 59s
# 2431:	learn: 0.0208904	total: 1m 42s	remaining: 2m 59s
# 2432:	learn: 0.0208904	total: 1m 42s	remaining: 2m 59s
# 2433:	learn: 0.0208903	total: 1m 42s	remaining: 2m 59s
# 2434:	learn: 0.0208903	total: 1m 42s	remaining: 2m 59s
# 2435:	learn: 0.0208903	total: 1m 42s	remaining: 2m 59s
# 2436:	learn: 0.0208903	total: 1m 42s	remaining: 2m 59s
# 2437:	learn: 0.0208902	total: 1m 42s	remaining: 2m 59s
# 2438:	learn: 0.0208902	total: 1m 42s	remaining: 2m 59s
# 2439:	learn: 0.0208902	total: 1m 42s	remaining: 2m 59s
# 2440:	learn: 0.0208902	total: 1m 42s	remaining: 2m 59s
# 2441:	learn: 0.0208902	total: 1m 42s	remaining: 2m 59s
# 2442:	learn: 0.0208901	total: 1m 42s	remaining: 2m 59s
# 2443:	learn: 0.0208901	total: 1m 42s	remaining: 2m 59s
# 2444:	learn: 0.0208901	total: 1m 42s	remaining: 2m 59s
# 2445:	learn: 0.0208901	total: 1m 42s	remaining: 2m 59s
# 2446:	learn: 0.0208900	total: 1m 43s	remaining: 2m 59s
# 2447:	learn: 0.0208900	total: 1m 43s	remaining: 2m 59s
# 2448:	learn: 0.0208900	total: 1m 43s	remaining: 2m 59s
# 2449:	learn: 0.0208900	total: 1m 43s	remaining: 2m 59s
# 2450:	learn: 0.0208899	total: 1m 43s	remaining: 2m 58s
# 2451:	learn: 0.0208899	total: 1m 43s	remaining: 2m 58s
# 2452:	learn: 0.0208899	total: 1m 43s	remaining: 2m 58s
# 2453:	learn: 0.0208899	total: 1m 43s	remaining: 2m 58s
# 2454:	learn: 0.0208898	total: 1m 43s	remaining: 2m 58s
# 2455:	learn: 0.0208898	total: 1m 43s	remaining: 2m 58s
# 2456:	learn: 0.0208898	total: 1m 43s	remaining: 2m 58s
# 2457:	learn: 0.0208898	total: 1m 43s	remaining: 2m 58s
# 2458:	learn: 0.0208897	total: 1m 43s	remaining: 2m 58s
# 2459:	learn: 0.0208897	total: 1m 43s	remaining: 2m 58s
# 2460:	learn: 0.0208897	total: 1m 43s	remaining: 2m 58s
# 2461:	learn: 0.0208897	total: 1m 43s	remaining: 2m 58s
# 2462:	learn: 0.0208897	total: 1m 43s	remaining: 2m 58s
# 2463:	learn: 0.0208896	total: 1m 43s	remaining: 2m 58s
# 2464:	learn: 0.0208896	total: 1m 43s	remaining: 2m 58s
# 2465:	learn: 0.0208896	total: 1m 43s	remaining: 2m 58s
# 2466:	learn: 0.0208896	total: 1m 43s	remaining: 2m 58s
# 2467:	learn: 0.0208895	total: 1m 43s	remaining: 2m 58s
# 2468:	learn: 0.0208895	total: 1m 43s	remaining: 2m 58s
# 2469:	learn: 0.0208895	total: 1m 43s	remaining: 2m 58s
# 2470:	learn: 0.0208895	total: 1m 43s	remaining: 2m 57s
# 2471:	learn: 0.0208894	total: 1m 43s	remaining: 2m 57s
# 2472:	learn: 0.0208894	total: 1m 43s	remaining: 2m 57s
# 2473:	learn: 0.0208894	total: 1m 44s	remaining: 2m 57s
# 2474:	learn: 0.0208894	total: 1m 44s	remaining: 2m 57s
# 2475:	learn: 0.0208893	total: 1m 44s	remaining: 2m 57s
# 2476:	learn: 0.0208893	total: 1m 44s	remaining: 2m 57s
# 2477:	learn: 0.0208893	total: 1m 44s	remaining: 2m 57s
# 2478:	learn: 0.0208893	total: 1m 44s	remaining: 2m 57s
# 2479:	learn: 0.0208892	total: 1m 44s	remaining: 2m 57s
# 2480:	learn: 0.0208892	total: 1m 44s	remaining: 2m 57s
# 2481:	learn: 0.0208892	total: 1m 44s	remaining: 2m 57s
# 2482:	learn: 0.0208892	total: 1m 44s	remaining: 2m 57s
# 2483:	learn: 0.0208892	total: 1m 44s	remaining: 2m 57s
# 2484:	learn: 0.0208891	total: 1m 44s	remaining: 2m 57s
# 2485:	learn: 0.0208891	total: 1m 44s	remaining: 2m 57s
# 2486:	learn: 0.0208891	total: 1m 44s	remaining: 2m 57s
# 2487:	learn: 0.0208891	total: 1m 44s	remaining: 2m 57s
# 2488:	learn: 0.0208890	total: 1m 45s	remaining: 2m 57s
# 2489:	learn: 0.0208890	total: 1m 45s	remaining: 2m 57s
# 2490:	learn: 0.0208890	total: 1m 45s	remaining: 2m 57s
# 2491:	learn: 0.0208890	total: 1m 45s	remaining: 2m 57s
# 2492:	learn: 0.0208889	total: 1m 45s	remaining: 2m 57s
# 2493:	learn: 0.0208889	total: 1m 45s	remaining: 2m 57s
# 2494:	learn: 0.0208889	total: 1m 45s	remaining: 2m 57s
# 2495:	learn: 0.0208889	total: 1m 45s	remaining: 2m 57s
# 2496:	learn: 0.0208889	total: 1m 45s	remaining: 2m 57s
# 2497:	learn: 0.0208888	total: 1m 45s	remaining: 2m 57s
# 2498:	learn: 0.0208888	total: 1m 45s	remaining: 2m 57s
# 2499:	learn: 0.0208888	total: 1m 45s	remaining: 2m 57s
# 2500:	learn: 0.0208888	total: 1m 45s	remaining: 2m 57s
# 2501:	learn: 0.0208887	total: 1m 45s	remaining: 2m 57s
# 2502:	learn: 0.0208887	total: 1m 46s	remaining: 2m 57s
# 2503:	learn: 0.0208887	total: 1m 46s	remaining: 2m 57s
# 2504:	learn: 0.0208887	total: 1m 46s	remaining: 2m 57s
# 2505:	learn: 0.0208886	total: 1m 46s	remaining: 2m 57s
# 2506:	learn: 0.0208886	total: 1m 46s	remaining: 2m 57s
# 2507:	learn: 0.0208886	total: 1m 46s	remaining: 2m 57s
# 2508:	learn: 0.0208886	total: 1m 46s	remaining: 2m 57s
# 2509:	learn: 0.0208885	total: 1m 46s	remaining: 2m 57s
# 2510:	learn: 0.0208885	total: 1m 46s	remaining: 2m 58s
# 2511:	learn: 0.0208885	total: 1m 46s	remaining: 2m 58s
# 2512:	learn: 0.0208885	total: 1m 46s	remaining: 2m 58s
# 2513:	learn: 0.0208885	total: 1m 46s	remaining: 2m 58s
# 2514:	learn: 0.0208884	total: 1m 46s	remaining: 2m 58s
# 2515:	learn: 0.0208884	total: 1m 46s	remaining: 2m 58s
# 2516:	learn: 0.0208884	total: 1m 47s	remaining: 2m 58s
# 2517:	learn: 0.0208884	total: 1m 47s	remaining: 2m 58s
# 2518:	learn: 0.0208883	total: 1m 47s	remaining: 2m 57s
# 2519:	learn: 0.0208883	total: 1m 47s	remaining: 2m 57s
# 2520:	learn: 0.0208883	total: 1m 47s	remaining: 2m 57s
# 2521:	learn: 0.0208883	total: 1m 47s	remaining: 2m 57s
# 2522:	learn: 0.0208882	total: 1m 47s	remaining: 2m 57s
# 2523:	learn: 0.0208882	total: 1m 47s	remaining: 2m 57s
# 2524:	learn: 0.0208882	total: 1m 47s	remaining: 2m 57s
# 2525:	learn: 0.0208882	total: 1m 47s	remaining: 2m 57s
# 2526:	learn: 0.0208882	total: 1m 47s	remaining: 2m 57s
# 2527:	learn: 0.0208881	total: 1m 47s	remaining: 2m 57s
# 2528:	learn: 0.0208881	total: 1m 47s	remaining: 2m 57s
# 2529:	learn: 0.0208881	total: 1m 47s	remaining: 2m 57s
# 2530:	learn: 0.0208881	total: 1m 47s	remaining: 2m 57s
# 2531:	learn: 0.0208880	total: 1m 47s	remaining: 2m 57s
# 2532:	learn: 0.0208880	total: 1m 47s	remaining: 2m 57s
# 2533:	learn: 0.0208880	total: 1m 47s	remaining: 2m 57s
# 2534:	learn: 0.0208880	total: 1m 47s	remaining: 2m 57s
# 2535:	learn: 0.0208880	total: 1m 47s	remaining: 2m 57s
# 2536:	learn: 0.0208879	total: 1m 47s	remaining: 2m 57s
# 2537:	learn: 0.0208879	total: 1m 47s	remaining: 2m 57s
# 2538:	learn: 0.0208879	total: 1m 47s	remaining: 2m 56s
# 2539:	learn: 0.0208879	total: 1m 47s	remaining: 2m 56s
# 2540:	learn: 0.0208878	total: 1m 48s	remaining: 2m 56s
# 2541:	learn: 0.0208878	total: 1m 48s	remaining: 2m 56s
# 2542:	learn: 0.0208878	total: 1m 48s	remaining: 2m 56s
# 2543:	learn: 0.0208878	total: 1m 48s	remaining: 2m 56s
# 2544:	learn: 0.0208878	total: 1m 48s	remaining: 2m 56s
# 2545:	learn: 0.0208877	total: 1m 48s	remaining: 2m 56s
# 2546:	learn: 0.0208877	total: 1m 48s	remaining: 2m 56s
# 2547:	learn: 0.0208877	total: 1m 48s	remaining: 2m 56s
# 2548:	learn: 0.0208877	total: 1m 48s	remaining: 2m 56s
# 2549:	learn: 0.0208876	total: 1m 48s	remaining: 2m 56s
# 2550:	learn: 0.0208876	total: 1m 48s	remaining: 2m 56s
# 2551:	learn: 0.0208876	total: 1m 48s	remaining: 2m 56s
# 2552:	learn: 0.0208876	total: 1m 48s	remaining: 2m 56s
# 2553:	learn: 0.0208876	total: 1m 48s	remaining: 2m 56s
# 2554:	learn: 0.0208875	total: 1m 48s	remaining: 2m 56s
# 2555:	learn: 0.0208875	total: 1m 48s	remaining: 2m 56s
# 2556:	learn: 0.0208875	total: 1m 48s	remaining: 2m 56s
# 2557:	learn: 0.0208875	total: 1m 48s	remaining: 2m 56s
# 2558:	learn: 0.0208874	total: 1m 48s	remaining: 2m 55s
# 2559:	learn: 0.0208874	total: 1m 48s	remaining: 2m 55s
# 2560:	learn: 0.0208874	total: 1m 48s	remaining: 2m 55s
# 2561:	learn: 0.0208874	total: 1m 48s	remaining: 2m 55s
# 2562:	learn: 0.0208874	total: 1m 48s	remaining: 2m 55s
# 2563:	learn: 0.0208873	total: 1m 48s	remaining: 2m 55s
# 2564:	learn: 0.0208873	total: 1m 48s	remaining: 2m 55s
# 2565:	learn: 0.0208873	total: 1m 48s	remaining: 2m 55s
# 2566:	learn: 0.0208873	total: 1m 48s	remaining: 2m 55s
# 2567:	learn: 0.0208872	total: 1m 48s	remaining: 2m 55s
# 2568:	learn: 0.0208872	total: 1m 49s	remaining: 2m 55s
# 2569:	learn: 0.0208872	total: 1m 49s	remaining: 2m 55s
# 2570:	learn: 0.0208872	total: 1m 49s	remaining: 2m 55s
# 2571:	learn: 0.0208872	total: 1m 49s	remaining: 2m 55s
# 2572:	learn: 0.0208871	total: 1m 49s	remaining: 2m 55s
# 2573:	learn: 0.0208871	total: 1m 49s	remaining: 2m 55s
# 2574:	learn: 0.0208871	total: 1m 49s	remaining: 2m 55s
# 2575:	learn: 0.0208871	total: 1m 49s	remaining: 2m 55s
# 2576:	learn: 0.0208870	total: 1m 49s	remaining: 2m 55s
# 2577:	learn: 0.0208870	total: 1m 49s	remaining: 2m 54s
# 2578:	learn: 0.0208870	total: 1m 49s	remaining: 2m 54s
# ...
# 6406:	learn: 0.0208430	total: 4m 32s	remaining: 12.6s
# 6407:	learn: 0.0208430	total: 4m 32s	remaining: 12.6s
# 6408:	learn: 0.0208430	total: 4m 32s	remaining: 12.5s
# 6409:	learn: 0.0208430	total: 4m 32s	remaining: 12.5s
# 6410:	learn: 0.0208430	total: 4m 32s	remaining: 12.4s
# 6411:	learn: 0.0208430	total: 4m 32s	remaining: 12.4s
# 6412:	learn: 0.0208430	total: 4m 32s	remaining: 12.3s
# 6413:	learn: 0.0208430	total: 4m 32s	remaining: 12.3s
# 6414:	learn: 0.0208430	total: 4m 32s	remaining: 12.3s
# 6415:	learn: 0.0208430	total: 4m 32s	remaining: 12.2s
# 6416:	learn: 0.0208430	total: 4m 32s	remaining: 12.2s
# 6417:	learn: 0.0208430	total: 4m 33s	remaining: 12.1s
# 6418:	learn: 0.0208430	total: 4m 33s	remaining: 12.1s
# 6419:	learn: 0.0208430	total: 4m 33s	remaining: 12s
# 6420:	learn: 0.0208429	total: 4m 33s	remaining: 12s
# 6421:	learn: 0.0208429	total: 4m 33s	remaining: 12s
# 6422:	learn: 0.0208429	total: 4m 33s	remaining: 11.9s
# 6423:	learn: 0.0208429	total: 4m 33s	remaining: 11.9s
# 6424:	learn: 0.0208429	total: 4m 33s	remaining: 11.8s
# 6425:	learn: 0.0208429	total: 4m 33s	remaining: 11.8s
# 6426:	learn: 0.0208429	total: 4m 33s	remaining: 11.7s
# 6427:	learn: 0.0208429	total: 4m 33s	remaining: 11.7s
# 6428:	learn: 0.0208429	total: 4m 33s	remaining: 11.7s
# 6429:	learn: 0.0208429	total: 4m 33s	remaining: 11.6s
# 6430:	learn: 0.0208429	total: 4m 33s	remaining: 11.6s
# 6431:	learn: 0.0208429	total: 4m 33s	remaining: 11.5s
# 6432:	learn: 0.0208429	total: 4m 33s	remaining: 11.5s
# 6433:	learn: 0.0208429	total: 4m 33s	remaining: 11.4s
# 6434:	learn: 0.0208429	total: 4m 33s	remaining: 11.4s
# 6435:	learn: 0.0208428	total: 4m 33s	remaining: 11.4s
# 6436:	learn: 0.0208428	total: 4m 33s	remaining: 11.3s
# 6437:	learn: 0.0208428	total: 4m 33s	remaining: 11.3s
# 6438:	learn: 0.0208428	total: 4m 33s	remaining: 11.2s
# 6439:	learn: 0.0208428	total: 4m 33s	remaining: 11.2s
# 6440:	learn: 0.0208428	total: 4m 33s	remaining: 11.1s
# 6441:	learn: 0.0208428	total: 4m 33s	remaining: 11.1s
# 6442:	learn: 0.0208428	total: 4m 33s	remaining: 11.1s
# 6443:	learn: 0.0208428	total: 4m 34s	remaining: 11s
# 6444:	learn: 0.0208428	total: 4m 34s	remaining: 11s
# 6445:	learn: 0.0208428	total: 4m 34s	remaining: 10.9s
# 6446:	learn: 0.0208428	total: 4m 34s	remaining: 10.9s
# 6447:	learn: 0.0208428	total: 4m 34s	remaining: 10.8s
# 6448:	learn: 0.0208428	total: 4m 34s	remaining: 10.8s
# 6449:	learn: 0.0208428	total: 4m 34s	remaining: 10.8s
# 6450:	learn: 0.0208427	total: 4m 34s	remaining: 10.7s
# 6451:	learn: 0.0208427	total: 4m 34s	remaining: 10.7s
# 6452:	learn: 0.0208427	total: 4m 34s	remaining: 10.6s
# 6453:	learn: 0.0208427	total: 4m 34s	remaining: 10.6s
# 6454:	learn: 0.0208427	total: 4m 34s	remaining: 10.5s
# 6455:	learn: 0.0208427	total: 4m 34s	remaining: 10.5s
# 6456:	learn: 0.0208427	total: 4m 34s	remaining: 10.5s
# 6457:	learn: 0.0208427	total: 4m 34s	remaining: 10.4s
# 6458:	learn: 0.0208427	total: 4m 34s	remaining: 10.4s
# 6459:	learn: 0.0208427	total: 4m 34s	remaining: 10.3s
# 6460:	learn: 0.0208427	total: 4m 34s	remaining: 10.3s
# 6461:	learn: 0.0208427	total: 4m 34s	remaining: 10.3s
# 6462:	learn: 0.0208427	total: 4m 35s	remaining: 10.2s
# 6463:	learn: 0.0208427	total: 4m 35s	remaining: 10.2s
# 6464:	learn: 0.0208427	total: 4m 35s	remaining: 10.1s
# 6465:	learn: 0.0208427	total: 4m 35s	remaining: 10.1s
# 6466:	learn: 0.0208426	total: 4m 35s	remaining: 10s
# 6467:	learn: 0.0208426	total: 4m 35s	remaining: 10s
# 6468:	learn: 0.0208426	total: 4m 35s	remaining: 9.96s
# 6469:	learn: 0.0208426	total: 4m 35s	remaining: 9.92s
# 6470:	learn: 0.0208426	total: 4m 35s	remaining: 9.88s
# 6471:	learn: 0.0208426	total: 4m 35s	remaining: 9.84s
# 6472:	learn: 0.0208426	total: 4m 35s	remaining: 9.8s
# 6473:	learn: 0.0208426	total: 4m 35s	remaining: 9.75s
# 6474:	learn: 0.0208426	total: 4m 35s	remaining: 9.71s
# 6475:	learn: 0.0208426	total: 4m 35s	remaining: 9.67s
# 6476:	learn: 0.0208426	total: 4m 36s	remaining: 9.63s
# 6477:	learn: 0.0208426	total: 4m 36s	remaining: 9.59s
# 6478:	learn: 0.0208426	total: 4m 36s	remaining: 9.55s
# 6479:	learn: 0.0208426	total: 4m 36s	remaining: 9.51s
# 6480:	learn: 0.0208426	total: 4m 36s	remaining: 9.46s
# 6481:	learn: 0.0208425	total: 4m 36s	remaining: 9.42s
# 6482:	learn: 0.0208425	total: 4m 36s	remaining: 9.38s
# 6483:	learn: 0.0208425	total: 4m 36s	remaining: 9.34s
# 6484:	learn: 0.0208425	total: 4m 36s	remaining: 9.3s
# 6485:	learn: 0.0208425	total: 4m 36s	remaining: 9.26s
# 6486:	learn: 0.0208425	total: 4m 36s	remaining: 9.21s
# 6487:	learn: 0.0208425	total: 4m 36s	remaining: 9.17s
# 6488:	learn: 0.0208425	total: 4m 36s	remaining: 9.13s
# 6489:	learn: 0.0208425	total: 4m 36s	remaining: 9.09s
# 6490:	learn: 0.0208425	total: 4m 36s	remaining: 9.05s
# 6491:	learn: 0.0208425	total: 4m 37s	remaining: 9.01s
# 6492:	learn: 0.0208425	total: 4m 37s	remaining: 8.96s
# 6493:	learn: 0.0208425	total: 4m 37s	remaining: 8.92s
# 6494:	learn: 0.0208425	total: 4m 37s	remaining: 8.88s
# 6495:	learn: 0.0208425	total: 4m 37s	remaining: 8.84s
# 6496:	learn: 0.0208425	total: 4m 37s	remaining: 8.8s
# 6497:	learn: 0.0208424	total: 4m 37s	remaining: 8.75s
# 6498:	learn: 0.0208424	total: 4m 37s	remaining: 8.71s
# 6499:	learn: 0.0208424	total: 4m 37s	remaining: 8.67s
# 6500:	learn: 0.0208424	total: 4m 37s	remaining: 8.63s
# 6501:	learn: 0.0208424	total: 4m 37s	remaining: 8.58s
# 6502:	learn: 0.0208424	total: 4m 37s	remaining: 8.54s
# 6503:	learn: 0.0208424	total: 4m 37s	remaining: 8.5s
# 6504:	learn: 0.0208424	total: 4m 37s	remaining: 8.46s
# 6505:	learn: 0.0208424	total: 4m 37s	remaining: 8.41s
# 6506:	learn: 0.0208424	total: 4m 37s	remaining: 8.37s
# 6507:	learn: 0.0208424	total: 4m 37s	remaining: 8.33s
# 6508:	learn: 0.0208424	total: 4m 37s	remaining: 8.28s
# 6509:	learn: 0.0208424	total: 4m 37s	remaining: 8.24s
# 6510:	learn: 0.0208424	total: 4m 38s	remaining: 8.2s
# 6511:	learn: 0.0208424	total: 4m 38s	remaining: 8.16s
# 6512:	learn: 0.0208423	total: 4m 38s	remaining: 8.11s
# 6513:	learn: 0.0208423	total: 4m 38s	remaining: 8.07s
# 6514:	learn: 0.0208423	total: 4m 38s	remaining: 8.03s
# 6515:	learn: 0.0208423	total: 4m 38s	remaining: 7.98s
# 6516:	learn: 0.0208423	total: 4m 38s	remaining: 7.94s
# 6517:	learn: 0.0208423	total: 4m 38s	remaining: 7.9s
# 6518:	learn: 0.0208423	total: 4m 38s	remaining: 7.86s
# 6519:	learn: 0.0208423	total: 4m 38s	remaining: 7.81s
# 6520:	learn: 0.0208423	total: 4m 38s	remaining: 7.77s
# 6521:	learn: 0.0208423	total: 4m 38s	remaining: 7.73s
# 6522:	learn: 0.0208423	total: 4m 38s	remaining: 7.68s
# 6523:	learn: 0.0208423	total: 4m 38s	remaining: 7.64s
# 6524:	learn: 0.0208423	total: 4m 38s	remaining: 7.6s
# 6525:	learn: 0.0208423	total: 4m 38s	remaining: 7.56s
# 6526:	learn: 0.0208423	total: 4m 38s	remaining: 7.51s
# 6527:	learn: 0.0208423	total: 4m 38s	remaining: 7.47s
# 6528:	learn: 0.0208422	total: 4m 38s	remaining: 7.43s
# 6529:	learn: 0.0208422	total: 4m 38s	remaining: 7.38s
# 6530:	learn: 0.0208422	total: 4m 38s	remaining: 7.34s
# 6531:	learn: 0.0208422	total: 4m 38s	remaining: 7.3s
# 6532:	learn: 0.0208422	total: 4m 38s	remaining: 7.26s
# 6533:	learn: 0.0208422	total: 4m 38s	remaining: 7.21s
# 6534:	learn: 0.0208422	total: 4m 38s	remaining: 7.17s
# 6535:	learn: 0.0208422	total: 4m 39s	remaining: 7.13s
# 6536:	learn: 0.0208422	total: 4m 39s	remaining: 7.09s
# 6537:	learn: 0.0208422	total: 4m 39s	remaining: 7.04s
# 6538:	learn: 0.0208422	total: 4m 39s	remaining: 7s
# 6539:	learn: 0.0208422	total: 4m 39s	remaining: 6.96s
# 6540:	learn: 0.0208422	total: 4m 39s	remaining: 6.91s
# 6541:	learn: 0.0208422	total: 4m 39s	remaining: 6.87s
# 6542:	learn: 0.0208422	total: 4m 39s	remaining: 6.83s
# 6543:	learn: 0.0208422	total: 4m 39s	remaining: 6.79s
# 6544:	learn: 0.0208421	total: 4m 39s	remaining: 6.74s
# 6545:	learn: 0.0208421	total: 4m 39s	remaining: 6.7s
# 6546:	learn: 0.0208421	total: 4m 39s	remaining: 6.66s
# 6547:	learn: 0.0208421	total: 4m 39s	remaining: 6.62s
# 6548:	learn: 0.0208421	total: 4m 39s	remaining: 6.57s
# 6549:	learn: 0.0208421	total: 4m 39s	remaining: 6.53s
# 6550:	learn: 0.0208421	total: 4m 39s	remaining: 6.49s
# 6551:	learn: 0.0208421	total: 4m 39s	remaining: 6.45s
# 6552:	learn: 0.0208421	total: 4m 39s	remaining: 6.4s
# 6553:	learn: 0.0208421	total: 4m 39s	remaining: 6.36s
# 6554:	learn: 0.0208421	total: 4m 39s	remaining: 6.32s
# 6555:	learn: 0.0208421	total: 4m 39s	remaining: 6.27s
# 6556:	learn: 0.0208421	total: 4m 39s	remaining: 6.23s
# 6557:	learn: 0.0208421	total: 4m 39s	remaining: 6.19s
# 6558:	learn: 0.0208421	total: 4m 39s	remaining: 6.14s
# 6559:	learn: 0.0208421	total: 4m 39s	remaining: 6.1s
# 6560:	learn: 0.0208420	total: 4m 40s	remaining: 6.06s
# 6561:	learn: 0.0208420	total: 4m 40s	remaining: 6.02s
# 6562:	learn: 0.0208420	total: 4m 40s	remaining: 5.97s
# 6563:	learn: 0.0208420	total: 4m 40s	remaining: 5.93s
# 6564:	learn: 0.0208420	total: 4m 40s	remaining: 5.89s
# 6565:	learn: 0.0208420	total: 4m 40s	remaining: 5.85s
# 6566:	learn: 0.0208420	total: 4m 40s	remaining: 5.8s
# 6567:	learn: 0.0208420	total: 4m 40s	remaining: 5.76s
# 6568:	learn: 0.0208420	total: 4m 40s	remaining: 5.72s
# 6569:	learn: 0.0208420	total: 4m 40s	remaining: 5.67s
# 6570:	learn: 0.0208420	total: 4m 40s	remaining: 5.63s
# 6571:	learn: 0.0208420	total: 4m 40s	remaining: 5.59s
# 6572:	learn: 0.0208420	total: 4m 40s	remaining: 5.55s
# 6573:	learn: 0.0208420	total: 4m 40s	remaining: 5.5s
# 6574:	learn: 0.0208420	total: 4m 40s	remaining: 5.46s
# 6575:	learn: 0.0208420	total: 4m 40s	remaining: 5.42s
# 6576:	learn: 0.0208419	total: 4m 40s	remaining: 5.38s
# 6577:	learn: 0.0208419	total: 4m 40s	remaining: 5.33s
# 6578:	learn: 0.0208419	total: 4m 40s	remaining: 5.29s
# 6579:	learn: 0.0208419	total: 4m 40s	remaining: 5.25s
# 6580:	learn: 0.0208419	total: 4m 40s	remaining: 5.2s
# 6581:	learn: 0.0208419	total: 4m 40s	remaining: 5.16s
# 6582:	learn: 0.0208419	total: 4m 40s	remaining: 5.12s
# 6583:	learn: 0.0208419	total: 4m 40s	remaining: 5.08s
# 6584:	learn: 0.0208419	total: 4m 40s	remaining: 5.03s
# 6585:	learn: 0.0208419	total: 4m 40s	remaining: 4.99s
# 6586:	learn: 0.0208419	total: 4m 40s	remaining: 4.95s
# 6587:	learn: 0.0208419	total: 4m 41s	remaining: 4.91s
# 6588:	learn: 0.0208419	total: 4m 41s	remaining: 4.86s
# 6589:	learn: 0.0208419	total: 4m 41s	remaining: 4.82s
# 6590:	learn: 0.0208419	total: 4m 41s	remaining: 4.78s
# 6591:	learn: 0.0208419	total: 4m 41s	remaining: 4.73s
# 6592:	learn: 0.0208418	total: 4m 41s	remaining: 4.69s
# 6593:	learn: 0.0208418	total: 4m 41s	remaining: 4.65s
# 6594:	learn: 0.0208418	total: 4m 41s	remaining: 4.61s
# 6595:	learn: 0.0208418	total: 4m 41s	remaining: 4.56s
# 6596:	learn: 0.0208418	total: 4m 41s	remaining: 4.52s
# 6597:	learn: 0.0208418	total: 4m 41s	remaining: 4.48s
# 6598:	learn: 0.0208418	total: 4m 41s	remaining: 4.43s
# 6599:	learn: 0.0208418	total: 4m 41s	remaining: 4.39s
# 6600:	learn: 0.0208418	total: 4m 41s	remaining: 4.35s
# 6601:	learn: 0.0208418	total: 4m 41s	remaining: 4.31s
# 6602:	learn: 0.0208418	total: 4m 41s	remaining: 4.26s
# 6603:	learn: 0.0208418	total: 4m 41s	remaining: 4.22s
# 6604:	learn: 0.0208418	total: 4m 41s	remaining: 4.18s
# 6605:	learn: 0.0208418	total: 4m 41s	remaining: 4.14s
# 6606:	learn: 0.0208418	total: 4m 41s	remaining: 4.09s
# 6607:	learn: 0.0208418	total: 4m 41s	remaining: 4.05s
# 6608:	learn: 0.0208417	total: 4m 41s	remaining: 4.01s
# 6609:	learn: 0.0208417	total: 4m 41s	remaining: 3.96s
# 6610:	learn: 0.0208417	total: 4m 41s	remaining: 3.92s
# 6611:	learn: 0.0208417	total: 4m 41s	remaining: 3.88s
# 6612:	learn: 0.0208417	total: 4m 41s	remaining: 3.84s
# 6613:	learn: 0.0208417	total: 4m 42s	remaining: 3.79s
# 6614:	learn: 0.0208417	total: 4m 42s	remaining: 3.75s
# 6615:	learn: 0.0208417	total: 4m 42s	remaining: 3.71s
# 6616:	learn: 0.0208417	total: 4m 42s	remaining: 3.67s
# 6617:	learn: 0.0208417	total: 4m 42s	remaining: 3.62s
# 6618:	learn: 0.0208417	total: 4m 42s	remaining: 3.58s
# 6619:	learn: 0.0208417	total: 4m 42s	remaining: 3.54s
# 6620:	learn: 0.0208417	total: 4m 42s	remaining: 3.5s
# 6621:	learn: 0.0208417	total: 4m 42s	remaining: 3.45s
# 6622:	learn: 0.0208417	total: 4m 42s	remaining: 3.41s
# 6623:	learn: 0.0208417	total: 4m 42s	remaining: 3.37s
# 6624:	learn: 0.0208416	total: 4m 42s	remaining: 3.33s
# 6625:	learn: 0.0208416	total: 4m 42s	remaining: 3.28s
# 6626:	learn: 0.0208416	total: 4m 42s	remaining: 3.24s
# 6627:	learn: 0.0208416	total: 4m 42s	remaining: 3.2s
# 6628:	learn: 0.0208416	total: 4m 42s	remaining: 3.15s
# 6629:	learn: 0.0208416	total: 4m 42s	remaining: 3.11s
# 6630:	learn: 0.0208416	total: 4m 42s	remaining: 3.07s
# 6631:	learn: 0.0208416	total: 4m 42s	remaining: 3.03s
# 6632:	learn: 0.0208416	total: 4m 42s	remaining: 2.98s
# 6633:	learn: 0.0208416	total: 4m 42s	remaining: 2.94s
# 6634:	learn: 0.0208416	total: 4m 42s	remaining: 2.9s
# 6635:	learn: 0.0208416	total: 4m 42s	remaining: 2.85s
# 6636:	learn: 0.0208416	total: 4m 42s	remaining: 2.81s
# 6637:	learn: 0.0208416	total: 4m 42s	remaining: 2.77s
# 6638:	learn: 0.0208416	total: 4m 42s	remaining: 2.73s
# 6639:	learn: 0.0208416	total: 4m 43s	remaining: 2.69s
# 6640:	learn: 0.0208415	total: 4m 43s	remaining: 2.64s
# 6641:	learn: 0.0208415	total: 4m 43s	remaining: 2.6s
# 6642:	learn: 0.0208415	total: 4m 43s	remaining: 2.56s
# 6643:	learn: 0.0208415	total: 4m 43s	remaining: 2.51s
# 6644:	learn: 0.0208415	total: 4m 43s	remaining: 2.47s
# 6645:	learn: 0.0208415	total: 4m 43s	remaining: 2.43s
# 6646:	learn: 0.0208415	total: 4m 43s	remaining: 2.39s
# 6647:	learn: 0.0208415	total: 4m 43s	remaining: 2.34s
# 6648:	learn: 0.0208415	total: 4m 43s	remaining: 2.3s
# 6649:	learn: 0.0208415	total: 4m 43s	remaining: 2.26s
# 6650:	learn: 0.0208415	total: 4m 43s	remaining: 2.22s
# 6651:	learn: 0.0208415	total: 4m 43s	remaining: 2.17s
# 6652:	learn: 0.0208415	total: 4m 43s	remaining: 2.13s
# 6653:	learn: 0.0208415	total: 4m 43s	remaining: 2.09s
# 6654:	learn: 0.0208415	total: 4m 43s	remaining: 2.04s
# 6655:	learn: 0.0208415	total: 4m 43s	remaining: 2s
# 6656:	learn: 0.0208414	total: 4m 43s	remaining: 1.96s
# 6657:	learn: 0.0208414	total: 4m 43s	remaining: 1.92s
# 6658:	learn: 0.0208414	total: 4m 43s	remaining: 1.87s
# 6659:	learn: 0.0208414	total: 4m 43s	remaining: 1.83s
# 6660:	learn: 0.0208414	total: 4m 43s	remaining: 1.79s
# 6661:	learn: 0.0208414	total: 4m 43s	remaining: 1.75s
# 6662:	learn: 0.0208414	total: 4m 43s	remaining: 1.7s
# 6663:	learn: 0.0208414	total: 4m 43s	remaining: 1.66s
# 6664:	learn: 0.0208414	total: 4m 43s	remaining: 1.62s
# 6665:	learn: 0.0208414	total: 4m 44s	remaining: 1.58s
# 6666:	learn: 0.0208414	total: 4m 44s	remaining: 1.53s
# 6667:	learn: 0.0208414	total: 4m 44s	remaining: 1.49s
# 6668:	learn: 0.0208414	total: 4m 44s	remaining: 1.45s
# 6669:	learn: 0.0208414	total: 4m 44s	remaining: 1.41s
# 6670:	learn: 0.0208414	total: 4m 44s	remaining: 1.36s
# 6671:	learn: 0.0208414	total: 4m 44s	remaining: 1.32s
# 6672:	learn: 0.0208413	total: 4m 44s	remaining: 1.28s
# 6673:	learn: 0.0208413	total: 4m 44s	remaining: 1.24s
# 6674:	learn: 0.0208413	total: 4m 44s	remaining: 1.19s
# 6675:	learn: 0.0208413	total: 4m 44s	remaining: 1.15s
# 6676:	learn: 0.0208413	total: 4m 44s	remaining: 1.11s
# 6677:	learn: 0.0208413	total: 4m 44s	remaining: 1.06s
# 6678:	learn: 0.0208413	total: 4m 44s	remaining: 1.02s
# 6679:	learn: 0.0208413	total: 4m 44s	remaining: 980ms
# 6680:	learn: 0.0208413	total: 4m 44s	remaining: 937ms
# 6681:	learn: 0.0208413	total: 4m 44s	remaining: 895ms
# 6682:	learn: 0.0208413	total: 4m 44s	remaining: 852ms
# 6683:	learn: 0.0208413	total: 4m 44s	remaining: 809ms
# 6684:	learn: 0.0208413	total: 4m 44s	remaining: 767ms
# 6685:	learn: 0.0208413	total: 4m 44s	remaining: 724ms
# 6686:	learn: 0.0208413	total: 4m 44s	remaining: 682ms
# 6687:	learn: 0.0208413	total: 4m 44s	remaining: 639ms
# 6688:	learn: 0.0208412	total: 4m 44s	remaining: 596ms
# 6689:	learn: 0.0208412	total: 4m 44s	remaining: 554ms
# 6690:	learn: 0.0208412	total: 4m 44s	remaining: 511ms
# 6691:	learn: 0.0208412	total: 4m 45s	remaining: 469ms
# 6692:	learn: 0.0208412	total: 4m 45s	remaining: 426ms
# 6693:	learn: 0.0208412	total: 4m 45s	remaining: 383ms
# 6694:	learn: 0.0208412	total: 4m 45s	remaining: 341ms
# 6695:	learn: 0.0208412	total: 4m 45s	remaining: 298ms
# 6696:	learn: 0.0208412	total: 4m 45s	remaining: 256ms
# 6697:	learn: 0.0208412	total: 4m 45s	remaining: 213ms
# 6698:	learn: 0.0208412	total: 4m 45s	remaining: 170ms
# 6699:	learn: 0.0208412	total: 4m 45s	remaining: 128ms
# 6700:	learn: 0.0208412	total: 4m 45s	remaining: 85.2ms
# 6701:	learn: 0.0208412	total: 4m 45s	remaining: 42.6ms
# 6702:	learn: 0.0208412	total: 4m 45s	remaining: 0us

# %%
import joblib
joblib.dump(model, '/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/model.pkl')
# Out:
# ['/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/model.pkl']

# %% [markdown]
# ### test 데이터 전처리

# %% [markdown]
# ##### test AWS 전처리 및 병합

# %%
# test aws : 년, 월, 일, 시 컬럼 생성 / 연도, 일시 컬럼 삭제
def datetime_testaws(data):
    for i in range(len(data)):
        data.loc[i, '년'] = 2021
    for i in range(len(data)):
        data.loc[i, '월'] = int(str(data.loc[i, '일시'])[:2])
    for i in range(len(data)):
        data.loc[i, '일'] = int(str(data.loc[i, '일시'])[3:5])
    for i in range(len(data)):
        data.loc[i, '시'] = int(str(data.loc[i, '일시'])[6:8])

    data.drop(['지점', '연도', '일시'], axis=1, inplace=True)
    return data

# 결측치 처리 : KNNimputer
def imputation(data):
    imputer = KNNImputer(n_neighbors=5)
    return pd.DataFrame(imputer.fit_transform(data))

# %%
# test_aws 날짜 칼럼 생성, 결측치 처리
datetime_testaws(test_aws_오월드)
test_aws_오월드 = imputation(test_aws_오월드)
test_aws_오월드['지점'] = '오월드'

datetime_testaws(test_aws_세천)
test_aws_세천 = imputation(test_aws_세천)
test_aws_세천['지점'] = '세천'

datetime_testaws(test_aws_장동)
test_aws_장동 = imputation(test_aws_장동)
test_aws_장동['지점'] = '장동'

datetime_testaws(test_aws_세종고운)
test_aws_세종고운 = imputation(test_aws_세종고운)
test_aws_세종고운['지점'] = '세종고운'

datetime_testaws(test_aws_세종금남)
test_aws_세종금남 = imputation(test_aws_세종금남)
test_aws_세종금남['지점'] = '세종금남'

datetime_testaws(test_aws_세종연서)
test_aws_세종연서 = imputation(test_aws_세종연서)
test_aws_세종연서['지점'] = '세종연서'

datetime_testaws(test_aws_세종전의)
test_aws_세종전의 = imputation(test_aws_세종전의)
test_aws_세종전의['지점'] = '세종전의'

datetime_testaws(test_aws_북격렬비도)
test_aws_북격렬비도 = imputation(test_aws_북격렬비도)
test_aws_북격렬비도['지점'] = '북격렬비도'

datetime_testaws(test_aws_호도)
test_aws_호도 = imputation(test_aws_호도)
test_aws_호도['지점'] = '호도'

datetime_testaws(test_aws_대산)
test_aws_대산 = imputation(test_aws_대산)
test_aws_대산['지점'] = '대산'

datetime_testaws(test_aws_홍북)
test_aws_홍북 = imputation(test_aws_홍북)
test_aws_홍북['지점'] = '홍북'

datetime_testaws(test_aws_홍성죽도)
test_aws_홍성죽도 = imputation(test_aws_홍성죽도)
test_aws_홍성죽도['지점'] = '홍성죽도'

datetime_testaws(test_aws_공주)
test_aws_공주 = imputation(test_aws_공주)
test_aws_공주['지점'] = '공주'

datetime_testaws(test_aws_서천)
test_aws_서천 = imputation(test_aws_서천)
test_aws_서천['지점'] = '서천'

datetime_testaws(test_aws_논산)
test_aws_논산 = imputation(test_aws_논산)
test_aws_논산['지점'] = '논산'

datetime_testaws(test_aws_당진)
test_aws_당진 = imputation(test_aws_당진)
test_aws_당진['지점'] = '당진'

datetime_testaws(test_aws_성거)
test_aws_성거 = imputation(test_aws_성거)
test_aws_성거['지점'] = '성거'

datetime_testaws(test_aws_청양)
test_aws_청양 = imputation(test_aws_청양)
test_aws_청양['지점'] = '청양'

datetime_testaws(test_aws_태안)
test_aws_태안 = imputation(test_aws_태안)
test_aws_태안['지점'] = '태안'

datetime_testaws(test_aws_예산)
test_aws_예산 = imputation(test_aws_예산)
test_aws_예산['지점'] = '예산'

datetime_testaws(test_aws_유구)
test_aws_유구 = imputation(test_aws_유구)
test_aws_유구['지점'] = '유구'

datetime_testaws(test_aws_정안)
test_aws_정안 = imputation(test_aws_정안)
test_aws_정안['지점'] = '정안'

datetime_testaws(test_aws_아산)
test_aws_아산 = imputation(test_aws_아산)
test_aws_아산['지점'] = '아산'

datetime_testaws(test_aws_양화)
test_aws_양화 = imputation(test_aws_양화)
test_aws_양화['지점'] = '양화'

datetime_testaws(test_aws_계룡)
test_aws_계룡 = imputation(test_aws_계룡)
test_aws_계룡['지점'] = '계룡'

datetime_testaws(test_aws_춘장대)
test_aws_춘장대 = imputation(test_aws_춘장대)
test_aws_춘장대['지점'] = '춘장대'

datetime_testaws(test_aws_대천항)
test_aws_대천항 = imputation(test_aws_대천항)
test_aws_대천항['지점'] = '대천항'

datetime_testaws(test_aws_안도)
test_aws_안도 = imputation(test_aws_안도)
test_aws_안도['지점'] = '안도'

datetime_testaws(test_aws_옹도)
test_aws_옹도 = imputation(test_aws_옹도)
test_aws_옹도['지점'] = '옹도'

datetime_testaws(test_aws_정산)
test_aws_정산 = imputation(test_aws_정산)
test_aws_정산['지점'] = '정산'

# %%
# test aws 합치기
test_aws = pd.concat([test_aws_오월드, test_aws_세천, test_aws_장동, test_aws_세종고운, test_aws_세종금남, test_aws_세종연서, test_aws_세종전의, test_aws_북격렬비도,
                      test_aws_호도, test_aws_대산, test_aws_홍북, test_aws_홍성죽도, test_aws_공주, test_aws_서천, test_aws_논산, test_aws_당진, test_aws_성거,
                      test_aws_청양, test_aws_태안, test_aws_예산, test_aws_유구, test_aws_정안, test_aws_아산, test_aws_양화, test_aws_계룡, test_aws_춘장대,
                      test_aws_대천항, test_aws_안도, test_aws_옹도, test_aws_정산])

# %%
test_aws.columns = ['기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '지점']

# %%
test_aws.to_csv('test_aws.csv')

# %%
test_aws.isna().sum()
# Out:
# 기온     0
# 풍향     0
# 풍속     0
# 강수량    0
# 습도     0
# 년      0
# 월      0
# 일      0
# 시      0
# 지점     0
# dtype: int64

# %%
# test_aws 불러오기
test_aws = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA/test_aws.csv')
test_aws.set_index('Unnamed: 0', inplace=True)

# %% [markdown]
# ##### test PM 전처리 및 데이터 생성 + 모델 예측

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
# %config InlineBackend.figure_format='retina'
pd.set_option('display.max_columns', None)

from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder

test_pm_공주 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/공주.csv')
test_pm_노은동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/노은동.csv')
test_pm_논산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/논산.csv')
test_pm_대천2동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/대천2동.csv')
test_pm_독곶리 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/독곶리.csv')
test_pm_동문동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/동문동.csv')
test_pm_모종동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/모종동.csv')
test_pm_문창동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/문창동.csv')
test_pm_성성동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/성성동.csv')
test_pm_신방동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/신방동.csv')
test_pm_신흥동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/신흥동.csv')
test_pm_아름동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/아름동.csv')
test_pm_예산군 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/예산군.csv')
test_pm_읍내동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/읍내동.csv')
test_pm_이원면 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/이원면.csv')
test_pm_정림동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/정림동.csv')
test_pm_홍성읍 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/TEST_INPUT/홍성읍.csv')
pm_aws = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling1/pm_aws.csv', index_col='Location')
test_aws = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling1/test_aws.csv', index_col='Unnamed: 0')

import joblib
model = joblib.load('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/model.pkl')

# %%
# PM : 년, 월, 일, 시 컬럼 생성 / 연도, 일시 컬럼 삭제
def datetime_testpm(data):
    for i in range(len(data)):
        data.loc[i, '년'] = 2021
        data.loc[i, '월'] = int(str(data.loc[i, '일시'])[:2])
        data.loc[i, '일'] = int(str(data.loc[i, '일시'])[3:5])
        data.loc[i, '시'] = int(str(data.loc[i, '일시'])[6:8])

    data.drop(['측정소', '연도', '일시'], axis=1, inplace=True)
    return data

# PM2.5_1, 2017, 2018, 2019, 2020, 2021 칼럼 생성 / 월, 일, 시, 측정소 타입 object 변환
def new_columns(data):
    # 한 시간 전 PM2.5 칼럼
    data['PM2.5_1'] = np.NaN

    # '년' 범주화
    for i in range(2017, 2022):
        data[f'{i}'] = np.where(data['년']==i, 1, 0)
    data.drop('년', axis=1, inplace=True)

    # object 타입으로 변경
    data['월'] = data['월'].astype('str')
    data['일'] = data['일'].astype('str')
    data['시'] = data['시'].astype('str')
    data['측정소'] = data['측정소'].astype('str')
    return data

# cat_features 적용할 변수
cat_features = ['월', '일', '시', '측정소']

# PM 라벨링 딕셔너리
pm_dict = {'아름동': 11, '신흥동': 10, '노은동': 1, '문창동': 7, '읍내동': 13, '정림동': 15, '공주': 0, '논산': 2, '대천2동': 3, '독곶리': 4,
           '동문동': 5, '모종동': 6, '신방동': 9, '예산군': 12, '이원면': 14, '홍성읍': 16, '성성동': 8}

# %% [markdown]
# ###### 1. 공주

# %%
# PM2.5 모델 예측 데이터
predict_공주 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_공주 = (1 / pm_aws.loc['공주']) / (1 / pm_aws.loc['공주']).sum()
# 2. 가중치 * aws
test_공주 = test_pm_공주.copy()

for i in range(len(test_pm_공주)):
    test_공주.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_공주.values).sum()
    test_공주.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_공주.values).sum()
    test_공주.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_공주.values).sum()
    test_공주.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_공주.values).sum()
    test_공주.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_공주.values).sum()

datetime_testpm(test_공주)
test_공주['측정소'] = pm_dict['공주']
test_공주.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_공주[test_공주['PM2.5'].isna()]), len(test_공주[test_공주['기온'].isna()]))

test_공주 = new_columns(test_공주)
test_공주['PM2.5_1'] = test_공주['PM2.5'].shift(1, fill_value=np.NaN)
test_공주.loc[0, 'PM2.5_1'] = train_pm[train_pm['측정소']==0].iloc[-1, 0]
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_공주) ):
    if np.isnan(test_공주.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_공주 = test_공주.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_공주.iloc[i, 0] = model.predict(x_공주) # i행 결측치 채우기
        predict_공주['PM2.5'].append(model.predict(x_공주)) # i행의 PM2.5 predict
        test_공주.iloc[i+1, 10] = model.predict(x_공주) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_공주['PM2.5']), np.isnan(predict_공주['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_공주 = pd.DataFrame(predict_공주)
predict_공주.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_공주.csv', index=False)

# %% [markdown]
# ###### 2. 노은동

# %%
# PM2.5 모델 예측 데이터
predict_노은동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_노은동 = (1 / pm_aws.loc['노은동']) / (1 / pm_aws.loc['노은동']).sum()
# 2. 가중치 * aws
test_노은동 = test_pm_노은동.copy()

for i in range(len(test_pm_노은동)):
    test_노은동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_노은동.values).sum()
    test_노은동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_노은동.values).sum()
    test_노은동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_노은동.values).sum()
    test_노은동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_노은동.values).sum()
    test_노은동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_노은동.values).sum()

datetime_testpm(test_노은동)
test_노은동['측정소'] = pm_dict['노은동']
test_노은동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_노은동[test_노은동['PM2.5'].isna()]), len(test_노은동[test_노은동['기온'].isna()]))

test_노은동 = new_columns(test_노은동)
test_노은동['PM2.5_1'] = test_노은동['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_노은동) ):
    if np.isnan(test_노은동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_노은동 = test_노은동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_노은동.iloc[i, 0] = model.predict(x_노은동) # i행 결측치 채우기
        predict_노은동['PM2.5'].append(model.predict(x_노은동)) # i행의 PM2.5 predict
        test_노은동.iloc[i+1, 10] = model.predict(x_노은동) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_노은동['PM2.5']), np.isnan(predict_노은동['PM2.5']).sum()
# Out:
# (4607, 4608, 0)

# %%
predict_노은동 = pd.DataFrame(predict_노은동)
predict_노은동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_노은동.csv', index=False)

# %% [markdown]
# ###### 3. 논산

# %%
# PM2.5 모델 예측 데이터
predict_논산 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_논산 = (1 / pm_aws.loc['논산']) / (1 / pm_aws.loc['논산']).sum()
# 2. 가중치 * aws
test_논산 = test_pm_논산.copy()

for i in range(len(test_pm_논산)):
    test_논산.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_논산.values).sum()
    test_논산.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_논산.values).sum()
    test_논산.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_논산.values).sum()
    test_논산.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_논산.values).sum()
    test_논산.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_논산.values).sum()

datetime_testpm(test_논산)
test_논산['측정소'] = pm_dict['논산']
test_논산.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_논산[test_논산['PM2.5'].isna()]), len(test_논산[test_논산['기온'].isna()]))

test_논산 = new_columns(test_논산)
test_논산['PM2.5_1'] = test_논산['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_논산) ):
    if np.isnan(test_논산.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_논산 = test_논산.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_논산.iloc[i, 0] = model.predict(x_논산) # i행 결측치 채우기
        predict_논산['PM2.5'].append(model.predict(x_논산)) # i행의 PM2.5 predict
        test_논산.iloc[i+1, 10] = model.predict(x_논산) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_논산['PM2.5']), np.isnan(predict_논산['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_논산 = pd.DataFrame(predict_논산)
predict_논산.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_논산.csv', index=False)

# %% [markdown]
# ###### 4. 대천2동

# %%
# PM2.5 모델 예측 데이터
predict_대천2동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_대천2동 = (1 / pm_aws.loc['대천2동']) / (1 / pm_aws.loc['대천2동']).sum()
# 2. 가중치 * aws
test_대천2동 = test_pm_대천2동.copy()

for i in range(len(test_pm_대천2동)):
    test_대천2동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_대천2동.values).sum()
    test_대천2동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_대천2동.values).sum()
    test_대천2동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_대천2동.values).sum()
    test_대천2동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_대천2동.values).sum()
    test_대천2동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_대천2동.values).sum()

datetime_testpm(test_대천2동)
test_대천2동['측정소'] = pm_dict['대천2동']
test_대천2동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_대천2동[test_대천2동['PM2.5'].isna()]), len(test_대천2동[test_대천2동['기온'].isna()]))

test_대천2동 = new_columns(test_대천2동)
test_대천2동['PM2.5_1'] = test_대천2동['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_대천2동) ):
    if np.isnan(test_대천2동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_대천2동 = test_대천2동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_대천2동.iloc[i, 0] = model.predict(x_대천2동) # i행 결측치 채우기
        predict_대천2동['PM2.5'].append(model.predict(x_대천2동)) # i행의 PM2.5 predict
        test_대천2동.iloc[i+1, 10] = model.predict(x_대천2동) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_대천2동['PM2.5']), np.isnan(predict_대천2동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_대천2동 = pd.DataFrame(predict_대천2동)
predict_대천2동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_대천2동.csv', index=False)

# %% [markdown]
# ###### 5. 독곶리

# %%
# PM2.5 모델 예측 데이터
predict_독곶리 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_독곶리 = (1 / pm_aws.loc['독곶리']) / (1 / pm_aws.loc['독곶리']).sum()
# 2. 가중치 * aws
test_독곶리 = test_pm_독곶리.copy()

for i in range(len(test_pm_독곶리)):
    test_독곶리.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_독곶리.values).sum()
    test_독곶리.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_독곶리.values).sum()
    test_독곶리.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_독곶리.values).sum()
    test_독곶리.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_독곶리.values).sum()
    test_독곶리.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_독곶리.values).sum()

datetime_testpm(test_독곶리)
test_독곶리['측정소'] = pm_dict['독곶리']
test_독곶리.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_독곶리[test_독곶리['PM2.5'].isna()]), len(test_독곶리[test_독곶리['기온'].isna()]))

test_독곶리 = new_columns(test_독곶리)
test_독곶리['PM2.5_1'] = test_독곶리['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_독곶리) ):
    if np.isnan(test_독곶리.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_독곶리 = test_독곶리.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_독곶리.iloc[i, 0] = model.predict(x_독곶리) # i행 결측치 채우기
        predict_독곶리['PM2.5'].append(model.predict(x_독곶리)) # i행의 PM2.5 predict
        test_독곶리.iloc[i+1, 10] = model.predict(x_독곶리) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_독곶리['PM2.5']), np.isnan(predict_독곶리['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_독곶리 = pd.DataFrame(predict_독곶리)
predict_독곶리.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_독곶리.csv', index=False)

# %% [markdown]
# ###### 6. 동문동

# %%
# PM2.5 모델 예측 데이터
predict_동문동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_동문동 = (1 / pm_aws.loc['동문동']) / (1 / pm_aws.loc['동문동']).sum()
# 2. 가중치 * aws
test_동문동 = test_pm_동문동.copy()

for i in range(len(test_pm_동문동)):
    test_동문동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_동문동.values).sum()
    test_동문동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_동문동.values).sum()
    test_동문동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_동문동.values).sum()
    test_동문동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_동문동.values).sum()
    test_동문동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_동문동.values).sum()

datetime_testpm(test_동문동)
test_동문동['측정소'] = pm_dict['동문동']
test_동문동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_동문동[test_동문동['PM2.5'].isna()]), len(test_동문동[test_동문동['기온'].isna()]))

test_동문동 = new_columns(test_동문동)
test_동문동['PM2.5_1'] = test_동문동['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_동문동) ):
    if np.isnan(test_동문동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_동문동 = test_동문동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_동문동.iloc[i, 0] = model.predict(x_동문동) # i행 결측치 채우기
        predict_동문동['PM2.5'].append(model.predict(x_동문동)) # i행의 PM2.5 predict
        test_동문동.iloc[i+1, 10] = model.predict(x_동문동) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_동문동['PM2.5']), np.isnan(predict_동문동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_동문동 = pd.DataFrame(predict_동문동)
predict_동문동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_동문동.csv', index=False)

# %% [markdown]
# ###### 7. 모종동

# %%
# PM2.5 모델 예측 데이터
predict_모종동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_모종동 = (1 / pm_aws.loc['모종동']) / (1 / pm_aws.loc['모종동']).sum()
# 2. 가중치 * aws
test_모종동 = test_pm_모종동.copy()

for i in range(len(test_pm_모종동)):
    test_모종동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_모종동.values).sum()
    test_모종동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_모종동.values).sum()
    test_모종동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_모종동.values).sum()
    test_모종동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_모종동.values).sum()
    test_모종동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_모종동.values).sum()

datetime_testpm(test_모종동)
test_모종동['측정소'] = pm_dict['모종동']
test_모종동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_모종동[test_모종동['PM2.5'].isna()]), len(test_모종동[test_모종동['기온'].isna()]))

test_모종동 = new_columns(test_모종동)
test_모종동['PM2.5_1'] = test_모종동['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_모종동) ):
    if np.isnan(test_모종동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_모종동 = test_모종동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_모종동.iloc[i, 0] = model.predict(x_모종동) # i행 결측치 채우기
        predict_모종동['PM2.5'].append(model.predict(x_모종동)) # i행의 PM2.5 predict
        test_모종동.iloc[i+1, 10] = model.predict(x_모종동) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_모종동['PM2.5']), np.isnan(predict_모종동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_모종동 = pd.DataFrame(predict_모종동)
predict_모종동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_모종동.csv', index=False)

# %% [markdown]
# ###### 8. 문창동

# %%
# PM2.5 모델 예측 데이터
predict_문창동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_문창동 = (1 / pm_aws.loc['문창동']) / (1 / pm_aws.loc['문창동']).sum()
# 2. 가중치 * aws
test_문창동 = test_pm_문창동.copy()

for i in range(len(test_pm_문창동)):
    test_문창동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_문창동.values).sum()
    test_문창동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_문창동.values).sum()
    test_문창동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_문창동.values).sum()
    test_문창동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_문창동.values).sum()
    test_문창동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_문창동.values).sum()

datetime_testpm(test_문창동)
test_문창동['측정소'] = pm_dict['문창동']
test_문창동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_문창동[test_문창동['PM2.5'].isna()]), len(test_문창동[test_문창동['기온'].isna()]))

test_문창동 = new_columns(test_문창동)
test_문창동['PM2.5_1'] = test_문창동['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_문창동) ):
    if np.isnan(test_문창동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_문창동 = test_문창동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_문창동.iloc[i, 0] = model.predict(x_문창동) # i행 결측치 채우기
        predict_문창동['PM2.5'].append(model.predict(x_문창동)) # i행의 PM2.5 predict
        test_문창동.iloc[i+1, 10] = model.predict(x_문창동) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_문창동['PM2.5']), np.isnan(predict_문창동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_문창동 = pd.DataFrame(predict_문창동)
predict_문창동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_문창동.csv', index=False)

# %% [markdown]
# ###### 9. 성성동

# %%
# PM2.5 모델 예측 데이터
predict_성성동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_성성동 = (1 / pm_aws.loc['성성동']) / (1 / pm_aws.loc['성성동']).sum()
# 2. 가중치 * aws
test_성성동 = test_pm_성성동.copy()

for i in range(len(test_pm_성성동)):
    test_성성동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_성성동.values).sum()
    test_성성동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_성성동.values).sum()
    test_성성동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_성성동.values).sum()
    test_성성동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_성성동.values).sum()
    test_성성동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_성성동.values).sum()

datetime_testpm(test_성성동)
test_성성동['측정소'] = pm_dict['성성동']
test_성성동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_성성동[test_성성동['PM2.5'].isna()]), len(test_성성동[test_성성동['기온'].isna()]))

test_성성동 = new_columns(test_성성동)
test_성성동['PM2.5_1'] = test_성성동['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_성성동) ):
    if np.isnan(test_성성동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_성성동 = test_성성동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_성성동.iloc[i, 0] = model.predict(x_성성동) # i행 결측치 채우기
        predict_성성동['PM2.5'].append(model.predict(x_성성동)) # i행의 PM2.5 predict
        test_성성동.iloc[i+1, 10] = model.predict(x_성성동) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_성성동['PM2.5']), np.isnan(predict_성성동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_성성동 = pd.DataFrame(predict_성성동)
predict_성성동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_성성동.csv', index=False)

# %% [markdown]
# ###### 10. 신방동

# %%
# PM2.5 모델 예측 데이터
predict_신방동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_신방동 = (1 / pm_aws.loc['신방동']) / (1 / pm_aws.loc['신방동']).sum()
# 2. 가중치 * aws
test_신방동 = test_pm_신방동.copy()

for i in range(len(test_pm_신방동)):
    test_신방동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_신방동.values).sum()
    test_신방동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_신방동.values).sum()
    test_신방동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_신방동.values).sum()
    test_신방동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_신방동.values).sum()
    test_신방동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_신방동.values).sum()

datetime_testpm(test_신방동)
test_신방동['측정소'] = pm_dict['신방동']
test_신방동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_신방동[test_신방동['PM2.5'].isna()]), len(test_신방동[test_신방동['기온'].isna()]))

test_신방동 = new_columns(test_신방동)
test_신방동['PM2.5_1'] = test_신방동['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_신방동) ):
    if np.isnan(test_신방동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_신방동 = test_신방동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_신방동.iloc[i, 0] = model.predict(x_신방동) # i행 결측치 채우기
        predict_신방동['PM2.5'].append(model.predict(x_신방동)) # i행의 PM2.5 predict
        test_신방동.iloc[i+1, 10] = model.predict(x_신방동) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_신방동['PM2.5']), np.isnan(predict_신방동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_신방동 = pd.DataFrame(predict_신방동)
predict_신방동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_신방동.csv', index=False)

# %% [markdown]
# ###### 11. 신흥동

# %%
# PM2.5 모델 예측 데이터
predict_신흥동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_신흥동 = (1 / pm_aws.loc['신흥동']) / (1 / pm_aws.loc['신흥동']).sum()
# 2. 가중치 * aws
test_신흥동 = test_pm_신흥동.copy()

for i in range(len(test_pm_신흥동)):
    test_신흥동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_신흥동.values).sum()
    test_신흥동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_신흥동.values).sum()
    test_신흥동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_신흥동.values).sum()
    test_신흥동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_신흥동.values).sum()
    test_신흥동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_신흥동.values).sum()

datetime_testpm(test_신흥동)
test_신흥동['측정소'] = pm_dict['신흥동']
test_신흥동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_신흥동[test_신흥동['PM2.5'].isna()]), len(test_신흥동[test_신흥동['기온'].isna()]))

test_신흥동 = new_columns(test_신흥동)
test_신흥동['PM2.5_1'] = test_신흥동['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_신흥동) ):
    if np.isnan(test_신흥동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_신흥동 = test_신흥동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_신흥동.iloc[i, 0] = model.predict(x_신흥동) # i행 결측치 채우기
        predict_신흥동['PM2.5'].append(model.predict(x_신흥동)) # i행의 PM2.5 predict
        test_신흥동.iloc[i+1, 10] = model.predict(x_신흥동) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_신흥동['PM2.5']), np.isnan(predict_신흥동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_신흥동 = pd.DataFrame(predict_신흥동)
predict_신흥동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_신흥동.csv', index=False)

# %% [markdown]
# ###### 12. 아름동

# %%
# PM2.5 모델 예측 데이터
predict_아름동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_아름동 = (1 / pm_aws.loc['아름동']) / (1 / pm_aws.loc['아름동']).sum()
# 2. 가중치 * aws
test_아름동 = test_pm_아름동.copy()

for i in range(len(test_pm_아름동)):
    test_아름동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_아름동.values).sum()
    test_아름동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_아름동.values).sum()
    test_아름동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_아름동.values).sum()
    test_아름동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_아름동.values).sum()
    test_아름동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_아름동.values).sum()

datetime_testpm(test_아름동)
test_아름동['측정소'] = pm_dict['아름동']
test_아름동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_아름동[test_아름동['PM2.5'].isna()]), len(test_아름동[test_아름동['기온'].isna()]))

test_아름동 = new_columns(test_아름동)
test_아름동['PM2.5_1'] = test_아름동['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_아름동) ):
    if np.isnan(test_아름동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_아름동 = test_아름동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_아름동.iloc[i, 0] = model.predict(x_아름동) # i행 결측치 채우기
        predict_아름동['PM2.5'].append(model.predict(x_아름동)) # i행의 PM2.5 predict
        test_아름동.iloc[i+1, 10] = model.predict(x_아름동) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_아름동['PM2.5']), np.isnan(predict_아름동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_아름동 = pd.DataFrame(predict_아름동)
predict_아름동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_아름동.csv', index=False)

# %% [markdown]
# ###### 13. 예산군

# %%
# PM2.5 모델 예측 데이터
predict_예산군 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_예산군 = (1 / pm_aws.loc['예산군']) / (1 / pm_aws.loc['예산군']).sum()
# 2. 가중치 * aws
test_예산군 = test_pm_예산군.copy()

for i in range(len(test_pm_예산군)):
    test_예산군.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_예산군.values).sum()
    test_예산군.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_예산군.values).sum()
    test_예산군.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_예산군.values).sum()
    test_예산군.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_예산군.values).sum()
    test_예산군.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_예산군.values).sum()

datetime_testpm(test_예산군)
test_예산군['측정소'] = pm_dict['예산군']
test_예산군.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_예산군[test_예산군['PM2.5'].isna()]), len(test_예산군[test_예산군['기온'].isna()]))

test_예산군 = new_columns(test_예산군)
test_예산군['PM2.5_1'] = test_예산군['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_예산군) ):
    if np.isnan(test_예산군.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_예산군 = test_예산군.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_예산군.iloc[i, 0] = model.predict(x_예산군) # i행 결측치 채우기
        predict_예산군['PM2.5'].append(model.predict(x_예산군)) # i행의 PM2.5 predict
        test_예산군.iloc[i+1, 10] = model.predict(x_예산군) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_예산군['PM2.5']), np.isnan(predict_예산군['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_예산군 = pd.DataFrame(predict_예산군)
predict_예산군.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_예산군.csv', index=False)

# %% [markdown]
# ###### 14. 읍내동

# %%
# PM2.5 모델 예측 데이터
predict_읍내동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_읍내동 = (1 / pm_aws.loc['읍내동']) / (1 / pm_aws.loc['읍내동']).sum()
# 2. 가중치 * aws
test_읍내동 = test_pm_읍내동.copy()

for i in range(len(test_pm_읍내동)):
    test_읍내동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_읍내동.values).sum()
    test_읍내동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_읍내동.values).sum()
    test_읍내동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_읍내동.values).sum()
    test_읍내동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_읍내동.values).sum()
    test_읍내동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_읍내동.values).sum()

datetime_testpm(test_읍내동)
test_읍내동['측정소'] = pm_dict['읍내동']
test_읍내동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_읍내동[test_읍내동['PM2.5'].isna()]), len(test_읍내동[test_읍내동['기온'].isna()]))

test_읍내동 = new_columns(test_읍내동)
test_읍내동['PM2.5_1'] = test_읍내동['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_읍내동) ):
    if np.isnan(test_읍내동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_읍내동 = test_읍내동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_읍내동.iloc[i, 0] = model.predict(x_읍내동) # i행 결측치 채우기
        predict_읍내동['PM2.5'].append(model.predict(x_읍내동)) # i행의 PM2.5 predict
        test_읍내동.iloc[i+1, 10] = model.predict(x_읍내동) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_읍내동['PM2.5']), np.isnan(predict_읍내동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_읍내동 = pd.DataFrame(predict_읍내동)
predict_읍내동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_읍내동.csv', index=False)

# %% [markdown]
# ###### 15. 이원면

# %%
# PM2.5 모델 예측 데이터
predict_이원면 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_이원면 = (1 / pm_aws.loc['이원면']) / (1 / pm_aws.loc['이원면']).sum()
# 2. 가중치 * aws
test_이원면 = test_pm_이원면.copy()

for i in range(len(test_pm_이원면)):
    test_이원면.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_이원면.values).sum()
    test_이원면.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_이원면.values).sum()
    test_이원면.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_이원면.values).sum()
    test_이원면.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_이원면.values).sum()
    test_이원면.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_이원면.values).sum()

datetime_testpm(test_이원면)
test_이원면['측정소'] = pm_dict['이원면']
test_이원면.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_이원면[test_이원면['PM2.5'].isna()]), len(test_이원면[test_이원면['기온'].isna()]))

test_이원면 = new_columns(test_이원면)
test_이원면['PM2.5_1'] = test_이원면['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_이원면) ):
    if np.isnan(test_이원면.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_이원면 = test_이원면.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_이원면.iloc[i, 0] = model.predict(x_이원면) # i행 결측치 채우기
        predict_이원면['PM2.5'].append(model.predict(x_이원면)) # i행의 PM2.5 predict
        test_이원면.iloc[i+1, 10] = model.predict(x_이원면) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_이원면['PM2.5']), np.isnan(predict_이원면['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_이원면 = pd.DataFrame(predict_이원면)
predict_이원면.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_이원면.csv', index=False)

# %% [markdown]
# ###### 16. 정림동

# %%
# PM2.5 모델 예측 데이터
predict_정림동 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_정림동 = (1 / pm_aws.loc['정림동']) / (1 / pm_aws.loc['정림동']).sum()
# 2. 가중치 * aws
test_정림동 = test_pm_정림동.copy()

for i in range(len(test_pm_정림동)):
    test_정림동.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_정림동.values).sum()
    test_정림동.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_정림동.values).sum()
    test_정림동.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_정림동.values).sum()
    test_정림동.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_정림동.values).sum()
    test_정림동.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_정림동.values).sum()

datetime_testpm(test_정림동)
test_정림동['측정소'] = pm_dict['정림동']
test_정림동.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_정림동[test_정림동['PM2.5'].isna()]), len(test_정림동[test_정림동['기온'].isna()]))

test_정림동 = new_columns(test_정림동)
test_정림동['PM2.5_1'] = test_정림동['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_정림동) ):
    if np.isnan(test_정림동.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_정림동 = test_정림동.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_정림동.iloc[i, 0] = model.predict(x_정림동) # i행 결측치 채우기
        predict_정림동['PM2.5'].append(model.predict(x_정림동)) # i행의 PM2.5 predict
        test_정림동.iloc[i+1, 10] = model.predict(x_정림동) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_정림동['PM2.5']), np.isnan(predict_정림동['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_정림동 = pd.DataFrame(predict_정림동)
predict_정림동.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_정림동.csv', index=False)

# %% [markdown]
# ###### 17. 홍성읍

# %%
# PM2.5 모델 예측 데이터
predict_홍성읍 = {'PM2.5': []}

# %%
# 1. 가중치 = pm_aws 값 반비레 / pm_aws 반비레 전체 합
weight_홍성읍 = (1 / pm_aws.loc['홍성읍']) / (1 / pm_aws.loc['홍성읍']).sum()
# 2. 가중치 * aws
test_홍성읍 = test_pm_홍성읍.copy()

for i in range(len(test_pm_홍성읍)):
    test_홍성읍.loc[i, '기온'] = (test_aws.loc[i]['기온'] * weight_홍성읍.values).sum()
    test_홍성읍.loc[i, '풍향'] = (test_aws.loc[i]['풍향'] * weight_홍성읍.values).sum()
    test_홍성읍.loc[i, '풍속'] = (test_aws.loc[i]['풍속'] * weight_홍성읍.values).sum()
    test_홍성읍.loc[i, '강수량'] = (test_aws.loc[i]['강수량'] * weight_홍성읍.values).sum()
    test_홍성읍.loc[i, '습도'] = (test_aws.loc[i]['습도'] * weight_홍성읍.values).sum()

datetime_testpm(test_홍성읍)
test_홍성읍['측정소'] = pm_dict['홍성읍']
test_홍성읍.columns = ['PM2.5', '기온', '풍향', '풍속', '강수량', '습도', '년', '월', '일', '시', '측정소']
print(len(test_홍성읍[test_홍성읍['PM2.5'].isna()]), len(test_홍성읍[test_홍성읍['기온'].isna()]))

test_홍성읍 = new_columns(test_홍성읍)
test_홍성읍['PM2.5_1'] = test_홍성읍['PM2.5'].shift(1, fill_value=np.NaN)
# Out:
# 4608 0

# %%
count = 0

for i in range( len(test_홍성읍) ):
    if np.isnan(test_홍성읍.iloc[i, 0]): # i행의 PM2.5가 nan 값이라면,
        x_홍성읍 = test_홍성읍.iloc[i, 1:] # input: i행의 PM2.5 제외한 데이터
        test_홍성읍.iloc[i, 0] = model.predict(x_홍성읍) # i행 결측치 채우기
        predict_홍성읍['PM2.5'].append(model.predict(x_홍성읍)) # i행의 PM2.5 predict
        test_홍성읍.iloc[i+1, 10] = model.predict(x_홍성읍) # i+1행의 PM2.5_1 채우기
        count += 1

# %%
count, len(predict_홍성읍['PM2.5']), np.isnan(predict_홍성읍['PM2.5']).sum()
# Out:
# (4608, 4608, 0)

# %%
predict_홍성읍 = pd.DataFrame(predict_홍성읍)
predict_홍성읍.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3/predict_홍성읍.csv', index=False)

# %% [markdown]
# ##### 예측값과 answer file 병합

# %%
predict_아름동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_아름동.csv')
predict_신흥동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_신흥동.csv')
predict_노은동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_노은동.csv')
predict_문창동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_문창동.csv')
predict_읍내동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_읍내동.csv')
predict_정림동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_정림동.csv')
predict_공주 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_공주.csv')
predict_논산 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_논산.csv')
predict_대천2동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_대천2동.csv')
predict_독곶리 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_독곶리.csv')
predict_동문동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_동문동.csv')
predict_모종동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_모종동.csv')
predict_신방동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_신방동.csv')
predict_예산군 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_예산군.csv')
predict_이원면 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_이원면.csv')
predict_홍성읍 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_홍성읍.csv')
predict_성성동 = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_성성동.csv')

# %%
predict = pd.concat([predict_공주, predict_노은동, predict_논산, predict_대천2동, predict_독곶리, predict_동문동, predict_모종동,
                     predict_문창동, predict_성성동, predict_신방동, predict_신흥동, predict_아름동, predict_예산군, predict_읍내동,
                     predict_이원면, predict_정림동, predict_홍성읍])

# %%
predict.reset_index(drop=True, inplace=True)

# %%
predict.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/predict_fix.csv')

# %%
answer = pd.read_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/answer_sample.csv')
answer.loc[:,'PM2.5'] = predict.loc[:,'PM2.5']

# %%
answer.head(10)
# Out:
#    연도           일시 측정소     PM2.5
# 0   4  01-03 00:00  공주  0.067580
# 1   4  01-03 01:00  공주  0.074296
# 2   4  01-03 02:00  공주  0.078367
# 3   4  01-03 03:00  공주  0.081180
# 4   4  01-03 04:00  공주  0.080293
# 5   4  01-03 05:00  공주  0.080182
# 6   4  01-03 06:00  공주  0.082189
# 7   4  01-03 07:00  공주  0.086800
# 8   4  01-03 08:00  공주  0.090554
# 9   4  01-03 09:00  공주  0.089112

# %%
answer.to_csv('/content/drive/MyDrive/AIVLE/제5회 AI SPARK 공모전/DATA_modeling3_1hour/answer_fix.csv', index=False)

# %%
len(answer[answer['PM2.5']<0])
# Out:
# 128

# %%
answer[answer['PM2.5']<0]['측정소'].value_counts()
# Out:
# 이원면     54
# 독곶리     22
# 정림동     14
# 노은동      9
# 논산       5
# 대천2동     5
# 동문동      5
# 문창동      5
# 예산군      3
# 공주       2
# 신흥동      2
# 모종동      1
# 신방동      1
# Name: 측정소, dtype: int64

# %%
plt.figure(figsize=(50,5))
sns.lineplot(x=answer[answer['측정소']=='이원면'].index, y='PM2.5', data=answer[answer['측정소']=='이원면'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.barh(y=x_train.columns, width=model.feature_importances_)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-348dcdcdfd36> in <cell line: 2>()
#       1 plt.figure(figsize=(15,5))
# ----> 2 plt.barh(y=x_train.columns, width=model.feature_importances_)
#       3 plt.show()
#
# NameError: name 'x_train' is not defined

# %%
fi = pd.DataFrame()
fi['PM2.5'] = model.feature_importances_
fi.index = x_train.columns
fi.sort_values(by='PM2.5', ascending=False)
# Out:
#              PM2.5
# PM2.5_1  99.401386
# 풍속        0.184724
# 기온        0.096264
# 시         0.094736
# 습도        0.078923
# 강수량       0.056723
# 월         0.053390
# 측정소       0.020030
# 풍향        0.008910
# 일         0.002224
# 2018      0.002022
# 2019      0.000323
# 2017      0.000201
# 2020      0.000143
# 2021      0.000000
